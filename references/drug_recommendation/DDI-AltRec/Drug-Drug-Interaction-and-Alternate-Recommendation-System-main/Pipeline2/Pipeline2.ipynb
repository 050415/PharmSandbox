# %% [markdown]
# ## Import Libraries

# %%
from gensim.models import Word2Vec
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import os
import xml.etree.ElementTree as ET
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score, classification_report, recall_score
from sklearn.utils import shuffle
from sklearn.ensemble import GradientBoostingClassifier, RandomForestClassifier
from sklearn.svm import SVC
import xgboost as xgb
from sklearn.metrics import accuracy_score, classification_report, recall_score
from sklearn.utils import shuffle
import matplotlib.pyplot as plt


from sklearn.manifold import TSNE

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout
from tensorflow.keras.optimizers import Adam

# %% [markdown]
# ## Word2Vec

# %%
model = Word2Vec.load("model.bin")

# %%
word_vector = model.wv['drugs']  
print(word_vector)
# Out:
# [-0.8893885   3.509865   -1.1649253   0.37511265 -0.88337153 -0.4662615
#  -2.0432796   0.831412    0.9755035   2.410084   -0.10849394 -1.883863
#  -1.8248148   2.787937   -1.5032511  -0.41665402  1.5385026  -2.6455333
#   0.88204783 -2.4548516   0.28260392  0.29351878  1.6321409  -0.4623531
#   3.0121746   1.7517947  -0.93291616  2.4090998  -2.6232476   2.6895576
#  -1.4975549   1.7319837   0.53198904 -1.9691468   0.34599096  2.0888896
#   1.3771238  -0.36920312 -1.5409142  -0.74937415 -0.366376   -1.2307234
#   0.63413936  2.5449655   2.1690147   1.1890692   0.48812467  0.8564312
#   0.5036675  -0.70403475  0.29097202 -0.718549    2.6806014   0.0149628
#  -0.6384842  -1.7613885  -0.72271276  0.86269784  1.0201939   0.5107717
#   0.48290032 -2.7008164   1.2013719   0.78600764  0.17969471 -2.3018062
#   0.8550455   2.644128   -1.0167307  -0.19610241 -1.2685068   2.743304
#  -2.0060565  -2.3079863  -1.2158242   1.782713   -2.1657627  -2.2557726
#   0.09969022 -0.7657959  -1.5388653  -1.6568203  -1.2926213  -1.5143746
#  -1.4776204   1.4074584   2.1499305  -1.5774325   2.2142925   1.1441789
#  -1.6341721   0.4103896  -0.29689124  0.6710259   0.747992    2.6404295
#  -3.6391923   1.7166951  -0.9705735  -1.0096952 ]

# %%
similar_words = model.wv.most_similar('drugs', topn=10) 
print(similar_words)
# Out:
# [('agents', 0.8188880085945129), ('medications', 0.7854257225990295), ('drug', 0.7784940600395203), ('medicaments', 0.7297026515007019), ('aeds', 0.7187907099723816), ('medicines', 0.7049173712730408), ('<abstracttext>drugs', 0.704905092716217), ('antiepileptics', 0.702126681804657), ('chemotherapeutics', 0.699542760848999), ('psychotropics', 0.6861249804496765)]

# %%
similarity = model.wv.similarity('girl', 'boy')  
print(similarity)
# Out:
# 0.975124

# %%
result_vector = model.wv['king'] - model.wv['man'] + model.wv['woman']
similar_to_result = model.wv.most_similar(positive=[result_vector], topn=10)
print(similar_to_result)
# Out:
# [('king', 0.7105740308761597), ('woman', 0.6388511657714844), ('memorial', 0.6239749789237976), ('margaret', 0.6186293363571167), ('princess', 0.618542492389679), ('mary', 0.6077402830123901), ('edward', 0.5938355922698975), ('george', 0.5795809030532837), ('groote', 0.5793609023094177), ('radiumhemmet', 0.5734840035438538)]

# %% [markdown]
# ## Dataset

# %% [markdown]
# Function to parse drug entities from a given XML file

# %%
def parse_drug_entities(file_path):
    tree = ET.parse(file_path)
    root = tree.getroot()
    drugs = set()
    
    for entity in root.findall(".//entity"):
        if entity.attrib.get('type') == 'drug' or entity.attrib.get('type') == 'brand' or entity.attrib.get('type') == 'drug_n':
            drugs.add(entity.attrib.get('text'))
    
    return drugs

# %% [markdown]
# Function to parse drug entities from XML files in a given directory

# %%
def extract_unique_drug_entities(directory):
    unique_drug_entities = set()
    for file_name in os.listdir(directory):
        if file_name.endswith('.xml'):
            file_path = os.path.join(directory, file_name)
            drug_entities = parse_drug_entities(file_path)  
            unique_drug_entities.update(drug_entities)
    return unique_drug_entities

# %% [markdown]
# Extract unique drug entities for training and testing datasets

# %%
train_dirs = ['../DDICorpus/Train/DrugBank', '../DDICorpus/Train/MedLine']
test_dirs = ['../DDICorpus/Test/Test for DDI Extraction task/DrugBank', '../DDICorpus/Test/Test for DDI Extraction task/MedLine']


all_drug_entities = set()
all_drug_entities_test = set()

for directory in train_dirs:
    all_drug_entities.update(extract_unique_drug_entities(directory))

for directory in test_dirs:
    all_drug_entities_test.update(extract_unique_drug_entities(directory))

# Print results
print(f"Total unique drug entities (train): {len(all_drug_entities)}")
print(all_drug_entities)

print(f"Total unique drug entities (test): {len(all_drug_entities_test)}")
print(all_drug_entities_test)
# Out:
# Total unique drug entities (train): 2085
# {'Trimethoprim', 'eplerenone', 'atovaquone', 'Trileptal', 'aspirins', 'filipin', 'naproxen', 'adrenaline', 'Cobalt', 'promoter', 'Lopinavir', 'veratrum alkaloids', 'CBZ', 'cloxacillin', 'Furadantin', 'lidocaine', 'PRECEDEX', 'cabergoline', 'bexarotene', 'tenofovir disoproxil fumarate', 'Allopurinol', 'co-trimoxazole', 'prochlorperazine', 'letrozole', 'mesoridazine', 'Clostridium difficile toxin A', 'glipizide', 'PROSCAR', 'oxymetazoline', 'BARACLUDE', 'cefamandole', 'medroxyprogesterone', 'S warfarin', 'coumaphos', 'Septra', 'ADL-8-2698', 'AZOPT', 'DIDREX', 'azathioprine', 'ALFENTA', 'dipyridamole', 'glibenclamide', 'cisplatin', 'ethinylestradiol', 'Cerivastatin', 'tamsulosin', 'ouabain', 'cilostazol', 'ERYTHROMYCIN', 'denileukin diftitox', 'Resveratrol', 'sulfur', 'sildenafil', 'COPEGUS', 'meperidine', 'dopamine HCl', 'minocycline', 'Maalox', 'doxazosin mesylate', 'Fentanyl', 'Accutane', 'nitrogen mustard', 'FLEXERIL', 'Neomycin', 'Isoproterenol hydrochloride', 'Nardil', 'Disopyramide', 'oxygen', 'benazepril', 'COLESTlD', 'ethynyl estradiol', 'HEMABATE', 'Acetaminophen', '5-DFCR', 'omeprazole', 'EXTRANEAL', 'edrophonium', 'imipramine', 'VIRACEPT', 'sodium colistemethate', 'norfluoxetine', 'desethylamiodarone', 'nicotine', 'phenprocoumon', 'dinoprost', 'Finasteride', 'ROMAZICON', 'Lomefloxacin', 'Tindal', 'diethylpropion', 'para-aminobenzoic acid', 'astemizole', 'Salicylic acid', 'Etodolac', 'Viracept', 'Primidone', 'procaine', 'Bumetanide', 'threohydrobupropion', 'nonsteroidal anti-inflammatory', 'ethoxzolamide', 'bumetanide', 'chlorothiazide', 'clorazepate dipotassium', 'EMCYT', 'Cisplatin', 'propantheline', 'mefloquine', 'infliximab', 'CMC-Cys', 'magnesium salt', 'Carbidopa', 'bepridil', 'trimethyl lead', 'telithromycin', 'Sectral', 'paroxetine', 'erythromycins', 'hydroxybupropion', 'eptifibatide', 'enflurane', 'peginterferon', 'Quetiapine fumarate', 'phenibut', 'Doxylamine', 'etodolac', 'Lodine', 'cefoperazone', 'Ephedrine', 'enoxacin', 'fluorouracil', 'Somatropin', 'Ergotamine', 'orphenadrine', 'zinc', 'tamoxifen', 'glutethimide', 'succinylcholine chloride', 'Femara', 'Gris-PEG', 'Lopressor', 'ampicillin', 'R(+) warfarin', 'dezocine', 'fluoxetine hydrochloride', 'INDOCIN', 'Trilisate', 'Ketoconazole', 'scopolamine', 'praziquantel', 'pimozide', 'Aspirin', 'folic acid', 'Cataflam', 'Xigris', 'CYP3A4', 'Nitroglycerin', 'amiloride', 'Dihydroergotamine', 'vinorelbine', 'nalbuphine', 'Theo-Dur', 'fluvoxamine', 'R- warfarin', 'TRACRIUM', 'Digoxin', 'tacrolimus', 'anticholinergic', 'atomoxetine', 'dyphylline', 'Esomeprazole', 'hydrodolasetron', 'drugs', 'Nimodipine', 'Marplan', 'methamphetamine', 'alprazolam', 'Isoproterenol', 'cefotaxime sodium', 'fibrinogen', 'diuretic', 'fluvoxamine maleate', 'DEET', 'Meclofenamate sodium', 'Anavar', 'COREG', 'nandrolone', 'Daunorubicin', 'N-allylnormetazocine', 'Zalcitabine', 'tazobactam', 'Amphotericin B', 'cocaine', 'ziprasidone', 'REMICADE', 'Myochrysine', 'sodium nitroprusside', 'erythromycin', 'pyrantel', 'VASOTEC', 'Cisapride', 'TAXOTERE', 'HUMIRA', 'penicillin V', 'dantrolene sodium', 'propoxyphene hydrochloride', 'cerulein', 'nabumetone', 'nelfinavir', 'delavirdine', 'Clarithromycin', '6-deoxy penciclovir', 'Daypro', 'galangin', 'calcium acetate', 'chloroquine', 'bishydroxycoumarin', 'ERGAMISOL', 'Desmopressin', 'VAPRISOL', 'cis-platinum', 'DIAMOX', 'Dapsone', 'Doxorubicin', 'cisapride', 'ZEVALIN', 'antiretroviral nucleoside analogues', 'putrescine', 'Piperacillin sodium', 'flupenthixol', 'progesterone', '3H-spiroperidol', 'chloramphenicol', 'efavirenz', 'Promethazine', 'beta-interferon', 'Kytril', 'Videx', 'Sonata', 'ALLEGRA', 'Theophylline', 'Nalfon', 'Zofran', 'diphenhydramine', 'Captopril', 'Flavoridin', 'trazodone', 'Simulect', 'didanosine', 'Midazolam', 'carbamazepine 10,11-epoxide', 'ABILIFY', 'felbamate', 'chlorpromazine', 'acamprosate', 'tranylcypromine', 'CRIXIVAN', 'boric acid', 'levothyroxine', 'Methylprednisolone', 'beta blockers', 'metrizamide', 'almotriptan', 'ramipril' ...
# Total unique drug entities (test): 727
# {'Trimethoprim', 'diltiazem', '3-[(2-methyl-1,3-thiazol-4-yl) ethynyl] pyridine', 'depo-subQ provera 104', 'naproxen', 'mecamylamine', 'stavudine', 'imexon', 'levonorgestrel', 'methylergonovine', 'Halothane', 'MIRAPEX', 'ELDEPRYL', '1-methyl-4-phenyl-1,2,3,6-tetrahydropyridine', 'doxorubicin', 'glipizide', 'Pravastatin', 'Streptokinase', 'SPIRIVA', 'FELDENE', 'Retavase', 'teniposide', 'MYKROX', 'ProAmatine', 'collagenase', 'linezolid', 'tigecycline', 'DZNep', 'azathioprine', 'methicillin', 'SKELAXIN', 'acetazolamide', 'pemoline', 'dipyridamole', 'SKELID', 'cisplatin', 'ethinylestradiol', 'Gentamicin', 'S-ketamine', 'antacids', 'fexofenadine', 'tetrahydrocannabinol', 'Neulasta', 'meperidine', 'minocycline', 'roxithromycin', 'paliperidone', 'hyaluronan lyase', 'butorphanol', 'Triprolidine', 'rivastigmine', 'ALIMTA', 'esomeprazole', 'meclizine', 'chondroitin ABC lyase', 'Nardil', 'protriptyline', 'pseudoephedrine', 'oxygen', 'ondansetron', 'ACEON', 'TOBI', 'cross-reacting material 197', 'inactivated AI vaccines', 'ASPIRIN', 'Acetaminophen', 'acetaminophen', 'endoxifen', 'cinacalcet', 'Methenamine', 'edrophonium', 'sirolimus', 'omeprazole', 'imipramine', "John's Wort", 'Sulfoxone', 'Herceptin', 'MOBIC', 'nicotine', 'ASMANEX TWISTHALER', 'TRITEC', 'celecoxib', 'clopidogrel', 'Lomefloxacin', 'Rifampin', 'ipratropium', 'ranitidine', 'astemizole', 'testolactone', 'norethindrone acetate', 'itraconazole', 'procaine', 'human insulin', 'theophyllines', 'vigabatrin', 'MPA', 'ribavirin', 'Phenobarbital', 'MEPERIDINE', 'norketamine', 'megestrol acetate', 'metoprolol succinate', 'CNS depressants', 'Carbidopa', 'Matulane', 'montelukast', 'telithromycin', 'Ibuprofen', 'paroxetine', 'insulin', 'enflurane', 'Guanethidine', 'Methysergide', 'Ephedrine', 'sodium colistimethate', 'MIVACRON', 'propranolol', 'rocuronium bromide', 'tamoxifen', 'rifapentin', 'selegiline', 'imiglucerase', 'vanillylmandelic acid', 'Gantanol', 'ampicillin', 'desethyloxybutynin', 'Pindolol', 'aluminum', 'sulfaphenazole', 'Zemplar', 'Ketoconazole', 'scopolamine', 'pimozide', 'Aspirin', 'folic acid', 'tolbutamide', 'furosemide', 'amlodipine', 'olsalazine', 'troleandomycin', 'Norpramin', 'Caffeine', 'amiloride', 'thiabendazole', 'trimetrexate', 'Scopolamine', 'heparinase III', 'nalbuphine', 'ALKERAN', 'Brilinta', 'thiopental', 'meropenem', 'fluvoxamine', 'solifenacin', 'herceptin', 'oxybutynin chloride', 'Abacavir', 'Digoxin', 'tacrolimus', 'ticagrelor', 'Tramadol', 'inactivated ND vaccine', 'phentermine hydrochloride', 'Marplan', 'GSLS', 'Furosemide', 'succinylcholine', 'Ropivacaine', '3-hydroxy ropivacaine', 'methylergonovine maleate', 'JANUVIA', 'simeticone', 'tenofovir', 'Elavil', 'bacitracin', 'methyprylon', 'TNKase', 'erythromycin', 'rimantadine', 'flecainide', 'temozolomide', 'cholestyramine', 'Cisapride', 'succimer', '3-Deazaneplanocin A', 'HMG-CoA reductase inhibitor', 'desglymidodrine', 'Succimer', 'nelfinavir', 'delavirdine', 'Riboflavin', 'INVEGA', 'bishydroxycoumarin', 'carmustine', 'verapamil', 'cisapride', 'methimazole', 'Exelon', 'neostigmine', 'levomepromazine', 'PURINETHOL', 'metolazone', 'Theophylline', 'Thalidomide', 'zidovudine', 'diphenhydramine', 'raloxifene', 'Infacol', 'ZEMURON', 'sulfinpyrazone', 'Isopto Carbachol', 'MAXAIR AUTOHALER', 'phenylbutazone', 'Methazolamide', 'Amphetamine', 'clomipramine', 'CaNa 2 EDTA', 'tranylcypromine', 'chlorpromazine', 'VERSED Syrup', 'potassium', 'Methylprednisolone', 'levothyroxine', 'irinotecan', 'Tenecteplase', 'Celontin', 'pramipexole', 'riboflavin', 'diphenylhydantoin', '5-FU', 'EPO', 'doxepin', 'lamivudine', 'rifampicin', 'oxybutynin', 'heparin', 'sulphasalazine', 'paclitaxel', 'clindamycin', 'carbamazepine', 'lithium', 'ELOXATIN', 'Ticagrelor', 'perindopril', 'ezetimibe', 'doxycycline', 'Vindesine', 'prazosin', 'voriconazole', 'sulfamethizole', 'ketoconazole', 'digoxin', 'phenytoins', 'sulfamethoxazole', 'azithromycin', 'Montelukast', 'fluconazole', 'mifepristone', 'diazepam', 'furazolidone', 'Nalidixic acid', ' ...

# %% [markdown]
# Function to extract drug vectors from the model for a given set of drug entities

# %%
def get_drug_vectors(drug_entities, model):
    drug_vectors = {}
    for drug in drug_entities:
        if drug in model.wv:
            drug_vectors[drug] = model.wv[drug]
            print(f"Vector for {drug} found in the model.")
        else:
            print(f"Vector for {drug} not found in the model.")
    return drug_vectors

# %% [markdown]
# Get vectors for training and testing drug entities

# %%
drug_vectors = get_drug_vectors(all_drug_entities, model)
drug_vectors_test = get_drug_vectors(all_drug_entities_test, model)
# Out:
# Vector for Trimethoprim not found in the model.
# Vector for eplerenone not found in the model.
# Vector for atovaquone found in the model.
# Vector for Trileptal not found in the model.
# Vector for aspirins found in the model.
# Vector for filipin found in the model.
# Vector for naproxen found in the model.
# Vector for adrenaline found in the model.
# Vector for Cobalt not found in the model.
# Vector for promoter found in the model.
# Vector for Lopinavir not found in the model.
# Vector for veratrum alkaloids not found in the model.
# Vector for CBZ not found in the model.
# Vector for cloxacillin found in the model.
# Vector for Furadantin not found in the model.
# Vector for lidocaine found in the model.
# Vector for PRECEDEX not found in the model.
# Vector for cabergoline found in the model.
# Vector for bexarotene not found in the model.
# Vector for tenofovir disoproxil fumarate not found in the model.
# Vector for Allopurinol not found in the model.
# Vector for co-trimoxazole found in the model.
# Vector for prochlorperazine found in the model.
# Vector for letrozole found in the model.
# Vector for mesoridazine found in the model.
# Vector for Clostridium difficile toxin A not found in the model.
# Vector for glipizide found in the model.
# Vector for PROSCAR not found in the model.
# Vector for oxymetazoline found in the model.
# Vector for BARACLUDE not found in the model.
# Vector for cefamandole found in the model.
# Vector for medroxyprogesterone found in the model.
# Vector for S warfarin not found in the model.
# Vector for coumaphos found in the model.
# Vector for Septra not found in the model.
# Vector for ADL-8-2698 not found in the model.
# Vector for AZOPT not found in the model.
# Vector for DIDREX not found in the model.
# Vector for azathioprine found in the model.
# Vector for ALFENTA not found in the model.
# Vector for dipyridamole found in the model.
# Vector for glibenclamide found in the model.
# Vector for cisplatin found in the model.
# Vector for ethinylestradiol found in the model.
# Vector for Cerivastatin not found in the model.
# Vector for tamsulosin found in the model.
# Vector for ouabain found in the model.
# Vector for cilostazol found in the model.
# Vector for ERYTHROMYCIN not found in the model.
# Vector for denileukin diftitox not found in the model.
# Vector for Resveratrol not found in the model.
# Vector for sulfur found in the model.
# Vector for sildenafil not found in the model.
# Vector for COPEGUS not found in the model.
# Vector for meperidine found in the model.
# Vector for dopamine HCl not found in the model.
# Vector for minocycline found in the model.
# Vector for Maalox not found in the model.
# Vector for doxazosin mesylate not found in the model.
# Vector for Fentanyl not found in the model.
# Vector for Accutane not found in the model.
# Vector for nitrogen mustard not found in the model.
# Vector for FLEXERIL not found in the model.
# Vector for Neomycin not found in the model.
# Vector for Isoproterenol hydrochloride not found in the model.
# Vector for Nardil not found in the model.
# Vector for Disopyramide not found in the model.
# Vector for oxygen found in the model.
# Vector for benazepril found in the model.
# Vector for COLESTlD not found in the model.
# Vector for ethynyl estradiol not found in the model.
# Vector for HEMABATE not found in the model.
# Vector for Acetaminophen not found in the model.
# Vector for 5-DFCR not found in the model.
# Vector for omeprazole found in the model.
# Vector for EXTRANEAL not found in the model.
# Vector for edrophonium found in the model.
# Vector for imipramine found in the model.
# Vector for VIRACEPT not found in the model.
# Vector for sodium colistemethate not found in the model.
# Vector for norfluoxetine found in the model.
# Vector for desethylamiodarone found in the model.
# Vector for nicotine found in the model.
# Vector for phenprocoumon found in the model.
# Vector for dinoprost found in the model.
# Vector for Finasteride not found in the model.
# Vector for ROMAZICON not found in the model.
# Vector for Lomefloxacin not found in the model.
# Vector for Tindal not found in the model.
# Vector for diethylpropion found in the model.
# Vector for para-aminobenzoic acid not found in the model.
# Vector for astemizole found in the model.
# Vector for Salicylic acid not found in the model.
# Vector for Etodolac not found in the model.
# Vector for Viracept not found in the model.
# Vector for Primidone not found in the model.
# Vector for procaine found in the model.
# Vector for Bumetanide not found in the model.
# Vector for threohydrobupropion found in the model.
# Vector for nonsteroidal anti-inflammatory not found in the model.
# Vector for ethoxzolamide found in the model.
# Vector for bumetanide found in the model.
# Vector for chlorothiazide found in the model.
# Vector for clorazepate dipotassium not found in the model.
# Vector for EMCYT not found in the model.
# Vector for Cisplatin not found in the model.
# Vector for propantheline found in the model.
# Vector for mefloquine found in the model.
# Vector for infliximab not found in the model.
# Vector for CMC-Cys not found in the model.
# Vector for magnesium salt not found in the model.
# Vector for Carbidopa not found in the model.
# Vector for bepridil found in the model.
# Vector for trimethyl lead not found in the model.
# Vector for telithromycin not found in the model.
# Vector for Sectral not found in the model.
# Vector for paroxetine found in the model.
# Vector for erythromycins found in the model.
# Vector for hydroxybupropion found in the model.
# Vector for eptifibatide not found in the model.
# Vector for enflurane found in the model.
# Vector for peginterferon not found in the model.
# Vector for Quetiapine fumarate not found in the model.
# Vector for phenibut found in the model.
# Vector for Doxylamine not found in the model.
# Vector for etodolac found in the model.
# Vector for Lodine not found in the model.
# Vector for cefoperazone found in the model.
# Vector for Ephedrine not found in the model.
# Vector for enoxacin found in the model.
# Vector for fluorouracil found in the model.
# Vector for Somatropin not found in the model.
# Vector for Ergotamine not found in the model.
# Vector for orphenadrine found in the model.
# Vector for zinc found in the model.
# Vector for tamoxifen found in the model.
# Vector for glutethimide found in the model.
# Vector for succinylcholine chloride not found in the model.
# Vector for Femara not found in the model.
# Vector for Gris-PEG not found in the model.
# Vector for Lopressor not found in the model.
# Vector for ampicillin found in the model.
# Vector for R(+) warfarin not found in the model.
# Vector for dezocine found in the model.
# Vector for fluoxetine hydrochloride not found in the model.
# Vector for INDOCIN not found in the model.
# Vector for Trilisate not found in the model.
# Vector for Ketoconazole not found in the model.
# Vector for scopolamine found in the model.
# Vector for praziquantel found in the model.
# Vector for pimozide found in the model.
# Vector for Aspirin not found in the model.
# Vector for folic acid not found in the model.
# Vector for Cataflam not found in the model.
# Vector for Xigris not found in the model.
# Vector for CYP3A4 not found in the model.
# Vector for Nitroglycerin not found in the model.
# Vector for amiloride found in the model.
# Vector for Dihydroergotamine not found in the model.
# Vector for vinorelbine found in the model.
# Vector for nalbuphine found in the model.
# Vector for Theo-Dur not found in the model.
# Vector for fluvoxamine found in the model.
# Vector for R- warfarin not found in the model.
# Vector for TRACRIUM not found in the model.
# Vector for Digoxin not found in the model.
# Vector for tacrolimus found in the model.
# Vector for anticholinergic found in the model.
# Vector for atomoxetine not found in the model.
# Vector for dyphylline found in the model.
# Vector for Esomeprazole not found in the model.
# Vector for hydrodolasetron not found in the model.
# Vector for drugs found in the model.
# Vector for Nimodipine not found in the model.
# Vector for Marplan not found in the model.
# Vector for methamphetamine found in the model.
# Vector for alprazolam found in the model.
# Vector for Isoproterenol not found in the model.
# Vector for cefotaxime sodium not found in the model.
# Vector for fibrinogen found in the model.
# Vector for diuretic found in the model.
# Vector for fluvoxamine maleate not found in the model.
# Vector for DEET not found in the model.
# Vector for Meclofenamate sodium not found in the model.
# Vector for Anavar not found in the model.
# Vector for COREG not found in the model.
# Vector for nandrolone found in the model.
# Vector for Daunorubicin not found in the model.
# Vector for N-allylnormetazocine not found in the model.
# Vector for Zalcitabine not found in the model.
# Vector for tazobactam found in the model.
# Vector for Amphotericin B not found in the model.
# Vector for cocaine found in the model.
# Vector for ziprasidone found in the model.
# Vector for REMICADE not found in the model.
# Vector for Myochrysine not found in the model.
# Vector for sodium nitroprusside not found in the model.
# Vector for erythromycin found in the model.
# Vector for pyrantel found in the model.
# Vector for VASOTEC not found in the model.
# Vector for Cisapride not found in the model.
# Vector for TAXOTERE not found in the model.
# Vector for HUMIRA not found in the model.
# Vector for penicillin V not found in the model.
# Vector for dantrolene sodium not found in the model.
# Vector for propoxyphene hydrochloride not found in the model.
# Vector for cerulein found in the model.
# Vector for nabumetone found in the model.
# Vector for nelfinavir not found in the model.
# Vector for delavirdine found in the model.
# Vector for Clarithromycin not found in the model.
# Vector for 6-deoxy penciclovir not found in the model.
# Vector for Daypro not found in the model.
# Vector for galangin found in the model.
# Vector for calcium acetate not found in the model.
# Vector for chloroquine found in the model.
# Vector for bishydroxycoumarin found in the model.
# Vector for ERGAMISOL not found in the model.
# Vector for Desmopressin not found in the model.
# Vector for VAPRISOL not found in the model.
# Vector for cis-platinum found in the model.
# Vector for DIAMOX not found in the model.
# Vector for Dapsone not found in the model.
# Vector for Doxorubicin not found in the model.
# Vector for cisapride found in the model.
# Vector for ZEVALIN not found in the model.
# Vector for antiretroviral nucleoside analogues not found in the model.
# Vector for putrescine found in the model.
# Vector for Piperacillin sodium not found in the model.
# Vector for flupenthixol found in the model.
# Vector for progesterone found in the model.
# Vector for 3H-spiroperidol not found in the model.
# Vector for chloramphenicol found in the model.
# Vector for efavirenz not found in the model.
# Vector for Promethazine not found in the model.
# Vector for beta-interferon found in the model.
# Vector for Kytril not found in the model.
# Vector for Videx not found in the model.
# Vector for Sonata not found in the model.
# Vector for ALLEGRA not found in the model.
# Vector for Theophylline not found in the model.
# Vector for Nalfon not found in the model.
# Vector for Zofran not found in the model.
# Vector for diphenhydramine found in the model.
# Vector for Captopril not found in the model.
# Vector for Flavoridin not found in the model.
# Vector for trazodone found in the model.
# Vector for Simulect not found in the model.
# Vector for didanosine found in the model.
# Vector for Midazolam not found in the model.
# Vector for carbamazepine 10,11-epoxide not found in the model.
# Vector for ABILIFY not found in the model.
# Vector for felbamate found in the model.
# Vector for chlorpromazine found in the model.
# Vector for acamprosate found in the model.
# Vector for tranylcypromine found in the model.
# Vector for CRIXIVAN not found in the model.
# Vector for boric acid not found in the model.
# Vector for levothyroxine found in the model.
# Vector for Methylprednisolone not found in the model.
# Vector for beta blockers not found in the model.
# Vector for metrizamide found in the model.
# Vector for almotriptan not found in the model.
# Vector for ramipril found in the model.
# Vector for intraconazole found in the model.
# Vector for Quinamm not found in the model.
# Vector for dantrolene found in the model.
# Vector for irinotecan found in the model.
# Vector for Coumadin not found in the model.
# Vector for ATROVENT not found in the model.
# Vector for NIZORAL not found in the model.
# Vector for ZYVOX not found in the model.
# Vector for (S)-warfarin not found in the model.
# Vector for D-Ala2-metenkephalinamide not found in the model.
# Vector for LEXAPRO not found in the model.
# Vector for 5-FU not found in the model.
# Vector for Monoamine Oxidase Inhibitors not found in the model.
# Vector for heparin found in the model.
# Vector for Carbimazole not found in the model.
# Vector for Nydrazid not found in the model.
# Vector for Gemzar not found in the model.
# Vector for prednisolone sodium succinate not found in the model.
# Vector for Cefuroxime not found in the model.
# Vector for enalapril found in the model.
# Vector for Amitriptyline not found in the model.
# Vector for misoprostol found in the model.
# Vector for colchicine found in the model.
# Vector for Cocaine not found in the model.
# Vector for anakinra found in the model.
# Vector for Robinul not found in the model.
# Vector for Plaquenil not found in the model.
# Vector for isosorbide dinitrate not found in the model.
# Vector for Phencyclidine not found in the model.
# Vector for prazosin found in the model.
# Vector for CHOLESTYRAMINE not found in the model.
# Vector for amiodarone found in the model.
# Vector for voriconazole not found in the model.
# Vector for T4 not found in the model.
# Vector for loratadine found in the model.
# Vector for Neurontin not found in the model.
# Vector for guafacine not found in the model.
# Vector for Theobromine not found in the model.
# Vector for Chlorthalidone not found in the model.
# Vector for BETAGAN not found in the model.
# Vector for ketoconazole found in the model.
# Vector for ifosfamide found in the model.
# Vector for NEUPOGEN not found in the model.
# Vector for Ranitidine not found in the model.
# Vector for 6-mercaptopurine found in the model.
# Vector for Plenaxis not found in the model.
# Vector for MS Contin not found in the model.
# Vector for Antizol not found in the model.
# Vector for Levetiracetam not found in the model.
# Vector for ciclosporin found in the model.
# Vector for 18-Methoxycoronaridine not found in the model.
# Vector for L-NAME not found in the model.
# Vector for azithromycin found in the model.
# Vector for Nateglinide not found in the model.
# Vector for fluconazole found in the model.
# Vector for diazepam found in the model.
# Vector for Fulvestrant not found in the model.
# Vector for Folic acid not found in the model.
# Vector for oxycodone found in the model.
# Vector for Ethosuximide not found in the model.
# Vector for edetate calcium disodium not found in the model.
# Vector for Mineral oil not found in the model.
# Vector for Aricept not found in the model.
# Vector for Tagamet not found in the model.
# Vector for Deltasone not found in the model.
# Vector for Indocin not found in the model.
# Vector for Perhexiline hydrogen maleate not found in the model.
# Vector for Etretinate not found in the model.
# Vector for loperamide found in the model.
# Vector for chlorambucil found in the model.
# Vector for Anagrelide not found in the model.
# Vector for palytoxin found in the model.
# Vector for dihydrotachysterol found in the model.
# Vector for Dopamine not found in the model.
# Vector for Ethinyl estradiol not found in the model.
# Vector for simvastatin found in the model.
# Vector for Levo-Dromoran not found in the model.
# Vector for hydrochloroquine found in the model.
# Vector for Atromid-S not found in the model.
# Vector for Magnesium not found in the model.
# Vector for Kineret not found in the model.
# Vector for antihypertensives found in the model.
# Vector for triclofos sodium not found in the model.
# Vector for zopiclone found in the model.
# Vector for secobarbitone sodium not found in the model.
# Vector for Rifampicin not found in the model.
# Vector for RAPTIVA not found in the model.
# Vector for rapamycin found in the model.
# Vector for human growth hormone not found in the model.
# Vector for imatinib not found in the model.
# Vector for aminophylline found in the model.
# Vector for methanol found in the model.
# Vector for amphetamine found in the model.
# Vector for desipramine hydrochloride not found in the model.
# Vector for propanolol found in the model.
# Vector for Ketoprofen not found in the model.
# Vector for Heparin Sodium not found in the model.
# Vector for Sulfacetamide not found in the model.
# Vector for Thiolated carboxymethylcellulose not found in the model.
# Vector for tricyclic antidepressants not found in the model.
# Vector for D.H.E. 45 not found in the model.
# Vector for ritonavir found in the model.
# Vector for Glibenclamide not found in the model.
# Vector for encainide found in the model.
# Vector for Cimetidine not found in the model.
# Vector for caspofungin acetate not found in the model.
# Vector for Gleevec not found in the model.
# Vector for glutamic acid not found in the model.
# Vector for oxazepam found in the model.
# Vector for methdilazine found in the model.
# Vector for mycophenolate found in the model.
# Vector for buforin II not found in the model.
# Vector for DIFFERIN not found in the model.
# Vector for receptor found in the model.
# Vector for calcium channel not found in the model.
# Vector for Mineral Oil not found in the model.
# Vector for lopinavir not found in the model.
# Vector for MEPRON not found in the model.
# Vector for nateglinide not found in the model.
# Vector for Interferon beta not found in the model.
# Vector for ethionamide found in the model.
# Vector for Kaletra not found in the model.
# Vector for n-dodecyl gallate not found in the model.
# Vector for gentamicin found in the model.
# Vector for famotidine found in the model.
# Vector for muromonab-CD3 not found in the model.
# Vector for echistatin found in the model.
# Vector for levodopa found in the model.
# Vector for Cardiac glycosides not found in the model.
# Vector for pralidoxime found in the model.
# Vector for Quinine not found in the model.
# Vector for methsuximide found in the model.
# Vector for Compazine not found in the model.
# Vector for L-glutamine not found in the model.
# Vector for Antiarrhythmics not found in the model.
# Vector for antihistamines found in the model.
# Vector for rifadin found in the model.
# Vector for Mellaril not found in the model.
# Vector for Urinary acidifying not found in the model.
# Vector for Benzyl alcohol not found in the model.
# Vector for ibogaine found in the model.
# Vector for Chloroquine not found in the model.
# Vector for Anticoagulants not found in the model.
# Vector for lovastatin found in the model.
# Vector for Non-pegylated interferon alfa-2a not found in the model.
# Vector for CPA not found in the model.
# Vector for Terfenadine not found in the model.
# Vector for clofazimine found in the model.
# Vector for Dexrazoxane not found in the model.
# Vector for T3 not found in the model.
# Vector for radiopertechnetate found in the model.
# Vector for magnesium hydroxide not found in the model.
# Vector for Antibiotics not found in the model.
# Vector for midazolam found in the model.
# Vector for codeine found in the model.
# Vector for FASLODEX not found in the model.
# Vector for glyceryl trinitrate not found in the model.
# Vector for Motrin not found in the model.
# Vector for Pulmozyme not found in the model.
# Vector for N-methyllevallorphan not found in the model.
# Vector for testosterone found in the model.
# Vector for Chloromycetin not found in the model.
# Vector for noradrenaline found in the model.
# Vector for 99mTc-MDP not found in the model.
# Vector for Ketorolac not found in the model.
# Vector for ORENCIA not found in the model.
# Vector for Duloxetine not found in the model.
# Vector for Lithostat not found in the model.
# Vector for caspofungin not found in the model.
# Vector for iloprost found in the model.
# Vector for N-desmethyldiazepam not found in the model.
# Vector for Phenytoin not found in the model.
# Vector for multivalent cations not found in the model.
# Vector for alcohol found in the model.
# Vector for Dasatinib not found in the model.
# Vector for bismuth subsalicylate not found in the model.
# Vector for rifabutin found in the model.
# Vector for aprepitant not found in the model.
# Vector for gallamine found in the model.
# Vector for diltiazem hydrochloride not found in the model.
# Vector for pravastatin found in the model.
# Vector for brinzolamide not found in the model.
# Vector for 25-Dihydroxycholecalciferol D3 not found in the model.
# Vector for bepridil hydrochloride not found in the model.
# Vector for iron found in the model.
# Vector for sodium iodide I131 not found in the model.
# Vector for busulfan found in the model.
# Vector for rocuronium found in the model.
# Vector for propofol found in the model.
# Vector for Rifamate not found in the model.
# Vector for Green tea polyphenols not found in the model.
# Vector for Probenecid not found in the model.
# Vector for ethacrynic acid not found in the model.
# Vector for CYP2C9 not found in the model.
# Vector for ascorbic acid not found in the model.
# Vector for interleukin-2 found in the model.
# Vector for gestodene found in the model.
# Vector for sodium valproate not found in the model.
# Vector for ELSPAR not found in the model.
# Vector for L-tryptophan not found in the model.
# Vector for N-desmethylclozapine not found in the model.
# Vector for PEGANONE not found in the model.
# Vector for leucovorin found in the model.
# Vector for Descarboethoxyloratadine not found in the model.
# Vector for Eplerenone not found in the model.
# Vector for TYSABRI not found in the model.
# Vector for Neoral not found in the model.
# Vector for Diazepam not found in the model.
# Vector for Disulfiram not found in the model.
# Vector for trazodone hydrochloride not found in the model.
# Vector for AKINETON not found in the model.
# Vector for salicylic acid not found in the model.
# Vector for thiothixene found in the model.
# Vector for enhancers found in the model.
# Vector for abatacept not found in the model.
# Vector for tacrine found in the model.
# Vector for 25-O-desacetylrifabutin not found in the model.
# Vector for Oxytocin not found in the model.
# Vector for DILAUDID not found in the model.
# Vector for fexofenadine hydrochloride not found in the model.
# Vector for metronidazole found in the model.
# Vector for quinupristin found in the model.
# Vector for Primaquine not found in the model.
# Vector for Clofibric acid not found in the model.
# Vector for penicillin found in the model.
# Vector for Diflunisal not found in the model.
# Vector for glucose found in the model.
# Vector for L-methionine not found in the model.
# Vector for NaFlu not found in the model.
# Vector for Loperamide not found in the model.
# Vector for Eszopiclone not found in the model.
# Vector for Soliris not found in the model.
# Vector for calcitriol found in the model.
# Vector for Metformin not found in the model.
# Vector for Ortho-Novum not found in the model.
# Vector for isoflurane found in the model.
# Vector for allopurinol sodium not found in the model.
# Vector for Lincomycin not found in the model.
# Vector for zaleplon not found in the model.
# Vector for ciclesonide not found in the model.
# Vector for ibutilide found in the model.
# Vector for oxaprozin found in the model.
# Vector for Colestipol not found in the model.
# Vector for ERBITUX not found in the model.
# Vector for Pediapred not found in the model.
# Vector for 4-hydroxyatomoxetine not found in the model.
# Vector for TORADOL not found in the model.
# Vector for vitamin B6 not found in the model.
# Vector for pyrimethamine found in the model.
# Vector for vancomycin found in the model.
# Vector for morphine found in the model.
# Vector for lamotrigine found in the model.
# Vector for ammonium chloride not found in the model.
# Vector for 5-fluorouracil found in the model.
# Vector for Proquin XR not found in the model.
# Vector for ketorolac found in the model.
# Vector for Labetalol HCl not found in the model.
# Vector for Erythromycin not found in the model.
# Vector for Amprenavir not found in the model.
# Vector for cefditoren pivoxil not found in the model.
# Vector for Bismuth subsalicylate not found in the model.
# Vector for prednisolone found in the model.
# Vector for MHD not found in the model.
# Vector for angiotensin found in the model.
# Vector for cefuroxime found in the model.
# Vector for Isocarboxazid not found in the model.
# Vector for Sildenafil citrate not found in the model.
# Vector for lithium carbonate not found in the model.
# Vector for pertechnetate found in the model.
# Vector for nilutamide found in the model.
# Vector for Carbamazepine epoxide not found in the model.
# Vector for Caverject not found in the model.
# Vector for BOTOX not found in the model.
# Vector for pilocarpine found in the model.
# Vector for TYKERB not found in the model.
# Vector for bupropion found in the model.
# Vector for Netilmicin not found in the model.
# Vector for ganciclovir found in the model.
# Vector for neurotensin found in the model.
# Vector for RR not found in the model.
# Vector for cardiotrast found in the model.
# Vector for ZINECARD not found in the model.
# Vector for Bosentan not found in the model.
# Vector for S- warfarin not found in the model.
# Vector for atorvastatin found in the model.
# Vector for Parnate not found in the model.
# Vector for Sumatriptan not found in the model.
# Vector for fondaparinux not found in the model.
# Vector for des-ciclesonide not found in the model.
# Vector for GABITRIL not found in the model.
# Vector for S(-) warfarin not found in the model.
# Vector for Vecuronium not found in the model.
# Vector for Albendazole sulfoxide not found in the model.
# Vector for Spermine not found in the model.
# Vector for sotalol found in the model.
# Vector for PERSANTINE not found in the model.
# Vector for formoterol found in the model.
# Vector for Sulindac not found in the model.
# Vector for valproate found in the model.
# Vector for Felodipine not found in the model.
# Vector for Vitrasert not found in the model.
# Vector for Azulfidine not found in the model.
# Vector for MYOBLOC not found in the model.
# Vector for Tegretol not found in the model.
# Vector for tramadol found in the model.
# Vector for Tenormin not found in the model.
# Vector for EDECRIN not found in the model.
# Vector for HALDOL not found in the model.
# Vector for Sirolimus not found in the model.
# Vector for antidiabetic found in the model.
# Vector for oxipurinol found in the model.
# Vector for Magnesium-Aluminum Hydroxide not found in the model.
# Vector for Tubocurarine not found in the model.
# Vector for mirtazapine found in the model.
# Vector for surfactant found in the model.
# Vector for Lofexidine not found in the model.
# Vector for t1 found in the model.
# Vector for daptomycin found in the model.
# Vector for colistin found in the model.
# Vector for carbamazepine epoxide not found in the model.
# Vector for carbenicillin indanyl sodium not found in the model.
# Vector for paraxanthine found in the model.
# Vector for organophosphate insecticide not found in the model.
# Vector for Nevirapine not found in the model.
# Vector for Inderal not found in the model.
# Vector for BEXTRA not found in the model.
# Vector for papaverine found in the model.
# Vector for cefoxitin found in the model.
# Vector for docetaxel found in the model.
# Vector for Ritonavir not found in the model.
# Vector for Castor oil not found in the model.
# Vector for WARFARIN not found in the model.
# Vector for Lanoxin not found in the model.
# Vector for methandrostenolone found in the model.
# Vector for Phenergan not found in the model.
# Vector for Fe not found in the model.
# Vector for Xanax not found in the model.
# Vector for guanfacine found in the model.
# Vector for L-histidine not found in the model.
# Vector for ProSom not found in the model.
# Vector for Cytosine arabinoside not found in the model.
# Vector for SYNAREL not found in the model.
# Vector for cinchophen found in the model.
# Vector for Ethoxzolamide not found in the model.
# Vector for levobupivacaine not found in the model.
# Vector for Mentax not found in the model.
# Vector for warfarin sodium not found in the model.
# Vector for metoprolol found in the model.
# Vector for digitoxin found in the model.
# Vector for dapsone hydroxylamine not found in the model.
# Vector for sodium dodecyl sulfate not found in the model.
# Vector for diphenoxylate found in the model.
# Vector for green tea gallocatechins not found in the model.
# Vector for etoposide found in the model.
# Vector for carbidopa found in the model.
# Vector for Progesterone not found in the model.
# Vector for Lanoxicaps not found in the model.
# Vector for INSPRA not found in the model.
# Vector for Vitamin B3 not found in the model.
# Vector for Winstrol not found in the model.
# Vector for Morphine not found in the model.
# Vector for rosuvastatin not found in the model.
# Vector for Clidinium not found in the model.
# Vector for Depakene not found in the model.
# Vector for dextromethorphan found in the model.
# Vector for Ultram not found in the model.
# Vector for Hydrodiuril not found in the model.
# Vector for clarithromycin found in the model.
# Vector for Gemfibrozil not found in the model.
# Vector for SMX not found in the model.
# Vector for Innovar Vet not found in the model.
# Vector for rosiglitazone not found in the model.
# Vector for topiramate found in the model.
# Vector for ibandronate found in the model.
# Vector for mechlorethamine found in the model.
# Vector for fosphenytoin found in the model.
# Vector for Pentamidine not found in the model.
# Vector for 5-oxo-desethylzaleplon glucuronide not found in the model.
# Vector for pyrilamine found in the model.
# Vector for BROVANA not found in the model.
# Vector for Maalox TC not found in the model.
# Vector for COLESTID not found in the model.
# Vector for Foscarnet not found in the model.
# Vector for Epirubicin not found in the model.
# Vector for maprotiline found in the model.
# Vector for Purinethol not found in the model.
# Vector for tolazamide found in the model.
# Vector for theophylline found in the model.
# Vector for Diazoxide not found in the model.
# Vector for Fluoxetine not found in the model.
# Vector for d-amphetamine found in the model.
# Vector for 6-MP not found in the model.
# Vector for vitamin B-12 not found in the model.
# Vector for KEMSTROTM not found in the model.
# Vector for Acetazolamide not found in the model.
# Vector for beta-blocking found in the model.
# Vector for atropine found in the model.
# Vector for dapsone found in the model.
# Vector for thiazolesulfone not found in the model.
# Vector for Propantheline not found in the model.
# Vector for fosinoprilat found in the model.
# Vector for Triazolam not found in the model.
# Vector for norethindrone found in the model.
# Vector for cerivastatin not found in the model.
# Vector for fosfomycin found in the model.
# Vector for Peganone not found in the model.
# Vector for Nelfinavir not found in the model.
# Vector for activated charcoal not found in the model.
# Vector for Chirocaine not found in the model.
# Vector for MPTP not found in the model.
# Vector for carboxytolbutamide found in the model.
# Vector for nitazoxanide found in the model.
# Vector for HYDROXYZINE not found in the model.
# Vector for asparaginase found in the model.
# Vector for cinoxacin found in the model.
# Vector for entacapone found in the model.
# Vector for FORADIL not found in the model.
# Vector for dehydro-aripiprazole not found in the model.
# Vector for niacinamide found in the model.
# Vector for Tegison not found in the model.
# Vector for haloperidol found in the model.
# Vector for Anabolin not found in the model.
# Vector for Bezalip not found in the model.
# Vector for clozapine N-oxide not found in the model.
# Vector for COLAZAL not found in the model.
# Vector for Zimelidine not found in the model.
# Vector for para-aminosalicylic acid not found in the model.
# Vector for ketamine found in the model.
# Vector for SCH-23390 not found in the model.
# Vector for pentobarbital found in the model.
# Vector for Trecator-SC not found in the model.
# Vector for AMERGE not found in the model.
# Vector for interferon-alfa found in the model.
# Vector for toxin found in the model.
# Vector for Lovenox not found in the model.
# Vector for Orudis KT not found in the model.
# Vector for amphotericin B not found in the model.
# Vector for nalidixic acid not found in the model.
# Vector for selegiline hydrochloride not found in the model.
# Vector for Olanzapine not found in the model.
# Vector for Sodium Iodide not found in the model.
# Vector for Glucose not found in the model.
# Vector for Relafen not found in the model.
# Vector for Pyrantel not found in the model.
# Vector for Desyrel not found in the model.
# Vector for Fosinopril not found in the model.
# Vector for Prednisolone not found in the model.
# Vector for p-aminosalicylic acid not found in the model.
# Vector for Anadrol not found in the model.
# Vector for Nafazodone not found in the model.
# Vector for Alprazolam not found in the model.
# Vector for cyclosporine found in the model.
# Vector for Chlorpropamide not found in the model.
# Vector for Keflex not found in the model.
# Vector for InsP(3) not found in the model.
# Vector for Etonogestrel not found in the model.
# Vector for dirithromycin found in the model.
# Vector for methyldopa found in the model.
# Vector for guanethidine found in the model.
# Vector for CLOLAR not found in the model.
# Vector for bezafibrate found in the model.
# Vector for Prozac not found in the model.
# Vector for fenfluramine found in the model.
# Vector for 1-methyl-4-phenyl-1,2,5,6-tetrahydropyridine not found in the model.
# Vector for flucytosine found in the model.
# Vector for gemifloxacin not found in the model.
# Vector for valdecoxib not found in the model.
# Vector for vecuronium found in the model.
# Vector for AUGMENTIN XR not found in the model.
# Vector for Rebif not found in the model.
# Vector for Naltrexone not found in the model.
# Vector for phenazepam found in the model.
# Vector for Vidaza not found in the model.
# Vector for clotrimazole found in the model.
# Vector for anesthetics found in the model.
# Vector for aliskiren not found in the model.
# Vector for Prostin VR Pediatric not found in the model.
# Vector for phosphate found in the model.
# Vector for Carboplatin not found in the model.
# Vector for neomycin sulfate not found in the model.
# Vector for dacarbazine found in the model.
# Vector for MIDAMOR not found in the model.
# Vector for tannic acid not found in the model.
# Vector for Aminoglutethimide not found in the model.
# Vector for DPCPX not found in the model.
# Vector for colestipol found in the model.
# Vector for carboxymethylcellulose-cysteine not found in the model.
# Vector for pyridoxine found in the model.
# Vector for OXC not found in the model.
# Vector for phenytoin sodium not found in the model.
# Vector for chlortetracycline found in the model.
# Vector for trimeprazine found in the model.
# Vector for acetaldehyde found in the model.
# Vector for niacin found in the model.
# Vector for Antiarrhythmic agents, class I not found in the model.
# Vector for norepinephrine found in the model.
# Vector for alfentanyl found in the model.
# Vector for CCNU not found in the model.
# Vector for acitretin found in the model.
# Vector for Lithium not found in the model.
# Vector for ginsenosides found in the model.
# Vector for aluminum hydroxide not found in the model.
# Vector for terbinafine found in the model.
# Vector for pentazocine found in the model.
# Vector for R warfarin not found in the model.
# Vector for neuroleptic found in the model.
# Vector for SUSTIVA not found in the model.
# Vector for buprenorphine found in the model.
# Vector for Hydrocodone not found in the model.
# Vector for citalopram found in the model.
# Vector for Flecainide not found in the model.
# Vector for lomefloxacin found in the model.
# Vector for Mephenytoin not found in the model.
# Vector for aripiprazole found in the model.
# Vector for quetiapine not found in the model.
# Vector for angiotensins found in the model.
# Vector for eprosartan found in the model.
# Vector for Orlistat not found in the model.
# Vector for dexrazoxane found in the model.
# Vector for diuretics found in the model.
# Vector for quinidine found in the model.
# Vector for gemfibrozil found in the model.
# Vector for chlorpropamide found in the model.
# Vector for Dantrolene not found in the model.
# Vector for cytochalasin D not found in the model.
# Vector for acetylcysteine found in the model.
# Vector for sumatriptan found in the model.
# Vector for Insulin not found in the model.
# Vector for dicyclomine found in the model.
# Vector for Indomethacin not found in the model.
# Vector for darifenacin not found in the model.
# Vector for Enoxacin not found in the model.
# Vector for hydrocodone found in the model.
# Vector for penciclovir found in the model.
# Vector for alosetron found in the model.
# Vector for EULEXIN not found in the model.
# Vector for Niacin not found in the model.
# Vector for zalcitabine found in the model.
# Vector for cephalothin sodium not found in the model.
# Vector for ipratropium bromide not found in the model.
# Vector for Gentamycin not found in the model.
# Vector for Itraconazole not found in the model.
# Vector for SPRYCEL not found in the model.
# Vector for 3-Hydroxydesloratadine not found in the model.
# Vector for barbiturates found in the model.
# Vector for Ginkgo biloba not found in the model.
# Vector for disopyramide phosphate not found in the model.
# Vector for histamine found in the model.
# Vector for anileridine found in the model.
# Vector for etomidate found in the model.
# Vector for Sodium cephalothin not found in the model.
# Vector for aluminum hydoxide not found in the model.
# Vector for Etofibrate not found in the model.
# Vector for propafenone found in the model.
# Vector for thiocyanate found in the model.
# Vector for methadone found in the model.
# Vector for Methamphetamine not found in the model.
# Vector for Thyroxine not found in the model.
# Vector for Ganoderma lucidum extract not found in the model.
# Vector for gliftor not found in the model.
# Vector for Glyburide not found in the model.
# Vector for Trexan not found in the model.
# Vector for Nicotinic Acid not found in the model.
# Vector for charcoal found in the model.
# Vector for fulvestrant not found in the model.
# Vector for Arecoline not found in the model.
# Vector for Eprosartan not found in the model.
# Vector for Estazolam not found in the model.
# Vector for amoxicillin found in the model.
# Vector for altretamine found in the model.
# Vector for Diphenhydramine hydrochloride not found in the model.
# Vector for tizoxanide not found in the model.
# Vector for cyclophosphamide found in the model.
# Vector for silver found in the model.
# Vector for SUBUTEX not found in the model.
# Vector for anidulafungin not found in the model.
# Vector for atropine sulfate not found in the model.
# Vector for Norpace not found in the model.
# Vector for sulfisoxazole found in the model.
# Vector for nafcillin found in the model.
# Vector for ergocalciferol found in the model.
# Vector for REVIA not found in the model.
# Vector for TARCEVA not found in the model.
# Vector for Selegiline not found in the model.
# Vector for antiarrhythmic found in the model.
# Vector for antibiotics found in the model.
# Vector for ofloxacin found in the model.
# Vector for Diasone not found in the model.
# Vector for glucagon found in the model.
# Vector for Zidovudine not found in the model.
# Vector for ADL 8-2698 not found in the model.
# Vector for allopurinol found in the model.
# Vector for risperidone found in the model.
# Vector for somatropin found in the model.
# Vector for ACTH not found in the model.
# Vector for sumatriptan succinate not found in the model.
# Vector for cefotetan found in the model.
# Vector for HMG-CoA Reductase Inhibitors not found in the model.
# Vector for (R)-warfarin not found in the model.
# Vector for aminopyrine found in the model.
# Vector for Antabuse not found in the model.
# Vector for PIPRACIL not found in the model.
# Vector for BREVIBLOC not found in the model.
# Vector for L-phenylalanine not found in the model.
# Vector for reseveratrol not found in the model.
# Vector for albendazole found in the model.
# Vector for clomiphene citrate not found in the model.
# Vector for Dilantin not found in the model.
# Vector for Nonsteroidal Antiinflammatory not found in the model.
# Vector for Omeprazole not found in the model.
# Vector for Warfarin not found in the model.
# Vector for tubocurarine found in the model.
# Vector for dofetillide not found in the model.
# Vector for rantidine hydrochloride not found in the model.
# Vector for clonidine found in the model.
# Vector for baclofen found in the model.
# Vector for BUSULFEX not found in the model.
# Vector for gefitinib not found in the model.
# Vector for antiarrhythmics found in the model.
# Vector for Pronestyl not found in the model.
# Vector for Cyclosporine A not found in the model.
# Vector for propoxyphene found in the model.
# Vector for phenformin found in the model.
# Vector for METH not found in the model.
# Vector for Caspofungin not found in the model.
# Vector for Phenurone not found in the model.
# Vector for valproic acid not found in the model.
# Vector for Hydrochlorothiazide not found in the model.
# Vector for Vitamin D2 not found in the model.
# Vector for Fluconazole not found in the model.
# Vector for TRISENOX not found in the model.
# Vector for nefazadone found in the model.
# Vector for Lipitor not found in the model.
# Vector for Orasone not found in the model.
# Vector for Natrecor not found in the model.
# Vector for STRATTERA not found in the model.
# Vector for Antipyrine not found in the model.
# Vector for MICRONASE not found in the model.
# Vector for ceftibuten found in the model.
# Vector for Mefloquine not found in the model.
# Vector for etidronate found in the model.
# Vector for Prolixin not found in the model.
# Vector for sympathomimetic found in the model.
# Vector for Misonidazole not found in the model.
# Vector for fentayl found in the model.
# Vector for mefenamic acid not found in the model.
# Vector for auranofin found in the model.
# Vector for ZEBETA not found in the model.
# Vector for Norepinephrine not found in the model.
# Vector for 6MNA not found in the model.
# Vector for NovoSeven not found in the model.
# Vector for Ganciclovir not found in the model.
# Vector for Norethindrone not found in the model.
# Vector for L-lysine not found in the model.
# Vector for Survanta not found in the model.
# Vector for desmethylastemizole found in the model.
# Vector for Ethyl alcohol not found in the model.
# Vector for phenelzine found in the model.
# Vector for Felbatol not found in the model.
# Vector for EGF not found in the model.
# Vector for beta-adrenergic blocking agents not found in the model.
# Vector for prostaglandin F2alpha not found in the model.
# Vector for lorazepam found in the model.
# Vector for verapamil hydrochloride not found in the model.
# Vector for sulphenazole not found in the model.
# Vector for Omniscan not found in the model.
# Vector for clofibrate found in the model.
# Vector for Bezalip retard not found in the model.
# Vector for trovafloxacin found in the model.
# Vector for pargyline found in the model.
# Vector for Bismuth not found in the model.
# Vector for atracurium found in the model.
# Vector for Anakinra not found in the model.
# Vector for albuterol found in the model.
# Vector for Kerlone not found in the model.
# Vector for droperidol found in the model.
# Vector for metamizol found in the model.
# Vector for Lamprene not found in the model.
# Vector for desmethylastermizole not found in the model.
# Vector for cefamandole naftate not found in the model.
# Vector for Aliskiren not found in the model.
# Vector for Indocyanine green not found in the model.
# Vector for Arthropan not found in the model.
# Vector for PLENDIL not found in the model.
# Vector for dextromethorphan hydrobromide not found in the model.
# Vector for Imuran not found in the model.
# Vector for Clomipramine HCl not found in the model.
# Vector for lapatinib not found in the model.
# Vector for Divalproex not found in the model.
# Vector for diphenidol found in the model.
# Vector for ethchlorvynol found in the model.
# Vector for PRINIVIL not found in the model.
# Vector for Immunosuppressive not found in the model.
# Vector for dicumarol found in the model.
# Vector for ginseng found in the model.
# Vector for epinephrine found in the model.
# Vector for Cetrotide not found in the model.
# Vector for sucralfate found in the model.
# Vector for cefprozil found in the model.
# Vector for Charcoal not found in the model.
# Vector for Lansoprazole not found in the model.
# Vector for Clonidine hydrochloride not found in the model.
# Vector for Sporanox not found in the model.
# Vector for Verapamil not found in the model.
# Vector for DHA not found in the model.
# Vector for Norpace CR not found in the model.
# Vector for etretinate found in the model.
# Vector for pentagastrin found in the model.
# Vector for beta-endorphin found in the model.
# Vector for IMITREX not found in the model.
# Vector for Didanosine not found in the model.
# Vector for lactulose found in the model.
# Vector for angiotensin 2 not found in the model.
# Vector for Azlocillin not found in the model.
# Vector for nitroprusside found in the model.
# Vector for secobarbital found in the model.
# Vector for vincristine found in the model.
# Vector for bitolterol found in the model.
# Vector for benzoxazinorifamycin found in the model.
# Vector for Ancobon not found in the model.
# Vector for VELCADE not found in the model.
# Vector for Ethanol not found in the model.
# Vector for Entacapone not found in the model.
# Vector for ERGOMAR not found in the model.
# Vector for fentanyl found in the model.
# Vector for halothane found in the model.
# Vector for Lorazepam not found in the model.
# Vector for Pletal not found in the model.
# Vector for Anaprox not found in the model.
# Vector for AOM not found in the model.
# Vector for chymotrypsin found in the model.
# Vector for dolasetron found in the model.
# Vector for Jacalin not found in the model.
# Vector for REVLIMID not found in the model.
# Vector for TAXOL not found in the model.
# Vector for Echistatin not found in the model.
# Vector for CIMETlDINE not found in the model.
# Vector for acetophenazine found in the model.
# Vector for bleomycin found in the model.
# Vector for Zarontin not found in the model.
# Vector for anticoagulant found in the model.
# Vector for Exjade not found in the model.
# Vector for ARIMIDEX not found in the model.
# Vector for Vitamin E not found in the model.
# Vector for Triamterene not found in the model.
# Vector for CEFOTAN not found in the model.
# Vector for NORVIR not found in the model.
# Vector for COPAXONE not found in the model.
# Vector for Ponstel not found in the model.
# Vector for Acetylcysteine not found in the model.
# Vector for AVASTIN not found in the model.
# Vector for amitriptyline HCl not found in the model.
# Vector for oxcarbazepine found in the model.
# Vector for cevimeline not found in the model.
# Vector for Atomoxetine not found in the model.
# Vector for nitrite found in the model.
# Vector for Venlafaxine not found in the model.
# Vector for diltiazem found in the model.
# Vector for KRM-1648 not found in the model.
# Vector for Buforin II not found in the model.
# Vector for MONUROL not found in the model.
# Vector for acenocoumarol found in the model.
# Vector for mecamylamine found in the model.
# Vector for stavudine found in the model.
# Vector for levonorgestrel found in the model.
# Vector for methylergonovine found in the model.
# Vector for felodipine found in the model.
# Vector for Fenfluramine not found in the model.
# Vector for Naproxen not found in the model.
# Vector for sodium citrate not found in the model.
# Vector for Epinephrine not found in the model.
# Vector for antidepressants found in the model.
# Vector for Abciximab not found in the model.
# Vector for DIABINESE not found in the model.
# Vector for EPA not found in the model.
# Vector for thimerosal found in the model.
# Vector for Aralen not found in the model.
# Vector for verografin found in the model.
# Vector for CMI not found in the model.
# Vector for L-CCG-1 not found in the model.
# Vector for Co not found in the model.
# Vector for fosinopril sodium not found in the model.
# Vector for doxorubicin found in the model.
# Vector for nitroglycerin found in the model.
# Vector for Advil not found in the model.
# ...
# Vector for vanillin found in the model.
# Vector for valsartan found in the model.
# Vector for isoflurane found in the model.
# Vector for acyclovir found in the model.
# Vector for REMERON SolTab not found in the model.
# Vector for Potassium not found in the model.
# Vector for phosphorous insecticides not found in the model.
# Vector for Cinacalcet not found in the model.
# Vector for Thiamine not found in the model.
# Vector for aminoglutethimide found in the model.
# Vector for pyrimethamine found in the model.
# Vector for vancomycin found in the model.
# Vector for methylprednisolone found in the model.
# Vector for morphine found in the model.
# Vector for amikacin found in the model.
# Vector for amoxapine found in the model.
# Vector for darbepoetin not found in the model.
# Vector for pantoprazole found in the model.
# Vector for prednisolone found in the model.
# Vector for calcium chloride not found in the model.
# Vector for piperine found in the model.
# Vector for caffeine found in the model.
# Vector for melphalan found in the model.
# Vector for thioridazine found in the model.
# Vector for metaproterenol sulfate not found in the model.
# Vector for atazanavir not found in the model.
# Vector for TEMODAR not found in the model.
# Vector for pectin found in the model.
# Vector for Paricalcitol not found in the model.
# Vector for mebendazole found in the model.
# Vector for pilocarpine found in the model.
# Vector for dexmedetomidine found in the model.
# Vector for ganciclovir found in the model.
# Vector for S-warfarin not found in the model.
# Vector for nitrous oxide not found in the model.
# Vector for Mitomycin-C not found in the model.
# Vector for voriconizole not found in the model.
# Vector for Alcohol not found in the model.
# Vector for Levodopa not found in the model.
# Vector for Implanon not found in the model.
# Vector for atorvastatin found in the model.
# Vector for Parnate not found in the model.
# Vector for Sorafenib not found in the model.
# Vector for ZANTAC not found in the model.
# Vector for thioguanine found in the model.
# Vector for methazolamide found in the model.
# Vector for alpha lipoic acid not found in the model.
# Vector for paracetamol found in the model.
# Vector for Celecoxib not found in the model.
# Vector for MPAG not found in the model.
# Vector for Cholestyramine not found in the model.
# Vector for ZADAXIN not found in the model.
# Vector for valproate found in the model.
# Vector for acetyl-l-carnitine found in the model.
# Vector for Sirolimus not found in the model.
# Vector for tramadol found in the model.
# Vector for sodium bicarbonate not found in the model.
# Vector for kaolin found in the model.
# Vector for gelusil found in the model.
# Vector for ABT-737 not found in the model.
# Vector for mirtazapine found in the model.
# Vector for nifedipine found in the model.
# Vector for rivastigmine tartrate not found in the model.
# Vector for METROGEL not found in the model.
# Vector for colistin found in the model.
# Vector for Rivastigmine not found in the model.
# Vector for Nutropin not found in the model.
# Vector for docetaxel found in the model.
# Vector for mannitol found in the model.
# Vector for Effient not found in the model.
# Vector for methylglyoxal found in the model.
# Vector for ZERIT not found in the model.
# Vector for TOLECTIN not found in the model.
# Vector for fenofibrate found in the model.
# Vector for SUTENT not found in the model.
# Vector for perindoprilat found in the model.
# Vector for tyramine found in the model.
# Vector for pindolol found in the model.
# Vector for suprofen found in the model.
# Vector for metoprolol found in the model.
# Vector for Amantadine not found in the model.
# Vector for sertraline found in the model.
# Vector for DIPRIVAN not found in the model.
# Vector for etoposide found in the model.
# Vector for terazosin found in the model.
# Vector for sodium salicylate not found in the model.
# Vector for methoxyflurane found in the model.
# Vector for methylphenidate found in the model.
# Vector for Calcitonin (salmon) not found in the model.
# Vector for Sulfamethoxazole not found in the model.
# Vector for levothyroxine sodium not found in the model.
# Vector for Ultram not found in the model.
# Vector for isocarboxazid found in the model.
# Vector for calcium found in the model.
# Vector for clarithromycin found in the model.
# Vector for Terbinafine not found in the model.
# Vector for Gemfibrozil not found in the model.
# Vector for DEMSER not found in the model.
# Vector for rosiglitazone not found in the model.
# Vector for Anafranil not found in the model.
# Vector for UNIVASC not found in the model.
# Vector for adeno-associated virus-2 not found in the model.
# Vector for ciprofloxacin found in the model.
# Vector for TRENTAL not found in the model.
# Vector for polymyxin B not found in the model.
# Vector for triamterene found in the model.
# Vector for nefazodone found in the model.
# Vector for theophylline found in the model.
# Vector for glyburide found in the model.
# Vector for Methotrexate not found in the model.
# Vector for diazoxide found in the model.
# Vector for Acetazolamide not found in the model.
# Vector for atropine found in the model.
# Vector for ethoxycoumarin found in the model.
# Vector for norethindrone found in the model.
# Vector for fosfomycin found in the model.
# Vector for Rifabutin not found in the model.
# Vector for VESIcare not found in the model.
# Vector for activated charcoal not found in the model.
# Vector for GH not found in the model.
# Vector for anastrozole not found in the model.
# Vector for Furafylline not found in the model.
# Vector for MPTP not found in the model.
# Vector for ferrous gluconate not found in the model.
# Vector for thyroxine found in the model.
# Vector for Myfortic not found in the model.
# Vector for pancuronium found in the model.
# Vector for vaccine found in the model.
# Vector for haloperidol found in the model.
# Vector for Pramipexole not found in the model.
# Vector for ZANOSAR not found in the model.
# Vector for Sulfamethizole not found in the model.
# Vector for Posicor not found in the model.
# Vector for Micafungin not found in the model.
# Vector for DISALCID not found in the model.
# Vector for ABT not found in the model.
# Vector for ketamine found in the model.
# Vector for imipramine HCl not found in the model.
# Vector for glycopyrrolate found in the model.
# Vector for pergolide mesylate not found in the model.
# Vector for CYLERT not found in the model.
# Vector for Moxifloxacin not found in the model.
# Vector for magnesium found in the model.
# Vector for inactivated ND vaccines not found in the model.
# Vector for amphotericin B not found in the model.
# Vector for DETROL LA not found in the model.
# Vector for phenobarbital found in the model.
# Vector for dexamethasone found in the model.
# Vector for Stavudine not found in the model.
# Vector for quinine found in the model.
# Vector for Mazindol not found in the model.
# Vector for probenecid found in the model.
# Vector for suxamethonium chloride not found in the model.
# Vector for Methergine not found in the model.
# Vector for cyclosporine found in the model.
# Vector for hydralazine found in the model.
# Vector for prasugrel not found in the model.
# Vector for beta-carotene found in the model.
# Vector for Sinequan not found in the model.
# Vector for Methyldopa not found in the model.
# Vector for LAMISIL not found in the model.
# Vector for methyldopa found in the model.
# Vector for Vitamin B2 not found in the model.
# Vector for guanethidine found in the model.
# Vector for Thioguanine not found in the model.
# Vector for alpha-lipoic acid not found in the model.
# Vector for panobinostat not found in the model.
# Vector for carbachol found in the model.
# Vector for moxifloxacin not found in the model.
# Vector for MEXITIL not found in the model.
# Vector for dihydroergotamine found in the model.
# Vector for lenalidomide not found in the model.
# Vector for amitriptyline found in the model.
# Vector for promethazine found in the model.
# Vector for Pilocarpine not found in the model.
# Vector for Anabolic steroids not found in the model.
# Vector for clotrimazole found in the model.
# Vector for tiludronate found in the model.
# Vector for reserpine found in the model.
# Vector for Melatonin not found in the model.
# Vector for CHEMET not found in the model.
# Vector for Fenofibrate not found in the model.
# Vector for dornase alfa not found in the model.
# Vector for dacarbazine found in the model.
# Vector for Aminoglutethimide not found in the model.
# Vector for VMA not found in the model.
# Vector for HERCEPTIN not found in the model.
# Vector for oxycodone hydrochloride not found in the model.
# Vector for tolmetin found in the model.
# Vector for heme iron not found in the model.
# Vector for modafinil found in the model.
# Vector for sunitinib not found in the model.
# Vector for norepinephrine found in the model.
# Vector for Nifedipine not found in the model.
# Vector for Lithium not found in the model.
# Vector for divalproex sodium not found in the model.
# Vector for aluminum hydroxide not found in the model.
# Vector for pentazocine found in the model.
# Vector for terbinafine found in the model.
# Vector for buprenorphine found in the model.
# Vector for cyclosporin found in the model.
# Vector for citalopram found in the model.
# Vector for lomefloxacin found in the model.
# Vector for Mephenytoin not found in the model.
# Vector for ferrous sulfate not found in the model.
# Vector for micafungin not found in the model.
# Vector for Oxandrolone not found in the model.
# Vector for mercaptopurine found in the model.
# Vector for Sunitinib not found in the model.
# Vector for gemfibrozil found in the model.
# Vector for quinidine found in the model.
# Vector for Isoflurane not found in the model.
# Vector for hydrochlorothiazide found in the model.
# Vector for sitagliptin not found in the model.
# Vector for diclofenac found in the model.
# Vector for chlorpropamide found in the model.
# Vector for ethinyl estradiol not found in the model.
# Vector for moexpril not found in the model.
# Vector for Insulin not found in the model.
# Vector for sumatriptan found in the model.
# Vector for Asendin not found in the model.
# Vector for ginseng stem-and-leaf saponins not found in the model.
# Vector for metaraminol found in the model.
# Vector for vitamin E acetate not found in the model.
# Vector for VUMON not found in the model.
# Vector for Ritalin not found in the model.
# Vector for Streptase not found in the model.
# Vector for Itraconazole not found in the model.
# Vector for desmethyldiazepam found in the model.
# Vector for Metolazone not found in the model.
# Vector for Metopirone not found in the model.
# Vector for paricalcitol not found in the model.
# Vector for Precocene I not found in the model.
# Vector for ethanol found in the model.
# Vector for Acyclovir not found in the model.
# Vector for doxazosin found in the model.
# Vector for phenytoin found in the model.
# Vector for propafenone found in the model.
# Vector for methadone found in the model.
# Vector for fluoxetine found in the model.
# Vector for Glyburide not found in the model.
# Vector for piperacillin found in the model.
# Vector for medroxyprogesterone acetate not found in the model.
# Vector for minoxidil found in the model.
# Vector for DIFLUCAN not found in the model.
# Vector for rifampin found in the model.
# Vector for Pamelor not found in the model.
# Vector for fludrocortisone acetate not found in the model.
# Vector for meloxicam found in the model.
# Vector for metoclopramide found in the model.
# Vector for Ismelin not found in the model.
# Vector for amoxicillin found in the model.
# Vector for Mexitil not found in the model.
# Vector for Cyclosporine not found in the model.
# Vector for Cerezyme not found in the model.
# Vector for Folinic acid not found in the model.
# Vector for magnesium-aluminum hydroxide not found in the model.
# Vector for quinpirole found in the model.
# Vector for thalidomide found in the model.
# Vector for Panobinostat not found in the model.
# Vector for Tofranil not found in the model.
# Vector for zileuton found in the model.
# Vector for Vitamin B1 not found in the model.
# Vector for Selegiline not found in the model.
# Vector for Mycophenolate Mofetil not found in the model.
# Vector for orlistat found in the model.
# Vector for oxandrolone found in the model.
# Vector for Zidovudine not found in the model.
# Vector for estradiol found in the model.
# Vector for cimetidine found in the model.
# Vector for ACTH not found in the model.
# Vector for sumatriptan succinate not found in the model.
# Vector for precocene I not found in the model.
# Vector for DTIC not found in the model.
# Vector for primidone found in the model.
# Vector for metformin found in the model.
# Vector for triprolidine found in the model.
# Vector for fluvastatin found in the model.
# Vector for tubocurarine found in the model.
# Vector for triiodothyronine found in the model.
# Vector for Warfarin not found in the model.
# Vector for potassium chloride not found in the model.
# Vector for clonidine found in the model.
# Vector for ergotamine found in the model.
# Vector for antipyrine found in the model.
# Vector for chloral hydrate not found in the model.
# Vector for Vivactil not found in the model.
# Vector for propoxyphene found in the model.
# Vector for ZOLINZA not found in the model.
# Vector for valproic acid not found in the model.
# Vector for Carboptic not found in the model.
# Vector for Fluconazole not found in the model.
# Vector for Methscopolamine not found in the model.
# Vector for LBH589 not found in the model.
# Vector for prednisone found in the model.
# Vector for REMERON not found in the model.
# Vector for Ondansetron not found in the model.
# Vector for Mecamylamine not found in the model.
# Vector for hemantane not found in the model.
# Vector for desipramine found in the model.
# Vector for tetracycline found in the model.
# Vector for griseofulvin found in the model.
# Vector for ALTABAX not found in the model.
# Vector for ticlopidine found in the model.
# Vector for Ganciclovir not found in the model.
# Vector for Ethyl alcohol not found in the model.
# Vector for diethyldithiocarbamate found in the model.
# Vector for phenelzine found in the model.
# Vector for lorazepam found in the model.
# Vector for human GH not found in the model.
# Vector for clofibrate found in the model.
# Vector for ropivacaine found in the model.
# Vector for droperidol found in the model.
# Vector for dobutamine found in the model.
# Vector for ZIAGEN not found in the model.
# Vector for tamsulosin HCI not found in the model.
# Vector for vinblastine found in the model.
# Vector for viomycin found in the model.
# Vector for Methyprylon not found in the model.
# Vector for lapatinib not found in the model.
# Vector for epinephrine found in the model.
# Vector for tolterodine not found in the model.
# Vector for sucralfate found in the model.
# Vector for PULMOZYME not found in the model.
# Vector for NEXAVAR not found in the model.
# Vector for mometasone furoate not found in the model.
# Vector for Lapatinib not found in the model.
# Vector for Raloxifene not found in the model.
# Vector for secobarbital found in the model.
# Vector for Hyaluronidase not found in the model.
# Vector for 1-methyl-4-phenyl-1,2,3,4-tetrahydropyridine not found in the model.
# Vector for ARAMINE not found in the model.
# Vector for mesalazine found in the model.
# Vector for acetylcholine chloride not found in the model.
# Vector for mexiletine found in the model.
# Vector for ibuprofen found in the model.
# Vector for methotrexate found in the model.
# Vector for Ethanol not found in the model.
# Vector for Thiabendazole not found in the model.
# Vector for fentanyl found in the model.
# Vector for sulfasalazine found in the model.
# Vector for Pyrimethamine not found in the model.
# Vector for halothane found in the model.
# Vector for pegvisomant not found in the model.
# Vector for warfarin found in the model.
# Vector for CRM197 not found in the model.
# Vector for SOMAVERT not found in the model.
# Vector for Hyaluronan lyase not found in the model.
# Vector for procainamide found in the model.
# Vector for indomethacin found in the model.
# Vector for nonheme iron not found in the model.
# Vector for melatonin found in the model.
# Vector for amitriptyline HCl not found in the model.

# %%
drug_vectors_df = pd.DataFrame.from_dict(drug_vectors, orient='index')
drug_vectors_df_test = pd.DataFrame.from_dict(drug_vectors_test, orient='index')

# %%
# Function to parse DDI relations from XML files in a given directory
def parse_ddi_relations_from_directory(directory):
    drug_pairs = []
    for file_name in os.listdir(directory):
        if file_name.endswith('.xml'):
            file_path = os.path.join(directory, file_name)
            drug_pairs.extend(parse_ddi_relations(file_path))
    return drug_pairs

# Function to parse DDI relations from a single file
def parse_ddi_relations(file_path):
    tree = ET.parse(file_path)
    root = tree.getroot()
    relations = []

    # Map entity IDs to drug names
    entity_id_to_name = {entity.attrib.get('id'): entity.attrib.get('text') for entity in root.findall(".//entity")}

    # Parse pairs and retrieve entity names
    for pair in root.findall(".//pair"):
        relation = {
            'e1': pair.attrib.get('e1'),
            'e2': pair.attrib.get('e2'),
            'ddi': pair.attrib.get('ddi'),
            'e1_name': entity_id_to_name.get(pair.attrib.get('e1')),
            'e2_name': entity_id_to_name.get(pair.attrib.get('e2'))
        }
        relations.append(relation)
    
    return relations

# Directories for training and testing datasets
train_dirs = ['../DDICorpus/Train/DrugBank', '../DDICorpus/Train/MedLine']
test_dirs = ['../DDICorpus/Test/Test for DDI Extraction task/DrugBank', '../DDICorpus/Test/Test for DDI Extraction task/MedLine']

# Extract drug pairs from training and testing directories
all_drug_pairs = []
all_drug_pairs_test = []

for directory in train_dirs:
    all_drug_pairs.extend(parse_ddi_relations_from_directory(directory))

for directory in test_dirs:
    all_drug_pairs_test.extend(parse_ddi_relations_from_directory(directory))

# %%
# Output the drug pairs
print(f"Training drug pairs: {len(all_drug_pairs)}")
print(all_drug_pairs)
# Out:
# Training drug pairs: 27792
# [{'e1': 'DDI-DrugBank.d519.s3.e0', 'e2': 'DDI-DrugBank.d519.s3.e1', 'ddi': 'false', 'e1_name': 'Plenaxis', 'e2_name': 'testosterone'}, {'e1': 'DDI-DrugBank.d297.s1.e0', 'e2': 'DDI-DrugBank.d297.s1.e1', 'ddi': 'false', 'e1_name': 'MTX', 'e2_name': 'NSAIDs'}, {'e1': 'DDI-DrugBank.d297.s1.e0', 'e2': 'DDI-DrugBank.d297.s1.e2', 'ddi': 'false', 'e1_name': 'MTX', 'e2_name': 'corticosteroids'}, {'e1': 'DDI-DrugBank.d297.s1.e0', 'e2': 'DDI-DrugBank.d297.s1.e3', 'ddi': 'false', 'e1_name': 'MTX', 'e2_name': 'TNF blocking agents'}, {'e1': 'DDI-DrugBank.d297.s1.e0', 'e2': 'DDI-DrugBank.d297.s1.e4', 'ddi': 'false', 'e1_name': 'MTX', 'e2_name': 'abatacept'}, {'e1': 'DDI-DrugBank.d297.s1.e1', 'e2': 'DDI-DrugBank.d297.s1.e2', 'ddi': 'false', 'e1_name': 'NSAIDs', 'e2_name': 'corticosteroids'}, {'e1': 'DDI-DrugBank.d297.s1.e1', 'e2': 'DDI-DrugBank.d297.s1.e3', 'ddi': 'false', 'e1_name': 'NSAIDs', 'e2_name': 'TNF blocking agents'}, {'e1': 'DDI-DrugBank.d297.s1.e1', 'e2': 'DDI-DrugBank.d297.s1.e4', 'ddi': 'false', 'e1_name': 'NSAIDs', 'e2_name': 'abatacept'}, {'e1': 'DDI-DrugBank.d297.s1.e2', 'e2': 'DDI-DrugBank.d297.s1.e3', 'ddi': 'false', 'e1_name': 'corticosteroids', 'e2_name': 'TNF blocking agents'}, {'e1': 'DDI-DrugBank.d297.s1.e2', 'e2': 'DDI-DrugBank.d297.s1.e4', 'ddi': 'false', 'e1_name': 'corticosteroids', 'e2_name': 'abatacept'}, {'e1': 'DDI-DrugBank.d297.s1.e3', 'e2': 'DDI-DrugBank.d297.s1.e4', 'ddi': 'false', 'e1_name': 'TNF blocking agents', 'e2_name': 'abatacept'}, {'e1': 'DDI-DrugBank.d297.s2.e0', 'e2': 'DDI-DrugBank.d297.s2.e1', 'ddi': 'false', 'e1_name': 'ORENCIA', 'e2_name': 'MTX'}, {'e1': 'DDI-DrugBank.d297.s2.e0', 'e2': 'DDI-DrugBank.d297.s2.e2', 'ddi': 'false', 'e1_name': 'ORENCIA', 'e2_name': 'NSAIDs'}, {'e1': 'DDI-DrugBank.d297.s2.e0', 'e2': 'DDI-DrugBank.d297.s2.e3', 'ddi': 'false', 'e1_name': 'ORENCIA', 'e2_name': 'corticosteroids'}, {'e1': 'DDI-DrugBank.d297.s2.e0', 'e2': 'DDI-DrugBank.d297.s2.e4', 'ddi': 'false', 'e1_name': 'ORENCIA', 'e2_name': 'TNF blocking agents'}, {'e1': 'DDI-DrugBank.d297.s2.e0', 'e2': 'DDI-DrugBank.d297.s2.e5', 'ddi': 'false', 'e1_name': 'ORENCIA', 'e2_name': 'azathioprine'}, {'e1': 'DDI-DrugBank.d297.s2.e0', 'e2': 'DDI-DrugBank.d297.s2.e6', 'ddi': 'false', 'e1_name': 'ORENCIA', 'e2_name': 'chloroquine'}, {'e1': 'DDI-DrugBank.d297.s2.e0', 'e2': 'DDI-DrugBank.d297.s2.e7', 'ddi': 'false', 'e1_name': 'ORENCIA', 'e2_name': 'gold'}, {'e1': 'DDI-DrugBank.d297.s2.e0', 'e2': 'DDI-DrugBank.d297.s2.e8', 'ddi': 'false', 'e1_name': 'ORENCIA', 'e2_name': 'hydroxychloroquine'}, {'e1': 'DDI-DrugBank.d297.s2.e0', 'e2': 'DDI-DrugBank.d297.s2.e9', 'ddi': 'false', 'e1_name': 'ORENCIA', 'e2_name': 'leflunomide'}, {'e1': 'DDI-DrugBank.d297.s2.e0', 'e2': 'DDI-DrugBank.d297.s2.e10', 'ddi': 'false', 'e1_name': 'ORENCIA', 'e2_name': 'sulfasalazine'}, {'e1': 'DDI-DrugBank.d297.s2.e0', 'e2': 'DDI-DrugBank.d297.s2.e11', 'ddi': 'false', 'e1_name': 'ORENCIA', 'e2_name': 'anakinra'}, {'e1': 'DDI-DrugBank.d297.s2.e1', 'e2': 'DDI-DrugBank.d297.s2.e2', 'ddi': 'false', 'e1_name': 'MTX', 'e2_name': 'NSAIDs'}, {'e1': 'DDI-DrugBank.d297.s2.e1', 'e2': 'DDI-DrugBank.d297.s2.e3', 'ddi': 'false', 'e1_name': 'MTX', 'e2_name': 'corticosteroids'}, {'e1': 'DDI-DrugBank.d297.s2.e1', 'e2': 'DDI-DrugBank.d297.s2.e4', 'ddi': 'false', 'e1_name': 'MTX', 'e2_name': 'TNF blocking agents'}, {'e1': 'DDI-DrugBank.d297.s2.e1', 'e2': 'DDI-DrugBank.d297.s2.e5', 'ddi': 'false', 'e1_name': 'MTX', 'e2_name': 'azathioprine'}, {'e1': 'DDI-DrugBank.d297.s2.e1', 'e2': 'DDI-DrugBank.d297.s2.e6', 'ddi': 'false', 'e1_name': 'MTX', 'e2_name': 'chloroquine'}, {'e1': 'DDI-DrugBank.d297.s2.e1', 'e2': 'DDI-DrugBank.d297.s2.e7', 'ddi': 'false', 'e1_name': 'MTX', 'e2_name': 'gold'}, {'e1': 'DDI-DrugBank.d297.s2.e1', 'e2': 'DDI-DrugBank.d297.s2.e8', 'ddi': 'false', 'e1_name': 'MTX', 'e2_name': 'hydroxychloroquine'}, {'e1': 'DDI-DrugBank.d297.s2.e1', 'e2': 'DDI-DrugBank.d297.s2.e9', 'ddi': 'false', 'e1_name': 'MTX', 'e2_name': 'leflunomide'}, {'e1': 'DDI-DrugBank.d297.s2.e1' ...

# %%
print(f"Testing drug pairs: {len(all_drug_pairs_test)}")
print(all_drug_pairs_test)
# Out:
# Testing drug pairs: 5716
# [{'e1': 'DDI-DrugBank.d610.s0.e0', 'e2': 'DDI-DrugBank.d610.s0.e1', 'ddi': 'false', 'e1_name': 'abacavir', 'e2_name': 'lamivudine'}, {'e1': 'DDI-DrugBank.d610.s0.e0', 'e2': 'DDI-DrugBank.d610.s0.e2', 'ddi': 'false', 'e1_name': 'abacavir', 'e2_name': 'zidovudine'}, {'e1': 'DDI-DrugBank.d610.s0.e0', 'e2': 'DDI-DrugBank.d610.s0.e3', 'ddi': 'false', 'e1_name': 'abacavir', 'e2_name': 'lamivudine'}, {'e1': 'DDI-DrugBank.d610.s0.e0', 'e2': 'DDI-DrugBank.d610.s0.e4', 'ddi': 'false', 'e1_name': 'abacavir', 'e2_name': 'zidovudine'}, {'e1': 'DDI-DrugBank.d610.s0.e1', 'e2': 'DDI-DrugBank.d610.s0.e2', 'ddi': 'false', 'e1_name': 'lamivudine', 'e2_name': 'zidovudine'}, {'e1': 'DDI-DrugBank.d610.s0.e1', 'e2': 'DDI-DrugBank.d610.s0.e3', 'ddi': 'false', 'e1_name': 'lamivudine', 'e2_name': 'lamivudine'}, {'e1': 'DDI-DrugBank.d610.s0.e1', 'e2': 'DDI-DrugBank.d610.s0.e4', 'ddi': 'false', 'e1_name': 'lamivudine', 'e2_name': 'zidovudine'}, {'e1': 'DDI-DrugBank.d610.s0.e2', 'e2': 'DDI-DrugBank.d610.s0.e3', 'ddi': 'false', 'e1_name': 'zidovudine', 'e2_name': 'lamivudine'}, {'e1': 'DDI-DrugBank.d610.s0.e2', 'e2': 'DDI-DrugBank.d610.s0.e4', 'ddi': 'false', 'e1_name': 'zidovudine', 'e2_name': 'zidovudine'}, {'e1': 'DDI-DrugBank.d610.s0.e3', 'e2': 'DDI-DrugBank.d610.s0.e4', 'ddi': 'false', 'e1_name': 'lamivudine', 'e2_name': 'zidovudine'}, {'e1': 'DDI-DrugBank.d610.s1.e0', 'e2': 'DDI-DrugBank.d610.s1.e1', 'ddi': 'false', 'e1_name': 'lamivudine', 'e2_name': 'zidovudine'}, {'e1': 'DDI-DrugBank.d610.s1.e0', 'e2': 'DDI-DrugBank.d610.s1.e2', 'ddi': 'false', 'e1_name': 'lamivudine', 'e2_name': 'abacavir'}, {'e1': 'DDI-DrugBank.d610.s1.e1', 'e2': 'DDI-DrugBank.d610.s1.e2', 'ddi': 'false', 'e1_name': 'zidovudine', 'e2_name': 'abacavir'}, {'e1': 'DDI-DrugBank.d610.s2.e0', 'e2': 'DDI-DrugBank.d610.s2.e1', 'ddi': 'false', 'e1_name': 'Abacavir', 'e2_name': 'ethanol'}, {'e1': 'DDI-DrugBank.d610.s3.e0', 'e2': 'DDI-DrugBank.d610.s3.e1', 'ddi': 'true', 'e1_name': 'Ethanol', 'e2_name': 'abacavir'}, {'e1': 'DDI-DrugBank.d610.s3.e0', 'e2': 'DDI-DrugBank.d610.s3.e2', 'ddi': 'false', 'e1_name': 'Ethanol', 'e2_name': 'methadone'}, {'e1': 'DDI-DrugBank.d610.s3.e0', 'e2': 'DDI-DrugBank.d610.s3.e3', 'ddi': 'false', 'e1_name': 'Ethanol', 'e2_name': 'abacavir'}, {'e1': 'DDI-DrugBank.d610.s3.e1', 'e2': 'DDI-DrugBank.d610.s3.e2', 'ddi': 'false', 'e1_name': 'abacavir', 'e2_name': 'methadone'}, {'e1': 'DDI-DrugBank.d610.s3.e1', 'e2': 'DDI-DrugBank.d610.s3.e3', 'ddi': 'false', 'e1_name': 'abacavir', 'e2_name': 'abacavir'}, {'e1': 'DDI-DrugBank.d610.s3.e2', 'e2': 'DDI-DrugBank.d610.s3.e3', 'ddi': 'false', 'e1_name': 'methadone', 'e2_name': 'abacavir'}, {'e1': 'DDI-DrugBank.d610.s4.e0', 'e2': 'DDI-DrugBank.d610.s4.e1', 'ddi': 'true', 'e1_name': 'methadone', 'e2_name': 'ZIAGEN'}, {'e1': 'DDI-DrugBank.d610.s4.e0', 'e2': 'DDI-DrugBank.d610.s4.e2', 'ddi': 'false', 'e1_name': 'methadone', 'e2_name': 'methadone'}, {'e1': 'DDI-DrugBank.d610.s4.e1', 'e2': 'DDI-DrugBank.d610.s4.e2', 'ddi': 'false', 'e1_name': 'ZIAGEN', 'e2_name': 'methadone'}, {'e1': 'DDI-DrugBank.d572.s0.e0', 'e2': 'DDI-DrugBank.d572.s0.e1', 'ddi': 'false', 'e1_name': 'Cholestyramine', 'e2_name': 'cholestyramine'}, {'e1': 'DDI-DrugBank.d572.s0.e0', 'e2': 'DDI-DrugBank.d572.s0.e2', 'ddi': 'false', 'e1_name': 'Cholestyramine', 'e2_name': 'ezetimibe'}, {'e1': 'DDI-DrugBank.d572.s0.e1', 'e2': 'DDI-DrugBank.d572.s0.e2', 'ddi': 'true', 'e1_name': 'cholestyramine', 'e2_name': 'ezetimibe'}, {'e1': 'DDI-DrugBank.d572.s1.e0', 'e2': 'DDI-DrugBank.d572.s1.e1', 'ddi': 'true', 'e1_name': 'ezetimibe', 'e2_name': 'cholestyramine'}, {'e1': 'DDI-DrugBank.d572.s2.e0', 'e2': 'DDI-DrugBank.d572.s2.e1', 'ddi': 'false', 'e1_name': 'Fibrates', 'e2_name': 'ezetimibe'}, {'e1': 'DDI-DrugBank.d572.s2.e0', 'e2': 'DDI-DrugBank.d572.s2.e2', 'ddi': 'false', 'e1_name': 'Fibrates', 'e2_name': 'fibrates'}, {'e1': 'DDI-DrugBank.d572.s2.e1', 'e2': 'DDI-DrugBank.d572.s2.e2', 'ddi': 'false', 'e1_name': 'ezetimibe', 'e2_name': 'fibrates'}, {'e1': 'DDI-DrugBank.d572.s5. ...

# %% [markdown]
# **Train Dataset Preparation**

# %%
drug_pairs_df = pd.DataFrame(all_drug_pairs)

drug_pairs_df = drug_pairs_df[['e1_name', 'e2_name', 'ddi']]
drug_pairs_df.columns = ['Drug1', 'Drug2', 'Interacting']

drug_pairs_df['Interacting'] = drug_pairs_df['Interacting'].apply(lambda x: x.lower() == 'true')
drug_pairs_df
# Out:
#                 Drug1                         Drug2  Interacting
# 0            Plenaxis                  testosterone        False
# 1                 MTX                        NSAIDs        False
# 2                 MTX               corticosteroids        False
# 3                 MTX           TNF blocking agents        False
# 4                 MTX                     abatacept        False
# ...               ...                           ...          ...
# 27787      anxiolytic                hypnotic drugs        False
# 27788       temazepam                benzodiazepine        False
# 27789       temazepam                       ethanol         True
# 27790  benzodiazepine                       ethanol        False
# 27791         alcohol  3-hydroxy-1,4-benzodiazepine         True
#
# [27792 rows x 3 columns]

# %% [markdown]
# Function to get vector representation or None if not available

# %%
def get_vector(drug):
    return drug_vectors.get(drug, None)

# %% [markdown]
# Add vector representations to the drug pairs DataFrame

# %%
drug_pairs_df['Drug1_Vector'] = drug_pairs_df['Drug1'].apply(get_vector)
drug_pairs_df['Drug2_Vector'] = drug_pairs_df['Drug2'].apply(get_vector)

# %% [markdown]
# Drop rows where either Drug1_Vector or Drug2_Vector is None

# %%
drug_pairs_df = drug_pairs_df.dropna(subset=['Drug1_Vector', 'Drug2_Vector'])

# %% [markdown]
# Add a new column 'Interaction_Label' with 1 for True and 0 for False in 'Interacting' column

# %%
drug_pairs_df['Interaction_Label'] = drug_pairs_df['Interacting'].astype(int)

# Drop rows where both Drug1 and Drug2 are the same
drug_pairs_df = drug_pairs_df[drug_pairs_df['Drug1'] != drug_pairs_df['Drug2']]
# Out:
# C:\Users\manav\AppData\Local\Temp\ipykernel_31620\2745480157.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   drug_pairs_df['Interaction_Label'] = drug_pairs_df['Interacting'].astype(int)

# %%
drug_pairs_df
# Out:
#               Drug1               Drug2  Interacting  \
# 56     azathioprine         chloroquine        False
# 57     azathioprine                gold        False
# 58     azathioprine  hydroxychloroquine        False
# 59     azathioprine         leflunomide        False
# 60     azathioprine       sulfasalazine        False
# ...             ...                 ...          ...
# 27781    atracurium          gentamycin        False
# 27782    atracurium          gentamycin         True
# 27783    gentamycin          atracurium         True
# 27784     temazepam             ethanol         True
# 27789     temazepam             ethanol         True
#
#                                             Drug1_Vector  \
# 56     [-1.7581139, 1.7656937, -0.8097911, -0.4637825...
# 57     [-1.7581139, 1.7656937, -0.8097911, -0.4637825...
# 58     [-1.7581139, 1.7656937, -0.8097911, -0.4637825...
# 59     [-1.7581139, 1.7656937, -0.8097911, -0.4637825...
# 60     [-1.7581139, 1.7656937, -0.8097911, -0.4637825...
# ...                                                  ...
# 27781  [-0.5961569, 0.7680444, 0.10006797, 0.44512144...
# 27782  [-0.5961569, 0.7680444, 0.10006797, 0.44512144...
# 27783  [-3.880826, 3.044013, -0.27987602, 1.8603655, ...
# 27784  [-1.5704364, -0.40990764, 1.0089173, -1.119097...
# 27789  [-1.5704364, -0.40990764, 1.0089173, -1.119097...
#
#                                             Drug2_Vector  Interaction_Label
# 56     [-2.6481946, 2.2783346, 1.1517652, 0.6890142, ...                  0
# 57     [1.5074506, 0.18530452, 1.1512405, -1.1938127,...                  0
# 58     [-1.1534871, 2.251285, -0.20287251, -0.6967244...                  0
# 59     [-0.5966278, 0.69640297, -0.25046876, 0.485497...                  0
# 60     [-2.2326422, 2.1954632, 0.23844823, 1.7091032,...                  0
# ...                                                  ...                ...
# 27781  [-3.880826, 3.044013, -0.27987602, 1.8603655, ...                  0
# 27782  [-3.880826, 3.044013, -0.27987602, 1.8603655, ...                  1
# 27783  [-0.5961569, 0.7680444, 0.10006797, 0.44512144...                  1
# 27784  [-2.3531077, -1.6309003, 0.5205146, 0.51192605...                  1
# 27789  [-2.3531077, -1.6309003, 0.5205146, 0.51192605...                  1
#
# [8774 rows x 6 columns]

# %% [markdown]
# **Test Dataset Preparation**

# %%
drug_pairs_df_test = pd.DataFrame(all_drug_pairs_test)

drug_pairs_df_test = drug_pairs_df_test[['e1_name', 'e2_name', 'ddi']]
drug_pairs_df_test.columns = ['Drug1', 'Drug2', 'Interacting']

drug_pairs_df_test['Interacting'] = drug_pairs_df_test['Interacting'].apply(lambda x: x.lower() == 'true')
drug_pairs_df_test
# Out:
#            Drug1       Drug2  Interacting
# 0       abacavir  lamivudine        False
# 1       abacavir  zidovudine        False
# 2       abacavir  lamivudine        False
# 3       abacavir  zidovudine        False
# 4     lamivudine  zidovudine        False
# ...          ...         ...          ...
# 5711   Ibuprofen    piperine         True
# 5712   ibuprofen    piperine         True
# 5713   ibuprofen   ibuprofen        False
# 5714    piperine   ibuprofen        False
# 5715    piperine   ibuprofen         True
#
# [5716 rows x 3 columns]

# %% [markdown]
# Add vector representations to the drug pairs DataFrame

# %%
drug_pairs_df_test['Drug1_Vector'] = drug_pairs_df_test['Drug1'].apply(get_vector)
drug_pairs_df_test['Drug2_Vector'] = drug_pairs_df_test['Drug2'].apply(get_vector)

# %% [markdown]
#  Drop rows where either Drug1_Vector or Drug2_Vector is None

# %%
drug_pairs_df_test = drug_pairs_df_test.dropna(subset=['Drug1_Vector', 'Drug2_Vector'])

# %% [markdown]
# Add a new column 'Interaction_Label' with 1 for True and 0 for False in 'Interacting' column

# %%
drug_pairs_df_test['Interaction_Label'] = drug_pairs_df_test['Interacting'].astype(int)
# Out:
# C:\Users\manav\AppData\Local\Temp\ipykernel_31620\1479532307.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   drug_pairs_df_test['Interaction_Label'] = drug_pairs_df_test['Interacting'].astype(int)

# %%
drug_pairs_df_test = drug_pairs_df_test[drug_pairs_df_test['Drug1'] != drug_pairs_df_test['Drug2']]
drug_pairs_df_test
# Out:
#            Drug1       Drug2  Interacting  \
# 4     lamivudine  zidovudine        False
# 6     lamivudine  zidovudine        False
# 7     zidovudine  lamivudine        False
# 9     lamivudine  zidovudine        False
# 10    lamivudine  zidovudine        False
# ...          ...         ...          ...
# 5677  amlodipine   valsartan        False
# 5678  amlodipine   valsartan        False
# 5679  amlodipine   valsartan        False
# 5680  amlodipine   valsartan         True
# 5683  amlodipine   valsartan         True
#
#                                            Drug1_Vector  \
# 4     [-0.560792, 0.45971608, -0.16508591, 0.1751265...
# 6     [-0.560792, 0.45971608, -0.16508591, 0.1751265...
# 7     [-2.874584, 2.7705395, -0.25578862, 1.188521, ...
# 9     [-0.560792, 0.45971608, -0.16508591, 0.1751265...
# 10    [-0.560792, 0.45971608, -0.16508591, 0.1751265...
# ...                                                 ...
# 5677  [-1.4792998, 1.8820828, 0.51280457, -0.6054044...
# 5678  [-1.4792998, 1.8820828, 0.51280457, -0.6054044...
# 5679  [-1.4792998, 1.8820828, 0.51280457, -0.6054044...
# 5680  [-1.4792998, 1.8820828, 0.51280457, -0.6054044...
# 5683  [-1.4792998, 1.8820828, 0.51280457, -0.6054044...
#
#                                            Drug2_Vector  Interaction_Label
# 4     [-2.874584, 2.7705395, -0.25578862, 1.188521, ...                  0
# 6     [-2.874584, 2.7705395, -0.25578862, 1.188521, ...                  0
# 7     [-0.560792, 0.45971608, -0.16508591, 0.1751265...                  0
# 9     [-2.874584, 2.7705395, -0.25578862, 1.188521, ...                  0
# 10    [-2.874584, 2.7705395, -0.25578862, 1.188521, ...                  0
# ...                                                 ...                ...
# 5677  [0.063874006, 0.22589242, -0.1554339, 0.099802...                  0
# 5678  [0.063874006, 0.22589242, -0.1554339, 0.099802...                  0
# 5679  [0.063874006, 0.22589242, -0.1554339, 0.099802...                  0
# 5680  [0.063874006, 0.22589242, -0.1554339, 0.099802...                  1
# 5683  [0.063874006, 0.22589242, -0.1554339, 0.099802...                  1
#
# [1433 rows x 6 columns]

# %% [markdown]
# Check the number of false and true rows in the 'Interacting' column

# %%
interaction_counts = drug_pairs_df['Interacting'].value_counts()
print(interaction_counts)

interaction_counts_test = drug_pairs_df_test['Interacting'].value_counts()
print(interaction_counts_test)
# Out:
# Interacting
# False    7840
# True      934
# Name: count, dtype: int64
# Interacting
# False    1317
# True      116
# Name: count, dtype: int64

# %%
## Could you save the dataframes to csv files and load them in the future?
drug_pairs_df.to_csv('drug_pairs_df.csv', index=False)
drug_pairs_df_test.to_csv('drug_pairs_df_test.csv', index=False)

# %% [markdown]
# Plot a pie chart for the training dataset interactions and testing dataset interactions

# %%
fig, axs = plt.subplots(1, 2, figsize=(12, 6))


axs[0].pie(interaction_counts, labels=interaction_counts.index, autopct='%1.1f%%', startangle=90)
axs[0].set_title('Drug Interactions in Training Dataset')


axs[1].pie(interaction_counts_test, labels=interaction_counts_test.index, autopct='%1.1f%%', startangle=90)
axs[1].set_title('Drug Interactions in Testing Dataset')

plt.show()

# %% [markdown]
# ## Visualisation

# %%
tsne = TSNE(n_components=2, random_state=42)
drug_vectors_2d = tsne.fit_transform(drug_vectors_df)

drug_vectors_2d_df = pd.DataFrame(drug_vectors_2d, index=drug_vectors_df.index, columns=['x', 'y'])

# Plot the 2D vectors
plt.figure(figsize=(14, 10))
plt.scatter(drug_vectors_2d_df['x'], drug_vectors_2d_df['y'])

# Annotate points with drug names
for drug, (x, y) in drug_vectors_2d_df.iterrows():
    plt.text(x, y, drug, fontsize=9)

plt.title('t-SNE visualization of drug vectors')
plt.xlabel('Dimension 1')
plt.ylabel('Dimension 2')
plt.show()

# %% [markdown]
# ## **Training**

# %% [markdown]
# ### Logistic Regression, Decision Tree, Random Forest, SVM

# %%
# Filter out rows where Drug1 is the same as Drug2
drug_pairs_df = drug_pairs_df[drug_pairs_df['Drug1'] != drug_pairs_df['Drug2']]
drug_pairs_df_test = drug_pairs_df_test[drug_pairs_df_test['Drug1'] != drug_pairs_df_test['Drug2']]

# Function to combine vectors
def combine_vectors(row):
    drug1_vector = row['Drug1_Vector'] if row['Drug1_Vector'] is not None else []
    drug2_vector = row['Drug2_Vector'] if row['Drug2_Vector'] is not None else []
    return list(drug1_vector) + list(drug2_vector)

# Apply the function to create combined vectors
drug_pairs_df['Combined_Vector'] = drug_pairs_df.apply(combine_vectors, axis=1)
drug_pairs_df_test['Combined_Vector'] = drug_pairs_df_test.apply(combine_vectors, axis=1)

# Prepare the feature matrix and labels
X_train_full = list(drug_pairs_df['Combined_Vector'])
y_train_full = list(drug_pairs_df['Interaction_Label'])

X_test = list(drug_pairs_df_test['Combined_Vector'])
y_test = list(drug_pairs_df_test['Interaction_Label'])

# Handle imbalanced data
proportions = [1, 2, 3, 4, 5]  # Example proportions
recalls = []

for proportion in proportions:
    # Separate majority and minority samples in the training set
    X_minority = [X_train_full[i] for i in range(len(y_train_full)) if y_train_full[i] == 1]
    y_minority = [y_train_full[i] for i in range(len(y_train_full)) if y_train_full[i] == 1]
    
    X_majority = [X_train_full[i] for i in range(len(y_train_full)) if y_train_full[i] == 0]
    y_majority = [y_train_full[i] for i in range(len(y_train_full)) if y_train_full[i] == 0]
    
    # Sample majority class to balance the dataset
    

    n_minority = len(X_minority)
    n_majority = n_minority * proportion
    X_majority = X_majority[:n_majority]
    y_majority = y_majority[:n_majority]
    
    # Combine the sampled majority and minority data
    X_train_balanced = X_minority + X_majority
    y_train_balanced = y_minority + y_majority
    
    # Shuffle the data to ensure random distribution
    X_train_balanced, y_train_balanced = shuffle(X_train_balanced, y_train_balanced, random_state=42)
    
    # Define models
    models = {
        "Logistic Regression": LogisticRegression(max_iter=1000),
        "Decision Tree": DecisionTreeClassifier(),
        "Random Forest": RandomForestClassifier(),
        "SVM": SVC()
    }
    
    for model_name, model in models.items():
        # Train the model on the balanced subset
        model.fit(X_train_balanced, y_train_balanced)
        
        # Predict on the test set
        y_pred = model.predict(X_test)
        
        # Evaluate the model using recall for both classes
        recall_minority = recall_score(y_test, y_pred, pos_label=1)
        recall_majority = recall_score(y_test, y_pred, pos_label=0)
        recalls.append((model_name, proportion, recall_minority, recall_majority))
        print(f"{model_name} - Proportion {proportion}:1 - Recall (Minority): {recall_minority:.2f} - Recall (Majority): {recall_majority:.2f}")
        
        # Optional: print additional metrics
        print(f"Accuracy: {accuracy_score(y_test, y_pred):.2f}")
        print(classification_report(y_test, y_pred))

# Plot Recall vs Training Data Proportion for each model
plt.figure(figsize=(10, 6))
for model_name in models.keys():
    model_recalls_minority = [recall_minority for name, proportion, recall_minority, recall_majority in recalls if name == model_name]
    model_recalls_majority = [recall_majority for name, proportion, recall_minority, recall_majority in recalls if name == model_name]
    plt.plot(proportions, model_recalls_minority, marker='o', label=f"{model_name} (Minority)")
    plt.plot(proportions, model_recalls_majority, marker='x', label=f"{model_name} (Majority)")

plt.xlabel("Training Data Proportion (Majority:Minority)")
plt.ylabel("Recall on Test Set")
plt.title("Recall vs. Training Data Proportion")
plt.legend()
plt.grid(True)
plt.show()
# Out:
# Logistic Regression - Proportion 1:1 - Recall (Minority): 0.72 - Recall (Majority): 0.39
# Accuracy: 0.41
#               precision    recall  f1-score   support
#
#            0       0.94      0.39      0.55      1317
#            1       0.09      0.72      0.17       116
#
#     accuracy                           0.41      1433
#    macro avg       0.52      0.55      0.36      1433
# weighted avg       0.87      0.41      0.52      1433
#
# Decision Tree - Proportion 1:1 - Recall (Minority): 0.71 - Recall (Majority): 0.33
# Accuracy: 0.36
#               precision    recall  f1-score   support
#
#            0       0.93      0.33      0.48      1317
#            1       0.08      0.71      0.15       116
#
#     accuracy                           0.36      1433
#    macro avg       0.51      0.52      0.32      1433
# weighted avg       0.86      0.36      0.46      1433
#
# Random Forest - Proportion 1:1 - Recall (Minority): 0.86 - Recall (Majority): 0.26
# Accuracy: 0.31
#               precision    recall  f1-score   support
#
#            0       0.96      0.26      0.41      1317
#            1       0.09      0.86      0.17       116
#
#     accuracy                           0.31      1433
#    macro avg       0.52      0.56      0.29      1433
# weighted avg       0.89      0.31      0.39      1433
#
# SVM - Proportion 1:1 - Recall (Minority): 0.86 - Recall (Majority): 0.32
# Accuracy: 0.36
#               precision    recall  f1-score   support
#
#            0       0.96      0.32      0.48      1317
#            1       0.10      0.86      0.18       116
#
#     accuracy                           0.36      1433
#    macro avg       0.53      0.59      0.33      1433
# weighted avg       0.89      0.36      0.45      1433
#
# Logistic Regression - Proportion 2:1 - Recall (Minority): 0.47 - Recall (Majority): 0.64
# Accuracy: 0.63
#               precision    recall  f1-score   support
#
#            0       0.93      0.64      0.76      1317
#            1       0.10      0.47      0.17       116
#
#     accuracy                           0.63      1433
#    macro avg       0.52      0.55      0.46      1433
# weighted avg       0.86      0.63      0.71      1433
#
# Decision Tree - Proportion 2:1 - Recall (Minority): 0.57 - Recall (Majority): 0.59
# Accuracy: 0.59
#               precision    recall  f1-score   support
#
#            0       0.94      0.59      0.72      1317
#            1       0.11      0.57      0.18       116
#
#     accuracy                           0.59      1433
#    macro avg       0.52      0.58      0.45      1433
# weighted avg       0.87      0.59      0.68      1433
#
# Random Forest - Proportion 2:1 - Recall (Minority): 0.44 - Recall (Majority): 0.67
# Accuracy: 0.65
#               precision    recall  f1-score   support
#
#            0       0.93      0.67      0.78      1317
#            1       0.10      0.44      0.17       116
#
#     accuracy                           0.65      1433
#    macro avg       0.52      0.55      0.47      1433
# weighted avg       0.86      0.65      0.73      1433
#
# SVM - Proportion 2:1 - Recall (Minority): 0.38 - Recall (Majority): 0.73
# Accuracy: 0.70
#               precision    recall  f1-score   support
#
#            0       0.93      0.73      0.81      1317
#            1       0.11      0.38      0.17       116
#
#     accuracy                           0.70      1433
#    macro avg       0.52      0.55      0.49      1433
# weighted avg       0.86      0.70      0.76      1433
#
# Logistic Regression - Proportion 3:1 - Recall (Minority): 0.29 - Recall (Majority): 0.74
# Accuracy: 0.70
#               precision    recall  f1-score   support
#
#            0       0.92      0.74      0.82      1317
#            1       0.09      0.29      0.14       116
#
#     accuracy                           0.70      1433
#    macro avg       0.51      0.52      0.48      1433
# weighted avg       0.85      0.70      0.77      1433
#
# Decision Tree - Proportion 3:1 - Recall (Minority): 0.42 - Recall (Majority): 0.68
# Accuracy: 0.66
#               precision    recall  f1-score   support
#
#            0       0.93      0.68      0.79      1317
#            1       0.10      0.42      0.17       116
#
#     accuracy                           0.66      1433
#    macro avg       0.52      0.55      0.48      1433
# weighted avg       0.86      0.66      0.74      1433
#
# Random Forest - Proportion 3:1 - Recall (Minority): 0.32 - Recall (Majority): 0.75
# Accuracy: 0.71
#               precision    recall  f1-score   support
#
#            0       0.93      0.75      0.83      1317
#            1       0.10      0.32      0.15       116
#
#     accuracy                           0.71      1433
#    macro avg       0.51      0.53      0.49      1433
# weighted avg       0.86      0.71      0.77      1433
#
# SVM - Proportion 3:1 - Recall (Minority): 0.25 - Recall (Majority): 0.87
# Accuracy: 0.82
#               precision    recall  f1-score   support
#
#            0       0.93      0.87      0.90      1317
#            1       0.14      0.25      0.18       116
#
#     accuracy                           0.82      1433
#    macro avg       0.54      0.56      0.54      1433
# weighted avg       0.87      0.82      0.84      1433
#
# Logistic Regression - Proportion 4:1 - Recall (Minority): 0.12 - Recall (Majority): 0.89
# Accuracy: 0.82
#               precision    recall  f1-score   support
#
#            0       0.92      0.89      0.90      1317
#            1       0.08      0.12      0.10       116
#
#     accuracy                           0.82      1433
#    macro avg       0.50      0.50      0.50      1433
# weighted avg       0.85      0.82      0.84      1433
#
# Decision Tree - Proportion 4:1 - Recall (Minority): 0.34 - Recall (Majority): 0.80
# Accuracy: 0.77
#               precision    recall  f1-score   support
#
#            0       0.93      0.80      0.86      1317
#            1       0.13      0.34      0.19       116
#
#     accuracy                           0.77      1433
#    macro avg       0.53      0.57      0.53      1433
# weighted avg       0.87      0.77      0.81      1433
#
# Random Forest - Proportion 4:1 - Recall (Minority): 0.22 - Recall (Majority): 0.93
# Accuracy: 0.87
#               precision    recall  f1-score   support
#
#            0       0.93      0.93      0.93      1317
#            1       0.21      0.22      0.22       116
#
#     accuracy                           0.87      1433
#    macro avg       0.57      0.57      0.57      1433
# weighted avg       0.87      0.87      0.87      1433
#
# SVM - Proportion 4:1 - Recall (Minority): 0.11 - Recall (Majority): 0.96
# Accuracy: 0.89
#               precision    recall  f1-score   support
#
#            0       0.92      0.96      0.94      1317
#            1       0.19      0.11      0.14       116
#
#     accuracy                           0.89      1433
#    macro avg       0.56      0.54      0.54      1433
# weighted avg       0.87      0.89      0.88      1433
#
# Logistic Regression - Proportion 5:1 - Recall (Minority): 0.06 - Recall (Majority): 0.94
# Accuracy: 0.87
#               precision    recall  f1-score   support
#
#            0       0.92      0.94      0.93      1317
#            1       0.08      0.06      0.07       116
#
#     accuracy                           0.87      1433
#    macro avg       0.50      0.50      0.50      1433
# weighted avg       0.85      0.87      0.86      1433
#
# Decision Tree - Proportion 5:1 - Recall (Minority): 0.31 - Recall (Majority): 0.85
# Accuracy: 0.81
#               precision    recall  f1-score   support
#
#            0       0.93      0.85      0.89      1317
#            1       0.16      0.31      0.21       116
#
#     accuracy                           0.81      1433
#    macro avg       0.54      0.58      0.55      1433
# weighted avg       0.87      0.81      0.84      1433
#
# Random Forest - Proportion 5:1 - Recall (Minority): 0.16 - Recall (Majority): 0.97
# Accuracy: 0.90
#               precision    recall  f1-score   support
#
#            0       0.93      0.97      0.95      1317
#            1       0.29      0.16      0.21       116
#
#     accuracy                           0.90      1433
#    macro avg       0.61      0.56      0.58      1433
# weighted avg       0.88      0.90      0.89      1433
#
# SVM - Proportion 5:1 - Recall (Minority): 0.03 - Recall (Majority): 0.99
# Accuracy: 0.91
#               precision    recall  f1-score   support
#
#            0       0.92      0.99      0.95      1317
#            1       0.19      0.03      0.06       116
#
#     accuracy                           0.91      1433
#    macro avg       0.56      0.51      0.51      1433
# weighted avg       0.86      0.91      0.88      1433

# %% [markdown]
# ## XgBoost

# %%
# Drop rows where both Drug1 and Drug2 are the same
drug_pairs_df = drug_pairs_df[drug_pairs_df['Drug1'] != drug_pairs_df['Drug2']]
drug_pairs_df_test = drug_pairs_df_test[drug_pairs_df_test['Drug1'] != drug_pairs_df_test['Drug2']]

# Combine the vectors of Drug1 and Drug2 into a single feature vector
def combine_vectors(row):
    drug1_vector = row['Drug1_Vector'] if row['Drug1_Vector'] is not None else []
    drug2_vector = row['Drug2_Vector'] if row['Drug2_Vector'] is not None else []
    return list(drug1_vector) + list(drug2_vector)

drug_pairs_df['Combined_Vector'] = drug_pairs_df.apply(combine_vectors, axis=1)
drug_pairs_df_test['Combined_Vector'] = drug_pairs_df_test.apply(combine_vectors, axis=1)

# Prepare the feature matrix and labels
X_train_full = list(drug_pairs_df['Combined_Vector'])
y_train_full = list(drug_pairs_df['Interaction_Label'])

X_test = list(drug_pairs_df_test['Combined_Vector'])
y_test = list(drug_pairs_df_test['Interaction_Label'])

# Handle imbalanced data
proportions = [1, 2, 3, 4, 5]  # Example proportions
recalls = []

for proportion in proportions:
    # Separate majority and minority samples in the training set
    X_minority = [X_train_full[i] for i in range(len(y_train_full)) if y_train_full[i] == 1]
    y_minority = [y_train_full[i] for i in range(len(y_train_full)) if y_train_full[i] == 1]
    
    X_majority = [X_train_full[i] for i in range(len(y_train_full)) if y_train_full[i] == 0]
    y_majority = [y_train_full[i] for i in range(len(y_train_full)) if y_train_full[i] == 0]
    
    # Sample majority class to balance the dataset
    n_minority = len(X_minority)
    n_majority = n_minority * proportion
    X_majority = X_majority[:n_majority]
    y_majority = y_majority[:n_majority]
    
    # Combine the sampled majority and minority data
    X_train_balanced = X_minority + X_majority
    y_train_balanced = y_minority + y_majority
    
    # Shuffle the data to ensure random distribution
    X_train_balanced, y_train_balanced = shuffle(X_train_balanced, y_train_balanced, random_state=42)
    
    # Train an XGBoost model on the balanced subset
    model = xgb.XGBClassifier(use_label_encoder=False, eval_metric='logloss')
    model.fit(X_train_balanced, y_train_balanced)
    
    # Predict on the test set
    y_pred = model.predict(X_test)
    
    # Evaluate the model using recall for both classes
    recall_class_1 = recall_score(y_test, y_pred, pos_label=1)
    recall_class_0 = recall_score(y_test, y_pred, pos_label=0)
    recalls.append((proportion, recall_class_1, recall_class_0))
    
    print(f"XGBoost - Proportion {proportion}:1 - Recall Class 1: {recall_class_1:.2f}, Recall Class 0: {recall_class_0:.2f}")
    print(f"Accuracy: {accuracy_score(y_test, y_pred):.2f}")
    print(classification_report(y_test, y_pred))

# Plot Recall vs Training Data Proportion for XGBoost
plt.figure(figsize=(10, 6))
proportions, recall_scores_class_1, recall_scores_class_0 = zip(*recalls)
plt.plot(proportions, recall_scores_class_1, marker='o', label='XGBoost Class 1')
plt.plot(proportions, recall_scores_class_0, marker='o', label='XGBoost Class 0')

plt.xlabel("Training Data Proportion (Majority:Minority)")
plt.ylabel("Recall on Test Set")
plt.title("Recall vs. Training Data Proportion for XGBoost")
plt.legend()
plt.grid(True)
plt.show()
# Out:
# c:\Users\manav\OneDrive\Desktop\NIT Surathkal\Semester 7\IT-449\Drug-Drug-Interaction-and-Alternate-Recommendation-System\.venv\lib\site-packages\xgboost\core.py:158: UserWarning: [13:56:47] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0ed59c031377d09b8-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# XGBoost - Proportion 1:1 - Recall Class 1: 0.81, Recall Class 0: 0.29
# Accuracy: 0.33
#               precision    recall  f1-score   support
#
#            0       0.95      0.29      0.44      1317
#            1       0.09      0.81      0.16       116
#
#     accuracy                           0.33      1433
#    macro avg       0.52      0.55      0.30      1433
# weighted avg       0.88      0.33      0.42      1433
# c:\Users\manav\OneDrive\Desktop\NIT Surathkal\Semester 7\IT-449\Drug-Drug-Interaction-and-Alternate-Recommendation-System\.venv\lib\site-packages\xgboost\core.py:158: UserWarning: [13:56:48] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0ed59c031377d09b8-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# XGBoost - Proportion 2:1 - Recall Class 1: 0.53, Recall Class 0: 0.64
# Accuracy: 0.63
#               precision    recall  f1-score   support
#
#            0       0.94      0.64      0.76      1317
#            1       0.11      0.53      0.19       116
#
#     accuracy                           0.63      1433
#    macro avg       0.53      0.58      0.48      1433
# weighted avg       0.87      0.63      0.72      1433
# c:\Users\manav\OneDrive\Desktop\NIT Surathkal\Semester 7\IT-449\Drug-Drug-Interaction-and-Alternate-Recommendation-System\.venv\lib\site-packages\xgboost\core.py:158: UserWarning: [13:56:51] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0ed59c031377d09b8-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# XGBoost - Proportion 3:1 - Recall Class 1: 0.50, Recall Class 0: 0.72
# Accuracy: 0.70
#               precision    recall  f1-score   support
#
#            0       0.94      0.72      0.82      1317
#            1       0.14      0.50      0.22       116
#
#     accuracy                           0.70      1433
#    macro avg       0.54      0.61      0.52      1433
# weighted avg       0.88      0.70      0.77      1433
# c:\Users\manav\OneDrive\Desktop\NIT Surathkal\Semester 7\IT-449\Drug-Drug-Interaction-and-Alternate-Recommendation-System\.venv\lib\site-packages\xgboost\core.py:158: UserWarning: [13:56:53] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0ed59c031377d09b8-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# XGBoost - Proportion 4:1 - Recall Class 1: 0.27, Recall Class 0: 0.90
# Accuracy: 0.85
#               precision    recall  f1-score   support
#
#            0       0.93      0.90      0.92      1317
#            1       0.19      0.27      0.22       116
#
#     accuracy                           0.85      1433
#    macro avg       0.56      0.58      0.57      1433
# weighted avg       0.87      0.85      0.86      1433
# c:\Users\manav\OneDrive\Desktop\NIT Surathkal\Semester 7\IT-449\Drug-Drug-Interaction-and-Alternate-Recommendation-System\.venv\lib\site-packages\xgboost\core.py:158: UserWarning: [13:56:55] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0ed59c031377d09b8-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# XGBoost - Proportion 5:1 - Recall Class 1: 0.18, Recall Class 0: 0.94
# Accuracy: 0.88
#               precision    recall  f1-score   support
#
#            0       0.93      0.94      0.94      1317
#            1       0.22      0.18      0.20       116
#
#     accuracy                           0.88      1433
#    macro avg       0.58      0.56      0.57      1433
# weighted avg       0.87      0.88      0.88      1433

# %% [markdown]
# ### Using Anomaly Detection Models

# %%
import numpy as np
import pandas as pd
from sklearn.ensemble import IsolationForest
from sklearn.svm import OneClassSVM
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, classification_report

# Combine the vectors of Drug1 and Drug2 into a single feature vector
def combine_vectors(row):
    drug1_vector = row['Drug1_Vector'] if row['Drug1_Vector'] is not None else []
    drug2_vector = row['Drug2_Vector'] if row['Drug2_Vector'] is not None else []
    return list(drug1_vector) + list(drug2_vector)

drug_pairs_df['Combined_Vector'] = drug_pairs_df.apply(combine_vectors, axis=1)
drug_pairs_df_test['Combined_Vector'] = drug_pairs_df_test.apply(combine_vectors, axis=1)

# Prepare the feature matrix and labels
X_train = np.array(list(drug_pairs_df['Combined_Vector']))
y_train = np.array(drug_pairs_df['Interaction_Label'])

X_test = np.array(list(drug_pairs_df_test['Combined_Vector']))
y_test = np.array(drug_pairs_df_test['Interaction_Label'])

# Separate the majority class (normal) and minority class (anomalies)
X_train_normal = X_train[y_train == 0]
X_train_anomalies = X_train[y_train == 1]

# Train Isolation Forest
iso_forest = IsolationForest(contamination=len(X_train_anomalies)/len(X_train))
iso_forest.fit(X_train_normal)

# Train One-Class SVM
oc_svm = OneClassSVM(nu=len(X_train_anomalies)/len(X_train), kernel='rbf', gamma=0.1)
oc_svm.fit(X_train_normal)

# Predict using Isolation Forest
y_pred_iso_forest = iso_forest.predict(X_test)
y_pred_iso_forest = np.where(y_pred_iso_forest == 1, 0, 1)  # Convert 1 to 0 (normal) and -1 to 1 (anomaly)

# Predict using One-Class SVM
y_pred_oc_svm = oc_svm.predict(X_test)
y_pred_oc_svm = np.where(y_pred_oc_svm == 1, 0, 1)  # Convert 1 to 0 (normal) and -1 to 1 (anomaly)

# Evaluate the models
def evaluate_model(y_true, y_pred, model_name):
    accuracy = accuracy_score(y_true, y_pred)
    precision = precision_score(y_true, y_pred)
    recall = recall_score(y_true, y_pred)
    f1 = f1_score(y_true, y_pred)
    print(f"{model_name} - Accuracy: {accuracy:.2f}, Precision: {precision:.2f}, Recall: {recall:.2f}, F1-Score: {f1:.2f}")
    print(classification_report(y_true, y_pred))

evaluate_model(y_test, y_pred_iso_forest, "Isolation Forest")
evaluate_model(y_test, y_pred_oc_svm, "One-Class SVM")
# Out:
# Isolation Forest - Accuracy: 0.85, Precision: 0.09, Recall: 0.09, F1-Score: 0.09
#               precision    recall  f1-score   support
#
#            0       0.92      0.92      0.92      1317
#            1       0.09      0.09      0.09       116
#
#     accuracy                           0.85      1433
#    macro avg       0.51      0.51      0.51      1433
# weighted avg       0.85      0.85      0.85      1433
#
# One-Class SVM - Accuracy: 0.27, Precision: 0.09, Recall: 0.91, F1-Score: 0.17
#               precision    recall  f1-score   support
#
#            0       0.96      0.22      0.35      1317
#            1       0.09      0.91      0.17       116
#
#     accuracy                           0.27      1433
#    macro avg       0.53      0.56      0.26      1433
# weighted avg       0.89      0.27      0.34      1433

# %% [markdown]
# ### Neural Network

# %%
# Import necessary libraries
import numpy as np
import pandas as pd
from sklearn.utils import shuffle
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout
from tensorflow.keras.optimizers import Adam


# Combine the vectors of Drug1 and Drug2 into a single feature vector
def combine_vectors(row):
    drug1_vector = row['Drug1_Vector'] if row['Drug1_Vector'] is not None else []
    drug2_vector = row['Drug2_Vector'] if row['Drug2_Vector'] is not None else []
    return list(drug1_vector) + list(drug2_vector)

drug_pairs_df['Combined_Vector'] = drug_pairs_df.apply(combine_vectors, axis=1)
drug_pairs_df_test['Combined_Vector'] = drug_pairs_df_test.apply(combine_vectors, axis=1)

# Prepare the feature matrix and labels
X_test = np.array(list(drug_pairs_df_test['Combined_Vector']))
y_test = np.array(drug_pairs_df_test['Interaction_Label'])

# Define the neural network model
def create_model(input_dim):
    model = Sequential()
    model.add(Dense(128, input_dim=input_dim, activation='relu'))
    model.add(Dropout(0.5))
    model.add(Dense(64, activation='relu'))
    model.add(Dropout(0.5))
    model.add(Dense(1, activation='sigmoid'))
    model.compile(optimizer=Adam(learning_rate=0.001), loss='binary_crossentropy', metrics=['accuracy'])
    return model

# Handle imbalanced data
proportions = [1.5, 2, 2.5, 3]
metrics = []

for proportion in proportions:
    # Separate majority and minority samples in the training set
    X_minority = [X_train_full[i] for i in range(len(y_train_full)) if y_train_full[i] == 1]
    y_minority = [y_train_full[i] for i in range(len(y_train_full)) if y_train_full[i] == 1]
    
    X_majority = [X_train_full[i] for i in range(len(y_train_full)) if y_train_full[i] == 0]
    y_majority = [y_train_full[i] for i in range(len(y_train_full)) if y_train_full[i] == 0]
    
    # Sample majority class to balance the dataset
    n_minority = len(X_minority)
    n_majority = int(n_minority * proportion)
    X_majority = X_majority[:n_majority]
    y_majority = y_majority[:n_majority]
    
    # Combine the sampled majority and minority data
    X_train_balanced = X_minority + X_majority
    y_train_balanced = y_minority + y_majority
    
    # Shuffle the data to ensure random distribution
    X_train_balanced, y_train_balanced = shuffle(X_train_balanced, y_train_balanced, random_state=42)
    
    # Convert to numpy arrays
    X_train_balanced = np.array(X_train_balanced)
    y_train_balanced = np.array(y_train_balanced)
    
    # Create and train the model
    model = create_model(input_dim=X_train_balanced.shape[1])
    model.fit(X_train_balanced, y_train_balanced, epochs=50, batch_size=32, validation_split=0.2)
    
    # Predict on the test set
    y_pred = (model.predict(X_test) > 0.5).astype("int32")
    
    # Evaluate the model using multiple metrics
    accuracy = accuracy_score(y_test, y_pred)
    precision = precision_score(y_test, y_pred)
    recall = recall_score(y_test, y_pred)
    f1 = f1_score(y_test, y_pred)
    
    metrics.append({
        'proportion': proportion,
        'accuracy': accuracy,
        'precision': precision,
        'recall': recall,
        'f1_score': f1
    })
    
    print(f"Proportion {proportion}:1 - Accuracy: {accuracy:.2f}, Precision: {precision:.2f}, Recall: {recall:.2f}, F1-Score: {f1:.2f}")

# Print all metrics
print("Metrics for different proportions:")
for metric in metrics:
    print(metric)
# Out:
# c:\Users\manav\OneDrive\Desktop\NIT Surathkal\Semester 7\IT-449\Drug-Drug-Interaction-and-Alternate-Recommendation-System\.venv\lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Epoch 1/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.5512 - loss: 0.8979 - val_accuracy: 0.6938 - val_loss: 0.5925
# Epoch 2/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6050 - loss: 0.6825 - val_accuracy: 0.7430 - val_loss: 0.5619
# Epoch 3/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6676 - loss: 0.6079 - val_accuracy: 0.7537 - val_loss: 0.5149
# Epoch 4/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6973 - loss: 0.5648 - val_accuracy: 0.7901 - val_loss: 0.4847
# Epoch 5/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7541 - loss: 0.5118 - val_accuracy: 0.8094 - val_loss: 0.4580
# Epoch 6/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7783 - loss: 0.4762 - val_accuracy: 0.8051 - val_loss: 0.4431
# Epoch 7/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7521 - loss: 0.4890 - val_accuracy: 0.8094 - val_loss: 0.4271
# Epoch 8/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7961 - loss: 0.4393 - val_accuracy: 0.8051 - val_loss: 0.4251
# Epoch 9/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8064 - loss: 0.4216 - val_accuracy: 0.8180 - val_loss: 0.4009
# Epoch 10/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8117 - loss: 0.4253 - val_accuracy: 0.8266 - val_loss: 0.3835
# Epoch 11/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8268 - loss: 0.3952 - val_accuracy: 0.8266 - val_loss: 0.3729
# Epoch 12/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8254 - loss: 0.3654 - val_accuracy: 0.8137 - val_loss: 0.3684
# Epoch 13/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8312 - loss: 0.3645 - val_accuracy: 0.8266 - val_loss: 0.3723
# Epoch 14/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8571 - loss: 0.3433 - val_accuracy: 0.8415 - val_loss: 0.3571
# Epoch 15/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8639 - loss: 0.3262 - val_accuracy: 0.8330 - val_loss: 0.3509
# Epoch 16/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8648 - loss: 0.3173 - val_accuracy: 0.8437 - val_loss: 0.3379
# Epoch 17/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8666 - loss: 0.3067 - val_accuracy: 0.8480 - val_loss: 0.3343
# Epoch 18/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8659 - loss: 0.3074 - val_accuracy: 0.8480 - val_loss: 0.3294
# Epoch 19/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8773 - loss: 0.2920 - val_accuracy: 0.8630 - val_loss: 0.3278
# Epoch 20/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8693 - loss: 0.2960 - val_accuracy: 0.8630 - val_loss: 0.3199
# Epoch 21/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8867 - loss: 0.2617 - val_accuracy: 0.8522 - val_loss: 0.3299
# Epoch 22/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8974 - loss: 0.2557 - val_accuracy: 0.8608 - val_loss: 0.3361
# Epoch 23/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9070 - loss: 0.2543 - val_accuracy: 0.8437 - val_loss: 0.3521
# Epoch 24/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9007 - loss: 0.2257 - val_accuracy: 0.8522 - val_loss: 0.3324
# Epoch 25/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9119 - loss: 0.2127 - val_accuracy: 0.8458 - val_loss: 0.3499
# Epoch 26/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9110 - loss: 0.2268 - val_accuracy: 0.8437 - val_loss: 0.3490
# Epoch 27/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9031 - loss: 0.2218 - val_accuracy: 0.8501 - val_loss: 0.3414
# Epoch 28/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9126 - loss: 0.2329 - val_accuracy: 0.8587 - val_loss: 0.3513
# Epoch 29/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9148 - loss: 0.2117 - val_accuracy: 0.8651 - val_loss: 0.3499
# Epoch 30/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8989 - loss: 0.2158 - val_accuracy: 0.8672 - val_loss: 0.3480
# Epoch 31/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9077 - loss: 0.2031 - val_accuracy: 0.8715 - val_loss: 0.3360
# Epoch 32/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9296 - loss: 0.1900 - val_accuracy: 0.8608 - val_loss: 0.3689
# Epoch 33/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9419 - loss: 0.1675 - val_accuracy: 0.8608 - val_loss: 0.3550
# Epoch 34/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9233 - loss: 0.1816 - val_accuracy: 0.8672 - val_loss: 0.3616
# Epoch 35/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9302 - loss: 0.1744 - val_accuracy: 0.8608 - val_loss: 0.3627
# Epoch 36/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9433 - loss: 0.1598 - val_accuracy: 0.8651 - val_loss: 0.3699
# Epoch 37/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9304 - loss: 0.1754 - val_accuracy: 0.8651 - val_loss: 0.3685
# Epoch 38/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9283 - loss: 0.1712 - val_accuracy: 0.8672 - val_loss: 0.3591
# Epoch 39/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9306 - loss: 0.1751 - val_accuracy: 0.8608 - val_loss: 0.3855
# Epoch 40/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9340 - loss: 0.1668 - val_accuracy: 0.8630 - val_loss: 0.3852
# Epoch 41/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9261 - loss: 0.1712 - val_accuracy: 0.8694 - val_loss: 0.3589
# Epoch 42/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9472 - loss: 0.1441 - val_accuracy: 0.8565 - val_loss: 0.4062
# Epoch 43/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9415 - loss: 0.1539 - val_accuracy: 0.8715 - val_loss: 0.3803
# Epoch 44/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9412 - loss: 0.1538 - val_accuracy: 0.8630 - val_loss: 0.3940
# Epoch 45/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9336 - loss: 0.1633 - val_accuracy: 0.8672 - val_loss: 0.3783
# Epoch 46/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9478 - loss: 0.1419 - val_accuracy: 0.8779 - val_loss: 0.4064
# Epoch 47/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9457 - loss: 0.1570 - val_accuracy: 0.8565 - val_loss: 0.4234
# Epoch 48/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9417 - loss: 0.1578 - val_accuracy: 0.8672 - val_loss: 0.3913
# Epoch 49/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9423 - loss: 0.1420 - val_accuracy: 0.8651 - val_loss: 0.4122
# Epoch 50/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9447 - loss: 0.1291 - val_accuracy: 0.8565 - val_loss: 0.4379
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Proportion 1.5:1 - Accuracy: 0.52, Precision: 0.11, Recall: 0.70, F1-Score: 0.19
# Epoch 1/50
# c:\Users\manav\OneDrive\Desktop\NIT Surathkal\Semester 7\IT-449\Drug-Drug-Interaction-and-Alternate-Recommendation-System\.venv\lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.5761 - loss: 0.8813 - val_accuracy: 0.7380 - val_loss: 0.5731
# Epoch 2/50
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6646 - loss: 0.6266 - val_accuracy: 0.7451 - val_loss: 0.5467
# Epoch 3/50
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7072 - loss: 0.5845 - val_accuracy: 0.7611 - val_loss: 0.5251
# Epoch 4/50
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7245 - loss: 0.5583 - val_accuracy: 0.7594 - val_loss: 0.5044
# Epoch 5/50
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7423 - loss: 0.5264 - val_accuracy: 0.7665 - val_loss: 0.4914
# Epoch 6/50
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7512 - loss: 0.5202 - val_accuracy: 0.7807 - val_loss: 0.4844
# Epoch 7/50
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7657 - loss: 0.4876 - val_accuracy: 0.7790 - val_loss: 0.4540
# Epoch 8/50
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7700 - loss: 0.4770 - val_accuracy: 0.7843 - val_loss: 0.4437
# Epoch 9/50
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7788 - loss: 0.4695 - val_accuracy: 0.7914 - val_loss: 0.4414
# Epoch 10/50
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7687 - loss: 0.4503 - val_accuracy: 0.7914 - val_loss: 0.4310
# Epoch 11/50
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7911 - loss: 0.4377 - val_accuracy: 0.7914 - val_loss: 0.4252
# Epoch 12/50
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8089 - loss: 0.4121 - val_accuracy: 0.8057 - val_loss: 0.4155
# Epoch 13/50
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8150 - loss: 0.4125 - val_accuracy: 0.8111 - val_loss: 0.4001
# Epoch 14/50
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8136 - loss: 0.3952 - val_accuracy: 0.8146 - val_loss: 0.3951
# Epoch 15/50
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8441 - loss: 0.3609 - val_accuracy: 0.8128 - val_loss: 0.3889
# Epoch 16/50
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8304 - loss: 0.3847 - val_accuracy: 0.8200 - val_loss: 0.3883
# Epoch 17/50
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8312 - loss: 0.3620 - val_accuracy: 0.8075 - val_loss: 0.3864
# Epoch 18/50
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8515 - loss: 0.3434 - val_accuracy: 0.8217 - val_loss: 0.3927
# Epoch 19/50
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8532 - loss: 0.3328 - val_accuracy: 0.8164 - val_loss: 0.3777
# Epoch 20/50
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8347 - loss: 0.3500 - val_accuracy: 0.8182 - val_loss: 0.3829
# Epoch 21/50
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8562 - loss: 0.3274 - val_accuracy: 0.8146 - val_loss: 0.3832
# Epoch 22/50
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8554 - loss: 0.3264 - val_accuracy: 0.8128 - val_loss: 0.3731
# Epoch 23/50
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8929 - loss: 0.2762 - val_accuracy: 0.8200 - val_loss: 0.3982
# Epoch 24/50
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8659 - loss: 0.2988 - val_accuracy: 0.8217 - val_loss: 0.3855
# Epoch 25/50
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8685 - loss: 0.2918 - val_accuracy: 0.8111 - val_loss: 0.3868
# Epoch 26/50
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8654 - loss: 0.3020 - val_accuracy: 0.8164 - val_loss: 0.3805
# Epoch 27/50
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8941 - loss: 0.2586 - val_accuracy: 0.8217 - val_loss: 0.3738
# Epoch 28/50
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8855 - loss: 0.2721 - val_accuracy: 0.8271 - val_loss: 0.3854
# Epoch 29/50
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8871 - loss: 0.2618 - val_accuracy: 0.8289 - val_loss: 0.3864
# Epoch 30/50
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8911 - loss: 0.2474 - val_accuracy: 0.8200 - val_loss: 0.4049
# Epoch 31/50
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8891 - loss: 0.2591 - val_accuracy: 0.8271 - val_loss: 0.3725
# Epoch 32/50
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8903 - loss: 0.2541 - val_accuracy: 0.8307 - val_loss: 0.3825
# Epoch 33/50
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8976 - loss: 0.2369 - val_accuracy: 0.8360 - val_loss: 0.3765
# Epoch 34/50
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9053 - loss: 0.2266 - val_accuracy: 0.8253 - val_loss: 0.3831
# Epoch 35/50
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8931 - loss: 0.2393 - val_accuracy: 0.8253 - val_loss: 0.4016
# Epoch 36/50
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8908 - loss: 0.2497 - val_accuracy: 0.8200 - val_loss: 0.4127
# Epoch 37/50
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9093 - loss: 0.2144 - val_accuracy: 0.8307 - val_loss: 0.4096
# Epoch 38/50
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8947 - loss: 0.2358 - val_accuracy: 0.8324 - val_loss: 0.4304
# Epoch 39/50
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9069 - loss: 0.2485 - val_accuracy: 0.8271 - val_loss: 0.4036
# Epoch 40/50
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9070 - loss: 0.2246 - val_accuracy: 0.8360 - val_loss: 0.4059
# Epoch 41/50
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9099 - loss: 0.2172 - val_accuracy: 0.8520 - val_loss: 0.3802
# Epoch 42/50
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9077 - loss: 0.2174 - val_accuracy: 0.8342 - val_loss: 0.3959
# Epoch 43/50
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9230 - loss: 0.2000 - val_accuracy: 0.8289 - val_loss: 0.4106
# Epoch 44/50
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9143 - loss: 0.1944 - val_accuracy: 0.8217 - val_loss: 0.4456
# Epoch 45/50
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9138 - loss: 0.2032 - val_accuracy: 0.8360 - val_loss: 0.4415
# Epoch 46/50
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9194 - loss: 0.1882 - val_accuracy: 0.8342 - val_loss: 0.4146
# Epoch 47/50
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9230 - loss: 0.1952 - val_accuracy: 0.8414 - val_loss: 0.4224
# Epoch 48/50
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9353 - loss: 0.1699 - val_accuracy: 0.8467 - val_loss: 0.4331
# Epoch 49/50
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9200 - loss: 0.1917 - val_accuracy: 0.8324 - val_loss: 0.4291
# Epoch 50/50
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9213 - loss: 0.1820 - val_accuracy: 0.8360 - val_loss: 0.4543
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# Proportion 2:1 - Accuracy: 0.55, Precision: 0.10, Recall: 0.54, F1-Score: 0.16
# Epoch 1/50
# c:\Users\manav\OneDrive\Desktop\NIT Surathkal\Semester 7\IT-449\Drug-Drug-Interaction-and-Alternate-Recommendation-System\.venv\lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.6385 - loss: 0.8797 - val_accuracy: 0.7584 - val_loss: 0.5557
# Epoch 2/50
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7022 - loss: 0.6123 - val_accuracy: 0.7722 - val_loss: 0.5306
# Epoch 3/50
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7406 - loss: 0.5676 - val_accuracy: 0.7722 - val_loss: 0.5098
# Epoch 4/50
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7330 - loss: 0.5446 - val_accuracy: 0.7890 - val_loss: 0.4865
# Epoch 5/50
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7734 - loss: 0.4968 - val_accuracy: 0.7951 - val_loss: 0.4798
# Epoch 6/50
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7739 - loss: 0.4973 - val_accuracy: 0.8012 - val_loss: 0.4562
# Epoch 7/50
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7895 - loss: 0.4743 - val_accuracy: 0.7890 - val_loss: 0.4411
# Epoch 8/50
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8160 - loss: 0.4254 - val_accuracy: 0.7997 - val_loss: 0.4398
# Epoch 9/50
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8022 - loss: 0.4143 - val_accuracy: 0.7997 - val_loss: 0.4307
# Epoch 10/50
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8047 - loss: 0.4220 - val_accuracy: 0.8119 - val_loss: 0.4243
# Epoch 11/50
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8310 - loss: 0.3900 - val_accuracy: 0.8104 - val_loss: 0.4111
# Epoch 12/50
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8294 - loss: 0.3990 - val_accuracy: 0.8104 - val_loss: 0.4040
# Epoch 13/50
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8404 - loss: 0.3602 - val_accuracy: 0.8089 - val_loss: 0.4119
# Epoch 14/50
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8323 - loss: 0.3750 - val_accuracy: 0.8150 - val_loss: 0.4191
# Epoch 15/50
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8446 - loss: 0.3715 - val_accuracy: 0.8242 - val_loss: 0.3953
# Epoch 16/50
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8377 - loss: 0.3533 - val_accuracy: 0.8150 - val_loss: 0.3964
# Epoch 17/50
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8546 - loss: 0.3313 - val_accuracy: 0.8058 - val_loss: 0.3934
# Epoch 18/50
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8736 - loss: 0.3128 - val_accuracy: 0.8242 - val_loss: 0.3959
# Epoch 19/50
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8507 - loss: 0.3263 - val_accuracy: 0.8303 - val_loss: 0.3879
# Epoch 20/50
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8702 - loss: 0.2948 - val_accuracy: 0.8073 - val_loss: 0.4028
# Epoch 21/50
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8554 - loss: 0.3135 - val_accuracy: 0.8257 - val_loss: 0.3944
# Epoch 22/50
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8653 - loss: 0.2949 - val_accuracy: 0.8257 - val_loss: 0.3970
# Epoch 23/50
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8786 - loss: 0.2984 - val_accuracy: 0.8349 - val_loss: 0.3981
# Epoch 24/50
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8806 - loss: 0.2678 - val_accuracy: 0.8318 - val_loss: 0.4066
# Epoch 25/50
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8838 - loss: 0.2750 - val_accuracy: 0.8287 - val_loss: 0.4012
# Epoch 26/50
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8819 - loss: 0.2596 - val_accuracy: 0.8379 - val_loss: 0.3998
# Epoch 27/50
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8739 - loss: 0.2709 - val_accuracy: 0.8379 - val_loss: 0.3957
# Epoch 28/50
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8920 - loss: 0.2464 - val_accuracy: 0.8287 - val_loss: 0.4210
# Epoch 29/50
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8872 - loss: 0.2531 - val_accuracy: 0.8471 - val_loss: 0.4126
# Epoch 30/50
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8989 - loss: 0.2365 - val_accuracy: 0.8394 - val_loss: 0.4188
# Epoch 31/50
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9038 - loss: 0.2296 - val_accuracy: 0.8303 - val_loss: 0.4251
# Epoch 32/50
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8925 - loss: 0.2475 - val_accuracy: 0.8364 - val_loss: 0.4177
# Epoch 33/50
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8946 - loss: 0.2430 - val_accuracy: 0.8394 - val_loss: 0.4124
# Epoch 34/50
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9035 - loss: 0.2210 - val_accuracy: 0.8364 - val_loss: 0.4137
# Epoch 35/50
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8992 - loss: 0.2304 - val_accuracy: 0.8394 - val_loss: 0.4364
# Epoch 36/50
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9167 - loss: 0.2124 - val_accuracy: 0.8425 - val_loss: 0.4399
# Epoch 37/50
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9115 - loss: 0.2070 - val_accuracy: 0.8532 - val_loss: 0.4175
# Epoch 38/50
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9008 - loss: 0.2174 - val_accuracy: 0.8517 - val_loss: 0.4279
# Epoch 39/50
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9267 - loss: 0.1904 - val_accuracy: 0.8364 - val_loss: 0.4611
# Epoch 40/50
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9095 - loss: 0.1909 - val_accuracy: 0.8394 - val_loss: 0.4565
# Epoch 41/50
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9154 - loss: 0.1907 - val_accuracy: 0.8379 - val_loss: 0.4641
# Epoch 42/50
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8977 - loss: 0.2159 - val_accuracy: 0.8379 - val_loss: 0.4528
# Epoch 43/50
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9042 - loss: 0.2016 - val_accuracy: 0.8486 - val_loss: 0.4778
# Epoch 44/50
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9010 - loss: 0.2167 - val_accuracy: 0.8425 - val_loss: 0.4536
# Epoch 45/50
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9167 - loss: 0.1887 - val_accuracy: 0.8287 - val_loss: 0.4520
# Epoch 46/50
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9134 - loss: 0.1901 - val_accuracy: 0.8410 - val_loss: 0.4470
# Epoch 47/50
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9165 - loss: 0.1804 - val_accuracy: 0.8440 - val_loss: 0.4599
# Epoch 48/50
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9244 - loss: 0.1796 - val_accuracy: 0.8425 - val_loss: 0.4623
# Epoch 49/50
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9140 - loss: 0.1875 - val_accuracy: 0.8410 - val_loss: 0.4738
# Epoch 50/50
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9221 - loss: 0.1747 - val_accuracy: 0.8517 - val_loss: 0.4688
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# Proportion 2.5:1 - Accuracy: 0.62, Precision: 0.11, Recall: 0.51, F1-Score: 0.18
# Epoch 1/50
# c:\Users\manav\OneDrive\Desktop\NIT Surathkal\Semester 7\IT-449\Drug-Drug-Interaction-and-Alternate-Recommendation-System\.venv\lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.6910 - loss: 0.6981 - val_accuracy: 0.7861 - val_loss: 0.5123
# Epoch 2/50
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7389 - loss: 0.5699 - val_accuracy: 0.8128 - val_loss: 0.5041
# Epoch 3/50
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7544 - loss: 0.5303 - val_accuracy: 0.8035 - val_loss: 0.4751
# Epoch 4/50
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7894 - loss: 0.4961 - val_accuracy: 0.8142 - val_loss: 0.4567
# Epoch 5/50
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7935 - loss: 0.4701 - val_accuracy: 0.8155 - val_loss: 0.4422
# Epoch 6/50
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8029 - loss: 0.4511 - val_accuracy: 0.8302 - val_loss: 0.4272
# Epoch 7/50
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8111 - loss: 0.4493 - val_accuracy: 0.8262 - val_loss: 0.4094
# Epoch 8/50
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8147 - loss: 0.4192 - val_accuracy: 0.8222 - val_loss: 0.4007
# Epoch 9/50
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8259 - loss: 0.3919 - val_accuracy: 0.8342 - val_loss: 0.4005
# Epoch 10/50
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8312 - loss: 0.3878 - val_accuracy: 0.8422 - val_loss: 0.3814
# Epoch 11/50
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8372 - loss: 0.3694 - val_accuracy: 0.8316 - val_loss: 0.3854
# Epoch 12/50
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8411 - loss: 0.3596 - val_accuracy: 0.8476 - val_loss: 0.3790
# Epoch 13/50
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8492 - loss: 0.3489 - val_accuracy: 0.8409 - val_loss: 0.3781
# Epoch 14/50
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8596 - loss: 0.3425 - val_accuracy: 0.8382 - val_loss: 0.3724
# Epoch 15/50
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8486 - loss: 0.3347 - val_accuracy: 0.8489 - val_loss: 0.3836
# Epoch 16/50
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8687 - loss: 0.3018 - val_accuracy: 0.8422 - val_loss: 0.3741
# Epoch 17/50
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8570 - loss: 0.3132 - val_accuracy: 0.8543 - val_loss: 0.3696
# Epoch 18/50
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8719 - loss: 0.2877 - val_accuracy: 0.8556 - val_loss: 0.3720
# Epoch 19/50
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8718 - loss: 0.3014 - val_accuracy: 0.8556 - val_loss: 0.3815
# Epoch 20/50
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8656 - loss: 0.2818 - val_accuracy: 0.8516 - val_loss: 0.3708
# Epoch 21/50
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8749 - loss: 0.2860 - val_accuracy: 0.8570 - val_loss: 0.3820
# Epoch 22/50
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8899 - loss: 0.2620 - val_accuracy: 0.8570 - val_loss: 0.3820
# Epoch 23/50
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8848 - loss: 0.2636 - val_accuracy: 0.8409 - val_loss: 0.3905
# Epoch 24/50
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8870 - loss: 0.2551 - val_accuracy: 0.8543 - val_loss: 0.3770
# Epoch 25/50
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8861 - loss: 0.2620 - val_accuracy: 0.8529 - val_loss: 0.3974
# Epoch 26/50
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8883 - loss: 0.2483 - val_accuracy: 0.8610 - val_loss: 0.3910
# Epoch 27/50
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8965 - loss: 0.2437 - val_accuracy: 0.8623 - val_loss: 0.3743
# Epoch 28/50
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9166 - loss: 0.2238 - val_accuracy: 0.8610 - val_loss: 0.4085
# Epoch 29/50
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8916 - loss: 0.2479 - val_accuracy: 0.8422 - val_loss: 0.3926
# Epoch 30/50
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9062 - loss: 0.2215 - val_accuracy: 0.8570 - val_loss: 0.4075
# Epoch 31/50
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9084 - loss: 0.2213 - val_accuracy: 0.8489 - val_loss: 0.4035
# Epoch 32/50
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9246 - loss: 0.1974 - val_accuracy: 0.8623 - val_loss: 0.4238
# Epoch 33/50
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8974 - loss: 0.2260 - val_accuracy: 0.8650 - val_loss: 0.4140
# Epoch 34/50
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9089 - loss: 0.2142 - val_accuracy: 0.8610 - val_loss: 0.4102
# Epoch 35/50
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9165 - loss: 0.1957 - val_accuracy: 0.8503 - val_loss: 0.4283
# Epoch 36/50
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9188 - loss: 0.1966 - val_accuracy: 0.8610 - val_loss: 0.3912
# Epoch 37/50
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9206 - loss: 0.1844 - val_accuracy: 0.8583 - val_loss: 0.4533
# Epoch 38/50
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9180 - loss: 0.1972 - val_accuracy: 0.8529 - val_loss: 0.4501
# Epoch 39/50
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9195 - loss: 0.1877 - val_accuracy: 0.8650 - val_loss: 0.3988
# Epoch 40/50
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9297 - loss: 0.1841 - val_accuracy: 0.8690 - val_loss: 0.4100
# Epoch 41/50
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9298 - loss: 0.1733 - val_accuracy: 0.8663 - val_loss: 0.4237
# Epoch 42/50
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9240 - loss: 0.1963 - val_accuracy: 0.8676 - val_loss: 0.4787
# Epoch 43/50
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9222 - loss: 0.1834 - val_accuracy: 0.8529 - val_loss: 0.4380
# Epoch 44/50
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9275 - loss: 0.1732 - val_accuracy: 0.8543 - val_loss: 0.4679
# Epoch 45/50
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9307 - loss: 0.1715 - val_accuracy: 0.8556 - val_loss: 0.4542
# Epoch 46/50
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9096 - loss: 0.1867 - val_accuracy: 0.8690 - val_loss: 0.4390
# Epoch 47/50
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9191 - loss: 0.1819 - val_accuracy: 0.8556 - val_loss: 0.4579
# Epoch 48/50
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9358 - loss: 0.1601 - val_accuracy: 0.8583 - val_loss: 0.4596
# Epoch 49/50
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9212 - loss: 0.1811 - val_accuracy: 0.8596 - val_loss: 0.4616
# Epoch 50/50
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9385 - loss: 0.1601 - val_accuracy: 0.8623 - val_loss: 0.4898
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Proportion 3:1 - Accuracy: 0.65, Precision: 0.12, Recall: 0.52, F1-Score: 0.19
# Metrics for different proportions:
# {'proportion': 1.5, 'accuracy': 0.5177948360083741, 'precision': 0.10990502035278155, 'recall': 0.6982758620689655, 'f1_score': 0.1899179366940211}
# {'proportion': 2, 'accuracy': 0.5526866713189114, 'precision': 0.0967741935483871, 'recall': 0.5431034482758621, 'f1_score': 0.16427640156453716}
# {'proportion': 2.5, 'accuracy': 0.6245638520586183, 'precision': 0.10925925925925926, 'recall': 0.5086206896551724, 'f1_score': 0.1798780487804878}
# {'proportion': 3, 'accuracy': 0.6482903000697837, 'precision': 0.11811023622047244, 'recall': 0.5172413793103449, 'f1_score': 0.19230769230769232}

# %%
drug_pairs_df
# drop the interacting column and combined vector column
drug_pairs_df = drug_pairs_df.drop(columns=['Interacting', 'Combined_Vector'])
drug_pairs_df_test = drug_pairs_df_test.drop(columns=['Interacting', 'Combined_Vector'])

# %%
# now put each element in the vector in a seperate column
drug_pairs_df = pd.concat([drug_pairs_df, pd.DataFrame(drug_pairs_df['Drug1_Vector'].tolist(), index=drug_pairs_df.index)], axis=1)
drug_pairs_df = pd.concat([drug_pairs_df, pd.DataFrame(drug_pairs_df['Drug2_Vector'].tolist(), index=drug_pairs_df.index)], axis=1)

drug_pairs_df_test = pd.concat([drug_pairs_df_test, pd.DataFrame(drug_pairs_df_test['Drug1_Vector'].tolist(), index=drug_pairs_df_test.index)], axis=1)
drug_pairs_df_test = pd.concat([drug_pairs_df_test, pd.DataFrame(drug_pairs_df_test['Drug2_Vector'].tolist(), index=drug_pairs_df_test.index)], axis=1)

drug_pairs_df

# drop the drug1_vector and drug2_vector columns
drug_pairs_df = drug_pairs_df.drop(columns=['Drug1_Vector', 'Drug2_Vector'])
drug_pairs_df_test = drug_pairs_df_test.drop(columns=['Drug1_Vector', 'Drug2_Vector'])

drug_pairs_df
# Out:
#               Drug1               Drug2  Interaction_Label         0  \
# 56     azathioprine         chloroquine                  0 -1.758114
# 57     azathioprine                gold                  0 -1.758114
# 58     azathioprine  hydroxychloroquine                  0 -1.758114
# 59     azathioprine         leflunomide                  0 -1.758114
# 60     azathioprine       sulfasalazine                  0 -1.758114
# ...             ...                 ...                ...       ...
# 27781    atracurium          gentamycin                  0 -0.596157
# 27782    atracurium          gentamycin                  1 -0.596157
# 27783    gentamycin          atracurium                  1 -3.880826
# 27784     temazepam             ethanol                  1 -1.570436
# 27789     temazepam             ethanol                  1 -1.570436
#
#               1         2         3         4         5         6  ...  \
# 56     1.765694 -0.809791 -0.463783 -0.266910 -2.708471 -2.522802  ...
# 57     1.765694 -0.809791 -0.463783 -0.266910 -2.708471 -2.522802  ...
# 58     1.765694 -0.809791 -0.463783 -0.266910 -2.708471 -2.522802  ...
# 59     1.765694 -0.809791 -0.463783 -0.266910 -2.708471 -2.522802  ...
# 60     1.765694 -0.809791 -0.463783 -0.266910 -2.708471 -2.522802  ...
# ...         ...       ...       ...       ...       ...       ...  ...
# 27781  0.768044  0.100068  0.445121 -0.348493 -0.423195 -0.691468  ...
# 27782  0.768044  0.100068  0.445121 -0.348493 -0.423195 -0.691468  ...
# 27783  3.044013 -0.279876  1.860366  0.554343 -1.678261  1.669158  ...
# 27784 -0.409908  1.008917 -1.119097  0.743915 -1.381125  0.803105  ...
# 27789 -0.409908  1.008917 -1.119097  0.743915 -1.381125  0.803105  ...
#
#              90        91        92        93        94        95        96  \
# 56     0.609182 -1.103451 -0.674822  0.447816 -1.713301  4.287992 -1.402226
# 57    -0.729576  0.364601  2.710251 -0.833248  1.185086  1.631089 -0.814780
# 58    -0.275613 -0.838406  0.843947  0.213685  0.384436  1.972222 -0.349594
# 59     0.662011 -0.680997 -0.601133  0.480509 -0.333032  0.075027  0.277612
# 60     0.010073 -0.144867  0.196258  0.794556  1.154247  1.096374 -2.615438
# ...         ...       ...       ...       ...       ...       ...       ...
# 27781  0.512056 -0.594453  1.091237 -0.764489 -0.556747  0.720983  0.530436
# 27782  0.512056 -0.594453  1.091237 -0.764489 -0.556747  0.720983  0.530436
# 27783  1.003237 -0.423746  0.609023  0.229881 -0.473903  1.382695 -2.111334
# 27784  2.523526  0.718531  1.174054 -0.620758 -1.036825  1.218856 -3.293271
# 27789  2.523526  0.718531  1.174054 -0.620758 -1.036825  1.218856 -3.293271
#
#              97        98        99
# 56     0.362941 -0.572616 -0.255392
# 57     1.661161  1.535915 -0.144224
# 58     0.379735 -0.623572  0.896211
# 59     0.365707  0.632011  0.561221
# 60     0.366685 -1.264366  0.142015
# ...         ...       ...       ...
# 27781  0.658089 -0.250704  0.805319
# 27782  0.658089 -0.250704  0.805319
# 27783 -1.018444 -0.552565  0.552426
# 27784 -2.935991  0.644816  1.567771
# 27789 -2.935991  0.644816  1.567771
#
# [8774 rows x 203 columns]

# %%
# Drop rows where both Drug1 and Drug2 are the same
drug_pairs_df = drug_pairs_df[drug_pairs_df['Drug1'] != drug_pairs_df['Drug2']]
drug_pairs_df_test = drug_pairs_df_test[drug_pairs_df_test['Drug1'] != drug_pairs_df_test['Drug2']]

# Select feature columns for both Drug1 and Drug2 vectors
# Assuming Drug1 vector columns start at index 4 and Drug2 at index 54 in your DataFrame
X_train_full = drug_pairs_df.iloc[:, 3:].values  # All vector columns
y_train_full = drug_pairs_df['Interaction_Label'].values

X_test = drug_pairs_df_test.iloc[:, 3:].values
y_test = drug_pairs_df_test['Interaction_Label'].values

# Handle imbalanced data
proportions = [1, 2, 3, 4, 5]  # Example proportions
recalls = []

for proportion in proportions:
    # Separate majority and minority samples in the training set
    X_minority = X_train_full[y_train_full == 1]
    y_minority = y_train_full[y_train_full == 1]
    
    X_majority = X_train_full[y_train_full == 0]
    y_majority = y_train_full[y_train_full == 0]
    
    # Sample majority class to balance the dataset
    n_minority = len(X_minority)
    n_majority = n_minority * proportion
    X_majority_sampled = X_majority[:n_majority]
    y_majority_sampled = y_majority[:n_majority]
    
    # Combine the sampled majority and minority data
    X_train_balanced = np.vstack((X_minority, X_majority_sampled))
    y_train_balanced = np.concatenate((y_minority, y_majority_sampled))
    
    # Shuffle the data to ensure random distribution
    X_train_balanced, y_train_balanced = shuffle(X_train_balanced, y_train_balanced, random_state=42)
    
    # Train an XGBoost model on the balanced subset
    model = xgb.XGBClassifier(use_label_encoder=False, eval_metric='logloss')
    model.fit(X_train_balanced, y_train_balanced)
    
    # Predict on the test set
    y_pred = model.predict(X_test)
    
    # Evaluate the model using recall for both classes
    recall_class_1 = recall_score(y_test, y_pred, pos_label=1)
    recall_class_0 = recall_score(y_test, y_pred, pos_label=0)
    recalls.append((proportion, recall_class_1, recall_class_0))
    
    print(f"XGBoost - Proportion {proportion}:1 - Recall Class 1: {recall_class_1:.2f}, Recall Class 0: {recall_class_0:.2f}")
    print(f"Accuracy: {accuracy_score(y_test, y_pred):.2f}")
    print(classification_report(y_test, y_pred))

# Plot Recall vs Training Data Proportion for XGBoost
plt.figure(figsize=(10, 6))
proportions, recall_scores_class_1, recall_scores_class_0 = zip(*recalls)
plt.plot(proportions, recall_scores_class_1, marker='o', label='XGBoost Class 1')
plt.plot(proportions, recall_scores_class_0, marker='o', label='XGBoost Class 0')

plt.xlabel("Training Data Proportion (Majority:Minority)")
plt.ylabel("Recall on Test Set")
plt.title("Recall vs. Training Data Proportion for XGBoost")
plt.legend()
plt.grid(True)
plt.show()
# Out:
# c:\Users\manav\OneDrive\Desktop\NIT Surathkal\Semester 7\IT-449\Drug-Drug-Interaction-and-Alternate-Recommendation-System\.venv\lib\site-packages\xgboost\core.py:158: UserWarning: [13:57:59] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0ed59c031377d09b8-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# XGBoost - Proportion 1:1 - Recall Class 1: 0.81, Recall Class 0: 0.29
# Accuracy: 0.33
#               precision    recall  f1-score   support
#
#            0       0.95      0.29      0.44      1317
#            1       0.09      0.81      0.16       116
#
#     accuracy                           0.33      1433
#    macro avg       0.52      0.55      0.30      1433
# weighted avg       0.88      0.33      0.42      1433
# c:\Users\manav\OneDrive\Desktop\NIT Surathkal\Semester 7\IT-449\Drug-Drug-Interaction-and-Alternate-Recommendation-System\.venv\lib\site-packages\xgboost\core.py:158: UserWarning: [13:58:01] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0ed59c031377d09b8-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# XGBoost - Proportion 2:1 - Recall Class 1: 0.53, Recall Class 0: 0.64
# Accuracy: 0.63
#               precision    recall  f1-score   support
#
#            0       0.94      0.64      0.76      1317
#            1       0.11      0.53      0.19       116
#
#     accuracy                           0.63      1433
#    macro avg       0.53      0.58      0.48      1433
# weighted avg       0.87      0.63      0.72      1433
# c:\Users\manav\OneDrive\Desktop\NIT Surathkal\Semester 7\IT-449\Drug-Drug-Interaction-and-Alternate-Recommendation-System\.venv\lib\site-packages\xgboost\core.py:158: UserWarning: [13:58:03] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0ed59c031377d09b8-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# XGBoost - Proportion 3:1 - Recall Class 1: 0.50, Recall Class 0: 0.72
# Accuracy: 0.70
#               precision    recall  f1-score   support
#
#            0       0.94      0.72      0.82      1317
#            1       0.14      0.50      0.22       116
#
#     accuracy                           0.70      1433
#    macro avg       0.54      0.61      0.52      1433
# weighted avg       0.88      0.70      0.77      1433
# c:\Users\manav\OneDrive\Desktop\NIT Surathkal\Semester 7\IT-449\Drug-Drug-Interaction-and-Alternate-Recommendation-System\.venv\lib\site-packages\xgboost\core.py:158: UserWarning: [13:58:05] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0ed59c031377d09b8-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# XGBoost - Proportion 4:1 - Recall Class 1: 0.27, Recall Class 0: 0.90
# Accuracy: 0.85
#               precision    recall  f1-score   support
#
#            0       0.93      0.90      0.92      1317
#            1       0.19      0.27      0.22       116
#
#     accuracy                           0.85      1433
#    macro avg       0.56      0.58      0.57      1433
# weighted avg       0.87      0.85      0.86      1433
# c:\Users\manav\OneDrive\Desktop\NIT Surathkal\Semester 7\IT-449\Drug-Drug-Interaction-and-Alternate-Recommendation-System\.venv\lib\site-packages\xgboost\core.py:158: UserWarning: [13:58:07] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0ed59c031377d09b8-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# XGBoost - Proportion 5:1 - Recall Class 1: 0.18, Recall Class 0: 0.94
# Accuracy: 0.88
#               precision    recall  f1-score   support
#
#            0       0.93      0.94      0.94      1317
#            1       0.22      0.18      0.20       116
#
#     accuracy                           0.88      1433
#    macro avg       0.58      0.56      0.57      1433
# weighted avg       0.87      0.88      0.88      1433

# %%
# Define a function to create the MLP model
def create_mlp_model(input_dim):
    model = Sequential()
    model.add(Dense(200, input_dim=input_dim, activation='relu'))
    model.add(Dense(128, activation='relu'))
    model.add(Dropout(0.3))  # Dropout layer for regularization
    model.add(Dense(64, activation='relu'))
    model.add(Dropout(0.3))

    model.add(Dense(1, activation='sigmoid'))  # Binary classification output layer
    
    model.compile(optimizer=Adam(), loss='binary_crossentropy', metrics=['accuracy'])
    return model

# Assuming Drug1 and Drug2 vectors combined result in 200 features
input_dim = 200  

# List to store recall results for each proportion
recalls = []

# Loop through different proportions for balancing
proportions = [1, 2, 3, 4, 5, 6]  # Example proportions
for proportion in proportions:
    # Separate majority and minority samples in the training set
    X_minority = X_train_full[y_train_full == 1]
    y_minority = y_train_full[y_train_full == 1]
    
    X_majority = X_train_full[y_train_full == 0]
    y_majority = y_train_full[y_train_full == 0]
    
    # Sample majority class to balance the dataset
    n_minority = len(X_minority)
    n_majority = n_minority * proportion
    X_majority_sampled = X_majority[:n_majority]
    y_majority_sampled = y_majority[:n_majority]
    
    # Combine the sampled majority and minority data
    X_train_balanced = np.vstack((X_minority, X_majority_sampled))
    y_train_balanced = np.concatenate((y_minority, y_majority_sampled))
    
    # Shuffle the data
    X_train_balanced, y_train_balanced = shuffle(X_train_balanced, y_train_balanced, random_state=42)
    
    # Create and train the MLP model
    model = create_mlp_model(input_dim)
    model.fit(X_train_balanced, y_train_balanced, epochs=20, batch_size=32, verbose=0)
    
    # Predict on the test set
    y_pred = (model.predict(X_test) > 0.5).astype("int32")
    
    # Evaluate recall for both classes
    recall_class_1 = recall_score(y_test, y_pred, pos_label=1)
    recall_class_0 = recall_score(y_test, y_pred, pos_label=0)
    recalls.append((proportion, recall_class_1, recall_class_0))
    
    print(f"MLP - Proportion {proportion}:1 - Recall Class 1: {recall_class_1:.2f}, Recall Class 0: {recall_class_0:.2f}")
    print(f"Accuracy: {accuracy_score(y_test, y_pred):.2f}")
    print(classification_report(y_test, y_pred))

# Plot Recall vs Training Data Proportion for MLP
plt.figure(figsize=(10, 6))
proportions, recall_scores_class_1, recall_scores_class_0 = zip(*recalls)
plt.plot(proportions, recall_scores_class_1, marker='o', label='MLP Class 1')
plt.plot(proportions, recall_scores_class_0, marker='o', label='MLP Class 0')

plt.xlabel("Training Data Proportion (Majority:Minority)")
plt.ylabel("Recall on Test Set")
plt.title("Recall vs. Training Data Proportion for MLP")
plt.legend()
plt.grid(True)
plt.show()
# Out:
# c:\Users\manav\OneDrive\Desktop\NIT Surathkal\Semester 7\IT-449\Drug-Drug-Interaction-and-Alternate-Recommendation-System\.venv\lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# MLP - Proportion 1:1 - Recall Class 1: 0.78, Recall Class 0: 0.35
# Accuracy: 0.38
#               precision    recall  f1-score   support
#
#            0       0.95      0.35      0.51      1317
#            1       0.10      0.78      0.17       116
#
#     accuracy                           0.38      1433
#    macro avg       0.52      0.57      0.34      1433
# weighted avg       0.88      0.38      0.48      1433
# c:\Users\manav\OneDrive\Desktop\NIT Surathkal\Semester 7\IT-449\Drug-Drug-Interaction-and-Alternate-Recommendation-System\.venv\lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# MLP - Proportion 2:1 - Recall Class 1: 0.47, Recall Class 0: 0.65
# Accuracy: 0.64
#               precision    recall  f1-score   support
#
#            0       0.93      0.65      0.77      1317
#            1       0.11      0.47      0.17       116
#
#     accuracy                           0.64      1433
#    macro avg       0.52      0.56      0.47      1433
# weighted avg       0.87      0.64      0.72      1433
# c:\Users\manav\OneDrive\Desktop\NIT Surathkal\Semester 7\IT-449\Drug-Drug-Interaction-and-Alternate-Recommendation-System\.venv\lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# MLP - Proportion 3:1 - Recall Class 1: 0.56, Recall Class 0: 0.64
# Accuracy: 0.63
#               precision    recall  f1-score   support
#
#            0       0.94      0.64      0.76      1317
#            1       0.12      0.56      0.20       116
#
#     accuracy                           0.63      1433
#    macro avg       0.53      0.60      0.48      1433
# weighted avg       0.88      0.63      0.71      1433
# c:\Users\manav\OneDrive\Desktop\NIT Surathkal\Semester 7\IT-449\Drug-Drug-Interaction-and-Alternate-Recommendation-System\.venv\lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# MLP - Proportion 4:1 - Recall Class 1: 0.47, Recall Class 0: 0.81
# Accuracy: 0.78
#               precision    recall  f1-score   support
#
#            0       0.95      0.81      0.87      1317
#            1       0.18      0.47      0.26       116
#
#     accuracy                           0.78      1433
#    macro avg       0.56      0.64      0.56      1433
# weighted avg       0.88      0.78      0.82      1433
# c:\Users\manav\OneDrive\Desktop\NIT Surathkal\Semester 7\IT-449\Drug-Drug-Interaction-and-Alternate-Recommendation-System\.venv\lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# MLP - Proportion 5:1 - Recall Class 1: 0.34, Recall Class 0: 0.88
# Accuracy: 0.83
#               precision    recall  f1-score   support
#
#            0       0.94      0.88      0.91      1317
#            1       0.20      0.34      0.25       116
#
#     accuracy                           0.83      1433
#    macro avg       0.57      0.61      0.58      1433
# weighted avg       0.88      0.83      0.85      1433
# c:\Users\manav\OneDrive\Desktop\NIT Surathkal\Semester 7\IT-449\Drug-Drug-Interaction-and-Alternate-Recommendation-System\.venv\lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# MLP - Proportion 6:1 - Recall Class 1: 0.27, Recall Class 0: 0.91
# Accuracy: 0.86
#               precision    recall  f1-score   support
#
#            0       0.93      0.91      0.92      1317
#            1       0.21      0.27      0.23       116
#
#     accuracy                           0.86      1433
#    macro avg       0.57      0.59      0.58      1433
# weighted avg       0.87      0.86      0.87      1433

# %%
# Define a function to create the MLP model
def create_mlp_model(input_dim):
    model = Sequential()
    model.add(Dense(200, input_dim=input_dim, activation='relu'))
    model.add(Dense(128, activation='relu'))
    model.add(Dropout(0.3))  # Dropout layer for regularization
    model.add(Dense(64, activation='relu'))
    model.add(Dropout(0.3))

    model.add(Dense(1, activation='sigmoid'))  # Binary classification output layer
    
    model.compile(optimizer=Adam(), loss='binary_crossentropy', metrics=['accuracy'])
    return model

# Assuming Drug1 and Drug2 vectors combined result in 200 features
input_dim = 200  

# List to store recall results for each proportion
recalls = []

# Loop through different proportions for balancing
proportions = [1, 2, 3, 4, 5, 6]  # Example proportions
for proportion in proportions:
    # Separate majority and minority samples in the training set
    X_minority = X_train_full[y_train_full == 1]
    y_minority = y_train_full[y_train_full == 1]
    
    X_majority = X_train_full[y_train_full == 0]
    y_majority = y_train_full[y_train_full == 0]
    
    # Sample majority class to balance the dataset
    n_minority = len(X_minority)
    n_majority = n_minority * proportion
    X_majority_sampled = X_majority[:n_majority]
    y_majority_sampled = y_majority[:n_majority]
    
    # Combine the sampled majority and minority data
    X_train_balanced = np.vstack((X_minority, X_majority_sampled))
    y_train_balanced = np.concatenate((y_minority, y_majority_sampled))
    
    # Shuffle the data
    X_train_balanced, y_train_balanced = shuffle(X_train_balanced, y_train_balanced, random_state=42)
    
    # Create and train the MLP model
    model = create_mlp_model(input_dim)
    model.fit(X_train_balanced, y_train_balanced, epochs=30, batch_size=32, verbose=0)
    

    # Predict on the test set
    y_pred = (model.predict(X_test) > 0.5).astype("int32")
    
    # Evaluate recall for both classes
    recall_class_1 = recall_score(y_test, y_pred, pos_label=1)
    recall_class_0 = recall_score(y_test, y_pred, pos_label=0)
    recalls.append((proportion, recall_class_1, recall_class_0))
    
    print(f"MLP - Proportion {proportion}:1 - Recall Class 1: {recall_class_1:.2f}, Recall Class 0: {recall_class_0:.2f}")
    print(f"Accuracy: {accuracy_score(y_test, y_pred):.2f}")
    print(classification_report(y_test, y_pred))

# Plot Recall vs Training Data Proportion for MLP
plt.figure(figsize=(10, 6))
proportions, recall_scores_class_1, recall_scores_class_0 = zip(*recalls)
plt.plot(proportions, recall_scores_class_1, marker='o', label='MLP Class 1')
plt.plot(proportions, recall_scores_class_0, marker='o', label='MLP Class 0')

plt.xlabel("Training Data Proportion (Majority:Minority)")
plt.ylabel("Recall on Test Set")
plt.title("Recall vs. Training Data Proportion for MLP")
plt.legend()
plt.grid(True)
plt.show()
# Out:
# c:\Users\manav\OneDrive\Desktop\NIT Surathkal\Semester 7\IT-449\Drug-Drug-Interaction-and-Alternate-Recommendation-System\.venv\lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# MLP - Proportion 1:1 - Recall Class 1: 0.78, Recall Class 0: 0.36
# Accuracy: 0.39
#               precision    recall  f1-score   support
#
#            0       0.95      0.36      0.52      1317
#            1       0.10      0.78      0.17       116
#
#     accuracy                           0.39      1433
#    macro avg       0.52      0.57      0.34      1433
# weighted avg       0.88      0.39      0.49      1433
# c:\Users\manav\OneDrive\Desktop\NIT Surathkal\Semester 7\IT-449\Drug-Drug-Interaction-and-Alternate-Recommendation-System\.venv\lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# MLP - Proportion 2:1 - Recall Class 1: 0.47, Recall Class 0: 0.59
# Accuracy: 0.58
#               precision    recall  f1-score   support
#
#            0       0.93      0.59      0.72      1317
#            1       0.09      0.47      0.16       116
#
#     accuracy                           0.58      1433
#    macro avg       0.51      0.53      0.44      1433
# weighted avg       0.86      0.58      0.68      1433
# c:\Users\manav\OneDrive\Desktop\NIT Surathkal\Semester 7\IT-449\Drug-Drug-Interaction-and-Alternate-Recommendation-System\.venv\lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# MLP - Proportion 3:1 - Recall Class 1: 0.54, Recall Class 0: 0.64
# Accuracy: 0.64
#               precision    recall  f1-score   support
#
#            0       0.94      0.64      0.76      1317
#            1       0.12      0.54      0.19       116
#
#     accuracy                           0.64      1433
#    macro avg       0.53      0.59      0.48      1433
# weighted avg       0.87      0.64      0.72      1433
# c:\Users\manav\OneDrive\Desktop\NIT Surathkal\Semester 7\IT-449\Drug-Drug-Interaction-and-Alternate-Recommendation-System\.venv\lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# MLP - Proportion 4:1 - Recall Class 1: 0.34, Recall Class 0: 0.78
# Accuracy: 0.75
#               precision    recall  f1-score   support
#
#            0       0.93      0.78      0.85      1317
#            1       0.12      0.34      0.18       116
#
#     accuracy                           0.75      1433
#    macro avg       0.53      0.56      0.52      1433
# weighted avg       0.87      0.75      0.80      1433
# c:\Users\manav\OneDrive\Desktop\NIT Surathkal\Semester 7\IT-449\Drug-Drug-Interaction-and-Alternate-Recommendation-System\.venv\lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# MLP - Proportion 5:1 - Recall Class 1: 0.27, Recall Class 0: 0.90
# Accuracy: 0.84
#               precision    recall  f1-score   support
#
#            0       0.93      0.90      0.91      1317
#            1       0.18      0.27      0.22       116
#
#     accuracy                           0.84      1433
#    macro avg       0.56      0.58      0.57      1433
# weighted avg       0.87      0.84      0.86      1433
# c:\Users\manav\OneDrive\Desktop\NIT Surathkal\Semester 7\IT-449\Drug-Drug-Interaction-and-Alternate-Recommendation-System\.venv\lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# MLP - Proportion 6:1 - Recall Class 1: 0.21, Recall Class 0: 0.91
# Accuracy: 0.86
#               precision    recall  f1-score   support
#
#            0       0.93      0.91      0.92      1317
#            1       0.17      0.21      0.19       116
#
#     accuracy                           0.86      1433
#    macro avg       0.55      0.56      0.56      1433
# weighted avg       0.87      0.86      0.86      1433

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout
from tensorflow.keras.optimizers import Adam


# Define a function to create the MLP model
def create_mlp_model(input_dim):
    model = Sequential()
    model.add(Dense(200, input_dim=input_dim, activation='relu'))
    # model.add(Dense(128, activation='relu'))
    # model.add(Dropout(0.3))  # Dropout layer for regularization
    model.add(Dense(64, activation='relu'))
    model.add(Dropout(0.3))
    model.add(Dense(64, activation='relu'))
    model.add(Dropout(0.3))
    model.add(Dense(64, activation='relu'))
    model.add(Dropout(0.3))
    model.add(Dense(64, activation='relu'))
    model.add(Dropout(0.3))
    model.add(Dense(64, activation='relu'))
    model.add(Dropout(0.3))
    model.add(Dense(64, activation='relu'))
    model.add(Dropout(0.3))
    model.add(Dense(64, activation='relu'))
    model.add(Dropout(0.3))
    model.add(Dense(1, activation='sigmoid'))  # Binary classification output layer
    
    model.compile(optimizer=Adam(), loss='binary_crossentropy', metrics=['accuracy'])
    return model

# Assuming Drug1 and Drug2 vectors combined result in 200 features
input_dim = 200  

# List to store recall results for each proportion
recalls = []

# Loop through different proportions for balancing
proportions = [1, 2, 3, 4, 5, 6]  # Example proportions
for proportion in proportions:
    # Separate majority and minority samples in the training set
    X_minority = X_train_full[y_train_full == 1]
    y_minority = y_train_full[y_train_full == 1]
    
    X_majority = X_train_full[y_train_full == 0]
    y_majority = y_train_full[y_train_full == 0]
    
    # Sample majority class to balance the dataset
    n_minority = len(X_minority)
    n_majority = n_minority * proportion
    X_majority_sampled = X_majority[:n_majority]
    y_majority_sampled = y_majority[:n_majority]
    
    # Combine the sampled majority and minority data
    X_train_balanced = np.vstack((X_minority, X_majority_sampled))
    y_train_balanced = np.concatenate((y_minority, y_majority_sampled))
    
    # Shuffle the data
    X_train_balanced, y_train_balanced = shuffle(X_train_balanced, y_train_balanced, random_state=42)
    
    # Create and train the MLP model
    model = create_mlp_model(input_dim)
    model.fit(X_train_balanced, y_train_balanced, epochs=30, batch_size=32, verbose=0)
    
    # Predict on the test set
    y_pred = (model.predict(X_test) > 0.5).astype("int32")
    
    # Evaluate recall for both classes
    recall_class_1 = recall_score(y_test, y_pred, pos_label=1)
    recall_class_0 = recall_score(y_test, y_pred, pos_label=0)
    recalls.append((proportion, recall_class_1, recall_class_0))
    
    print(f"MLP - Proportion {proportion}:1 - Recall Class 1: {recall_class_1:.2f}, Recall Class 0: {recall_class_0:.2f}")
    print(f"Accuracy: {accuracy_score(y_test, y_pred):.2f}")
    print(classification_report(y_test, y_pred))

# Plot Recall vs Training Data Proportion for MLP
plt.figure(figsize=(10, 6))
proportions, recall_scores_class_1, recall_scores_class_0 = zip(*recalls)
plt.plot(proportions, recall_scores_class_1, marker='o', label='MLP Class 1')
plt.plot(proportions, recall_scores_class_0, marker='o', label='MLP Class 0')

plt.xlabel("Training Data Proportion (Majority:Minority)")
plt.ylabel("Recall on Test Set")
plt.title("Recall vs. Training Data Proportion for MLP")
plt.legend()
plt.grid(True)
plt.show()
# Out:
# c:\Users\manav\OneDrive\Desktop\NIT Surathkal\Semester 7\IT-449\Drug-Drug-Interaction-and-Alternate-Recommendation-System\.venv\lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step
# MLP - Proportion 1:1 - Recall Class 1: 0.85, Recall Class 0: 0.32
# Accuracy: 0.37
#               precision    recall  f1-score   support
#
#            0       0.96      0.32      0.48      1317
#            1       0.10      0.85      0.18       116
#
#     accuracy                           0.37      1433
#    macro avg       0.53      0.59      0.33      1433
# weighted avg       0.89      0.37      0.46      1433
# c:\Users\manav\OneDrive\Desktop\NIT Surathkal\Semester 7\IT-449\Drug-Drug-Interaction-and-Alternate-Recommendation-System\.venv\lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step
# MLP - Proportion 2:1 - Recall Class 1: 0.58, Recall Class 0: 0.59
# Accuracy: 0.59
#               precision    recall  f1-score   support
#
#            0       0.94      0.59      0.73      1317
#            1       0.11      0.58      0.19       116
#
#     accuracy                           0.59      1433
#    macro avg       0.53      0.59      0.46      1433
# weighted avg       0.87      0.59      0.68      1433
# c:\Users\manav\OneDrive\Desktop\NIT Surathkal\Semester 7\IT-449\Drug-Drug-Interaction-and-Alternate-Recommendation-System\.venv\lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step
# MLP - Proportion 3:1 - Recall Class 1: 0.58, Recall Class 0: 0.61
# Accuracy: 0.61
#               precision    recall  f1-score   support
#
#            0       0.94      0.61      0.74      1317
#            1       0.12      0.58      0.19       116
#
#     accuracy                           0.61      1433
#    macro avg       0.53      0.60      0.47      1433
# weighted avg       0.88      0.61      0.70      1433
# c:\Users\manav\OneDrive\Desktop\NIT Surathkal\Semester 7\IT-449\Drug-Drug-Interaction-and-Alternate-Recommendation-System\.venv\lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step
# MLP - Proportion 4:1 - Recall Class 1: 0.33, Recall Class 0: 0.84
# Accuracy: 0.80
#               precision    recall  f1-score   support
#
#            0       0.93      0.84      0.89      1317
#            1       0.16      0.33      0.21       116
#
#     accuracy                           0.80      1433
#    macro avg       0.55      0.59      0.55      1433
# weighted avg       0.87      0.80      0.83      1433
# c:\Users\manav\OneDrive\Desktop\NIT Surathkal\Semester 7\IT-449\Drug-Drug-Interaction-and-Alternate-Recommendation-System\.venv\lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# MLP - Proportion 5:1 - Recall Class 1: 0.39, Recall Class 0: 0.80
# Accuracy: 0.77
#               precision    recall  f1-score   support
#
#            0       0.94      0.80      0.86      1317
#            1       0.15      0.39      0.21       116
#
#     accuracy                           0.77      1433
#    macro avg       0.54      0.59      0.54      1433
# weighted avg       0.87      0.77      0.81      1433
# c:\Users\manav\OneDrive\Desktop\NIT Surathkal\Semester 7\IT-449\Drug-Drug-Interaction-and-Alternate-Recommendation-System\.venv\lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# MLP - Proportion 6:1 - Recall Class 1: 0.30, Recall Class 0: 0.89
# Accuracy: 0.84
#               precision    recall  f1-score   support
#
#            0       0.94      0.89      0.91      1317
#            1       0.20      0.30      0.24       116
#
#     accuracy                           0.84      1433
#    macro avg       0.57      0.60      0.58      1433
# weighted avg       0.88      0.84      0.86      1433

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout
from tensorflow.keras.optimizers import Adam


# Define a function to create the MLP model
def create_mlp_model(input_dim):
    model = Sequential()
    model.add(Dense(200, input_dim=input_dim, activation='relu'))
    # model.add(Dense(128, activation='relu'))
    # model.add(Dropout(0.3))  # Dropout layer for regularization
    model.add(Dense(128, activation='relu'))
    model.add(Dropout(0.3))
    model.add(Dense(128, activation='relu'))
    model.add(Dropout(0.3))
    model.add(Dense(128, activation='relu'))
    model.add(Dropout(0.3))
    model.add(Dense(64, activation='relu'))
    model.add(Dropout(0.3))
    model.add(Dense(64, activation='relu'))
    model.add(Dropout(0.3))
    model.add(Dense(64, activation='relu'))
    model.add(Dropout(0.3))
    model.add(Dense(64, activation='relu'))
    model.add(Dropout(0.3))
    model.add(Dense(1, activation='sigmoid'))  # Binary classification output layer
    
    model.compile(optimizer=Adam(), loss='binary_crossentropy', metrics=['accuracy'])
    return model

# Assuming Drug1 and Drug2 vectors combined result in 200 features
input_dim = 200  

# List to store recall results for each proportion
recalls = []

# Loop through different proportions for balancing
proportions = [1, 2, 3, 4, 5, 6, 7, 8]  # Example proportions
for proportion in proportions:
    # Separate majority and minority samples in the training set
    X_minority = X_train_full[y_train_full == 1]
    y_minority = y_train_full[y_train_full == 1]
    
    X_majority = X_train_full[y_train_full == 0]
    y_majority = y_train_full[y_train_full == 0]
    
    # Sample majority class to balance the dataset
    n_minority = len(X_minority)
    n_majority = n_minority * proportion
    X_majority_sampled = X_majority[:n_majority]
    y_majority_sampled = y_majority[:n_majority]
    
    # Combine the sampled majority and minority data
    X_train_balanced = np.vstack((X_minority, X_majority_sampled))
    y_train_balanced = np.concatenate((y_minority, y_majority_sampled))
    
    # Shuffle the data
    X_train_balanced, y_train_balanced = shuffle(X_train_balanced, y_train_balanced, random_state=42)
    
    # Create and train the MLP model
    model = create_mlp_model(input_dim)
    model.fit(X_train_balanced, y_train_balanced, epochs=20, batch_size=32, verbose=0)
    
    # Predict on the test set
    y_pred = (model.predict(X_test) > 0.5).astype("int32")
    
    # Evaluate recall for both classes
    recall_class_1 = recall_score(y_test, y_pred, pos_label=1)
    recall_class_0 = recall_score(y_test, y_pred, pos_label=0)
    recalls.append((proportion, recall_class_1, recall_class_0))
    
    print(f"MLP - Proportion {proportion}:1 - Recall Class 1: {recall_class_1:.2f}, Recall Class 0: {recall_class_0:.2f}")
    print(f"Accuracy: {accuracy_score(y_test, y_pred):.2f}")
    print(classification_report(y_test, y_pred))

# Plot Recall vs Training Data Proportion for MLP
plt.figure(figsize=(10, 6))
proportions, recall_scores_class_1, recall_scores_class_0 = zip(*recalls)
plt.plot(proportions, recall_scores_class_1, marker='o', label='MLP Class 1')
plt.plot(proportions, recall_scores_class_0, marker='o', label='MLP Class 0')

plt.xlabel("Training Data Proportion (Majority:Minority)")
plt.ylabel("Recall on Test Set")
plt.title("Recall vs. Training Data Proportion for MLP")
plt.legend()
plt.grid(True)
plt.show()
# Out:
# c:\Users\manav\OneDrive\Desktop\NIT Surathkal\Semester 7\IT-449\Drug-Drug-Interaction-and-Alternate-Recommendation-System\.venv\lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# MLP - Proportion 1:1 - Recall Class 1: 0.70, Recall Class 0: 0.37
# Accuracy: 0.39
#               precision    recall  f1-score   support
#
#            0       0.93      0.37      0.53      1317
#            1       0.09      0.70      0.16       116
#
#     accuracy                           0.39      1433
#    macro avg       0.51      0.53      0.34      1433
# weighted avg       0.86      0.39      0.50      1433
# c:\Users\manav\OneDrive\Desktop\NIT Surathkal\Semester 7\IT-449\Drug-Drug-Interaction-and-Alternate-Recommendation-System\.venv\lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# MLP - Proportion 2:1 - Recall Class 1: 0.41, Recall Class 0: 0.67
# Accuracy: 0.65
#               precision    recall  f1-score   support
#
#            0       0.93      0.67      0.78      1317
#            1       0.10      0.41      0.16       116
#
#     accuracy                           0.65      1433
#    macro avg       0.51      0.54      0.47      1433
# weighted avg       0.86      0.65      0.73      1433
# c:\Users\manav\OneDrive\Desktop\NIT Surathkal\Semester 7\IT-449\Drug-Drug-Interaction-and-Alternate-Recommendation-System\.venv\lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# MLP - Proportion 3:1 - Recall Class 1: 0.71, Recall Class 0: 0.60
# Accuracy: 0.61
#               precision    recall  f1-score   support
#
#            0       0.96      0.60      0.74      1317
#            1       0.13      0.71      0.23       116
#
#     accuracy                           0.61      1433
#    macro avg       0.55      0.65      0.48      1433
# weighted avg       0.89      0.61      0.70      1433
# c:\Users\manav\OneDrive\Desktop\NIT Surathkal\Semester 7\IT-449\Drug-Drug-Interaction-and-Alternate-Recommendation-System\.venv\lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# MLP - Proportion 4:1 - Recall Class 1: 0.49, Recall Class 0: 0.77
# Accuracy: 0.75
#               precision    recall  f1-score   support
#
#            0       0.95      0.77      0.85      1317
#            1       0.16      0.49      0.24       116
#
#     accuracy                           0.75      1433
#    macro avg       0.55      0.63      0.55      1433
# weighted avg       0.88      0.75      0.80      1433
# c:\Users\manav\OneDrive\Desktop\NIT Surathkal\Semester 7\IT-449\Drug-Drug-Interaction-and-Alternate-Recommendation-System\.venv\lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# MLP - Proportion 5:1 - Recall Class 1: 0.36, Recall Class 0: 0.84
# Accuracy: 0.80
#               precision    recall  f1-score   support
#
#            0       0.94      0.84      0.88      1317
#            1       0.16      0.36      0.23       116
#
#     accuracy                           0.80      1433
#    macro avg       0.55      0.60      0.56      1433
# weighted avg       0.87      0.80      0.83      1433
# c:\Users\manav\OneDrive\Desktop\NIT Surathkal\Semester 7\IT-449\Drug-Drug-Interaction-and-Alternate-Recommendation-System\.venv\lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# MLP - Proportion 6:1 - Recall Class 1: 0.33, Recall Class 0: 0.82
# Accuracy: 0.78
#               precision    recall  f1-score   support
#
#            0       0.93      0.82      0.87      1317
#            1       0.14      0.33      0.19       116
#
#     accuracy                           0.78      1433
#    macro avg       0.54      0.57      0.53      1433
# weighted avg       0.87      0.78      0.82      1433
# c:\Users\manav\OneDrive\Desktop\NIT Surathkal\Semester 7\IT-449\Drug-Drug-Interaction-and-Alternate-Recommendation-System\.venv\lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# MLP - Proportion 7:1 - Recall Class 1: 0.23, Recall Class 0: 0.92
# Accuracy: 0.86
#               precision    recall  f1-score   support
#
#            0       0.93      0.92      0.92      1317
#            1       0.20      0.23      0.21       116
#
#     accuracy                           0.86      1433
#    macro avg       0.56      0.57      0.57      1433
# weighted avg       0.87      0.86      0.87      1433
# c:\Users\manav\OneDrive\Desktop\NIT Surathkal\Semester 7\IT-449\Drug-Drug-Interaction-and-Alternate-Recommendation-System\.venv\lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# MLP - Proportion 8:1 - Recall Class 1: 0.19, Recall Class 0: 0.93
# Accuracy: 0.87
#               precision    recall  f1-score   support
#
#            0       0.93      0.93      0.93      1317
#            1       0.19      0.19      0.19       116
#
#     accuracy                           0.87      1433
#    macro avg       0.56      0.56      0.56      1433
# weighted avg       0.87      0.87      0.87      1433

# %%
import numpy as np
from sklearn.preprocessing import StandardScaler
from sklearn.utils import shuffle
from sklearn.metrics import recall_score, accuracy_score, classification_report
import matplotlib.pyplot as plt
import tensorflow as tf

def create_mlp_model(input_dim):
    model = Sequential()
    model.add(Dense(200, input_dim=input_dim, activation='relu'))
    model.add(Dense(128, activation='relu'))
    model.add(Dropout(0.3))  # Dropout layer for regularization
    model.add(Dense(64, activation='relu'))
    model.add(Dropout(0.3))

    model.add(Dense(1, activation='sigmoid'))  # Binary classification output layer
    
    model.compile(optimizer=Adam(), loss='binary_crossentropy', metrics=['accuracy'])
    return model
# Assuming the create_mlp_model function is defined and input_dim is 200
# Standardize features
scaler = StandardScaler()
X_train_full_scaled = scaler.fit_transform(X_train_full)
X_test_scaled = scaler.transform(X_test)

# List to store recall results for each proportion
recalls = []

# Loop through different proportions for balancing
proportions = [1, 2, 3, 4, 5]

for proportion in proportions:
    # Separate majority and minority samples in the training set
    X_minority = X_train_full_scaled[y_train_full == 1]
    y_minority = y_train_full[y_train_full == 1]
    
    X_majority = X_train_full_scaled[y_train_full == 0]
    y_majority = y_train_full[y_train_full == 0]
    
    # Sample majority class to balance the dataset
    n_minority = len(X_minority)
    n_majority = n_minority * proportion
    X_majority_sampled = X_majority[:n_majority]
    y_majority_sampled = y_majority[:n_majority]
    
    # Combine the sampled majority and minority data
    X_train_balanced = np.vstack((X_minority, X_majority_sampled))
    y_train_balanced = np.concatenate((y_minority, y_majority_sampled))
    
    # Shuffle the data
    X_train_balanced, y_train_balanced = shuffle(X_train_balanced, y_train_balanced, random_state=42)
    
    # Create and train the MLP model
    model = create_mlp_model(input_dim)
    model.fit(X_train_balanced, y_train_balanced, epochs=20, batch_size=32, verbose=0)
    
    # Predict on the test set
    y_pred = (model.predict(X_test_scaled) > 0.5).astype("int32")
    
    # Evaluate recall for both classes
    recall_class_1 = recall_score(y_test, y_pred, pos_label=1)
    recall_class_0 = recall_score(y_test, y_pred, pos_label=0)
    recalls.append((proportion, recall_class_1, recall_class_0))
    
    print(f"MLP - Proportion {proportion}:1 - Recall Class 1: {recall_class_1:.2f}, Recall Class 0: {recall_class_0:.2f}")
    print(f"Accuracy: {accuracy_score(y_test, y_pred):.2f}")
    print(classification_report(y_test, y_pred))

# Plot Recall vs Training Data Proportion for MLP
plt.figure(figsize=(10, 6))
proportions, recall_scores_class_1, recall_scores_class_0 = zip(*recalls)
plt.plot(proportions, recall_scores_class_1, marker='o', label='MLP Class 1')
plt.plot(proportions, recall_scores_class_0, marker='o', label='MLP Class 0')

plt.xlabel("Training Data Proportion (Majority:Minority)")
plt.ylabel("Recall on Test Set")
plt.title("Recall vs. Training Data Proportion for MLP")
plt.legend()
plt.grid(True)
plt.show()
# Out:
# c:\Users\manav\OneDrive\Desktop\NIT Surathkal\Semester 7\IT-449\Drug-Drug-Interaction-and-Alternate-Recommendation-System\.venv\lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# MLP - Proportion 1:1 - Recall Class 1: 0.76, Recall Class 0: 0.39
# Accuracy: 0.42
#               precision    recall  f1-score   support
#
#            0       0.95      0.39      0.56      1317
#            1       0.10      0.76      0.18       116
#
#     accuracy                           0.42      1433
#    macro avg       0.52      0.58      0.37      1433
# weighted avg       0.88      0.42      0.53      1433
# c:\Users\manav\OneDrive\Desktop\NIT Surathkal\Semester 7\IT-449\Drug-Drug-Interaction-and-Alternate-Recommendation-System\.venv\lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# MLP - Proportion 2:1 - Recall Class 1: 0.47, Recall Class 0: 0.65
# Accuracy: 0.63
#               precision    recall  f1-score   support
#
#            0       0.93      0.65      0.77      1317
#            1       0.11      0.47      0.17       116
#
#     accuracy                           0.63      1433
#    macro avg       0.52      0.56      0.47      1433
# weighted avg       0.87      0.63      0.72      1433
# c:\Users\manav\OneDrive\Desktop\NIT Surathkal\Semester 7\IT-449\Drug-Drug-Interaction-and-Alternate-Recommendation-System\.venv\lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# MLP - Proportion 3:1 - Recall Class 1: 0.43, Recall Class 0: 0.68
# Accuracy: 0.66
#               precision    recall  f1-score   support
#
#            0       0.93      0.68      0.78      1317
#            1       0.11      0.43      0.17       116
#
#     accuracy                           0.66      1433
#    macro avg       0.52      0.55      0.48      1433
# weighted avg       0.86      0.66      0.73      1433
# c:\Users\manav\OneDrive\Desktop\NIT Surathkal\Semester 7\IT-449\Drug-Drug-Interaction-and-Alternate-Recommendation-System\.venv\lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# MLP - Proportion 4:1 - Recall Class 1: 0.35, Recall Class 0: 0.83
# Accuracy: 0.79
#               precision    recall  f1-score   support
#
#            0       0.94      0.83      0.88      1317
#            1       0.15      0.35      0.22       116
#
#     accuracy                           0.79      1433
#    macro avg       0.55      0.59      0.55      1433
# weighted avg       0.87      0.79      0.83      1433
# c:\Users\manav\OneDrive\Desktop\NIT Surathkal\Semester 7\IT-449\Drug-Drug-Interaction-and-Alternate-Recommendation-System\.venv\lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# MLP - Proportion 5:1 - Recall Class 1: 0.31, Recall Class 0: 0.88
# Accuracy: 0.84
#               precision    recall  f1-score   support
#
#            0       0.94      0.88      0.91      1317
#            1       0.19      0.31      0.24       116
#
#     accuracy                           0.84      1433
#    macro avg       0.56      0.60      0.57      1433
# weighted avg       0.88      0.84      0.85      1433
