# %% [markdown]
# ## Import Libraries

# %%
from gensim.models import Word2Vec
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import os
import xml.etree.ElementTree as ET
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score, classification_report, recall_score
from sklearn.utils import shuffle
from sklearn.ensemble import GradientBoostingClassifier, RandomForestClassifier
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score, classification_report, recall_score
from sklearn.utils import shuffle
import matplotlib.pyplot as plt

from sklearn.manifold import TSNE

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout
from tensorflow.keras.optimizers import Adam

import torch

# %% [markdown]
# ## BioBert

# %%
# Load the .pt file
file_path = 'drug_embeddings.pt'
data = torch.load(file_path, map_location=torch.device('cpu'))

# Check type and structure
print("Type of loaded object:", type(data))

# If it's a dictionary with drug names
if isinstance(data, dict):
    print("Number of drugs:", len(data))
    # Print first few entries
    for i, (drug, value) in enumerate(data.items()):
        print(f"{drug}: {value.shape if hasattr(value, 'shape') else type(value)}")
        if i == 4:  # just print first 5 for preview
            break
else:
    print("Unexpected format.")

# %% [markdown]
# ## Dataset

# %% [markdown]
# Function to parse drug entities from a given XML file

# %%
def parse_drug_entities(file_path):
    tree = ET.parse(file_path)
    root = tree.getroot()
    drugs = set()
    
    for entity in root.findall(".//entity"):
        if entity.attrib.get('type') == 'drug' or entity.attrib.get('type') == 'brand' or entity.attrib.get('type') == 'drug_n':
            drugs.add(entity.attrib.get('text'))
    
    return drugs

# %% [markdown]
# Function to parse drug entities from XML files in a given directory

# %%
def extract_unique_drug_entities(directory):
    unique_drug_entities = set()
    for file_name in os.listdir(directory):
        if file_name.endswith('.xml'):
            file_path = os.path.join(directory, file_name)
            drug_entities = parse_drug_entities(file_path)  
            unique_drug_entities.update(drug_entities)
    return unique_drug_entities

# %% [markdown]
# Extract unique drug entities for training and testing datasets

# %%
train_dirs = ['../Dataset/DDICorpus/Train/DrugBank', '../Dataset/DDICorpus/Train/MedLine']
test_dirs = ['../Dataset/DDICorpus/Test/Test for DDI Extraction task/DrugBank', '../Dataset/DDICorpus/Test/Test for DDI Extraction task/MedLine']


all_drug_entities = set()
all_drug_entities_test = set()

for directory in train_dirs:
    all_drug_entities.update(extract_unique_drug_entities(directory))

for directory in test_dirs:
    all_drug_entities_test.update(extract_unique_drug_entities(directory))

# Print results
print(f"Total unique drug entities (train): {len(all_drug_entities)}")
print(all_drug_entities)

print(f"Total unique drug entities (test): {len(all_drug_entities_test)}")
print(all_drug_entities_test)
# Out:
# Total unique drug entities (train): 2085
# {'Diethyl pyrocarbonate', 'sodium nitroprusside', 'benzocaine', 'Paroxetine', 'activated charcoal', 'Meperidine', 'Rifamate', 'cholestryramine', 'aripiprazole', 'eszopiclone', 'Dicumarol', 'calcitriol', 'Lanoxin', 'docetaxel', 'FACTIVE', 'MYOBLOC', 'Accutane', 'nafcillin', 'sirolimus', 'Seroquel', 'noradrenaline', 'sulfasalazine', 'Valium', 'ciclosporin', 'Ethinyl estradiol', 'sodium iodide I131', 'calcium channel', 'boric acid', 'cephalexin', 'tuftsin', 'zonisamide', 'Theobromine', 'Selegiline', '6-deoxy penciclovir', 'Estazolam', 'CEFOTAN', 'bivalirudin', 'lamotrigine', 'desflurane', 'para-aminobenzoic acid', 'Duloxetine', 'DILAUDID', 'NUROMAX', 'Tylenol', 'antiarrhythmics', 'bitolterol', 'Calcidiol', 'Exemestane', 'cypermethrin', '4-hydroxytamoxifen', 'Enflurane', 'Gemzar', 'Soriatane', 'Xanax', 'corticosteroid', 'olanzapine', 'Ibogaine', 'glutamate', 'papaverine', 'SMX', '3-hydroxydesloratadine', 'caffeine', 'Ocupress', 'Prostigmin', 'Naproxen', 'Orudis', 'sodium valproate', 'D-penicillamine', 'valproate', 'dextropropoxyphene', 'doxorubicinol', 'dexfenfluramine', 'antipyrine', 'Trexan', 'dinoprost', 'Targretin', 'sodium thiosulfate', 'Stelazine', 'erythromycins', 'zalcitabine', 'famciclovir', 'diethylstilbestrol', 'Septra', 'Lovastatin', 'WELLBUTRIN', 'naproxen', 'VIRACEPT', 'mefloquine', 'propoxyphene', 'cyclosporine A', 'Fexofenadine', 'Tenormin', 'Keppra', 'COREG', 'Lincomycin', 'ELSPAR', 'sodium colistemethate', 'WelChol', 'Dopamine', 'Gabapentin', 'Atracurium', 'Dihydroergotamine', 'allopurinol sodium', 'tazobactam', 'ginsenosides', 'Advil', 'TYSABRI', 'FROVA', 'sulfonylurea', 'rifapentine', 'Permitil', 'Gris-PEG', 'Lansoprazole', 'Triamterene', 'Levothyroxine Sodium', 'Doxorubicin', 'Sporanox', 'amylase', 'Kadian', 'Dexbrompheniramine', 'oxyphenbutazone', 'amitriptyline HCl', 'Thioridazine', 'levothyroxine sodium', 'imipramine hydrochloride', '5-oxo-desethylzaleplon', 'BOTOX', 'Bactrim', 'metoprolol', 'eplerenone', 'doxorubicin HCL', 'endotoxin', 'Resveratrol', '5-fluorouracil', 'NovoLog', 'zidovudine', 'carbamazepine', 'PROPECIA', 'itraconazole', 'estradiol', 'BARACLUDE', 'icodextrin', 'Dexamethasone', 'hydrochloroquine', 'enkephalins', 'aliskiren', 'Myochrysine', '4-hydroxytolbutamide', 'quinidine', 'cyclosporin', 'carvedilol', 'Sirolimus', 'levamisole', 'verografin', 'Fluvastatin', 'carbidopa', 'Sodium Pertechnetate Tc99m', 'filipin', 'loratadine', 'morphine', 'prednisone', 'Magan', 'lopinavir', 'Medroxyprogesterone Acetate', 'RR', 'thiabendazole', 'SUBOXONE', 'Pepto-Bismol', 'choline salicylate', 'R-warfarin', 'mesalamine', 'sertindole', 'allopurinol', 'Auranofin', 'formoterol', 'aspirin', 'captopril', 'Amiodarone', 'albendazole', 'escitalopram', 'ethotoin', 'mecamylamine', 'Phenylbutazone', 'tadalafil', 'neomycin sulfate', 'pseudoephedrine', 'Aranesp', 'Aminosalicylic acid', 'Acebutolol', 'norfloxacin', 'Vidaza', 'somatrem', 'IOPIDINE', 'ethionamide', 'Warfarin', 'acetaldehyde', 'rosiglitazone', 'ADL-8-2698', 'chloroquine', 'benzodiazepines', 'alcohol', 'Azlocillin', 'ENBREL', 'Indocyanine green', 'EXTRANEAL', 'tubocurarine', 'Orudis KT', 'PGF2alpha', 'Serentil', 'Angiomax', 'norbuprenorphine', 'chlorothiazide', 't1', 'digoxin', 'DURAGESIC', 'nizatidine', 'iloprost', 'kanamycin', 'CMC-Cys', 'Valdecoxib', '6-mercaptopurine', 'Mithracin', 'Dapsone', 'clofarabine', 'azithromycin', 'Orlistat', 'Isoproterenol hydrochloride', 'Griseofulvin', 'secobarbital', 'idoxuridine', 'prilocaine', 'thiazolesulfone', 'ribavirin', 'magnesium salt', 'fludrocortisone acetate', 'INH', 'trimeprazine', 'Trilisate', 'sulfur', 'Neurontin', 'Neoral', 'Albendazole sulfoxide', 'HIVID', 'diphenoxylate', 'Nimotop', 'Celexa', 'guafacine', 'PABA', 'Dofetilide', 'S(-) warfarin', 'Ginkgo biloba', 'ketamine', 'palytoxin', 'pentazocine', 'Nevirapine', 'theophylline', 'TAO', 'imipramine', 'Antiarrhythmics', 'ORENCIA', 'Saquinavir', 'latamoxef', 'norethandrolone', 'rifabutin', 'capecitabine', 'ethyl alcohol', 'fondaparinux sodium', 'trifluoperazine',  ...
# Total unique drug entities (test): 727
# {'darbepoetin', 'ipratropium', 'Paroxetine', 'activated charcoal', 'primidone', 'pantoprazole', 'inactivated ND vaccines', 'methylergonovine maleate', 'metoprolol succinate', 'iron', 'methadone', 'docetaxel', 'Theophylline', 'sirolimus', 'rifapentin', 'rivastigmine', 'tranylcypromine', 'Ondansetron', 'sulfasalazine', 'Pravastatin', 'Methyldopa', 'CRM197', 'ZOLINZA', 'collagenase', 'mifepristone', 'Selegiline', 'acetylcholine chloride', 'ABT', 'micafungin', 'DISALCID', 'REMERON', 'Cinacalcet', 'suprofen', 'paliperidone', 'amlodipine', 'gentamicin', 'PURINETHOL', 'desipramine', 'TRENTAL', 'Pantoprazole', 'Abacavir', 'Sulfamethizole', 'Ultram', 'oxandrolone', 'Micafungin', 'ASPIRIN', 'lamivudine', 'Imexon', 'montelukast', 'chlorpromazine', 'Terfenadine', 'clomipramine', 'meloxicam', 'Amantadine', '3-Deazaneplanocin A', 'caffeine', 'quinine', 'Folinic acid', 'valproate', 'vigabatrin', 'meclizine', 'antipyrine', 'Streptokinase', 'human GH', 'Gantanol', 'saquinavir', 'ZADAXIN', 'diazoxide', 'pindolol', 'Isopto Carbachol', 'naproxen', 'MYCAMINE', 'propoxyphene', 'gemfibrozil', 'Acetaminophen', 'ASMANEX TWISTHALER', 'ephedrine', 'DETROL LA', 'oxybutynin chloride', 'gelusil', 'MYKROX', 'paracetamol', 'Melatonin', 'dacarbazine', 'oxygen', 'ethoxycoumarin', 'Celecoxib', 'amitriptyline HCl', 'levothyroxine sodium', 'lovastatin', 'heparinase III', 'SOMAVERT', 'metoprolol', 'estradiol', 'zidovudine', 'carbamazepine', 'itraconazole', 'trimetrexate', 'LAMISIL', 'colistin', 'acetaminophen', 'methazolamide', 'quinidine', 'cyclosporin', 'Sirolimus', 'Pramipexole', 'ganciclovir', 'thiopental', 'lapatinib', 'precocene I', '14- hydroxy- clarithromycin', 'prednisone', 'fluoxetine', 'morphine', 'phenytoin', 'methsuximide', 'CHEMET', 'thiabendazole', 'VMA', 'R-warfarin', 'nonheme iron', 'Miochol', 'aspirin', 'metaproterenol sulfate', 'mecamylamine', 'Methotrexate', 'nitrous oxide', 'scopolamine', 'pseudoephedrine', 'methylergonovine', 'Potassium', 'orlistat', 'salicylic acid', 'rosiglitazone', 'GSLS', 'Warfarin', 'alcohol', 'sulfamethoxazole', 'probenecid', 'urea', 'Rivastigmine', 'warfarin', 'indomethacin', 'simeticone', 'phenelzine', 'tubocurarine', 'paclitaxel', 'digoxin', 'Lithium', 'perindopril', 'Mitotane', 'Thiabendazole', 'Meloxicam', 'TABLOID', 'azithromycin', 'Cisapride', 'Montelukast', 'linezolid', 'secobarbital', 'Vindesine', 'ribavirin', 'fludrocortisone acetate', 'DEMSER', 'raloxifene', 'enflurane', 'FLOMAX', 'ketamine', 'pentazocine', 'theophylline', '1-aminobenzotriazole', 'imiglucerase', 'imipramine', 'tigecycline', 'piperacillin', 'Ibuprofen', 'rifabutin', 'sulfinpyrazone', 'prazosin', 'griseofulvin', 'Cimetidine', 'vancomycin', 'S-ketamine', 'miconazole', 'metaraminol', 'omeprazole', 'methylphenidate', 'conjugated estrogens', 'Vitamin B2', 'Carboptic', 'MPAG', 'Anabolic steroids', 'pimozide', 'piperine', 'methimazole', 'diclofenac', 'propafenone', 'Cyclosporine', 'promethazine', 'Asendin', 'Furafylline', 'edrophonium', 'pramipexole', 'lincomycin', 'imexon', 'dexamethasone', 'norethindrone acetate', 'levonorgesterol', 'selegiline', 'leucovorin', 'erythromycin', 'doxazosin', 'Paliperidone', 'Sinequan', 'MIVACRON', 'sodium bicarbonate', 'neostigmine', 'melatonin', 'Nalidixic acid', 'methoxyflurane', 'Celontin', 'fenofibrate', 'Aspirin', 'mesalazine', 'Methergine', 'methotrexate', 'THC', 'acyclovir', 'tiludronate', 'MAXAIR AUTOHALER', 'Metolazone', 'phenylpropanolamine', 'rifampin', 'cyclosporine', 'hyaluronan lyase', 'metolazone', 'tetrahydrocannabinol', 'streptozocin', 'Trimethoprim', 'Thalidomide', 'VESIcare', 'droperidol', 'Metopirone', 'amantadine', 'anastrozole', 'levothyroxine', 'tyramine', 'pilocarpine', 'norepinephrine', 'thioridazine', 'diethyldithiocarbamate', 'bethanechol', 'imipramine HCl', 'SUTENT', 'butorphanol', 'verapamil', 'Mycophenolate Mofetil', 'alpha lipoic acid', 'Digoxin', 'Sunitinib', 'hydroxyzine', 'vanillin', 'triprolidine', 'succinylcholine', 'sulfamethizole', 'voriconizole', 'heme iron', 'moexpril', 'acetazo ...

# %% [markdown]
# Function to extract drug vectors from the model for a given set of drug entities

# %%
import torch

# Load the drug embeddings
drug_embeddings = torch.load('drug_embeddings.pt', map_location=torch.device('cpu'))

# Updated function
def get_drug_vectors(drug_entities, embedding_dict):
    drug_vectors = {}
    for drug in drug_entities:
        if drug in embedding_dict:
            drug_vectors[drug] = embedding_dict[drug].numpy()
            print(f"Vector for {drug} found in the embedding dictionary.")
        else:
            print(f"Vector for {drug} not found in the embedding dictionary.")
    return drug_vectors

# Usage
drug_vectors = get_drug_vectors(all_drug_entities, drug_embeddings)
drug_vectors_test = get_drug_vectors(all_drug_entities_test, drug_embeddings)
# Out:
# Vector for Diethyl pyrocarbonate not found in the embedding dictionary.
# Vector for sodium nitroprusside found in the embedding dictionary.
# Vector for benzocaine found in the embedding dictionary.
# Vector for Paroxetine not found in the embedding dictionary.
# Vector for activated charcoal found in the embedding dictionary.
# Vector for Meperidine not found in the embedding dictionary.
# Vector for Rifamate not found in the embedding dictionary.
# Vector for cholestryramine found in the embedding dictionary.
# Vector for aripiprazole not found in the embedding dictionary.
# Vector for eszopiclone not found in the embedding dictionary.
# Vector for Dicumarol not found in the embedding dictionary.
# Vector for calcitriol found in the embedding dictionary.
# Vector for Lanoxin not found in the embedding dictionary.
# Vector for docetaxel not found in the embedding dictionary.
# Vector for FACTIVE not found in the embedding dictionary.
# Vector for MYOBLOC not found in the embedding dictionary.
# Vector for Accutane not found in the embedding dictionary.
# Vector for nafcillin found in the embedding dictionary.
# Vector for sirolimus not found in the embedding dictionary.
# Vector for Seroquel not found in the embedding dictionary.
# Vector for noradrenaline found in the embedding dictionary.
# Vector for sulfasalazine found in the embedding dictionary.
# Vector for Valium not found in the embedding dictionary.
# Vector for ciclosporin found in the embedding dictionary.
# Vector for Ethinyl estradiol not found in the embedding dictionary.
# Vector for sodium iodide I131 not found in the embedding dictionary.
# Vector for calcium channel found in the embedding dictionary.
# Vector for boric acid found in the embedding dictionary.
# Vector for cephalexin found in the embedding dictionary.
# Vector for tuftsin not found in the embedding dictionary.
# Vector for zonisamide found in the embedding dictionary.
# Vector for Theobromine not found in the embedding dictionary.
# Vector for Selegiline not found in the embedding dictionary.
# Vector for 6-deoxy penciclovir not found in the embedding dictionary.
# Vector for Estazolam not found in the embedding dictionary.
# Vector for CEFOTAN not found in the embedding dictionary.
# Vector for bivalirudin not found in the embedding dictionary.
# Vector for lamotrigine found in the embedding dictionary.
# Vector for desflurane found in the embedding dictionary.
# Vector for para-aminobenzoic acid not found in the embedding dictionary.
# Vector for Duloxetine not found in the embedding dictionary.
# Vector for DILAUDID not found in the embedding dictionary.
# Vector for NUROMAX not found in the embedding dictionary.
# Vector for Tylenol not found in the embedding dictionary.
# Vector for antiarrhythmics found in the embedding dictionary.
# Vector for bitolterol found in the embedding dictionary.
# Vector for Calcidiol not found in the embedding dictionary.
# Vector for Exemestane not found in the embedding dictionary.
# Vector for cypermethrin found in the embedding dictionary.
# Vector for 4-hydroxytamoxifen not found in the embedding dictionary.
# Vector for Enflurane not found in the embedding dictionary.
# Vector for Gemzar not found in the embedding dictionary.
# Vector for Soriatane not found in the embedding dictionary.
# Vector for Xanax not found in the embedding dictionary.
# Vector for corticosteroid found in the embedding dictionary.
# Vector for olanzapine found in the embedding dictionary.
# Vector for Ibogaine not found in the embedding dictionary.
# Vector for glutamate found in the embedding dictionary.
# Vector for papaverine found in the embedding dictionary.
# Vector for SMX not found in the embedding dictionary.
# Vector for 3-hydroxydesloratadine not found in the embedding dictionary.
# Vector for caffeine found in the embedding dictionary.
# Vector for Ocupress not found in the embedding dictionary.
# Vector for Prostigmin not found in the embedding dictionary.
# Vector for Naproxen not found in the embedding dictionary.
# Vector for Orudis not found in the embedding dictionary.
# Vector for sodium valproate found in the embedding dictionary.
# Vector for D-penicillamine not found in the embedding dictionary.
# Vector for valproate found in the embedding dictionary.
# Vector for dextropropoxyphene found in the embedding dictionary.
# Vector for doxorubicinol not found in the embedding dictionary.
# Vector for dexfenfluramine found in the embedding dictionary.
# Vector for antipyrine found in the embedding dictionary.
# Vector for Trexan not found in the embedding dictionary.
# Vector for dinoprost found in the embedding dictionary.
# Vector for Targretin not found in the embedding dictionary.
# Vector for sodium thiosulfate found in the embedding dictionary.
# Vector for Stelazine not found in the embedding dictionary.
# Vector for erythromycins found in the embedding dictionary.
# Vector for zalcitabine found in the embedding dictionary.
# Vector for famciclovir found in the embedding dictionary.
# Vector for diethylstilbestrol found in the embedding dictionary.
# Vector for Septra not found in the embedding dictionary.
# Vector for Lovastatin not found in the embedding dictionary.
# Vector for WELLBUTRIN not found in the embedding dictionary.
# Vector for naproxen found in the embedding dictionary.
# Vector for VIRACEPT not found in the embedding dictionary.
# Vector for mefloquine found in the embedding dictionary.
# Vector for propoxyphene found in the embedding dictionary.
# Vector for cyclosporine A not found in the embedding dictionary.
# Vector for Fexofenadine not found in the embedding dictionary.
# Vector for Tenormin not found in the embedding dictionary.
# Vector for Keppra not found in the embedding dictionary.
# Vector for COREG not found in the embedding dictionary.
# Vector for Lincomycin not found in the embedding dictionary.
# Vector for ELSPAR not found in the embedding dictionary.
# Vector for sodium colistemethate not found in the embedding dictionary.
# Vector for WelChol not found in the embedding dictionary.
# Vector for Dopamine not found in the embedding dictionary.
# Vector for Gabapentin not found in the embedding dictionary.
# Vector for Atracurium not found in the embedding dictionary.
# Vector for Dihydroergotamine not found in the embedding dictionary.
# Vector for allopurinol sodium not found in the embedding dictionary.
# Vector for tazobactam found in the embedding dictionary.
# Vector for ginsenosides not found in the embedding dictionary.
# Vector for Advil not found in the embedding dictionary.
# Vector for TYSABRI not found in the embedding dictionary.
# Vector for FROVA not found in the embedding dictionary.
# Vector for sulfonylurea found in the embedding dictionary.
# Vector for rifapentine found in the embedding dictionary.
# Vector for Permitil not found in the embedding dictionary.
# Vector for Gris-PEG not found in the embedding dictionary.
# Vector for Lansoprazole not found in the embedding dictionary.
# Vector for Triamterene not found in the embedding dictionary.
# Vector for Levothyroxine Sodium not found in the embedding dictionary.
# Vector for Doxorubicin not found in the embedding dictionary.
# Vector for Sporanox not found in the embedding dictionary.
# Vector for amylase found in the embedding dictionary.
# Vector for Kadian not found in the embedding dictionary.
# Vector for Dexbrompheniramine not found in the embedding dictionary.
# Vector for oxyphenbutazone found in the embedding dictionary.
# Vector for amitriptyline HCl not found in the embedding dictionary.
# Vector for Thioridazine not found in the embedding dictionary.
# Vector for levothyroxine sodium found in the embedding dictionary.
# Vector for imipramine hydrochloride found in the embedding dictionary.
# Vector for 5-oxo-desethylzaleplon not found in the embedding dictionary.
# Vector for BOTOX not found in the embedding dictionary.
# Vector for Bactrim not found in the embedding dictionary.
# Vector for metoprolol found in the embedding dictionary.
# Vector for eplerenone not found in the embedding dictionary.
# Vector for doxorubicin HCL not found in the embedding dictionary.
# Vector for endotoxin not found in the embedding dictionary.
# Vector for Resveratrol not found in the embedding dictionary.
# Vector for 5-fluorouracil found in the embedding dictionary.
# Vector for NovoLog not found in the embedding dictionary.
# Vector for zidovudine found in the embedding dictionary.
# Vector for carbamazepine found in the embedding dictionary.
# Vector for PROPECIA not found in the embedding dictionary.
# Vector for itraconazole found in the embedding dictionary.
# Vector for estradiol found in the embedding dictionary.
# Vector for BARACLUDE not found in the embedding dictionary.
# Vector for icodextrin not found in the embedding dictionary.
# Vector for Dexamethasone not found in the embedding dictionary.
# Vector for hydrochloroquine found in the embedding dictionary.
# Vector for enkephalins not found in the embedding dictionary.
# Vector for aliskiren not found in the embedding dictionary.
# Vector for Myochrysine not found in the embedding dictionary.
# Vector for 4-hydroxytolbutamide not found in the embedding dictionary.
# Vector for quinidine found in the embedding dictionary.
# Vector for cyclosporin found in the embedding dictionary.
# Vector for carvedilol found in the embedding dictionary.
# Vector for Sirolimus not found in the embedding dictionary.
# Vector for levamisole found in the embedding dictionary.
# Vector for verografin found in the embedding dictionary.
# Vector for Fluvastatin not found in the embedding dictionary.
# Vector for carbidopa found in the embedding dictionary.
# Vector for Sodium Pertechnetate Tc99m not found in the embedding dictionary.
# Vector for filipin not found in the embedding dictionary.
# Vector for loratadine found in the embedding dictionary.
# Vector for morphine found in the embedding dictionary.
# Vector for prednisone found in the embedding dictionary.
# Vector for Magan not found in the embedding dictionary.
# Vector for lopinavir not found in the embedding dictionary.
# Vector for Medroxyprogesterone Acetate not found in the embedding dictionary.
# Vector for RR not found in the embedding dictionary.
# Vector for thiabendazole found in the embedding dictionary.
# Vector for SUBOXONE not found in the embedding dictionary.
# Vector for Pepto-Bismol not found in the embedding dictionary.
# Vector for choline salicylate found in the embedding dictionary.
# Vector for R-warfarin not found in the embedding dictionary.
# Vector for mesalamine found in the embedding dictionary.
# Vector for sertindole found in the embedding dictionary.
# Vector for allopurinol found in the embedding dictionary.
# Vector for Auranofin not found in the embedding dictionary.
# Vector for formoterol found in the embedding dictionary.
# Vector for aspirin found in the embedding dictionary.
# Vector for captopril found in the embedding dictionary.
# Vector for Amiodarone not found in the embedding dictionary.
# Vector for albendazole found in the embedding dictionary.
# Vector for escitalopram not found in the embedding dictionary.
# Vector for ethotoin found in the embedding dictionary.
# Vector for mecamylamine found in the embedding dictionary.
# Vector for Phenylbutazone not found in the embedding dictionary.
# Vector for tadalafil not found in the embedding dictionary.
# Vector for neomycin sulfate found in the embedding dictionary.
# Vector for pseudoephedrine found in the embedding dictionary.
# Vector for Aranesp not found in the embedding dictionary.
# Vector for Aminosalicylic acid not found in the embedding dictionary.
# Vector for Acebutolol not found in the embedding dictionary.
# Vector for norfloxacin found in the embedding dictionary.
# Vector for Vidaza not found in the embedding dictionary.
# Vector for somatrem found in the embedding dictionary.
# Vector for IOPIDINE not found in the embedding dictionary.
# Vector for ethionamide found in the embedding dictionary.
# Vector for Warfarin not found in the embedding dictionary.
# Vector for acetaldehyde not found in the embedding dictionary.
# Vector for rosiglitazone not found in the embedding dictionary.
# Vector for ADL-8-2698 not found in the embedding dictionary.
# Vector for chloroquine found in the embedding dictionary.
# Vector for benzodiazepines found in the embedding dictionary.
# Vector for alcohol found in the embedding dictionary.
# Vector for Azlocillin not found in the embedding dictionary.
# Vector for ENBREL not found in the embedding dictionary.
# Vector for Indocyanine green not found in the embedding dictionary.
# Vector for EXTRANEAL not found in the embedding dictionary.
# Vector for tubocurarine found in the embedding dictionary.
# Vector for Orudis KT not found in the embedding dictionary.
# Vector for PGF2alpha not found in the embedding dictionary.
# Vector for Serentil not found in the embedding dictionary.
# Vector for Angiomax not found in the embedding dictionary.
# Vector for norbuprenorphine not found in the embedding dictionary.
# Vector for chlorothiazide found in the embedding dictionary.
# Vector for t1 found in the embedding dictionary.
# Vector for digoxin found in the embedding dictionary.
# Vector for DURAGESIC not found in the embedding dictionary.
# Vector for nizatidine found in the embedding dictionary.
# Vector for iloprost found in the embedding dictionary.
# Vector for kanamycin found in the embedding dictionary.
# Vector for CMC-Cys not found in the embedding dictionary.
# Vector for Valdecoxib not found in the embedding dictionary.
# Vector for 6-mercaptopurine found in the embedding dictionary.
# Vector for Mithracin not found in the embedding dictionary.
# Vector for Dapsone not found in the embedding dictionary.
# Vector for clofarabine not found in the embedding dictionary.
# Vector for azithromycin found in the embedding dictionary.
# Vector for Orlistat not found in the embedding dictionary.
# Vector for Isoproterenol hydrochloride not found in the embedding dictionary.
# Vector for Griseofulvin not found in the embedding dictionary.
# Vector for secobarbital found in the embedding dictionary.
# Vector for idoxuridine found in the embedding dictionary.
# Vector for prilocaine found in the embedding dictionary.
# Vector for thiazolesulfone not found in the embedding dictionary.
# Vector for ribavirin found in the embedding dictionary.
# Vector for magnesium salt found in the embedding dictionary.
# Vector for fludrocortisone acetate found in the embedding dictionary.
# Vector for INH not found in the embedding dictionary.
# Vector for trimeprazine found in the embedding dictionary.
# Vector for Trilisate not found in the embedding dictionary.
# Vector for sulfur found in the embedding dictionary.
# Vector for Neurontin not found in the embedding dictionary.
# Vector for Neoral not found in the embedding dictionary.
# Vector for Albendazole sulfoxide not found in the embedding dictionary.
# Vector for HIVID not found in the embedding dictionary.
# Vector for diphenoxylate found in the embedding dictionary.
# Vector for Nimotop not found in the embedding dictionary.
# Vector for Celexa not found in the embedding dictionary.
# Vector for guafacine not found in the embedding dictionary.
# Vector for PABA not found in the embedding dictionary.
# Vector for Dofetilide not found in the embedding dictionary.
# Vector for S(-) warfarin not found in the embedding dictionary.
# Vector for Ginkgo biloba not found in the embedding dictionary.
# Vector for ketamine found in the embedding dictionary.
# Vector for palytoxin not found in the embedding dictionary.
# Vector for pentazocine found in the embedding dictionary.
# Vector for Nevirapine not found in the embedding dictionary.
# Vector for theophylline found in the embedding dictionary.
# Vector for TAO not found in the embedding dictionary.
# Vector for imipramine found in the embedding dictionary.
# Vector for Antiarrhythmics not found in the embedding dictionary.
# Vector for ORENCIA not found in the embedding dictionary.
# Vector for Saquinavir not found in the embedding dictionary.
# Vector for latamoxef found in the embedding dictionary.
# Vector for norethandrolone found in the embedding dictionary.
# Vector for rifabutin found in the embedding dictionary.
# Vector for capecitabine not found in the embedding dictionary.
# Vector for ethyl alcohol found in the embedding dictionary.
# Vector for fondaparinux sodium not found in the embedding dictionary.
# Vector for trifluoperazine found in the embedding dictionary.
# Vector for Pronestyl not found in the embedding dictionary.
# Vector for fosinopril sodium found in the embedding dictionary.
# Vector for TRISENOX not found in the embedding dictionary.
# Vector for griseofulvin found in the embedding dictionary.
# Vector for ADL 8-2698 not found in the embedding dictionary.
# Vector for 1-methyl-4-phenyl-1,2,5,6-tetrahydropyridine not found in the embedding dictionary.
# Vector for a-methyldopa found in the embedding dictionary.
# Vector for Cimetidine not found in the embedding dictionary.
# Vector for vancomycin found in the embedding dictionary.
# Vector for cycloserine found in the embedding dictionary.
# Vector for lymecycline found in the embedding dictionary.
# Vector for cysteine found in the embedding dictionary.
# Vector for bleomycin found in the embedding dictionary.
# Vector for CYP2C9 not found in the embedding dictionary.
# Vector for pentamidine found in the embedding dictionary.
# Vector for omeprazole found in the embedding dictionary.
# Vector for etodolac found in the embedding dictionary.
# Vector for methylphenidate found in the embedding dictionary.
# Vector for Disopyramide not found in the embedding dictionary.
# Vector for DOXIL not found in the embedding dictionary.
# Vector for Mercaptopurine not found in the embedding dictionary.
# Vector for vitamin B6 not found in the embedding dictionary.
# Vector for naloxone found in the embedding dictionary.
# Vector for glimepiride found in the embedding dictionary.
# Vector for retinyl acetate found in the embedding dictionary.
# Vector for Tindal not found in the embedding dictionary.
# Vector for diclofenac found in the embedding dictionary.
# Vector for propafenone found in the embedding dictionary.
# Vector for Cyclosporine not found in the embedding dictionary.
# Vector for nitroglycerin found in the embedding dictionary.
# Vector for diltiazem hydrochloride found in the embedding dictionary.
# Vector for SPRYCEL not found in the embedding dictionary.
# Vector for promethazine found in the embedding dictionary.
# Vector for cyclosporin A not found in the embedding dictionary.
# Vector for MAXIPIME not found in the embedding dictionary.
# Vector for nortriptyline hydrochloride found in the embedding dictionary.
# Vector for Ortho-Novum not found in the embedding dictionary.
# Vector for lincomycin found in the embedding dictionary.
# Vector for ZDV not found in the embedding dictionary.
# Vector for cetirizine found in the embedding dictionary.
# Vector for Sensipar not found in the embedding dictionary.
# Vector for norethindrone acetate found in the embedding dictionary.
# Vector for STADOL NS not found in the embedding dictionary.
# Vector for sulfapyridine found in the embedding dictionary.
# Vector for colchicine found in the embedding dictionary.
# Vector for selegiline found in the embedding dictionary.
# Vector for green tea gallocatechins not found in the embedding dictionary.
# Vector for fenbufen found in the embedding dictionary.
# Vector for digitoxin found in the embedding dictionary.
# Vector for doxazosin found in the embedding dictionary.
# Vector for bexarotene not found in the embedding dictionary.
# Vector for Vitrasert not found in the embedding dictionary.
# Vector for cis-platinum found in the embedding dictionary.
# Vector for didanosine found in the embedding dictionary.
# Vector for Azithromycin not found in the embedding dictionary.
# Vector for triacetyloleandomycin found in the embedding dictionary.
# Vector for atovaquone found in the embedding dictionary.
# Vector for Diclofenac not found in the embedding dictionary.
# Vector for FORADIL not found in the embedding dictionary.
# Vector for salicylate found in the embedding dictionary.
# Vector for diethylpropion found in the embedding dictionary.
# Vector for OXC not found in the embedding dictionary.
# Vector for heroin found in the embedding dictionary.
# Vector for sodium bicarbonate found in the embedding dictionary.
# Vector for Prozac not found in the embedding dictionary.
# Vector for Theo-Dur not found in the embedding dictionary.
# Vector for cefazolin found in the embedding dictionary.
# Vector for Lopressor not found in the embedding dictionary.
# Vector for phenyramidol not found in the embedding dictionary.
# Vector for spermidine not found in the embedding dictionary.
# Vector for angiotensin 2 not found in the embedding dictionary.
# Vector for prochlorperazine edisylate found in the embedding dictionary.
# Vector for perphenazine found in the embedding dictionary.
# Vector for Monoamine Oxidase Inhibitors not found in the embedding dictionary.
# Vector for Furazolidone not found in the embedding dictionary.
# Vector for cytochalasin D not found in the embedding dictionary.
# Vector for atracurium found in the embedding dictionary.
# Vector for diflunisal found in the embedding dictionary.
# Vector for ziprasidone not found in the embedding dictionary.
# Vector for succinylcholine chloride found in the embedding dictionary.
# Vector for Oruvail not found in the embedding dictionary.
# Vector for cefoxitin found in the embedding dictionary.
# Vector for phenelzine sulfate found in the embedding dictionary.
# Vector for DEET not found in the embedding dictionary.
# Vector for Amoxicillin not found in the embedding dictionary.
# Vector for glyceryl trinitrate found in the embedding dictionary.
# Vector for cyclosporine found in the embedding dictionary.
# Vector for flurbiprofen found in the embedding dictionary.
# Vector for Tegison not found in the embedding dictionary.
# Vector for Thalidomide not found in the embedding dictionary.
# Vector for cefmenoxime found in the embedding dictionary.
# Vector for droperidol found in the embedding dictionary.
# Vector for nitroferricyanide found in the embedding dictionary.
# Vector for Clidinium not found in the embedding dictionary.
# Vector for SUPRAX not found in the embedding dictionary.
# Vector for norepinephrine found in the embedding dictionary.
# Vector for Atromid-S not found in the embedding dictionary.
# Vector for leukocyte transfusions not found in the embedding dictionary.
# Vector for amyl nitrite found in the embedding dictionary.
# Vector for thioridazine found in the embedding dictionary.
# Vector for VAPRISOL not found in the embedding dictionary.
# Vector for everolimus not found in the embedding dictionary.
# Vector for Apraclonidine not found in the embedding dictionary.
# Vector for butorphanol found in the embedding dictionary.
# Vector for verapamil found in the embedding dictionary.
# Vector for PROSTIN E2 not found in the embedding dictionary.
# Vector for buspirone found in the embedding dictionary.
# Vector for amrinone found in the embedding dictionary.
# Vector for Cuprimine not found in the embedding dictionary.
# Vector for Type II pyrethroid not found in the embedding dictionary.
# Vector for flutamide found in the embedding dictionary.
# Vector for 25-O-desacetylrifabutin not found in the embedding dictionary.
# Vector for penicillins found in the embedding dictionary.
# Vector for nitazoxanide found in the embedding dictionary.
# Vector for granisetron found in the embedding dictionary.
# Vector for lithium carbonate found in the embedding dictionary.
# Vector for Cordarone I.V. not found in the embedding dictionary.
# Vector for nonsteroidal anti-inflammatory found in the embedding dictionary.
# Vector for anidulafungin not found in the embedding dictionary.
# Vector for Green tea polyphenols not found in the embedding dictionary.
# Vector for Bezalip retard not found in the embedding dictionary.
# Vector for succinylcholine found in the embedding dictionary.
# Vector for Carbimazole not found in the embedding dictionary.
# Vector for flavoridin not found in the embedding dictionary.
# Vector for ethinamate found in the embedding dictionary.
# Vector for acetazolamide found in the embedding dictionary.
# Vector for Sulfacetamide not found in the embedding dictionary.
# Vector for Meclofenamate sodium not found in the embedding dictionary.
# Vector for Dasatinib not found in the embedding dictionary.
# Vector for Charcoal not found in the embedding dictionary.
# Vector for alefacept not found in the embedding dictionary.
# Vector for Eldepryl not found in the embedding dictionary.
# Vector for insulin found in the embedding dictionary.
# Vector for ACTH not found in the embedding dictionary.
# Vector for Nimodipine not found in the embedding dictionary.
# Vector for netilmicin found in the embedding dictionary.
# Vector for cinoxacin found in the embedding dictionary.
# Vector for ethosuximide found in the embedding dictionary.
# Vector for norfluoxetine not found in the embedding dictionary.
# Vector for Dantrium not found in the embedding dictionary.
# Vector for clonazepam found in the embedding dictionary.
# Vector for Voltaren not found in the embedding dictionary.
# Vector for dasatinib not found in the embedding dictionary.
# Vector for oxipurinol found in the embedding dictionary.
# Vector for pyrilamine found in the embedding dictionary.
# Vector for Pentamidine not found in the embedding dictionary.
# Vector for acenocoumarol found in the embedding dictionary.
# Vector for Somatropin not found in the embedding dictionary.
# Vector for antibiotics found in the embedding dictionary.
# Vector for Geocillin not found in the embedding dictionary.
# Vector for trovafloxacin not found in the embedding dictionary.
# Vector for minocycline found in the embedding dictionary.
# Vector for propantheline found in the embedding dictionary.
# Vector for Cefizox not found in the embedding dictionary.
# Vector for desmethylastermizole not found in the embedding dictionary.
# Vector for thyroid found in the embedding dictionary.
# Vector for RAPTIVA not found in the embedding dictionary.
# Vector for lidocaine found in the embedding dictionary.
# Vector for warfarin sodium found in the embedding dictionary.
# Vector for Dantrolene not found in the embedding dictionary.
# Vector for Nydrazid not found in the embedding dictionary.
# Vector for NaCMC not found in the embedding dictionary.
# Vector for glucagon found in the embedding dictionary.
# Vector for sodium cephalothin found in the embedding dictionary.
# Vector for fexofenadine hydrochloride not found in the embedding dictionary.
# Vector for Lamivudine not found in the embedding dictionary.
# Vector for irinotecan found in the embedding dictionary.
# Vector for Tadalafil not found in the embedding dictionary.
# Vector for Kaletra not found in the embedding dictionary.
# Vector for methysergide found in the embedding dictionary.
# Vector for physostigmine found in the embedding dictionary.
# Vector for ethinylestradiol found in the embedding dictionary.
# Vector for phencyclidine not found in the embedding dictionary.
# Vector for tolbutamide found in the embedding dictionary.
# Vector for nalidixic acid found in the embedding dictionary.
# Vector for Bexarotene not found in the embedding dictionary.
# Vector for norethindrone found in the embedding dictionary.
# Vector for Topamax not found in the embedding dictionary.
# Vector for Depakene not found in the embedding dictionary.
# Vector for ACZONE not found in the embedding dictionary.
# Vector for progesterone found in the embedding dictionary.
# Vector for Epinephrine not found in the embedding dictionary.
# Vector for Antiminth not found in the embedding dictionary.
# Vector for Furosemide not found in the embedding dictionary.
# Vector for simvastatin found in the embedding dictionary.
# Vector for hydroxyitraconazole not found in the embedding dictionary.
# Vector for terbutaline found in the embedding dictionary.
# Vector for bismuth subsalicylate found in the embedding dictionary.
# Vector for cobalt found in the embedding dictionary.
# Vector for 5-DFUR not found in the embedding dictionary.
# Vector for Bromocriptine mesylate not found in the embedding dictionary.
# Vector for sulfisoxazole found in the embedding dictionary.
# Vector for FLOLAN not found in the embedding dictionary.
# Vector for Prostin VR Pediatric not found in the embedding dictionary.
# Vector for alprazolam found in the embedding dictionary.
# Vector for trichlorfon not found in the embedding dictionary.
# Vector for tiagabine found in the embedding dictionary.
# Vector for ondansetron found in the embedding dictionary.
# Vector for busulfan found in the embedding dictionary.
# Vector for labetalol found in the embedding dictionary.
# Vector for bezafibrate found in the embedding dictionary.
# Vector for iodamide found in the embedding dictionary.
# Vector for Azathioprine not found in the embedding dictionary.
# Vector for isoniazide found in the embedding dictionary.
# Vector for labetalol HCl not found in the embedding dictionary.
# Vector for Furadantin not found in the embedding dictionary.
# Vector for oxytetracycline found in the embedding dictionary.
# Vector for Phencyclidine not found in the embedding dictionary.
# Vector for niacinamide found in the embedding dictionary.
# Vector for procarbazine found in the embedding dictionary.
# Vector for Sectral not found in the embedding dictionary.
# Vector for clonidine hydrochloride found in the embedding dictionary.
# Vector for EGF not found in the embedding dictionary.
# Vector for sertraline found in the embedding dictionary.
# Vector for Depakote not found in the embedding dictionary.
# Vector for Zarontin not found in the embedding dictionary.
# Vector for anti-arrhythmic found in the embedding dictionary.
# Vector for Enalapril not found in the embedding dictionary.
# Vector for aluminum found in the embedding dictionary.
# Vector for Enoxacin not found in the embedding dictionary.
# Vector for cholestyramine found in the embedding dictionary.
# Vector for ALPHAGAN P not found in the embedding dictionary.
# Vector for Caffeine not found in the embedding dictionary.
# Vector for amphotericin found in the embedding dictionary.
# Vector for TMP not found in the embedding dictionary.
# Vector for Allopurinol not found in the embedding dictionary.
# Vector for penicillamine found in the embedding dictionary.
# Vector for Phospholine Iodide not found in the embedding dictionary.
# Vector for carbachol found in the embedding dictionary.
# Vector for arginine found in the embedding dictionary.
# Vector for PTX not found in the embedding dictionary.
# Vector for (-)-NANM not found in the embedding dictionary.
# Vector for Eszopiclone not found in the embedding dictionary.
# Vector for Methadone not found in the embedding dictionary.
# Vector for amphotericin B not found in the embedding dictionary.
# Vector for atorvastatin not found in the embedding dictionary.
# Vector for dofetillide not found in the embedding dictionary.
# Vector for OVCON-35 not found in the embedding dictionary.
# Vector for magnesium/choline salicylate not found in the embedding dictionary.
# Vector for Gentamycin not found in the embedding dictionary.
# Vector for Omeprazole not found in the embedding dictionary.
# Vector for ZEBETA not found in the embedding dictionary.
# Vector for nisoldipine found in the embedding dictionary.
# Vector for Propantheline not found in the embedding dictionary.
# Vector for VIDEX not found in the embedding dictionary.
# Vector for Nicotine not found in the embedding dictionary.
# Vector for cefditoren not found in the embedding dictionary.
# Vector for Acarbose not found in the embedding dictionary.
# Vector for topiramate found in the embedding dictionary.
# Vector for Prednisone not found in the embedding dictionary.
# Vector for epinephrine found in the embedding dictionary.
# Vector for Nardil not found in the embedding dictionary.
# Vector for LEVSIN not found in the embedding dictionary.
# Vector for acamprosate found in the embedding dictionary.
# Vector for Nizoral not found in the embedding dictionary.
# Vector for Itraconazole not found in the embedding dictionary.
# Vector for timolol found in the embedding dictionary.
# Vector for COLESTlD not found in the embedding dictionary.
# Vector for dantrolene found in the embedding dictionary.
# Vector for nevirapine found in the embedding dictionary.
# Vector for antidepressants found in the embedding dictionary.
# Vector for Procainamide not found in the embedding dictionary.
# Vector for Jacalin not found in the embedding dictionary.
# Vector for disulfiram found in the embedding dictionary.
# Vector for thiocyanate found in the embedding dictionary.
# Vector for ethanol found in the embedding dictionary.
# Vector for penicillin V not found in the embedding dictionary.
# Vector for chloroprocaine found in the embedding dictionary.
# Vector for CIMETlDINE not found in the embedding dictionary.
# Vector for Anabolin not found in the embedding dictionary.
# Vector for gefitinib not found in the embedding dictionary.
# Vector for Soliris not found in the embedding dictionary.
# Vector for MPTP not found in the embedding dictionary.
# Vector for Trecator not found in the embedding dictionary.
# Vector for Anesthetic not found in the embedding dictionary.
# Vector for Gantrisin not found in the embedding dictionary.
# Vector for Cyclophosphamide not found in the embedding dictionary.
# Vector for alosetron not found in the embedding dictionary.
# Vector for galangin found in the embedding dictionary.
# Vector for ethacrynic acid found in the embedding dictionary.
# Vector for Etretinate not found in the embedding dictionary.
# Vector for Fosinopril not found in the embedding dictionary.
# Vector for surfactant found in the embedding dictionary.
# Vector for nalbuphine found in the embedding dictionary.
# Vector for cocaine found in the embedding dictionary.
# Vector for clofazimine found in the embedding dictionary.
# Vector for arsenate not found in the embedding dictionary.
# Vector for Antizol not found in the embedding dictionary.
# Vector for trazodone found in the embedding dictionary.
# Vector for Purinethol not found in the embedding dictionary.
# Vector for REFLUDAN not found in the embedding dictionary.
# Vector for NTG not found in the embedding dictionary.
# Vector for ATROVENT not found in the embedding dictionary.
# Vector for L-phenylalanine not found in the embedding dictionary.
# Vector for CNS depressants not found in the embedding dictionary.
# Vector for flupenthixol found in the embedding dictionary.
# Vector for Ketoprofen not found in the embedding dictionary.
# Vector for Sulfapyridine not found in the embedding dictionary.
# Vector for alendronate found in the embedding dictionary.
# Vector for peginterferon not found in the embedding dictionary.
# Vector for alfentanil found in the embedding dictionary.
# Vector for Vecuronium not found in the embedding dictionary.
# Vector for Arecoline not found in the embedding dictionary.
# Vector for FLUOTHANE not found in the embedding dictionary.
# Vector for heparin found in the embedding dictionary.
# Vector for AZOPT not found in the embedding dictionary.
# Vector for REMICADE not found in the embedding dictionary.
# Vector for oxytocin found in the embedding dictionary.
# Vector for cefamandole naftate found in the embedding dictionary.
# Vector for Amphotericin B not found in the embedding dictionary.
# Vector for ERYTHROMYCIN not found in the embedding dictionary.
# Vector for Heparin sodium not found in the embedding dictionary.
# Vector for HEXALEN not found in the embedding dictionary.
# Vector for ciclesonide not found in the embedding dictionary.
# Vector for cefditoren pivoxil not found in the embedding dictionary.
# Vector for Captopril not found in the embedding dictionary.
# Vector for Phenytoin not found in the embedding dictionary.
# Vector for voriconazole not found in the embedding dictionary.
# Vector for doxylamine found in the embedding dictionary.
# Vector for ZYVOX not found in the embedding dictionary.
# Vector for Nateglinide not found in the embedding dictionary.
# Vector for IDV not found in the embedding dictionary.
# Vector for Tiazac not found in the embedding dictionary.
# Vector for magnesium trisilicate found in the embedding dictionary.
# Vector for folic acid found in the embedding dictionary.
# Vector for oxacillin found in the embedding dictionary.
# Vector for oxymetazoline found in the embedding dictionary.
# Vector for TRACLEER not found in the embedding dictionary.
# Vector for PLENDIL not found in the embedding dictionary.
# Vector for ergot found in the embedding dictionary.
# Vector for Cholestytamine not found in the embedding dictionary.
# Vector for Fluconazole not found in the embedding dictionary.
# Vector for Pyrantel not found in the embedding dictionary.
# Vector for Disulfiram not found in the embedding dictionary.
# Vector for MONUROL not found in the embedding dictionary.
# Vector for para-aminosalicylic acid found in the embedding dictionary.
# Vector for midazolam found in the embedding dictionary.
# Vector for zopiclone found in the embedding dictionary.
# Vector for Rofecoxib not found in the embedding dictionary.
# Vector for IRESSA not found in the embedding dictionary.
# Vector for Amprenavir not found in the embedding dictionary.
# Vector for SINEQUAN not found in the embedding dictionary.
# Vector for ALFENTA not found in the embedding dictionary.
# Vector for quetiapine not found in the embedding dictionary.
# Vector for Ethinyl Estradiol not found in the embedding dictionary.
# Vector for Leucovorin not found in the embedding dictionary.
# Vector for ibogaine not found in the embedding dictionary.
# Vector for Diazepam not found in the embedding dictionary.
# Vector for etomidate found in the embedding dictionary.
# Vector for benzoxazinorifamycin not found in the embedding dictionary.
# Vector for Alcohol not found in the embedding dictionary.
# Vector for letrozole not found in the embedding dictionary.
# Vector for levorphanol found in the embedding dictionary.
# Vector for atomoxetine not found in the embedding dictionary.
# Vector for estazolam found in the embedding dictionary.
# Vector for Sulfoxone not found in the embedding dictionary.
# Vector for selegiline hydrochloride found in the embedding dictionary.
# Vector for paroxetine found in the embedding dictionary.
# Vector for Gold not found in the embedding dictionary.
# Vector for diltiazem found in the embedding dictionary.
# Vector for nicotine found in the embedding dictionary.
# Vector for haloperidol found in the embedding dictionary.
# Vector for terfenadine found in the embedding dictionary.
# Vector for Carbamazepine epoxide not found in the embedding dictionary.
# Vector for Clofibric acid not found in the embedding dictionary.
# Vector for Fenbufen not found in the embedding dictionary.
# Vector for nicotinamide found in the embedding dictionary.
# Vector for doxycycline found in the embedding dictionary.
# Vector for Perhexiline hydrogen maleate not found in the embedding dictionary.
# Vector for albendazole sulfoxide found in the embedding dictionary.
# Vector for Cytosine arabinoside not found in the embedding dictionary.
# Vector for carbamazepine epoxide not found in the embedding dictionary.
# Vector for Delavirdine not found in the embedding dictionary.
# Vector for gemifloxacin not found in the embedding dictionary.
# Vector for ceftazidime found in the embedding dictionary.
# Vector for Ponstel not found in the embedding dictionary.
# Vector for valproic acid found in the embedding dictionary.
# Vector for Vitamin D2 not found in the embedding dictionary.
# Vector for Amitriptyline not found in the embedding dictionary.
# Vector for glutamic acid found in the embedding dictionary.
# Vector for Robinul not found in the embedding dictionary.
# Vector for vitamin C not found in the embedding dictionary.
# Vector for sodium dodecyl sulfate not found in the embedding dictionary.
# Vector for Primidone not found in the embedding dictionary.
# Vector for TRACRIUM not found in the embedding dictionary.
# Vector for lorazepam found in the embedding dictionary.
# Vector for Cetrotide not found in the embedding dictionary.
# Vector for pancreatin found in the embedding dictionary.
# Vector for Fluoxetine not found in the embedding dictionary.
# Vector for magnesium salicylate found in the embedding dictionary.
# Vector for Acetohydroxamic acid not found in the embedding dictionary.
# Vector for Isocarboxazid not found in the embedding dictionary.
# Vector for SCH-23390 not found in the embedding dictionary.
# Vector for felodipine found in the embedding dictionary.
# Vector for fosfomycin found in the embedding dictionary.
# Vector for triazolam found in the embedding dictionary.
# Vector for vinblastine found in the embedding dictionary.
# Vector for Cyclopropane not found in the embedding dictionary.
# Vector for 3H-spiroperidol not found in the embedding dictionary.
# Vector for organophosphate insecticide not found in the embedding dictionary.
# Vector for Imipramine not found in the embedding dictionary.
# Vector for aluminum hydroxide found in the embedding dictionary.
# Vector for isoflurane found in the embedding dictionary.
# Vector for isotretinoin found in the embedding dictionary.
# Vector for Phenergan not found in the embedding dictionary.
# Vector for methyldopa found in the embedding dictionary.
# Vector for hydralazine found in the embedding dictionary.
# Vector for nefazadone found in the embedding dictionary.
# Vector for PROSCAR not found in the embedding dictionary.
# Vector for Alosetron not found in the embedding dictionary.
# Vector for levetiracetam not found in the embedding dictionary.
# Vector for cerulein not found in the embedding dictionary.
# Vector for nafarelin acetate found in the embedding dictionary.
# Vector for EMTRIVA not found in the embedding dictionary.
# Vector for Levodopa not found in the embedding dictionary.
# Vector for Human growth hormone not found in the embedding dictionary.
# Vector for ketoconazole found in the embedding dictionary.
# Vector for Dexrazoxane not found in the embedding dictionary.
# Vector for hydroxybupropion not found in the embedding dictionary.
# Vector for flumazenil found in the embedding dictionary.
# Vector for aminocaproic acid found in the embedding dictionary.
# Vector for Trecator-SC not found in the embedding dictionary.
# Vector for Hydrodiuril not found in the embedding dictionary.
# Vector for eprosartan not found in the embedding dictionary.
# Vector for N-desmethylclozapine not found in the embedding dictionary.
# Vector for divalproex sodium found in the embedding dictionary.
# Vector for cefuroxime found in the embedding dictionary.
# Vector for norgestrel found in the embedding dictionary.
# Vector for GL not found in the embedding dictionary.
# Vector for bacitracin found in the embedding dictionary.
# Vector for Bezalip not found in the embedding dictionary.
# Vector for erlotinib not found in the embedding dictionary.
# Vector for furazolidone found in the embedding dictionary.
# Vector for hydroxylated fenoprofen not found in the embedding dictionary.
# Vector for sodium fluorescein found in the embedding dictionary.
# Vector for INVIRASE not found in the embedding dictionary.
# Vector for apomorphine found in the embedding dictionary.
# Vector for ibutilide found in the embedding dictionary.
# Vector for Clozapine not found in the embedding dictionary.
# Vector for 4-hydroxyatomoxetine not found in the embedding dictionary.
# Vector for Ancobon not found in the embedding dictionary.
# Vector for Ascorbic acid not found in the embedding dictionary.
# Vector for cephalothin found in the embedding dictionary.
# Vector for Grepafloxacin not found in the embedding dictionary.
# Vector for cisapride found in the embedding dictionary.
# Vector for IMITREX not found in the embedding dictionary.
# Vector for 99mTc-MDP not found in the embedding dictionary.
# Vector for d-amphetamine found in the embedding dictionary.
# Vector for etoposide found in the embedding dictionary.
# Vector for Spermine not found in the embedding dictionary.
# Vector for Midazolam not found in the embedding dictionary.
# Vector for CELEBREX not found in the embedding dictionary.
# Vector for triamterene found in the embedding dictionary.
# Vector for charcoal found in the embedding dictionary.
# Vector for Prednisolone not found in the embedding dictionary.
# Vector for DPCPX not found in the embedding dictionary.
# Vector for nefazodone found in the embedding dictionary.
# Vector for ritonavir not found in the embedding dictionary.
# Vector for Carmustine not found in the embedding dictionary.
# Vector for fosphenytoin not found in the embedding dictionary.
# Vector for descarboethoxyloratadine found in the embedding dictionary.
# Vector for ZEVALIN not found in the embedding dictionary.
# Vector for radiopertechnetate found in the embedding dictionary.
# Vector for lofexidine found in the embedding dictionary.
# Vector for Clostridium difficile toxin A not found in the embedding dictionary.
# Vector for clarithromycin found in the embedding dictionary.
# Vector for Survanta not found in the embedding dictionary.
# Vector for Argatroban not found in the embedding dictionary.
# Vector for antiarrhythmic drug found in the embedding dictionary.
# Vector for Desyrel not found in the embedding dictionary.
# Vector for Sucralfate not found in the embedding dictionary.
# Vector for dantrolene sodium found in the embedding dictionary.
# Vector for ruthenium red not found in the embedding dictionary.
# Vector for Carboplatin not found in the embedding dictionary.
# Vector for furosemide found in the embedding dictionary.
# Vector for histamine found in the embedding dictionary.
# Vector for cloxacillin found in the embedding dictionary.
# Vector for L-CCG-1 not found in the embedding dictionary.
# Vector for Gemfibrozil not found in the embedding dictionary.
# Vector for Astramorph not found in the embedding dictionary.
# Vector for Mellaril not found in the embedding dictionary.
# Vector for digitalis found in the embedding dictionary.
# Vector for Quinine not found in the embedding dictionary.
# Vector for Albuterol not found in the embedding dictionary.
# Vector for pyrantel found in the embedding dictionary.
# Vector for D-Ala2-metenkephalinamide not found in the embedding dictionary.
# Vector for Ketorolac not found in the embedding dictionary.
# Vector for levodopa found in the embedding dictionary.
# Vector for anileridine found in the embedding dictionary.
# Vector for fenoprofen found in the embedding dictionary.
# Vector for nitrofurantoin found in the embedding dictionary.
# Vector for Lipitor not found in the embedding dictionary.
# Vector for Netilmicin not found in the embedding dictionary.
# Vector for nicardipine HCl not found in the embedding dictionary.
# Vector for cardiotrast found in the embedding dictionary.
# Vector for disopyramide phosphate found in the embedding dictionary.
# Vector for CLOLAR not found in the embedding dictionary.
# Vector for loracarbef found in the embedding dictionary.
# Vector for penicillin G not found in the embedding dictionary.
# Vector for Hydrocodone not found in the embedding dictionary.
# Vector for chlorpropamide found in the embedding dictionary.
# Vector for chloral hydrate found in the embedding dictionary.
# Vector for Caspofungin not found in the embedding dictionary.
# Vector for Plenaxis not found in the embedding dictionary.
# Vector for frovatriptan not found in the embedding dictionary.
# Vector for doxapram found in the embedding dictionary.
# Vector for Norpace CR not found in the embedding dictionary.
# Vector for naltrexone found in the embedding dictionary.
# Vector for VIOXX not found in the embedding dictionary.
# Vector for Calcitriol not found in the embedding dictionary.
# Vector for Thyroxine not found in the embedding dictionary.
# Vector for fentayl found in the embedding dictionary.
# Vector for guanadrel found in the embedding dictionary.
# Vector for Dimenhydrinate not found in the embedding dictionary.
# Vector for silver found in the embedding dictionary.
# Vector for 16,16-dimethylprostaglandin E2 not found in the embedding dictionary.
# Vector for MIDAMOR not found in the embedding dictionary.
# Vector for rifadin found in the embedding dictionary.
# Vector for Medrol not found in the embedding dictionary.
# Vector for diuretics found in the embedding dictionary.
# Vector for conivaptan not found in the embedding dictionary.
# Vector for alfentanyl found in the embedding dictionary.
# Vector for infliximab not found in the embedding dictionary.
# Vector for encainide found in the embedding dictionary.
# Vector for naproxen sodium found in the embedding dictionary.
# Vector for METH not found in the embedding dictionary.
# ...
# Vector for hydralazine found in the embedding dictionary.
# Vector for dihydroergotamine found in the embedding dictionary.
# Vector for Fenofibrate not found in the embedding dictionary.
# Vector for 1-methyl-4-phenyl-1,2,3,6-tetrahydropyridine not found in the embedding dictionary.
# Vector for hemantane not found in the embedding dictionary.
# Vector for Levodopa not found in the embedding dictionary.
# Vector for ketoconazole found in the embedding dictionary.
# Vector for acetylsalicylic acid found in the embedding dictionary.
# Vector for divalproex sodium found in the embedding dictionary.
# Vector for bacitracin found in the embedding dictionary.
# Vector for Alupent not found in the embedding dictionary.
# Vector for furazolidone found in the embedding dictionary.
# Vector for TNKase not found in the embedding dictionary.
# Vector for testolactone not found in the embedding dictionary.
# Vector for ARAMINE not found in the embedding dictionary.
# Vector for terbinafine found in the embedding dictionary.
# Vector for Tenecteplase not found in the embedding dictionary.
# Vector for prednisolone found in the embedding dictionary.
# Vector for Sulfamethoxazole not found in the embedding dictionary.
# Vector for cisapride found in the embedding dictionary.
# Vector for chondroitin ABC lyase not found in the embedding dictionary.
# Vector for Pamelor not found in the embedding dictionary.
# Vector for Effient not found in the embedding dictionary.
# Vector for etoposide found in the embedding dictionary.
# Vector for Vivactil not found in the embedding dictionary.
# Vector for INVEGA not found in the embedding dictionary.
# Vector for protriptyline found in the embedding dictionary.
# Vector for triamterene found in the embedding dictionary.
# Vector for levonorgestrel found in the embedding dictionary.
# Vector for nefazodone found in the embedding dictionary.
# Vector for ritonavir not found in the embedding dictionary.
# Vector for desethyloxybutynin not found in the embedding dictionary.
# Vector for carmustine not found in the embedding dictionary.
# Vector for nelfinavir not found in the embedding dictionary.
# Vector for TRITEC not found in the embedding dictionary.
# Vector for clarithromycin found in the embedding dictionary.
# Vector for Lomefloxacin not found in the embedding dictionary.
# Vector for 1-methyl-4-phenyl-1,2,3,4-tetrahydropyridine not found in the embedding dictionary.
# Vector for Ganciclovir not found in the embedding dictionary.
# Vector for ALKERAN not found in the embedding dictionary.
# Vector for Rimantadine HCl not found in the embedding dictionary.
# Vector for mycophenolate mofetil found in the embedding dictionary.
# Vector for piroxicam found in the embedding dictionary.
# Vector for Precocene I not found in the embedding dictionary.
# Vector for SALICYLIC ACID not found in the embedding dictionary.
# Vector for furosemide found in the embedding dictionary.
# Vector for Gemfibrozil not found in the embedding dictionary.
# Vector for Phenobarbital not found in the embedding dictionary.
# Vector for magnesium-aluminum hydroxide not found in the embedding dictionary.
# Vector for Ropivacaine not found in the embedding dictionary.
# Vector for Marplan not found in the embedding dictionary.
# Vector for prasugrel not found in the embedding dictionary.
# Vector for ZANTAC not found in the embedding dictionary.
# Vector for Mitomycin-C not found in the embedding dictionary.
# Vector for levodopa found in the embedding dictionary.
# Vector for Matulane not found in the embedding dictionary.
# Vector for MEPERIDINE not found in the embedding dictionary.
# Vector for Terbinafine not found in the embedding dictionary.
# Vector for John's Wort not found in the embedding dictionary.
# Vector for chlorpropamide found in the embedding dictionary.
# Vector for chloral hydrate found in the embedding dictionary.
# Vector for ProAmatine not found in the embedding dictionary.
# Vector for telithromycin not found in the embedding dictionary.
# Vector for GH not found in the embedding dictionary.
# Vector for meropenem not found in the embedding dictionary.
# Vector for amphetamine found in the embedding dictionary.
# Vector for ACEON not found in the embedding dictionary.
# Vector for mometasone furoate not found in the embedding dictionary.
# Vector for Scopolamine not found in the embedding dictionary.
# Vector for MPA not found in the embedding dictionary.
# Vector for sitagliptin not found in the embedding dictionary.
# Vector for flecainide found in the embedding dictionary.
# Vector for Riboflavin not found in the embedding dictionary.
# Vector for quinpirole not found in the embedding dictionary.
# Vector for hydroxychloroquine sulfate not found in the embedding dictionary.
# Vector for dipyridamole found in the embedding dictionary.
# Vector for 3-hydroxy ropivacaine not found in the embedding dictionary.
# Vector for polymyxin B not found in the embedding dictionary.
# Vector for JANUVIA not found in the embedding dictionary.
# Vector for doxepin found in the embedding dictionary.
# Vector for Elavil not found in the embedding dictionary.
# Vector for tramadol found in the embedding dictionary.
# Vector for thioguanine not found in the embedding dictionary.
# Vector for EVISTA not found in the embedding dictionary.
# Vector for AAV2 not found in the embedding dictionary.
# Vector for metformin found in the embedding dictionary.
# Vector for Exelon not found in the embedding dictionary.
# Vector for fentanyl found in the embedding dictionary.
# Vector for sumatriptan succinate found in the embedding dictionary.
# Vector for TOLECTIN not found in the embedding dictionary.
# Vector for Ketoconazole not found in the embedding dictionary.
# Vector for pravastatin found in the embedding dictionary.
# Vector for Retavase not found in the embedding dictionary.
# Vector for Nifedipine not found in the embedding dictionary.
# Vector for CYLERT not found in the embedding dictionary.
# Vector for METROGEL not found in the embedding dictionary.
# Vector for Rifampin not found in the embedding dictionary.
# Vector for retapamulin not found in the embedding dictionary.
# Vector for cinacalcet not found in the embedding dictionary.
# Vector for pralidoxime found in the embedding dictionary.
# Vector for procainamide found in the embedding dictionary.
# Vector for herceptin not found in the embedding dictionary.
# Vector for levomepromazine not found in the embedding dictionary.
# Vector for Zidovudine not found in the embedding dictionary.
# Vector for lithium found in the embedding dictionary.
# Vector for lomefloxacin found in the embedding dictionary.
# Vector for aminophylline found in the embedding dictionary.
# Vector for procaine hydrochloride not found in the embedding dictionary.
# Vector for modafinil not found in the embedding dictionary.
# Vector for ibuprofen found in the embedding dictionary.
# Vector for glyburide found in the embedding dictionary.
# Vector for MEXITIL not found in the embedding dictionary.
# Vector for clofibrate found in the embedding dictionary.
# Vector for Ritalin not found in the embedding dictionary.
# Vector for ZETIA not found in the embedding dictionary.
# Vector for vanillylmandelic acid not found in the embedding dictionary.
# Vector for Plavix not found in the embedding dictionary.
# Vector for Pilocarpine not found in the embedding dictionary.
# Vector for NEXAVAR not found in the embedding dictionary.
# Vector for (2-adamantyl)hexamethylenimine not found in the embedding dictionary.
# Vector for inactivated ND vaccine not found in the embedding dictionary.
# Vector for dobutamine found in the embedding dictionary.
# Vector for ethinyl estradiol found in the embedding dictionary.
# Vector for spironolactone found in the embedding dictionary.
# Vector for fluvastatin found in the embedding dictionary.
# Vector for stavudine found in the embedding dictionary.
# Vector for procaine found in the embedding dictionary.
# Vector for Carbamazepine not found in the embedding dictionary.
# Vector for propofol found in the embedding dictionary.
# Vector for terazosin found in the embedding dictionary.
# Vector for pergolide mesylate not found in the embedding dictionary.
# Vector for tetracycline found in the embedding dictionary.
# Vector for teniposide found in the embedding dictionary.
# Vector for mercaptopurine found in the embedding dictionary.
# Vector for viomycin not found in the embedding dictionary.
# Vector for Parnate not found in the embedding dictionary.
# Vector for Ismelin not found in the embedding dictionary.
# Vector for CCI-779 not found in the embedding dictionary.
# Vector for oxymorphone not found in the embedding dictionary.
# Vector for azathioprine found in the embedding dictionary.
# Vector for sunitinib not found in the embedding dictionary.
# Vector for ranitidine found in the embedding dictionary.
# Vector for potassium found in the embedding dictionary.
# Vector for norketamine not found in the embedding dictionary.
# Vector for lenalidomide not found in the embedding dictionary.
# Vector for Dexmedetomidine not found in the embedding dictionary.
# Vector for Cerezyme not found in the embedding dictionary.
# Vector for Tofranil not found in the embedding dictionary.
# Vector for Tacrolimus not found in the embedding dictionary.
# Vector for celecoxib not found in the embedding dictionary.
# Vector for clonidine found in the embedding dictionary.
# Vector for Piperine not found in the embedding dictionary.
# Vector for Ticlopidine not found in the embedding dictionary.
# Vector for mirtazapine found in the embedding dictionary.
# Vector for DIPRIVAN not found in the embedding dictionary.
# Vector for zileuton found in the embedding dictionary.
# Vector for nortriptyline found in the embedding dictionary.
# Vector for troleandomycin found in the embedding dictionary.
# Vector for DITROPAN XL not found in the embedding dictionary.
# Vector for amoxicillin found in the embedding dictionary.
# Vector for Infacol not found in the embedding dictionary.
# Vector for Ticagrelor not found in the embedding dictionary.
# Vector for panobinostat not found in the embedding dictionary.
# Vector for sucralfate found in the embedding dictionary.
# Vector for ascorbic acid found in the embedding dictionary.
# Vector for theophyllines not found in the embedding dictionary.
# Vector for Hyaluronan lyase not found in the embedding dictionary.
# Vector for Amphetamine not found in the embedding dictionary.
# Vector for ZAVESCA not found in the embedding dictionary.
# Vector for delavirdine not found in the embedding dictionary.
# Vector for thyroxine found in the embedding dictionary.
# Vector for Guanethidine not found in the embedding dictionary.
# Vector for Halothane not found in the embedding dictionary.
# Vector for Gentamicin not found in the embedding dictionary.
# Vector for simethicone found in the embedding dictionary.
# Vector for reserpine found in the embedding dictionary.
# Vector for ticlopidine found in the embedding dictionary.
# Vector for tolterodine not found in the embedding dictionary.
# Vector for 5-FU not found in the embedding dictionary.
# Vector for Sorafenib not found in the embedding dictionary.
# Vector for fluvoxamine found in the embedding dictionary.
# Vector for SYMLIN not found in the embedding dictionary.
# Vector for Methscopolamine not found in the embedding dictionary.
# Vector for LBH589 not found in the embedding dictionary.
# Vector for hydrochlorothiazide found in the embedding dictionary.
# Vector for Mecamylamine not found in the embedding dictionary.
# Vector for pemoline not found in the embedding dictionary.
# Vector for Methylprednisolone not found in the embedding dictionary.
# Vector for Acyclovir not found in the embedding dictionary.
# Vector for atropine found in the embedding dictionary.
# Vector for Astemizole not found in the embedding dictionary.
# Vector for phenylephrine not found in the embedding dictionary.
# Vector for EPO not found in the embedding dictionary.
# Vector for MIRAPEX not found in the embedding dictionary.
# Vector for Rifabutin not found in the embedding dictionary.
# Vector for Ethanol not found in the embedding dictionary.
# Vector for astemizole found in the embedding dictionary.
# Vector for FELDENE not found in the embedding dictionary.
# Vector for VERSED Syrup not found in the embedding dictionary.
# Vector for DTIC not found in the embedding dictionary.
# Vector for Insulin not found in the embedding dictionary.
# Vector for S-warfarin not found in the embedding dictionary.
# Vector for sodium colistimethate found in the embedding dictionary.
# Vector for Thioguanine not found in the embedding dictionary.
# Vector for oxybutynin not found in the embedding dictionary.
# Vector for perindoprilat not found in the embedding dictionary.
# Vector for Cholestyramine not found in the embedding dictionary.
# Vector for ZIAGEN not found in the embedding dictionary.
# Vector for moxifloxacin not found in the embedding dictionary.
# Vector for rimantadine HCl not found in the embedding dictionary.
# Vector for Probenecid not found in the embedding dictionary.
# Vector for Zemplar not found in the embedding dictionary.
# Vector for methicillin not found in the embedding dictionary.
# Vector for buprenorphine found in the embedding dictionary.
# Vector for Stavudine not found in the embedding dictionary.
# Vector for Mazindol not found in the embedding dictionary.
# Vector for Neulasta not found in the embedding dictionary.
# Vector for indinavir not found in the embedding dictionary.
# Vector for diazepam found in the embedding dictionary.
# Vector for ergotamine found in the embedding dictionary.
# Vector for Aminoglutethimide not found in the embedding dictionary.
# Vector for mazindol found in the embedding dictionary.
# Vector for Methenamine not found in the embedding dictionary.
# Vector for ampicillin found in the embedding dictionary.
# Vector for ZERIT not found in the embedding dictionary.
# Vector for nifedipine found in the embedding dictionary.
# Vector for cimetidine found in the embedding dictionary.
# Vector for ELDEPRYL not found in the embedding dictionary.
# Vector for ZANOSAR not found in the embedding dictionary.
# Vector for paricalcitol not found in the embedding dictionary.
# Vector for solifenacin not found in the embedding dictionary.
# Vector for doxorubicin found in the embedding dictionary.
# Vector for Paricalcitol not found in the embedding dictionary.
# Vector for amitriptyline found in the embedding dictionary.
# Vector for mitotane found in the embedding dictionary.
# Vector for rocuronium bromide not found in the embedding dictionary.
# Vector for amikacin found in the embedding dictionary.
# Vector for methylprednisolone found in the embedding dictionary.
# Vector for Thiamine not found in the embedding dictionary.
# Vector for valsartan not found in the embedding dictionary.
# Vector for megestrol acetate not found in the embedding dictionary.
# Vector for Clopidogrel not found in the embedding dictionary.
# Vector for Permax not found in the embedding dictionary.
# Vector for Moxifloxacin not found in the embedding dictionary.
# Vector for Streptozocin not found in the embedding dictionary.
# Vector for pyrimethamine found in the embedding dictionary.
# Vector for temozolomide not found in the embedding dictionary.
# Vector for Calcium not found in the embedding dictionary.
# Vector for ezetimibe not found in the embedding dictionary.
# Vector for nondepolarizing agents not found in the embedding dictionary.
# Vector for ferrous gluconate not found in the embedding dictionary.
# Vector for atazanavir not found in the embedding dictionary.
# Vector for fluconazole found in the embedding dictionary.
# Vector for phentermine hydrochloride not found in the embedding dictionary.
# Vector for Streptase not found in the embedding dictionary.
# Vector for phenobarbital found in the embedding dictionary.
# Vector for citalopram found in the embedding dictionary.
# Vector for Pindolol not found in the embedding dictionary.
# Vector for calcium found in the embedding dictionary.
# Vector for Raloxifene not found in the embedding dictionary.
# Vector for ferrous sulfate found in the embedding dictionary.
# Vector for Leukine not found in the embedding dictionary.
# Vector for methyprylon not found in the embedding dictionary.

# %% [markdown]
# Get vectors for training and testing drug entities

# %%
drug_vectors_df = pd.DataFrame.from_dict(drug_vectors, orient='index')
drug_vectors_df_test = pd.DataFrame.from_dict(drug_vectors_test, orient='index')

# %%
# Function to parse DDI relations from XML files in a given directory
def parse_ddi_relations_from_directory(directory):
    drug_pairs = []
    for file_name in os.listdir(directory):
        if file_name.endswith('.xml'):
            file_path = os.path.join(directory, file_name)
            drug_pairs.extend(parse_ddi_relations(file_path))
    return drug_pairs

# Function to parse DDI relations from a single file
def parse_ddi_relations(file_path):
    tree = ET.parse(file_path)
    root = tree.getroot()
    relations = []

    # Map entity IDs to drug names
    entity_id_to_name = {entity.attrib.get('id'): entity.attrib.get('text') for entity in root.findall(".//entity")}

    # Parse pairs and retrieve entity names
    for pair in root.findall(".//pair"):
        relation = {
            'e1': pair.attrib.get('e1'),
            'e2': pair.attrib.get('e2'),
            'ddi': pair.attrib.get('ddi'),
            'e1_name': entity_id_to_name.get(pair.attrib.get('e1')),
            'e2_name': entity_id_to_name.get(pair.attrib.get('e2'))
        }
        relations.append(relation)
    
    return relations

# Directories for training and testing datasets
train_dirs = ['../Dataset/DDICorpus/Train/DrugBank', '../Dataset/DDICorpus/Train/MedLine']
test_dirs = ['../Dataset/DDICorpus/Test/Test for DDI Extraction task/DrugBank', '../Dataset/DDICorpus/Test/Test for DDI Extraction task/MedLine']

# Extract drug pairs from training and testing directories
all_drug_pairs = []
all_drug_pairs_test = []

for directory in train_dirs:
    all_drug_pairs.extend(parse_ddi_relations_from_directory(directory))

for directory in test_dirs:
    all_drug_pairs_test.extend(parse_ddi_relations_from_directory(directory))

# %%
# Output the drug pairs
print(f"Training drug pairs: {len(all_drug_pairs)}")
print(all_drug_pairs)
# Out:
# Training drug pairs: 27792
# [{'e1': 'DDI-DrugBank.d481.s0.e0', 'e2': 'DDI-DrugBank.d481.s0.e1', 'ddi': 'true', 'e1_name': 'calcium', 'e2_name': 'EMCYT'}, {'e1': 'DDI-DrugBank.d419.s0.e0', 'e2': 'DDI-DrugBank.d419.s0.e1', 'ddi': 'true', 'e1_name': 'allopurinol', 'e2_name': 'ampicillin'}, {'e1': 'DDI-DrugBank.d419.s0.e0', 'e2': 'DDI-DrugBank.d419.s0.e2', 'ddi': 'false', 'e1_name': 'allopurinol', 'e2_name': 'ampicillin'}, {'e1': 'DDI-DrugBank.d419.s0.e1', 'e2': 'DDI-DrugBank.d419.s0.e2', 'ddi': 'false', 'e1_name': 'ampicillin', 'e2_name': 'ampicillin'}, {'e1': 'DDI-DrugBank.d419.s1.e0', 'e2': 'DDI-DrugBank.d419.s1.e1', 'ddi': 'true', 'e1_name': 'ampicillin', 'e2_name': 'allopurinol'}, {'e1': 'DDI-DrugBank.d419.s2.e0', 'e2': 'DDI-DrugBank.d419.s2.e1', 'ddi': 'false', 'e1_name': 'AUGMENTIN XR', 'e2_name': 'allopurinol'}, {'e1': 'DDI-DrugBank.d419.s2.e0', 'e2': 'DDI-DrugBank.d419.s2.e2', 'ddi': 'false', 'e1_name': 'AUGMENTIN XR', 'e2_name': 'AUGMENTIN XR'}, {'e1': 'DDI-DrugBank.d419.s2.e1', 'e2': 'DDI-DrugBank.d419.s2.e2', 'ddi': 'false', 'e1_name': 'allopurinol', 'e2_name': 'AUGMENTIN XR'}, {'e1': 'DDI-DrugBank.d419.s4.e0', 'e2': 'DDI-DrugBank.d419.s4.e1', 'ddi': 'false', 'e1_name': 'AUGMENTIN XR', 'e2_name': 'allopurinol'}, {'e1': 'DDI-DrugBank.d419.s5.e0', 'e2': 'DDI-DrugBank.d419.s5.e1', 'ddi': 'false', 'e1_name': 'broad-spectrum antibiotics', 'e2_name': 'AUGMENTIN XR'}, {'e1': 'DDI-DrugBank.d419.s5.e0', 'e2': 'DDI-DrugBank.d419.s5.e2', 'ddi': 'true', 'e1_name': 'broad-spectrum antibiotics', 'e2_name': 'contraceptives'}, {'e1': 'DDI-DrugBank.d419.s5.e1', 'e2': 'DDI-DrugBank.d419.s5.e2', 'ddi': 'true', 'e1_name': 'AUGMENTIN XR', 'e2_name': 'contraceptives'}, {'e1': 'DDI-DrugBank.d234.s0.e0', 'e2': 'DDI-DrugBank.d234.s0.e1', 'ddi': 'false', 'e1_name': 'central nervous system depressants', 'e2_name': 'benzodiazepines'}, {'e1': 'DDI-DrugBank.d234.s1.e0', 'e2': 'DDI-DrugBank.d234.s1.e1', 'ddi': 'false', 'e1_name': 'ROMAZICON', 'e2_name': 'narcotics'}, {'e1': 'DDI-DrugBank.d234.s1.e0', 'e2': 'DDI-DrugBank.d234.s1.e2', 'ddi': 'false', 'e1_name': 'ROMAZICON', 'e2_name': 'anesthetics'}, {'e1': 'DDI-DrugBank.d234.s1.e0', 'e2': 'DDI-DrugBank.d234.s1.e3', 'ddi': 'false', 'e1_name': 'ROMAZICON', 'e2_name': 'muscle relaxants'}, {'e1': 'DDI-DrugBank.d234.s1.e1', 'e2': 'DDI-DrugBank.d234.s1.e2', 'ddi': 'false', 'e1_name': 'narcotics', 'e2_name': 'anesthetics'}, {'e1': 'DDI-DrugBank.d234.s1.e1', 'e2': 'DDI-DrugBank.d234.s1.e3', 'ddi': 'false', 'e1_name': 'narcotics', 'e2_name': 'muscle relaxants'}, {'e1': 'DDI-DrugBank.d234.s1.e2', 'e2': 'DDI-DrugBank.d234.s1.e3', 'ddi': 'false', 'e1_name': 'anesthetics', 'e2_name': 'muscle relaxants'}, {'e1': 'DDI-DrugBank.d234.s2.e0', 'e2': 'DDI-DrugBank.d234.s2.e1', 'ddi': 'true', 'e1_name': 'ROMAZICON', 'e2_name': 'cyclic antidepressants'}, {'e1': 'DDI-DrugBank.d234.s2.e0', 'e2': 'DDI-DrugBank.d234.s2.e2', 'ddi': 'false', 'e1_name': 'ROMAZICON', 'e2_name': 'benzodiazepine'}, {'e1': 'DDI-DrugBank.d234.s2.e0', 'e2': 'DDI-DrugBank.d234.s2.e3', 'ddi': 'false', 'e1_name': 'ROMAZICON', 'e2_name': 'flumazenil'}, {'e1': 'DDI-DrugBank.d234.s2.e1', 'e2': 'DDI-DrugBank.d234.s2.e2', 'ddi': 'false', 'e1_name': 'cyclic antidepressants', 'e2_name': 'benzodiazepine'}, {'e1': 'DDI-DrugBank.d234.s2.e1', 'e2': 'DDI-DrugBank.d234.s2.e3', 'ddi': 'false', 'e1_name': 'cyclic antidepressants', 'e2_name': 'flumazenil'}, {'e1': 'DDI-DrugBank.d234.s2.e2', 'e2': 'DDI-DrugBank.d234.s2.e3', 'ddi': 'false', 'e1_name': 'benzodiazepine', 'e2_name': 'flumazenil'}, {'e1': 'DDI-DrugBank.d234.s4.e0', 'e2': 'DDI-DrugBank.d234.s4.e1', 'ddi': 'true', 'e1_name': 'ROMAZICON', 'e2_name': 'benzodiazepine'}, {'e1': 'DDI-DrugBank.d234.s5.e0', 'e2': 'DDI-DrugBank.d234.s5.e1', 'ddi': 'true', 'e1_name': 'ROMAZICON', 'e2_name': 'benzodiazepines'}, {'e1': 'DDI-DrugBank.d234.s6.e0', 'e2': 'DDI-DrugBank.d234.s6.e1', 'ddi': 'true', 'e1_name': 'zopiclone', 'e2_name': 'ROMAZICON'}, {'e1': 'DDI-DrugBank.d234.s7.e0', 'e2': 'DDI-DrugBank.d234.s7.e1', 'ddi': 'false', 'e1_name': 'benzodiazepines ...

# %%
print(f"Testing drug pairs: {len(all_drug_pairs_test)}")
print(all_drug_pairs_test)
# Out:
# Testing drug pairs: 5716
# [{'e1': 'DDI-DrugBank.d765.s0.e0', 'e2': 'DDI-DrugBank.d765.s0.e1', 'ddi': 'true', 'e1_name': 'Ketoconazole', 'e2_name': 'tolterodine'}, {'e1': 'DDI-DrugBank.d765.s1.e0', 'e2': 'DDI-DrugBank.d765.s1.e1', 'ddi': 'false', 'e1_name': 'ketoconazole', 'e2_name': 'azole antifungals'}, {'e1': 'DDI-DrugBank.d765.s1.e0', 'e2': 'DDI-DrugBank.d765.s1.e2', 'ddi': 'false', 'e1_name': 'ketoconazole', 'e2_name': 'itraconazole'}, {'e1': 'DDI-DrugBank.d765.s1.e0', 'e2': 'DDI-DrugBank.d765.s1.e3', 'ddi': 'false', 'e1_name': 'ketoconazole', 'e2_name': 'miconazole'}, {'e1': 'DDI-DrugBank.d765.s1.e0', 'e2': 'DDI-DrugBank.d765.s1.e4', 'ddi': 'false', 'e1_name': 'ketoconazole', 'e2_name': 'macrolide antibiotics'}, {'e1': 'DDI-DrugBank.d765.s1.e0', 'e2': 'DDI-DrugBank.d765.s1.e5', 'ddi': 'false', 'e1_name': 'ketoconazole', 'e2_name': 'erythromycin'}, {'e1': 'DDI-DrugBank.d765.s1.e0', 'e2': 'DDI-DrugBank.d765.s1.e6', 'ddi': 'false', 'e1_name': 'ketoconazole', 'e2_name': 'clarithromycin'}, {'e1': 'DDI-DrugBank.d765.s1.e0', 'e2': 'DDI-DrugBank.d765.s1.e7', 'ddi': 'false', 'e1_name': 'ketoconazole', 'e2_name': 'cyclosporine'}, {'e1': 'DDI-DrugBank.d765.s1.e0', 'e2': 'DDI-DrugBank.d765.s1.e8', 'ddi': 'false', 'e1_name': 'ketoconazole', 'e2_name': 'vinblastine'}, {'e1': 'DDI-DrugBank.d765.s1.e0', 'e2': 'DDI-DrugBank.d765.s1.e9', 'ddi': 'true', 'e1_name': 'ketoconazole', 'e2_name': 'DETROL LA'}, {'e1': 'DDI-DrugBank.d765.s1.e1', 'e2': 'DDI-DrugBank.d765.s1.e2', 'ddi': 'false', 'e1_name': 'azole antifungals', 'e2_name': 'itraconazole'}, {'e1': 'DDI-DrugBank.d765.s1.e1', 'e2': 'DDI-DrugBank.d765.s1.e3', 'ddi': 'false', 'e1_name': 'azole antifungals', 'e2_name': 'miconazole'}, {'e1': 'DDI-DrugBank.d765.s1.e1', 'e2': 'DDI-DrugBank.d765.s1.e4', 'ddi': 'false', 'e1_name': 'azole antifungals', 'e2_name': 'macrolide antibiotics'}, {'e1': 'DDI-DrugBank.d765.s1.e1', 'e2': 'DDI-DrugBank.d765.s1.e5', 'ddi': 'false', 'e1_name': 'azole antifungals', 'e2_name': 'erythromycin'}, {'e1': 'DDI-DrugBank.d765.s1.e1', 'e2': 'DDI-DrugBank.d765.s1.e6', 'ddi': 'false', 'e1_name': 'azole antifungals', 'e2_name': 'clarithromycin'}, {'e1': 'DDI-DrugBank.d765.s1.e1', 'e2': 'DDI-DrugBank.d765.s1.e7', 'ddi': 'false', 'e1_name': 'azole antifungals', 'e2_name': 'cyclosporine'}, {'e1': 'DDI-DrugBank.d765.s1.e1', 'e2': 'DDI-DrugBank.d765.s1.e8', 'ddi': 'false', 'e1_name': 'azole antifungals', 'e2_name': 'vinblastine'}, {'e1': 'DDI-DrugBank.d765.s1.e1', 'e2': 'DDI-DrugBank.d765.s1.e9', 'ddi': 'true', 'e1_name': 'azole antifungals', 'e2_name': 'DETROL LA'}, {'e1': 'DDI-DrugBank.d765.s1.e2', 'e2': 'DDI-DrugBank.d765.s1.e3', 'ddi': 'false', 'e1_name': 'itraconazole', 'e2_name': 'miconazole'}, {'e1': 'DDI-DrugBank.d765.s1.e2', 'e2': 'DDI-DrugBank.d765.s1.e4', 'ddi': 'false', 'e1_name': 'itraconazole', 'e2_name': 'macrolide antibiotics'}, {'e1': 'DDI-DrugBank.d765.s1.e2', 'e2': 'DDI-DrugBank.d765.s1.e5', 'ddi': 'false', 'e1_name': 'itraconazole', 'e2_name': 'erythromycin'}, {'e1': 'DDI-DrugBank.d765.s1.e2', 'e2': 'DDI-DrugBank.d765.s1.e6', 'ddi': 'false', 'e1_name': 'itraconazole', 'e2_name': 'clarithromycin'}, {'e1': 'DDI-DrugBank.d765.s1.e2', 'e2': 'DDI-DrugBank.d765.s1.e7', 'ddi': 'false', 'e1_name': 'itraconazole', 'e2_name': 'cyclosporine'}, {'e1': 'DDI-DrugBank.d765.s1.e2', 'e2': 'DDI-DrugBank.d765.s1.e8', 'ddi': 'false', 'e1_name': 'itraconazole', 'e2_name': 'vinblastine'}, {'e1': 'DDI-DrugBank.d765.s1.e2', 'e2': 'DDI-DrugBank.d765.s1.e9', 'ddi': 'true', 'e1_name': 'itraconazole', 'e2_name': 'DETROL LA'}, {'e1': 'DDI-DrugBank.d765.s1.e3', 'e2': 'DDI-DrugBank.d765.s1.e4', 'ddi': 'false', 'e1_name': 'miconazole', 'e2_name': 'macrolide antibiotics'}, {'e1': 'DDI-DrugBank.d765.s1.e3', 'e2': 'DDI-DrugBank.d765.s1.e5', 'ddi': 'false', 'e1_name': 'miconazole', 'e2_name': 'erythromycin'}, {'e1': 'DDI-DrugBank.d765.s1.e3', 'e2': 'DDI-DrugBank.d765.s1.e6', 'ddi': 'false', 'e1_name': 'miconazole', 'e2_name': 'clarithromycin'}, {'e1': 'DDI-DrugBank.d765.s1.e3', 'e2': 'DDI-DrugBank.d765.s1.e7', 'ddi': ' ...

# %% [markdown]
# **Train Dataset Preparation**

# %%
drug_pairs_df = pd.DataFrame(all_drug_pairs)

drug_pairs_df = drug_pairs_df[['e1_name', 'e2_name', 'ddi']]
drug_pairs_df.columns = ['Drug1', 'Drug2', 'Interacting']

drug_pairs_df['Interacting'] = drug_pairs_df['Interacting'].apply(lambda x: x.lower() == 'true')
drug_pairs_df
# Out:
#              Drug1        Drug2  Interacting
# 0          calcium        EMCYT         True
# 1      allopurinol   ampicillin         True
# 2      allopurinol   ampicillin        False
# 3       ampicillin   ampicillin        False
# 4       ampicillin  allopurinol         True
# ...            ...          ...          ...
# 27787  cloxacillin  cloxacillin        False
# 27788  cloxacillin   probenecid        False
# 27789  cloxacillin   probenecid        False
# 27790  cloxacillin   probenecid        False
# 27791   probenecid  cloxacillin         True
#
# [27792 rows x 3 columns]

# %% [markdown]
# Function to get vector representation or None if not available

# %%
def get_vector(drug):
    return drug_vectors.get(drug, None)

# %% [markdown]
# Add vector representations to the drug pairs DataFrame

# %%
drug_pairs_df['Drug1_Vector'] = drug_pairs_df['Drug1'].apply(get_vector)
drug_pairs_df['Drug2_Vector'] = drug_pairs_df['Drug2'].apply(get_vector)

# %% [markdown]
# Drop rows where either Drug1_Vector or Drug2_Vector is None

# %%
drug_pairs_df = drug_pairs_df.dropna(subset=['Drug1_Vector', 'Drug2_Vector'])

# %% [markdown]
# Add a new column 'Interaction_Label' with 1 for True and 0 for False in 'Interacting' column

# %%
drug_pairs_df['Interaction_Label'] = drug_pairs_df['Interacting'].astype(int)

# Drop rows where both Drug1 and Drug2 are the same
drug_pairs_df = drug_pairs_df[drug_pairs_df['Drug1'] != drug_pairs_df['Drug2']]
# Out:
# /var/folders/pv/wpg0wtcs5kj1758khrqy155m0000gn/T/ipykernel_42670/2745480157.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   drug_pairs_df['Interaction_Label'] = drug_pairs_df['Interacting'].astype(int)

# %%
drug_pairs_df
# Out:
#                  Drug1        Drug2  Interacting  \
# 1          allopurinol   ampicillin         True
# 2          allopurinol   ampicillin        False
# 4           ampicillin  allopurinol         True
# 28     benzodiazepines   flumazenil        False
# 29             ethanol   flumazenil        False
# ...                ...          ...          ...
# 27785       probenecid  cloxacillin        False
# 27788      cloxacillin   probenecid        False
# 27789      cloxacillin   probenecid        False
# 27790      cloxacillin   probenecid        False
# 27791       probenecid  cloxacillin         True
#
#                                             Drug1_Vector  \
# 1      [nan, nan, nan, nan, nan, nan, nan, nan, nan, ...
# 2      [nan, nan, nan, nan, nan, nan, nan, nan, nan, ...
# 4      [nan, nan, nan, nan, nan, nan, nan, nan, nan, ...
# 28     [nan, nan, nan, nan, nan, nan, nan, nan, nan, ...
# 29     [nan, nan, nan, nan, nan, nan, nan, nan, nan, ...
# ...                                                  ...
# 27785  [nan, nan, nan, nan, nan, nan, nan, nan, nan, ...
# 27788  [nan, nan, nan, nan, nan, nan, nan, nan, nan, ...
# 27789  [nan, nan, nan, nan, nan, nan, nan, nan, nan, ...
# 27790  [nan, nan, nan, nan, nan, nan, nan, nan, nan, ...
# 27791  [nan, nan, nan, nan, nan, nan, nan, nan, nan, ...
#
#                                             Drug2_Vector  Interaction_Label
# 1      [nan, nan, nan, nan, nan, nan, nan, nan, nan, ...                  1
# 2      [nan, nan, nan, nan, nan, nan, nan, nan, nan, ...                  0
# 4      [nan, nan, nan, nan, nan, nan, nan, nan, nan, ...                  1
# 28     [nan, nan, nan, nan, nan, nan, nan, nan, nan, ...                  0
# 29     [nan, nan, nan, nan, nan, nan, nan, nan, nan, ...                  0
# ...                                                  ...                ...
# 27785  [nan, nan, nan, nan, nan, nan, nan, nan, nan, ...                  0
# 27788  [nan, nan, nan, nan, nan, nan, nan, nan, nan, ...                  0
# 27789  [nan, nan, nan, nan, nan, nan, nan, nan, nan, ...                  0
# 27790  [nan, nan, nan, nan, nan, nan, nan, nan, nan, ...                  0
# 27791  [nan, nan, nan, nan, nan, nan, nan, nan, nan, ...                  1
#
# [9336 rows x 6 columns]

# %% [markdown]
# **Test Dataset Preparation**

# %%
drug_pairs_df_test = pd.DataFrame(all_drug_pairs_test)

drug_pairs_df_test = drug_pairs_df_test[['e1_name', 'e2_name', 'ddi']]
drug_pairs_df_test.columns = ['Drug1', 'Drug2', 'Interacting']

drug_pairs_df_test['Interacting'] = drug_pairs_df_test['Interacting'].apply(lambda x: x.lower() == 'true')
drug_pairs_df_test
# Out:
#                Drug1                  Drug2  Interacting
# 0       Ketoconazole            tolterodine         True
# 1       ketoconazole      azole antifungals        False
# 2       ketoconazole           itraconazole        False
# 3       ketoconazole             miconazole        False
# 4       ketoconazole  macrolide antibiotics        False
# ...              ...                    ...          ...
# 5711     Furafylline            precocene I        False
# 5712  sulfaphenazole              quinidine        False
# 5713  sulfaphenazole            precocene I        False
# 5714       quinidine            precocene I         True
# 5715     precocene I            precocene I        False
#
# [5716 rows x 3 columns]

# %% [markdown]
# Add vector representations to the drug pairs DataFrame

# %%
drug_pairs_df_test['Drug1_Vector'] = drug_pairs_df_test['Drug1'].apply(get_vector)
drug_pairs_df_test['Drug2_Vector'] = drug_pairs_df_test['Drug2'].apply(get_vector)

# %% [markdown]
#  Drop rows where either Drug1_Vector or Drug2_Vector is None

# %%
drug_pairs_df_test = drug_pairs_df_test.dropna(subset=['Drug1_Vector', 'Drug2_Vector'])

# %% [markdown]
# Add a new column 'Interaction_Label' with 1 for True and 0 for False in 'Interacting' column

# %%
drug_pairs_df_test['Interaction_Label'] = drug_pairs_df_test['Interacting'].astype(int)
# Out:
# /var/folders/pv/wpg0wtcs5kj1758khrqy155m0000gn/T/ipykernel_42670/1479532307.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   drug_pairs_df_test['Interaction_Label'] = drug_pairs_df_test['Interacting'].astype(int)

# %%
drug_pairs_df_test = drug_pairs_df_test[drug_pairs_df_test['Drug1'] != drug_pairs_df_test['Drug2']]
drug_pairs_df_test
# Out:
#                 Drug1                  Drug2  Interacting  \
# 2        ketoconazole           itraconazole        False
# 3        ketoconazole             miconazole        False
# 4        ketoconazole  macrolide antibiotics        False
# 5        ketoconazole           erythromycin        False
# 6        ketoconazole         clarithromycin        False
# ...               ...                    ...          ...
# 5653       sucralfate           erythromycin        False
# 5663        tamoxifen             paroxetine         True
# 5664        tamoxifen             fluoxetine         True
# 5667       paroxetine             fluoxetine        False
# 5708  tranylcypromine           ketoconazole        False
#
#                                            Drug1_Vector  \
# 2     [nan, nan, nan, nan, nan, nan, nan, nan, nan, ...
# 3     [nan, nan, nan, nan, nan, nan, nan, nan, nan, ...
# 4     [nan, nan, nan, nan, nan, nan, nan, nan, nan, ...
# 5     [nan, nan, nan, nan, nan, nan, nan, nan, nan, ...
# 6     [nan, nan, nan, nan, nan, nan, nan, nan, nan, ...
# ...                                                 ...
# 5653  [nan, nan, nan, nan, nan, nan, nan, nan, nan, ...
# 5663  [nan, nan, nan, nan, nan, nan, nan, nan, nan, ...
# 5664  [nan, nan, nan, nan, nan, nan, nan, nan, nan, ...
# 5667  [nan, nan, nan, nan, nan, nan, nan, nan, nan, ...
# 5708  [nan, nan, nan, nan, nan, nan, nan, nan, nan, ...
#
#                                            Drug2_Vector  Interaction_Label
# 2     [nan, nan, nan, nan, nan, nan, nan, nan, nan, ...                  0
# 3     [nan, nan, nan, nan, nan, nan, nan, nan, nan, ...                  0
# 4     [nan, nan, nan, nan, nan, nan, nan, nan, nan, ...                  0
# 5     [nan, nan, nan, nan, nan, nan, nan, nan, nan, ...                  0
# 6     [nan, nan, nan, nan, nan, nan, nan, nan, nan, ...                  0
# ...                                                 ...                ...
# 5653  [nan, nan, nan, nan, nan, nan, nan, nan, nan, ...                  0
# 5663  [nan, nan, nan, nan, nan, nan, nan, nan, nan, ...                  1
# 5664  [nan, nan, nan, nan, nan, nan, nan, nan, nan, ...                  1
# 5667  [nan, nan, nan, nan, nan, nan, nan, nan, nan, ...                  0
# 5708  [nan, nan, nan, nan, nan, nan, nan, nan, nan, ...                  0
#
# [1535 rows x 6 columns]

# %% [markdown]
# Check the number of false and true rows in the 'Interacting' column

# %%
interaction_counts = drug_pairs_df['Interacting'].value_counts()
print(interaction_counts)

interaction_counts_test = drug_pairs_df_test['Interacting'].value_counts()
print(interaction_counts_test)
# Out:
# Interacting
# False    8311
# True     1025
# Name: count, dtype: int64
# Interacting
# False    1413
# True      122
# Name: count, dtype: int64

# %%
## Could you save the dataframes to csv files and load them in the future?
drug_pairs_df.to_csv('drug_pairs_df.csv', index=False)
drug_pairs_df_test.to_csv('drug_pairs_df_test.csv', index=False)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[37], line 2
#       1 ## Could you save the dataframes to csv files and load them in the future?
# ----> 2 drug_pairs_df.to_csv('drug_pairs_df.csv', index=False)
#       3 drug_pairs_df_test.to_csv('drug_pairs_df_test.csv', index=False)
#
# File ~/Desktop/Drug-Drug-Interaction-and-Alternate-Recommendation-System/.venv/lib/python3.9/site-packages/pandas/util/_decorators.py:333, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     327 if len(args) > num_allow_args:
#     328     warnings.warn(
#     329         msg.format(arguments=_format_argument_list(allow_args)),
#     330         FutureWarning,
#     331         stacklevel=find_stack_level(),
#     332     )
# --> 333 return func(*args, **kwargs)
#
# File ~/Desktop/Drug-Drug-Interaction-and-Alternate-Recommendation-System/.venv/lib/python3.9/site-packages/pandas/core/generic.py:3967, in NDFrame.to_csv(self, path_or_buf, sep, na_rep, float_format, columns, header, index, index_label, mode, encoding, compression, quoting, quotechar, lineterminator, chunksize, date_format, doublequote, escapechar, decimal, errors, storage_options)
#    3956 df = self if isinstance(self, ABCDataFrame) else self.to_frame()
#    3958 formatter = DataFrameFormatter(
#    3959     frame=df,
#    3960     header=header,
#    (...)
#    3964     decimal=decimal,
#    3965 )
# -> 3967 return DataFrameRenderer(formatter).to_csv(
#    3968     path_or_buf,
#    3969     lineterminator=lineterminator,
#    3970     sep=sep,
#    3971     encoding=encoding,
#    3972     errors=errors,
#    3973     compression=compression,
#    3974     quoting=quoting,
#    3975     columns=columns,
#    3976     index_label=index_label,
#    3977     mode=mode,
#    3978     chunksize=chunksize,
#    3979     quotechar=quotechar,
#    3980     date_format=date_format,
#    3981     doublequote=doublequote,
#    3982     escapechar=escapechar,
#    3983     storage_options=storage_options,
#    3984 )
#
# File ~/Desktop/Drug-Drug-Interaction-and-Alternate-Recommendation-System/.venv/lib/python3.9/site-packages/pandas/io/formats/format.py:1014, in DataFrameRenderer.to_csv(self, path_or_buf, encoding, sep, columns, index_label, mode, compression, quoting, quotechar, lineterminator, chunksize, date_format, doublequote, escapechar, errors, storage_options)
#     993     created_buffer = False
#     995 csv_formatter = CSVFormatter(
#     996     path_or_buf=path_or_buf,
#     997     lineterminator=lineterminator,
#    (...)
#    1012     formatter=self.fmt,
#    1013 )
# -> 1014 csv_formatter.save()
#    1016 if created_buffer:
#    1017     assert isinstance(path_or_buf, StringIO)
#
# File ~/Desktop/Drug-Drug-Interaction-and-Alternate-Recommendation-System/.venv/lib/python3.9/site-packages/pandas/io/formats/csvs.py:270, in CSVFormatter.save(self)
#     251 with get_handle(
#     252     self.filepath_or_buffer,
#     253     self.mode,
#    (...)
#     258 ) as handles:
#     259     # Note: self.encoding is irrelevant here
#     260     self.writer = csvlib.writer(
#     261         handles.handle,
#     262         lineterminator=self.lineterminator,
#    (...)
#     267         quotechar=self.quotechar,
#     268     )
# --> 270     self._save()
#
# File ~/Desktop/Drug-Drug-Interaction-and-Alternate-Recommendation-System/.venv/lib/python3.9/site-packages/pandas/io/formats/csvs.py:275, in CSVFormatter._save(self)
#     273 if self._need_to_save_header:
#     274     self._save_header()
# --> 275 self._save_body()
#
# File ~/Desktop/Drug-Drug-Interaction-and-Alternate-Recommendation-System/.venv/lib/python3.9/site-packages/pandas/io/formats/csvs.py:313, in CSVFormatter._save_body(self)
#     311 if start_i >= end_i:
#     312     break
# --> 313 self._save_chunk(start_i, end_i)
#
# File ~/Desktop/Drug-Drug-Interaction-and-Alternate-Recommendation-System/.venv/lib/python3.9/site-packages/pandas/io/formats/csvs.py:324, in CSVFormatter._save_chunk(self, start_i, end_i)
#     321 data = list(res._iter_column_arrays())
#     323 ix = self.data_index[slicer]._get_values_for_csv(**self._number_format)
# --> 324 libwriters.write_csv_rows(
#     325     data,
#     326     ix,
#     327     self.nlevels,
#     328     self.cols,
#     329     self.writer,
#     330 )
#
# File writers.pyx:73, in pandas._libs.writers.write_csv_rows()
#
# File ~/Desktop/Drug-Drug-Interaction-and-Alternate-Recommendation-System/.venv/lib/python3.9/site-packages/numpy/core/arrayprint.py:1612, in _array_str_implementation(a, max_line_width, precision, suppress_small, array2string)
#    1606 if a.shape == ():
#    1607     # obtain a scalar and call str on it, avoiding problems for subclasses
#    1608     # for which indexing with () returns a 0d instead of a scalar by using
#    1609     # ndarray's getindex. Also guard against recursive 0d object arrays.
#    1610     return _guarded_repr_or_str(np.ndarray.__getitem__(a, ()))
# -> 1612 return array2string(a, max_line_width, precision, suppress_small, ' ', "")
#
# File ~/Desktop/Drug-Drug-Interaction-and-Alternate-Recommendation-System/.venv/lib/python3.9/site-packages/numpy/core/arrayprint.py:736, in array2string(a, max_line_width, precision, suppress_small, separator, prefix, style, formatter, threshold, edgeitems, sign, floatmode, suffix, legacy)
#     733 if a.size == 0:
#     734     return "[]"
# --> 736 return _array2string(a, options, separator, prefix)
#
# File ~/Desktop/Drug-Drug-Interaction-and-Alternate-Recommendation-System/.venv/lib/python3.9/site-packages/numpy/core/arrayprint.py:513, in _recursive_guard.<locals>.decorating_function.<locals>.wrapper(self, *args, **kwargs)
#     511 repr_running.add(key)
#     512 try:
# --> 513     return f(self, *args, **kwargs)
#     514 finally:
#     515     repr_running.discard(key)
#
# File ~/Desktop/Drug-Drug-Interaction-and-Alternate-Recommendation-System/.venv/lib/python3.9/site-packages/numpy/core/arrayprint.py:546, in _array2string(a, options, separator, prefix)
#     543 # skip over array(
#     544 next_line_prefix += " "*len(prefix)
# --> 546 lst = _formatArray(a, format_function, options['linewidth'],
#     547                    next_line_prefix, separator, options['edgeitems'],
#     548                    summary_insert, options['legacy'])
#     549 return lst
#
# File ~/Desktop/Drug-Drug-Interaction-and-Alternate-Recommendation-System/.venv/lib/python3.9/site-packages/numpy/core/arrayprint.py:889, in _formatArray(a, format_function, line_width, next_line_prefix, separator, edge_items, summary_insert, legacy)
#     885     return s
#     887 try:
#     888     # invoke the recursive part with an initial index and prefix
# --> 889     return recurser(index=(),
#     890                     hanging_indent=next_line_prefix,
#     891                     curr_width=line_width)
#     892 finally:
#     893     # recursive closures have a cyclic reference to themselves, which
#     894     # requires gc to collect (gh-10620). To avoid this problem, for
#     895     # performance and PyPy friendliness, we break the cycle:
#     896     recurser = None
#
# File ~/Desktop/Drug-Drug-Interaction-and-Alternate-Recommendation-System/.venv/lib/python3.9/site-packages/numpy/core/arrayprint.py:845, in _formatArray.<locals>.recurser(index, hanging_indent, curr_width)
#     842         line += separator
#     844 for i in range(trailing_items, 1, -1):
# --> 845     word = recurser(index + (-i,), next_hanging_indent, next_width)
#     846     s, line = _extendLine_pretty(
#     847         s, line, word, elem_width, hanging_indent, legacy)
#     848     line += separator
#
# File ~/Desktop/Drug-Drug-Interaction-and-Alternate-Recommendation-System/.venv/lib/python3.9/site-packages/numpy/core/arrayprint.py:799, in _formatArray.<locals>.recurser(index, hanging_indent, curr_width)
#     796 axes_left = a.ndim - axis
#     798 if axes_left == 0:
# --> 799     return format_function(a[index])
#     801 # when recursing, add a space to align with the [ added, and reduce the
#     802 # length of the line by 1
#     803 next_hanging_indent = hanging_indent + ' '
#
# File ~/Desktop/Drug-Drug-Interaction-and-Alternate-Recommendation-System/.venv/lib/python3.9/site-packages/numpy/core/arrayprint.py:1027, in FloatingFormat.__call__(self, x)
#    1025             sign = '-' if x < 0 else '+' if self.sign == '+' else ''
#    1026             ret = sign + _format_options['infstr']
# -> 1027         return ' '*(self.pad_left + self.pad_right + 1 - len(ret)) + ret
#    1029 if self.exp_format:
#    1030     return dragon4_scientific(x,
#    1031                               precision=self.precision,
#    1032                               min_digits=self.min_digits,
#    (...)
#    1036                               pad_left=self.pad_left,
#    1037                               exp_digits=self.exp_size)
#
# File ~/Desktop/Drug-Drug-Interaction-and-Alternate-Recommendation-System/.venv/lib/python3.9/site-packages/numpy/core/_ufunc_config.py:436, in errstate.__exit__(self, *exc_info)
#     435 def __exit__(self, *exc_info):
# --> 436     seterr(**self.oldstate)
#     437     if self.call is not _Unspecified:
#     438         seterrcall(self.oldcall)
#
# File ~/Desktop/Drug-Drug-Interaction-and-Alternate-Recommendation-System/.venv/lib/python3.9/site-packages/numpy/core/_ufunc_config.py:111, in seterr(all, divide, over, under, invalid)
#      35 """
#      36 Set how floating-point errors are handled.
#      37
#    (...)
#     107
#     108 """
#     110 pyvals = umath.geterrobj()
# --> 111 old = geterr()
#     113 if divide is None:
#     114     divide = all or old['divide']
#
# File ~/Desktop/Drug-Drug-Interaction-and-Alternate-Recommendation-System/.venv/lib/python3.9/site-packages/numpy/core/_ufunc_config.py:168, in geterr()
#     132 @set_module('numpy')
#     133 def geterr():
#     134     """
#     135     Get the current way of handling floating-point errors.
#     136
#    (...)
#     166
#     167     """
# --> 168     maskvalue = umath.geterrobj()[1]
#     169     mask = 7
#     170     res = {}
#
# KeyboardInterrupt:

# %% [markdown]
# Plot a pie chart for the training dataset interactions and testing dataset interactions

# %%
fig, axs = plt.subplots(1, 2, figsize=(12, 6))


axs[0].pie(interaction_counts, labels=interaction_counts.index, autopct='%1.1f%%', startangle=90)
axs[0].set_title('Drug Interactions in Training Dataset')


axs[1].pie(interaction_counts_test, labels=interaction_counts_test.index, autopct='%1.1f%%', startangle=90)
axs[1].set_title('Drug Interactions in Testing Dataset')

plt.show()

# %% [markdown]
# ## Visualisation

# %%
tsne = TSNE(n_components=2, random_state=42)
drug_vectors_2d = tsne.fit_transform(drug_vectors_df)

drug_vectors_2d_df = pd.DataFrame(drug_vectors_2d, index=drug_vectors_df.index, columns=['x', 'y'])

# Plot the 2D vectors
plt.figure(figsize=(14, 10))
plt.scatter(drug_vectors_2d_df['x'], drug_vectors_2d_df['y'])

# Annotate points with drug names
for drug, (x, y) in drug_vectors_2d_df.iterrows():
    plt.text(x, y, drug, fontsize=9)

plt.title('t-SNE visualization of drug vectors')
plt.xlabel('Dimension 1')
plt.ylabel('Dimension 2')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[39], line 2
#       1 tsne = TSNE(n_components=2, random_state=42)
# ----> 2 drug_vectors_2d = tsne.fit_transform(drug_vectors_df)
#       4 drug_vectors_2d_df = pd.DataFrame(drug_vectors_2d, index=drug_vectors_df.index, columns=['x', 'y'])
#       6 # Plot the 2D vectors
#
# File ~/Desktop/Drug-Drug-Interaction-and-Alternate-Recommendation-System/.venv/lib/python3.9/site-packages/sklearn/manifold/_t_sne.py:1119, in TSNE.fit_transform(self, X, y)
#    1117 self._validate_params()
#    1118 self._check_params_vs_input(X)
# -> 1119 embedding = self._fit(X)
#    1120 self.embedding_ = embedding
#    1121 return self.embedding_
#
# File ~/Desktop/Drug-Drug-Interaction-and-Alternate-Recommendation-System/.venv/lib/python3.9/site-packages/sklearn/manifold/_t_sne.py:854, in TSNE._fit(self, X, skip_num_points)
#     851     self.learning_rate_ = self.learning_rate
#     853 if self.method == "barnes_hut":
# --> 854     X = self._validate_data(
#     855         X,
#     856         accept_sparse=["csr"],
#     857         ensure_min_samples=2,
#     858         dtype=[np.float32, np.float64],
#     859     )
#     860 else:
#     861     X = self._validate_data(
#     862         X, accept_sparse=["csr", "csc", "coo"], dtype=[np.float32, np.float64]
#     863     )
#
# File ~/Desktop/Drug-Drug-Interaction-and-Alternate-Recommendation-System/.venv/lib/python3.9/site-packages/sklearn/base.py:565, in BaseEstimator._validate_data(self, X, y, reset, validate_separately, **check_params)
#     563     raise ValueError("Validation should be done on X, y or both.")
#     564 elif not no_val_X and no_val_y:
# --> 565     X = check_array(X, input_name="X", **check_params)
#     566     out = X
#     567 elif no_val_X and not no_val_y:
#
# File ~/Desktop/Drug-Drug-Interaction-and-Alternate-Recommendation-System/.venv/lib/python3.9/site-packages/sklearn/utils/validation.py:921, in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator, input_name)
#     915         raise ValueError(
#     916             "Found array with dim %d. %s expected <= 2."
#     917             % (array.ndim, estimator_name)
#     918         )
#     920     if force_all_finite:
# --> 921         _assert_all_finite(
#     922             array,
#     923             input_name=input_name,
#     924             estimator_name=estimator_name,
#     925             allow_nan=force_all_finite == "allow-nan",
#     926         )
#     928 if ensure_min_samples > 0:
#     929     n_samples = _num_samples(array)
#
# File ~/Desktop/Drug-Drug-Interaction-and-Alternate-Recommendation-System/.venv/lib/python3.9/site-packages/sklearn/utils/validation.py:161, in _assert_all_finite(X, allow_nan, msg_dtype, estimator_name, input_name)
#     144 if estimator_name and input_name == "X" and has_nan_error:
#     145     # Improve the error message on how to handle missing values in
#     146     # scikit-learn.
#     147     msg_err += (
#     148         f"\n{estimator_name} does not accept missing values"
#     149         " encoded as NaN natively. For supervised learning, you might want"
#    (...)
#     159         "#estimators-that-handle-nan-values"
#     160     )
# --> 161 raise ValueError(msg_err)
#
# ValueError: Input X contains NaN.
# TSNE does not accept missing values encoded as NaN natively. For supervised learning, you might want to consider sklearn.ensemble.HistGradientBoostingClassifier and Regressor which accept missing values encoded as NaNs natively. Alternatively, it is possible to preprocess the data, for instance by using an imputer transformer in a pipeline or drop samples with missing values. See https://scikit-learn.org/stable/modules/impute.html You can find a list of all estimators that handle NaN values at the following page: https://scikit-learn.org/stable/modules/impute.html#estimators-that-handle-nan-values

# %% [markdown]
# ## **Training**

# %% [markdown]
# ### Logistic Regression, Decision Tree, Random Forest, SVM

# %%
# Filter out rows where Drug1 is the same as Drug2
drug_pairs_df = drug_pairs_df[drug_pairs_df['Drug1'] != drug_pairs_df['Drug2']]
drug_pairs_df_test = drug_pairs_df_test[drug_pairs_df_test['Drug1'] != drug_pairs_df_test['Drug2']]

# Function to combine vectors
def combine_vectors(row):
    drug1_vector = row['Drug1_Vector'] if row['Drug1_Vector'] is not None else []
    drug2_vector = row['Drug2_Vector'] if row['Drug2_Vector'] is not None else []
    return list(drug1_vector) + list(drug2_vector)

# Apply the function to create combined vectors
drug_pairs_df['Combined_Vector'] = drug_pairs_df.apply(combine_vectors, axis=1)
drug_pairs_df_test['Combined_Vector'] = drug_pairs_df_test.apply(combine_vectors, axis=1)

# Prepare the feature matrix and labels
X_train_full = list(drug_pairs_df['Combined_Vector'])
y_train_full = list(drug_pairs_df['Interaction_Label'])

X_test = list(drug_pairs_df_test['Combined_Vector'])
y_test = list(drug_pairs_df_test['Interaction_Label'])

# Handle imbalanced data
proportions = [1, 2, 3, 4, 5]  # Example proportions
recalls = []

for proportion in proportions:
    # Separate majority and minority samples in the training set
    X_minority = [X_train_full[i] for i in range(len(y_train_full)) if y_train_full[i] == 1]
    y_minority = [y_train_full[i] for i in range(len(y_train_full)) if y_train_full[i] == 1]
    
    X_majority = [X_train_full[i] for i in range(len(y_train_full)) if y_train_full[i] == 0]
    y_majority = [y_train_full[i] for i in range(len(y_train_full)) if y_train_full[i] == 0]
    
    # Sample majority class to balance the dataset
    

    n_minority = len(X_minority)
    n_majority = n_minority * proportion
    X_majority = X_majority[:n_majority]
    y_majority = y_majority[:n_majority]
    
    # Combine the sampled majority and minority data
    X_train_balanced = X_minority + X_majority
    y_train_balanced = y_minority + y_majority
    
    # Shuffle the data to ensure random distribution
    X_train_balanced, y_train_balanced = shuffle(X_train_balanced, y_train_balanced, random_state=42)
    
    # Define models
    models = {
        "Logistic Regression": LogisticRegression(max_iter=1000),
        "Decision Tree": DecisionTreeClassifier(),
        "Random Forest": RandomForestClassifier(),
        "SVM": SVC()
    }
    
    for model_name, model in models.items():
        # Train the model on the balanced subset
        model.fit(X_train_balanced, y_train_balanced)
        
        # Predict on the test set
        y_pred = model.predict(X_test)
        
        # Evaluate the model using recall for both classes
        recall_minority = recall_score(y_test, y_pred, pos_label=1)
        recall_majority = recall_score(y_test, y_pred, pos_label=0)
        recalls.append((model_name, proportion, recall_minority, recall_majority))
        print(f"{model_name} - Proportion {proportion}:1 - Recall (Minority): {recall_minority:.2f} - Recall (Majority): {recall_majority:.2f}")
        
        # Optional: print additional metrics
        print(f"Accuracy: {accuracy_score(y_test, y_pred):.2f}")
        print(classification_report(y_test, y_pred))

# Plot Recall vs Training Data Proportion for each model
plt.figure(figsize=(10, 6))
for model_name in models.keys():
    model_recalls_minority = [recall_minority for name, proportion, recall_minority, recall_majority in recalls if name == model_name]
    model_recalls_majority = [recall_majority for name, proportion, recall_minority, recall_majority in recalls if name == model_name]
    plt.plot(proportions, model_recalls_minority, marker='o', label=f"{model_name} (Minority)")
    plt.plot(proportions, model_recalls_majority, marker='x', label=f"{model_name} (Majority)")

plt.xlabel("Training Data Proportion (Majority:Minority)")
plt.ylabel("Recall on Test Set")
plt.title("Recall vs. Training Data Proportion")
plt.legend()
plt.grid(True)
plt.show()
# Out:
# Logistic Regression - Proportion 1:1 - Recall (Minority): 0.72 - Recall (Majority): 0.39
# Accuracy: 0.41
#               precision    recall  f1-score   support
#
#            0       0.94      0.39      0.55      1317
#            1       0.09      0.72      0.17       116
#
#     accuracy                           0.41      1433
#    macro avg       0.52      0.55      0.36      1433
# weighted avg       0.87      0.41      0.52      1433
#
# Decision Tree - Proportion 1:1 - Recall (Minority): 0.71 - Recall (Majority): 0.33
# Accuracy: 0.36
#               precision    recall  f1-score   support
#
#            0       0.93      0.33      0.48      1317
#            1       0.08      0.71      0.15       116
#
#     accuracy                           0.36      1433
#    macro avg       0.51      0.52      0.32      1433
# weighted avg       0.86      0.36      0.46      1433
#
# Random Forest - Proportion 1:1 - Recall (Minority): 0.86 - Recall (Majority): 0.26
# Accuracy: 0.31
#               precision    recall  f1-score   support
#
#            0       0.96      0.26      0.41      1317
#            1       0.09      0.86      0.17       116
#
#     accuracy                           0.31      1433
#    macro avg       0.52      0.56      0.29      1433
# weighted avg       0.89      0.31      0.39      1433
#
# SVM - Proportion 1:1 - Recall (Minority): 0.86 - Recall (Majority): 0.32
# Accuracy: 0.36
#               precision    recall  f1-score   support
#
#            0       0.96      0.32      0.48      1317
#            1       0.10      0.86      0.18       116
#
#     accuracy                           0.36      1433
#    macro avg       0.53      0.59      0.33      1433
# weighted avg       0.89      0.36      0.45      1433
#
# Logistic Regression - Proportion 2:1 - Recall (Minority): 0.47 - Recall (Majority): 0.64
# Accuracy: 0.63
#               precision    recall  f1-score   support
#
#            0       0.93      0.64      0.76      1317
#            1       0.10      0.47      0.17       116
#
#     accuracy                           0.63      1433
#    macro avg       0.52      0.55      0.46      1433
# weighted avg       0.86      0.63      0.71      1433
#
# Decision Tree - Proportion 2:1 - Recall (Minority): 0.57 - Recall (Majority): 0.59
# Accuracy: 0.59
#               precision    recall  f1-score   support
#
#            0       0.94      0.59      0.72      1317
#            1       0.11      0.57      0.18       116
#
#     accuracy                           0.59      1433
#    macro avg       0.52      0.58      0.45      1433
# weighted avg       0.87      0.59      0.68      1433
#
# Random Forest - Proportion 2:1 - Recall (Minority): 0.44 - Recall (Majority): 0.67
# Accuracy: 0.65
#               precision    recall  f1-score   support
#
#            0       0.93      0.67      0.78      1317
#            1       0.10      0.44      0.17       116
#
#     accuracy                           0.65      1433
#    macro avg       0.52      0.55      0.47      1433
# weighted avg       0.86      0.65      0.73      1433
#
# SVM - Proportion 2:1 - Recall (Minority): 0.38 - Recall (Majority): 0.73
# Accuracy: 0.70
#               precision    recall  f1-score   support
#
#            0       0.93      0.73      0.81      1317
#            1       0.11      0.38      0.17       116
#
#     accuracy                           0.70      1433
#    macro avg       0.52      0.55      0.49      1433
# weighted avg       0.86      0.70      0.76      1433
#
# Logistic Regression - Proportion 3:1 - Recall (Minority): 0.29 - Recall (Majority): 0.74
# Accuracy: 0.70
#               precision    recall  f1-score   support
#
#            0       0.92      0.74      0.82      1317
#            1       0.09      0.29      0.14       116
#
#     accuracy                           0.70      1433
#    macro avg       0.51      0.52      0.48      1433
# weighted avg       0.85      0.70      0.77      1433
#
# Decision Tree - Proportion 3:1 - Recall (Minority): 0.42 - Recall (Majority): 0.68
# Accuracy: 0.66
#               precision    recall  f1-score   support
#
#            0       0.93      0.68      0.79      1317
#            1       0.10      0.42      0.17       116
#
#     accuracy                           0.66      1433
#    macro avg       0.52      0.55      0.48      1433
# weighted avg       0.86      0.66      0.74      1433
#
# Random Forest - Proportion 3:1 - Recall (Minority): 0.32 - Recall (Majority): 0.75
# Accuracy: 0.71
#               precision    recall  f1-score   support
#
#            0       0.93      0.75      0.83      1317
#            1       0.10      0.32      0.15       116
#
#     accuracy                           0.71      1433
#    macro avg       0.51      0.53      0.49      1433
# weighted avg       0.86      0.71      0.77      1433
#
# SVM - Proportion 3:1 - Recall (Minority): 0.25 - Recall (Majority): 0.87
# Accuracy: 0.82
#               precision    recall  f1-score   support
#
#            0       0.93      0.87      0.90      1317
#            1       0.14      0.25      0.18       116
#
#     accuracy                           0.82      1433
#    macro avg       0.54      0.56      0.54      1433
# weighted avg       0.87      0.82      0.84      1433
#
# Logistic Regression - Proportion 4:1 - Recall (Minority): 0.12 - Recall (Majority): 0.89
# Accuracy: 0.82
#               precision    recall  f1-score   support
#
#            0       0.92      0.89      0.90      1317
#            1       0.08      0.12      0.10       116
#
#     accuracy                           0.82      1433
#    macro avg       0.50      0.50      0.50      1433
# weighted avg       0.85      0.82      0.84      1433
#
# Decision Tree - Proportion 4:1 - Recall (Minority): 0.34 - Recall (Majority): 0.80
# Accuracy: 0.77
#               precision    recall  f1-score   support
#
#            0       0.93      0.80      0.86      1317
#            1       0.13      0.34      0.19       116
#
#     accuracy                           0.77      1433
#    macro avg       0.53      0.57      0.53      1433
# weighted avg       0.87      0.77      0.81      1433
#
# Random Forest - Proportion 4:1 - Recall (Minority): 0.22 - Recall (Majority): 0.93
# Accuracy: 0.87
#               precision    recall  f1-score   support
#
#            0       0.93      0.93      0.93      1317
#            1       0.21      0.22      0.22       116
#
#     accuracy                           0.87      1433
#    macro avg       0.57      0.57      0.57      1433
# weighted avg       0.87      0.87      0.87      1433
#
# SVM - Proportion 4:1 - Recall (Minority): 0.11 - Recall (Majority): 0.96
# Accuracy: 0.89
#               precision    recall  f1-score   support
#
#            0       0.92      0.96      0.94      1317
#            1       0.19      0.11      0.14       116
#
#     accuracy                           0.89      1433
#    macro avg       0.56      0.54      0.54      1433
# weighted avg       0.87      0.89      0.88      1433
#
# Logistic Regression - Proportion 5:1 - Recall (Minority): 0.06 - Recall (Majority): 0.94
# Accuracy: 0.87
#               precision    recall  f1-score   support
#
#            0       0.92      0.94      0.93      1317
#            1       0.08      0.06      0.07       116
#
#     accuracy                           0.87      1433
#    macro avg       0.50      0.50      0.50      1433
# weighted avg       0.85      0.87      0.86      1433
#
# Decision Tree - Proportion 5:1 - Recall (Minority): 0.31 - Recall (Majority): 0.85
# Accuracy: 0.81
#               precision    recall  f1-score   support
#
#            0       0.93      0.85      0.89      1317
#            1       0.16      0.31      0.21       116
#
#     accuracy                           0.81      1433
#    macro avg       0.54      0.58      0.55      1433
# weighted avg       0.87      0.81      0.84      1433
#
# Random Forest - Proportion 5:1 - Recall (Minority): 0.16 - Recall (Majority): 0.97
# Accuracy: 0.90
#               precision    recall  f1-score   support
#
#            0       0.93      0.97      0.95      1317
#            1       0.29      0.16      0.21       116
#
#     accuracy                           0.90      1433
#    macro avg       0.61      0.56      0.58      1433
# weighted avg       0.88      0.90      0.89      1433
#
# SVM - Proportion 5:1 - Recall (Minority): 0.03 - Recall (Majority): 0.99
# Accuracy: 0.91
#               precision    recall  f1-score   support
#
#            0       0.92      0.99      0.95      1317
#            1       0.19      0.03      0.06       116
#
#     accuracy                           0.91      1433
#    macro avg       0.56      0.51      0.51      1433
# weighted avg       0.86      0.91      0.88      1433

# %% [markdown]
# ## XgBoost

# %%
# Drop rows where both Drug1 and Drug2 are the same
drug_pairs_df = drug_pairs_df[drug_pairs_df['Drug1'] != drug_pairs_df['Drug2']]
drug_pairs_df_test = drug_pairs_df_test[drug_pairs_df_test['Drug1'] != drug_pairs_df_test['Drug2']]

# Combine the vectors of Drug1 and Drug2 into a single feature vector
def combine_vectors(row):
    drug1_vector = row['Drug1_Vector'] if row['Drug1_Vector'] is not None else []
    drug2_vector = row['Drug2_Vector'] if row['Drug2_Vector'] is not None else []
    return list(drug1_vector) + list(drug2_vector)

drug_pairs_df['Combined_Vector'] = drug_pairs_df.apply(combine_vectors, axis=1)
drug_pairs_df_test['Combined_Vector'] = drug_pairs_df_test.apply(combine_vectors, axis=1)

# Prepare the feature matrix and labels
X_train_full = list(drug_pairs_df['Combined_Vector'])
y_train_full = list(drug_pairs_df['Interaction_Label'])

X_test = list(drug_pairs_df_test['Combined_Vector'])
y_test = list(drug_pairs_df_test['Interaction_Label'])

# Handle imbalanced data
proportions = [1, 2, 3, 4, 5]  # Example proportions
recalls = []

for proportion in proportions:
    # Separate majority and minority samples in the training set
    X_minority = [X_train_full[i] for i in range(len(y_train_full)) if y_train_full[i] == 1]
    y_minority = [y_train_full[i] for i in range(len(y_train_full)) if y_train_full[i] == 1]
    
    X_majority = [X_train_full[i] for i in range(len(y_train_full)) if y_train_full[i] == 0]
    y_majority = [y_train_full[i] for i in range(len(y_train_full)) if y_train_full[i] == 0]
    
    # Sample majority class to balance the dataset
    n_minority = len(X_minority)
    n_majority = n_minority * proportion
    X_majority = X_majority[:n_majority]
    y_majority = y_majority[:n_majority]
    
    # Combine the sampled majority and minority data
    X_train_balanced = X_minority + X_majority
    y_train_balanced = y_minority + y_majority
    
    # Shuffle the data to ensure random distribution
    X_train_balanced, y_train_balanced = shuffle(X_train_balanced, y_train_balanced, random_state=42)
    
    # Train an XGBoost model on the balanced subset
    model = xgb.XGBClassifier(use_label_encoder=False, eval_metric='logloss')
    model.fit(X_train_balanced, y_train_balanced)
    
    # Predict on the test set
    y_pred = model.predict(X_test)
    
    # Evaluate the model using recall for both classes
    recall_class_1 = recall_score(y_test, y_pred, pos_label=1)
    recall_class_0 = recall_score(y_test, y_pred, pos_label=0)
    recalls.append((proportion, recall_class_1, recall_class_0))
    
    print(f"XGBoost - Proportion {proportion}:1 - Recall Class 1: {recall_class_1:.2f}, Recall Class 0: {recall_class_0:.2f}")
    print(f"Accuracy: {accuracy_score(y_test, y_pred):.2f}")
    print(classification_report(y_test, y_pred))

# Plot Recall vs Training Data Proportion for XGBoost
plt.figure(figsize=(10, 6))
proportions, recall_scores_class_1, recall_scores_class_0 = zip(*recalls)
plt.plot(proportions, recall_scores_class_1, marker='o', label='XGBoost Class 1')
plt.plot(proportions, recall_scores_class_0, marker='o', label='XGBoost Class 0')

plt.xlabel("Training Data Proportion (Majority:Minority)")
plt.ylabel("Recall on Test Set")
plt.title("Recall vs. Training Data Proportion for XGBoost")
plt.legend()
plt.grid(True)
plt.show()
# Out:
# c:\Users\manav\OneDrive\Desktop\NIT Surathkal\Semester 7\IT-449\Drug-Drug-Interaction-and-Alternate-Recommendation-System\.venv\lib\site-packages\xgboost\core.py:158: UserWarning: [13:56:47] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0ed59c031377d09b8-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# XGBoost - Proportion 1:1 - Recall Class 1: 0.81, Recall Class 0: 0.29
# Accuracy: 0.33
#               precision    recall  f1-score   support
#
#            0       0.95      0.29      0.44      1317
#            1       0.09      0.81      0.16       116
#
#     accuracy                           0.33      1433
#    macro avg       0.52      0.55      0.30      1433
# weighted avg       0.88      0.33      0.42      1433
# c:\Users\manav\OneDrive\Desktop\NIT Surathkal\Semester 7\IT-449\Drug-Drug-Interaction-and-Alternate-Recommendation-System\.venv\lib\site-packages\xgboost\core.py:158: UserWarning: [13:56:48] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0ed59c031377d09b8-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# XGBoost - Proportion 2:1 - Recall Class 1: 0.53, Recall Class 0: 0.64
# Accuracy: 0.63
#               precision    recall  f1-score   support
#
#            0       0.94      0.64      0.76      1317
#            1       0.11      0.53      0.19       116
#
#     accuracy                           0.63      1433
#    macro avg       0.53      0.58      0.48      1433
# weighted avg       0.87      0.63      0.72      1433
# c:\Users\manav\OneDrive\Desktop\NIT Surathkal\Semester 7\IT-449\Drug-Drug-Interaction-and-Alternate-Recommendation-System\.venv\lib\site-packages\xgboost\core.py:158: UserWarning: [13:56:51] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0ed59c031377d09b8-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# XGBoost - Proportion 3:1 - Recall Class 1: 0.50, Recall Class 0: 0.72
# Accuracy: 0.70
#               precision    recall  f1-score   support
#
#            0       0.94      0.72      0.82      1317
#            1       0.14      0.50      0.22       116
#
#     accuracy                           0.70      1433
#    macro avg       0.54      0.61      0.52      1433
# weighted avg       0.88      0.70      0.77      1433
# c:\Users\manav\OneDrive\Desktop\NIT Surathkal\Semester 7\IT-449\Drug-Drug-Interaction-and-Alternate-Recommendation-System\.venv\lib\site-packages\xgboost\core.py:158: UserWarning: [13:56:53] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0ed59c031377d09b8-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# XGBoost - Proportion 4:1 - Recall Class 1: 0.27, Recall Class 0: 0.90
# Accuracy: 0.85
#               precision    recall  f1-score   support
#
#            0       0.93      0.90      0.92      1317
#            1       0.19      0.27      0.22       116
#
#     accuracy                           0.85      1433
#    macro avg       0.56      0.58      0.57      1433
# weighted avg       0.87      0.85      0.86      1433
# c:\Users\manav\OneDrive\Desktop\NIT Surathkal\Semester 7\IT-449\Drug-Drug-Interaction-and-Alternate-Recommendation-System\.venv\lib\site-packages\xgboost\core.py:158: UserWarning: [13:56:55] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0ed59c031377d09b8-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# XGBoost - Proportion 5:1 - Recall Class 1: 0.18, Recall Class 0: 0.94
# Accuracy: 0.88
#               precision    recall  f1-score   support
#
#            0       0.93      0.94      0.94      1317
#            1       0.22      0.18      0.20       116
#
#     accuracy                           0.88      1433
#    macro avg       0.58      0.56      0.57      1433
# weighted avg       0.87      0.88      0.88      1433

# %% [markdown]
# ### Using Anomaly Detection Models

# %%
import numpy as np
import pandas as pd
from sklearn.ensemble import IsolationForest
from sklearn.svm import OneClassSVM
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, classification_report

# Combine the vectors of Drug1 and Drug2 into a single feature vector
def combine_vectors(row):
    drug1_vector = row['Drug1_Vector'] if row['Drug1_Vector'] is not None else []
    drug2_vector = row['Drug2_Vector'] if row['Drug2_Vector'] is not None else []
    return list(drug1_vector) + list(drug2_vector)

drug_pairs_df['Combined_Vector'] = drug_pairs_df.apply(combine_vectors, axis=1)
drug_pairs_df_test['Combined_Vector'] = drug_pairs_df_test.apply(combine_vectors, axis=1)

# Prepare the feature matrix and labels
X_train = np.array(list(drug_pairs_df['Combined_Vector']))
y_train = np.array(drug_pairs_df['Interaction_Label'])

X_test = np.array(list(drug_pairs_df_test['Combined_Vector']))
y_test = np.array(drug_pairs_df_test['Interaction_Label'])

# Separate the majority class (normal) and minority class (anomalies)
X_train_normal = X_train[y_train == 0]
X_train_anomalies = X_train[y_train == 1]

# Train Isolation Forest
iso_forest = IsolationForest(contamination=len(X_train_anomalies)/len(X_train))
iso_forest.fit(X_train_normal)

# Train One-Class SVM
oc_svm = OneClassSVM(nu=len(X_train_anomalies)/len(X_train), kernel='rbf', gamma=0.1)
oc_svm.fit(X_train_normal)

# Predict using Isolation Forest
y_pred_iso_forest = iso_forest.predict(X_test)
y_pred_iso_forest = np.where(y_pred_iso_forest == 1, 0, 1)  # Convert 1 to 0 (normal) and -1 to 1 (anomaly)

# Predict using One-Class SVM
y_pred_oc_svm = oc_svm.predict(X_test)
y_pred_oc_svm = np.where(y_pred_oc_svm == 1, 0, 1)  # Convert 1 to 0 (normal) and -1 to 1 (anomaly)

# Evaluate the models
def evaluate_model(y_true, y_pred, model_name):
    accuracy = accuracy_score(y_true, y_pred)
    precision = precision_score(y_true, y_pred)
    recall = recall_score(y_true, y_pred)
    f1 = f1_score(y_true, y_pred)
    print(f"{model_name} - Accuracy: {accuracy:.2f}, Precision: {precision:.2f}, Recall: {recall:.2f}, F1-Score: {f1:.2f}")
    print(classification_report(y_true, y_pred))

evaluate_model(y_test, y_pred_iso_forest, "Isolation Forest")
evaluate_model(y_test, y_pred_oc_svm, "One-Class SVM")
# Out:
# Isolation Forest - Accuracy: 0.85, Precision: 0.09, Recall: 0.09, F1-Score: 0.09
#               precision    recall  f1-score   support
#
#            0       0.92      0.92      0.92      1317
#            1       0.09      0.09      0.09       116
#
#     accuracy                           0.85      1433
#    macro avg       0.51      0.51      0.51      1433
# weighted avg       0.85      0.85      0.85      1433
#
# One-Class SVM - Accuracy: 0.27, Precision: 0.09, Recall: 0.91, F1-Score: 0.17
#               precision    recall  f1-score   support
#
#            0       0.96      0.22      0.35      1317
#            1       0.09      0.91      0.17       116
#
#     accuracy                           0.27      1433
#    macro avg       0.53      0.56      0.26      1433
# weighted avg       0.89      0.27      0.34      1433

# %% [markdown]
# ### Neural Network

# %%
# Import necessary libraries
import numpy as np
import pandas as pd
from sklearn.utils import shuffle
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout
from tensorflow.keras.optimizers import Adam


# Combine the vectors of Drug1 and Drug2 into a single feature vector
def combine_vectors(row):
    drug1_vector = row['Drug1_Vector'] if row['Drug1_Vector'] is not None else []
    drug2_vector = row['Drug2_Vector'] if row['Drug2_Vector'] is not None else []
    return list(drug1_vector) + list(drug2_vector)

drug_pairs_df['Combined_Vector'] = drug_pairs_df.apply(combine_vectors, axis=1)
drug_pairs_df_test['Combined_Vector'] = drug_pairs_df_test.apply(combine_vectors, axis=1)

# Prepare the feature matrix and labels
X_test = np.array(list(drug_pairs_df_test['Combined_Vector']))
y_test = np.array(drug_pairs_df_test['Interaction_Label'])

# Define the neural network model
def create_model(input_dim):
    model = Sequential()
    model.add(Dense(128, input_dim=input_dim, activation='relu'))
    model.add(Dropout(0.5))
    model.add(Dense(64, activation='relu'))
    model.add(Dropout(0.5))
    model.add(Dense(1, activation='sigmoid'))
    model.compile(optimizer=Adam(learning_rate=0.001), loss='binary_crossentropy', metrics=['accuracy'])
    return model

# Handle imbalanced data
proportions = [1.5, 2, 2.5, 3]
metrics = []

for proportion in proportions:
    # Separate majority and minority samples in the training set
    X_minority = [X_train_full[i] for i in range(len(y_train_full)) if y_train_full[i] == 1]
    y_minority = [y_train_full[i] for i in range(len(y_train_full)) if y_train_full[i] == 1]
    
    X_majority = [X_train_full[i] for i in range(len(y_train_full)) if y_train_full[i] == 0]
    y_majority = [y_train_full[i] for i in range(len(y_train_full)) if y_train_full[i] == 0]
    
    # Sample majority class to balance the dataset
    n_minority = len(X_minority)
    n_majority = int(n_minority * proportion)
    X_majority = X_majority[:n_majority]
    y_majority = y_majority[:n_majority]
    
    # Combine the sampled majority and minority data
    X_train_balanced = X_minority + X_majority
    y_train_balanced = y_minority + y_majority
    
    # Shuffle the data to ensure random distribution
    X_train_balanced, y_train_balanced = shuffle(X_train_balanced, y_train_balanced, random_state=42)
    
    # Convert to numpy arrays
    X_train_balanced = np.array(X_train_balanced)
    y_train_balanced = np.array(y_train_balanced)
    
    # Create and train the model
    model = create_model(input_dim=X_train_balanced.shape[1])
    model.fit(X_train_balanced, y_train_balanced, epochs=50, batch_size=32, validation_split=0.2)
    
    # Predict on the test set
    y_pred = (model.predict(X_test) > 0.5).astype("int32")
    
    # Evaluate the model using multiple metrics
    accuracy = accuracy_score(y_test, y_pred)
    precision = precision_score(y_test, y_pred)
    recall = recall_score(y_test, y_pred)
    f1 = f1_score(y_test, y_pred)
    
    metrics.append({
        'proportion': proportion,
        'accuracy': accuracy,
        'precision': precision,
        'recall': recall,
        'f1_score': f1
    })
    
    print(f"Proportion {proportion}:1 - Accuracy: {accuracy:.2f}, Precision: {precision:.2f}, Recall: {recall:.2f}, F1-Score: {f1:.2f}")

# Print all metrics
print("Metrics for different proportions:")
for metric in metrics:
    print(metric)
# Out:
# c:\Users\manav\OneDrive\Desktop\NIT Surathkal\Semester 7\IT-449\Drug-Drug-Interaction-and-Alternate-Recommendation-System\.venv\lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Epoch 1/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.5512 - loss: 0.8979 - val_accuracy: 0.6938 - val_loss: 0.5925
# Epoch 2/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6050 - loss: 0.6825 - val_accuracy: 0.7430 - val_loss: 0.5619
# Epoch 3/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6676 - loss: 0.6079 - val_accuracy: 0.7537 - val_loss: 0.5149
# Epoch 4/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6973 - loss: 0.5648 - val_accuracy: 0.7901 - val_loss: 0.4847
# Epoch 5/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7541 - loss: 0.5118 - val_accuracy: 0.8094 - val_loss: 0.4580
# Epoch 6/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7783 - loss: 0.4762 - val_accuracy: 0.8051 - val_loss: 0.4431
# Epoch 7/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7521 - loss: 0.4890 - val_accuracy: 0.8094 - val_loss: 0.4271
# Epoch 8/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7961 - loss: 0.4393 - val_accuracy: 0.8051 - val_loss: 0.4251
# Epoch 9/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8064 - loss: 0.4216 - val_accuracy: 0.8180 - val_loss: 0.4009
# Epoch 10/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8117 - loss: 0.4253 - val_accuracy: 0.8266 - val_loss: 0.3835
# Epoch 11/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8268 - loss: 0.3952 - val_accuracy: 0.8266 - val_loss: 0.3729
# Epoch 12/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8254 - loss: 0.3654 - val_accuracy: 0.8137 - val_loss: 0.3684
# Epoch 13/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8312 - loss: 0.3645 - val_accuracy: 0.8266 - val_loss: 0.3723
# Epoch 14/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8571 - loss: 0.3433 - val_accuracy: 0.8415 - val_loss: 0.3571
# Epoch 15/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8639 - loss: 0.3262 - val_accuracy: 0.8330 - val_loss: 0.3509
# Epoch 16/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8648 - loss: 0.3173 - val_accuracy: 0.8437 - val_loss: 0.3379
# Epoch 17/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8666 - loss: 0.3067 - val_accuracy: 0.8480 - val_loss: 0.3343
# Epoch 18/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8659 - loss: 0.3074 - val_accuracy: 0.8480 - val_loss: 0.3294
# Epoch 19/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8773 - loss: 0.2920 - val_accuracy: 0.8630 - val_loss: 0.3278
# Epoch 20/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8693 - loss: 0.2960 - val_accuracy: 0.8630 - val_loss: 0.3199
# Epoch 21/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8867 - loss: 0.2617 - val_accuracy: 0.8522 - val_loss: 0.3299
# Epoch 22/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8974 - loss: 0.2557 - val_accuracy: 0.8608 - val_loss: 0.3361
# Epoch 23/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9070 - loss: 0.2543 - val_accuracy: 0.8437 - val_loss: 0.3521
# Epoch 24/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9007 - loss: 0.2257 - val_accuracy: 0.8522 - val_loss: 0.3324
# Epoch 25/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9119 - loss: 0.2127 - val_accuracy: 0.8458 - val_loss: 0.3499
# Epoch 26/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9110 - loss: 0.2268 - val_accuracy: 0.8437 - val_loss: 0.3490
# Epoch 27/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9031 - loss: 0.2218 - val_accuracy: 0.8501 - val_loss: 0.3414
# Epoch 28/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9126 - loss: 0.2329 - val_accuracy: 0.8587 - val_loss: 0.3513
# Epoch 29/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9148 - loss: 0.2117 - val_accuracy: 0.8651 - val_loss: 0.3499
# Epoch 30/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8989 - loss: 0.2158 - val_accuracy: 0.8672 - val_loss: 0.3480
# Epoch 31/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9077 - loss: 0.2031 - val_accuracy: 0.8715 - val_loss: 0.3360
# Epoch 32/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9296 - loss: 0.1900 - val_accuracy: 0.8608 - val_loss: 0.3689
# Epoch 33/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9419 - loss: 0.1675 - val_accuracy: 0.8608 - val_loss: 0.3550
# Epoch 34/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9233 - loss: 0.1816 - val_accuracy: 0.8672 - val_loss: 0.3616
# Epoch 35/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9302 - loss: 0.1744 - val_accuracy: 0.8608 - val_loss: 0.3627
# Epoch 36/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9433 - loss: 0.1598 - val_accuracy: 0.8651 - val_loss: 0.3699
# Epoch 37/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9304 - loss: 0.1754 - val_accuracy: 0.8651 - val_loss: 0.3685
# Epoch 38/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9283 - loss: 0.1712 - val_accuracy: 0.8672 - val_loss: 0.3591
# Epoch 39/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9306 - loss: 0.1751 - val_accuracy: 0.8608 - val_loss: 0.3855
# Epoch 40/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9340 - loss: 0.1668 - val_accuracy: 0.8630 - val_loss: 0.3852
# Epoch 41/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9261 - loss: 0.1712 - val_accuracy: 0.8694 - val_loss: 0.3589
# Epoch 42/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9472 - loss: 0.1441 - val_accuracy: 0.8565 - val_loss: 0.4062
# Epoch 43/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9415 - loss: 0.1539 - val_accuracy: 0.8715 - val_loss: 0.3803
# Epoch 44/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9412 - loss: 0.1538 - val_accuracy: 0.8630 - val_loss: 0.3940
# Epoch 45/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9336 - loss: 0.1633 - val_accuracy: 0.8672 - val_loss: 0.3783
# Epoch 46/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9478 - loss: 0.1419 - val_accuracy: 0.8779 - val_loss: 0.4064
# Epoch 47/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9457 - loss: 0.1570 - val_accuracy: 0.8565 - val_loss: 0.4234
# Epoch 48/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9417 - loss: 0.1578 - val_accuracy: 0.8672 - val_loss: 0.3913
# Epoch 49/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9423 - loss: 0.1420 - val_accuracy: 0.8651 - val_loss: 0.4122
# Epoch 50/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9447 - loss: 0.1291 - val_accuracy: 0.8565 - val_loss: 0.4379
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Proportion 1.5:1 - Accuracy: 0.52, Precision: 0.11, Recall: 0.70, F1-Score: 0.19
# Epoch 1/50
# c:\Users\manav\OneDrive\Desktop\NIT Surathkal\Semester 7\IT-449\Drug-Drug-Interaction-and-Alternate-Recommendation-System\.venv\lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.5761 - loss: 0.8813 - val_accuracy: 0.7380 - val_loss: 0.5731
# Epoch 2/50
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6646 - loss: 0.6266 - val_accuracy: 0.7451 - val_loss: 0.5467
# Epoch 3/50
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7072 - loss: 0.5845 - val_accuracy: 0.7611 - val_loss: 0.5251
# Epoch 4/50
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7245 - loss: 0.5583 - val_accuracy: 0.7594 - val_loss: 0.5044
# Epoch 5/50
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7423 - loss: 0.5264 - val_accuracy: 0.7665 - val_loss: 0.4914
# Epoch 6/50
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7512 - loss: 0.5202 - val_accuracy: 0.7807 - val_loss: 0.4844
# Epoch 7/50
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7657 - loss: 0.4876 - val_accuracy: 0.7790 - val_loss: 0.4540
# Epoch 8/50
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7700 - loss: 0.4770 - val_accuracy: 0.7843 - val_loss: 0.4437
# Epoch 9/50
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7788 - loss: 0.4695 - val_accuracy: 0.7914 - val_loss: 0.4414
# Epoch 10/50
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7687 - loss: 0.4503 - val_accuracy: 0.7914 - val_loss: 0.4310
# Epoch 11/50
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7911 - loss: 0.4377 - val_accuracy: 0.7914 - val_loss: 0.4252
# Epoch 12/50
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8089 - loss: 0.4121 - val_accuracy: 0.8057 - val_loss: 0.4155
# Epoch 13/50
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8150 - loss: 0.4125 - val_accuracy: 0.8111 - val_loss: 0.4001
# Epoch 14/50
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8136 - loss: 0.3952 - val_accuracy: 0.8146 - val_loss: 0.3951
# Epoch 15/50
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8441 - loss: 0.3609 - val_accuracy: 0.8128 - val_loss: 0.3889
# Epoch 16/50
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8304 - loss: 0.3847 - val_accuracy: 0.8200 - val_loss: 0.3883
# Epoch 17/50
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8312 - loss: 0.3620 - val_accuracy: 0.8075 - val_loss: 0.3864
# Epoch 18/50
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8515 - loss: 0.3434 - val_accuracy: 0.8217 - val_loss: 0.3927
# Epoch 19/50
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8532 - loss: 0.3328 - val_accuracy: 0.8164 - val_loss: 0.3777
# Epoch 20/50
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8347 - loss: 0.3500 - val_accuracy: 0.8182 - val_loss: 0.3829
# Epoch 21/50
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8562 - loss: 0.3274 - val_accuracy: 0.8146 - val_loss: 0.3832
# Epoch 22/50
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8554 - loss: 0.3264 - val_accuracy: 0.8128 - val_loss: 0.3731
# Epoch 23/50
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8929 - loss: 0.2762 - val_accuracy: 0.8200 - val_loss: 0.3982
# Epoch 24/50
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8659 - loss: 0.2988 - val_accuracy: 0.8217 - val_loss: 0.3855
# Epoch 25/50
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8685 - loss: 0.2918 - val_accuracy: 0.8111 - val_loss: 0.3868
# Epoch 26/50
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8654 - loss: 0.3020 - val_accuracy: 0.8164 - val_loss: 0.3805
# Epoch 27/50
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8941 - loss: 0.2586 - val_accuracy: 0.8217 - val_loss: 0.3738
# Epoch 28/50
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8855 - loss: 0.2721 - val_accuracy: 0.8271 - val_loss: 0.3854
# Epoch 29/50
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8871 - loss: 0.2618 - val_accuracy: 0.8289 - val_loss: 0.3864
# Epoch 30/50
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8911 - loss: 0.2474 - val_accuracy: 0.8200 - val_loss: 0.4049
# Epoch 31/50
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8891 - loss: 0.2591 - val_accuracy: 0.8271 - val_loss: 0.3725
# Epoch 32/50
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8903 - loss: 0.2541 - val_accuracy: 0.8307 - val_loss: 0.3825
# Epoch 33/50
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8976 - loss: 0.2369 - val_accuracy: 0.8360 - val_loss: 0.3765
# Epoch 34/50
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9053 - loss: 0.2266 - val_accuracy: 0.8253 - val_loss: 0.3831
# Epoch 35/50
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8931 - loss: 0.2393 - val_accuracy: 0.8253 - val_loss: 0.4016
# Epoch 36/50
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8908 - loss: 0.2497 - val_accuracy: 0.8200 - val_loss: 0.4127
# Epoch 37/50
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9093 - loss: 0.2144 - val_accuracy: 0.8307 - val_loss: 0.4096
# Epoch 38/50
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8947 - loss: 0.2358 - val_accuracy: 0.8324 - val_loss: 0.4304
# Epoch 39/50
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9069 - loss: 0.2485 - val_accuracy: 0.8271 - val_loss: 0.4036
# Epoch 40/50
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9070 - loss: 0.2246 - val_accuracy: 0.8360 - val_loss: 0.4059
# Epoch 41/50
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9099 - loss: 0.2172 - val_accuracy: 0.8520 - val_loss: 0.3802
# Epoch 42/50
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9077 - loss: 0.2174 - val_accuracy: 0.8342 - val_loss: 0.3959
# Epoch 43/50
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9230 - loss: 0.2000 - val_accuracy: 0.8289 - val_loss: 0.4106
# Epoch 44/50
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9143 - loss: 0.1944 - val_accuracy: 0.8217 - val_loss: 0.4456
# Epoch 45/50
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9138 - loss: 0.2032 - val_accuracy: 0.8360 - val_loss: 0.4415
# Epoch 46/50
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9194 - loss: 0.1882 - val_accuracy: 0.8342 - val_loss: 0.4146
# Epoch 47/50
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9230 - loss: 0.1952 - val_accuracy: 0.8414 - val_loss: 0.4224
# Epoch 48/50
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9353 - loss: 0.1699 - val_accuracy: 0.8467 - val_loss: 0.4331
# Epoch 49/50
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9200 - loss: 0.1917 - val_accuracy: 0.8324 - val_loss: 0.4291
# Epoch 50/50
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9213 - loss: 0.1820 - val_accuracy: 0.8360 - val_loss: 0.4543
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# Proportion 2:1 - Accuracy: 0.55, Precision: 0.10, Recall: 0.54, F1-Score: 0.16
# Epoch 1/50
# c:\Users\manav\OneDrive\Desktop\NIT Surathkal\Semester 7\IT-449\Drug-Drug-Interaction-and-Alternate-Recommendation-System\.venv\lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.6385 - loss: 0.8797 - val_accuracy: 0.7584 - val_loss: 0.5557
# Epoch 2/50
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7022 - loss: 0.6123 - val_accuracy: 0.7722 - val_loss: 0.5306
# Epoch 3/50
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7406 - loss: 0.5676 - val_accuracy: 0.7722 - val_loss: 0.5098
# Epoch 4/50
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7330 - loss: 0.5446 - val_accuracy: 0.7890 - val_loss: 0.4865
# Epoch 5/50
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7734 - loss: 0.4968 - val_accuracy: 0.7951 - val_loss: 0.4798
# Epoch 6/50
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7739 - loss: 0.4973 - val_accuracy: 0.8012 - val_loss: 0.4562
# Epoch 7/50
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7895 - loss: 0.4743 - val_accuracy: 0.7890 - val_loss: 0.4411
# Epoch 8/50
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8160 - loss: 0.4254 - val_accuracy: 0.7997 - val_loss: 0.4398
# Epoch 9/50
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8022 - loss: 0.4143 - val_accuracy: 0.7997 - val_loss: 0.4307
# Epoch 10/50
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8047 - loss: 0.4220 - val_accuracy: 0.8119 - val_loss: 0.4243
# Epoch 11/50
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8310 - loss: 0.3900 - val_accuracy: 0.8104 - val_loss: 0.4111
# Epoch 12/50
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8294 - loss: 0.3990 - val_accuracy: 0.8104 - val_loss: 0.4040
# Epoch 13/50
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8404 - loss: 0.3602 - val_accuracy: 0.8089 - val_loss: 0.4119
# Epoch 14/50
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8323 - loss: 0.3750 - val_accuracy: 0.8150 - val_loss: 0.4191
# Epoch 15/50
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8446 - loss: 0.3715 - val_accuracy: 0.8242 - val_loss: 0.3953
# Epoch 16/50
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8377 - loss: 0.3533 - val_accuracy: 0.8150 - val_loss: 0.3964
# Epoch 17/50
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8546 - loss: 0.3313 - val_accuracy: 0.8058 - val_loss: 0.3934
# Epoch 18/50
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8736 - loss: 0.3128 - val_accuracy: 0.8242 - val_loss: 0.3959
# Epoch 19/50
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8507 - loss: 0.3263 - val_accuracy: 0.8303 - val_loss: 0.3879
# Epoch 20/50
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8702 - loss: 0.2948 - val_accuracy: 0.8073 - val_loss: 0.4028
# Epoch 21/50
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8554 - loss: 0.3135 - val_accuracy: 0.8257 - val_loss: 0.3944
# Epoch 22/50
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8653 - loss: 0.2949 - val_accuracy: 0.8257 - val_loss: 0.3970
# Epoch 23/50
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8786 - loss: 0.2984 - val_accuracy: 0.8349 - val_loss: 0.3981
# Epoch 24/50
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8806 - loss: 0.2678 - val_accuracy: 0.8318 - val_loss: 0.4066
# Epoch 25/50
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8838 - loss: 0.2750 - val_accuracy: 0.8287 - val_loss: 0.4012
# Epoch 26/50
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8819 - loss: 0.2596 - val_accuracy: 0.8379 - val_loss: 0.3998
# Epoch 27/50
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8739 - loss: 0.2709 - val_accuracy: 0.8379 - val_loss: 0.3957
# Epoch 28/50
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8920 - loss: 0.2464 - val_accuracy: 0.8287 - val_loss: 0.4210
# Epoch 29/50
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8872 - loss: 0.2531 - val_accuracy: 0.8471 - val_loss: 0.4126
# Epoch 30/50
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8989 - loss: 0.2365 - val_accuracy: 0.8394 - val_loss: 0.4188
# Epoch 31/50
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9038 - loss: 0.2296 - val_accuracy: 0.8303 - val_loss: 0.4251
# Epoch 32/50
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8925 - loss: 0.2475 - val_accuracy: 0.8364 - val_loss: 0.4177
# Epoch 33/50
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8946 - loss: 0.2430 - val_accuracy: 0.8394 - val_loss: 0.4124
# Epoch 34/50
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9035 - loss: 0.2210 - val_accuracy: 0.8364 - val_loss: 0.4137
# Epoch 35/50
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8992 - loss: 0.2304 - val_accuracy: 0.8394 - val_loss: 0.4364
# Epoch 36/50
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9167 - loss: 0.2124 - val_accuracy: 0.8425 - val_loss: 0.4399
# Epoch 37/50
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9115 - loss: 0.2070 - val_accuracy: 0.8532 - val_loss: 0.4175
# Epoch 38/50
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9008 - loss: 0.2174 - val_accuracy: 0.8517 - val_loss: 0.4279
# Epoch 39/50
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9267 - loss: 0.1904 - val_accuracy: 0.8364 - val_loss: 0.4611
# Epoch 40/50
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9095 - loss: 0.1909 - val_accuracy: 0.8394 - val_loss: 0.4565
# Epoch 41/50
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9154 - loss: 0.1907 - val_accuracy: 0.8379 - val_loss: 0.4641
# Epoch 42/50
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8977 - loss: 0.2159 - val_accuracy: 0.8379 - val_loss: 0.4528
# Epoch 43/50
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9042 - loss: 0.2016 - val_accuracy: 0.8486 - val_loss: 0.4778
# Epoch 44/50
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9010 - loss: 0.2167 - val_accuracy: 0.8425 - val_loss: 0.4536
# Epoch 45/50
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9167 - loss: 0.1887 - val_accuracy: 0.8287 - val_loss: 0.4520
# Epoch 46/50
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9134 - loss: 0.1901 - val_accuracy: 0.8410 - val_loss: 0.4470
# Epoch 47/50
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9165 - loss: 0.1804 - val_accuracy: 0.8440 - val_loss: 0.4599
# Epoch 48/50
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9244 - loss: 0.1796 - val_accuracy: 0.8425 - val_loss: 0.4623
# Epoch 49/50
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9140 - loss: 0.1875 - val_accuracy: 0.8410 - val_loss: 0.4738
# Epoch 50/50
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9221 - loss: 0.1747 - val_accuracy: 0.8517 - val_loss: 0.4688
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# Proportion 2.5:1 - Accuracy: 0.62, Precision: 0.11, Recall: 0.51, F1-Score: 0.18
# Epoch 1/50
# c:\Users\manav\OneDrive\Desktop\NIT Surathkal\Semester 7\IT-449\Drug-Drug-Interaction-and-Alternate-Recommendation-System\.venv\lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.6910 - loss: 0.6981 - val_accuracy: 0.7861 - val_loss: 0.5123
# Epoch 2/50
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7389 - loss: 0.5699 - val_accuracy: 0.8128 - val_loss: 0.5041
# Epoch 3/50
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7544 - loss: 0.5303 - val_accuracy: 0.8035 - val_loss: 0.4751
# Epoch 4/50
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7894 - loss: 0.4961 - val_accuracy: 0.8142 - val_loss: 0.4567
# Epoch 5/50
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7935 - loss: 0.4701 - val_accuracy: 0.8155 - val_loss: 0.4422
# Epoch 6/50
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8029 - loss: 0.4511 - val_accuracy: 0.8302 - val_loss: 0.4272
# Epoch 7/50
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8111 - loss: 0.4493 - val_accuracy: 0.8262 - val_loss: 0.4094
# Epoch 8/50
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8147 - loss: 0.4192 - val_accuracy: 0.8222 - val_loss: 0.4007
# Epoch 9/50
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8259 - loss: 0.3919 - val_accuracy: 0.8342 - val_loss: 0.4005
# Epoch 10/50
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8312 - loss: 0.3878 - val_accuracy: 0.8422 - val_loss: 0.3814
# Epoch 11/50
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8372 - loss: 0.3694 - val_accuracy: 0.8316 - val_loss: 0.3854
# Epoch 12/50
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8411 - loss: 0.3596 - val_accuracy: 0.8476 - val_loss: 0.3790
# Epoch 13/50
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8492 - loss: 0.3489 - val_accuracy: 0.8409 - val_loss: 0.3781
# Epoch 14/50
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8596 - loss: 0.3425 - val_accuracy: 0.8382 - val_loss: 0.3724
# Epoch 15/50
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8486 - loss: 0.3347 - val_accuracy: 0.8489 - val_loss: 0.3836
# Epoch 16/50
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8687 - loss: 0.3018 - val_accuracy: 0.8422 - val_loss: 0.3741
# Epoch 17/50
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8570 - loss: 0.3132 - val_accuracy: 0.8543 - val_loss: 0.3696
# Epoch 18/50
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8719 - loss: 0.2877 - val_accuracy: 0.8556 - val_loss: 0.3720
# Epoch 19/50
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8718 - loss: 0.3014 - val_accuracy: 0.8556 - val_loss: 0.3815
# Epoch 20/50
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8656 - loss: 0.2818 - val_accuracy: 0.8516 - val_loss: 0.3708
# Epoch 21/50
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8749 - loss: 0.2860 - val_accuracy: 0.8570 - val_loss: 0.3820
# Epoch 22/50
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8899 - loss: 0.2620 - val_accuracy: 0.8570 - val_loss: 0.3820
# Epoch 23/50
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8848 - loss: 0.2636 - val_accuracy: 0.8409 - val_loss: 0.3905
# Epoch 24/50
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8870 - loss: 0.2551 - val_accuracy: 0.8543 - val_loss: 0.3770
# Epoch 25/50
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8861 - loss: 0.2620 - val_accuracy: 0.8529 - val_loss: 0.3974
# Epoch 26/50
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8883 - loss: 0.2483 - val_accuracy: 0.8610 - val_loss: 0.3910
# Epoch 27/50
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8965 - loss: 0.2437 - val_accuracy: 0.8623 - val_loss: 0.3743
# Epoch 28/50
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9166 - loss: 0.2238 - val_accuracy: 0.8610 - val_loss: 0.4085
# Epoch 29/50
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8916 - loss: 0.2479 - val_accuracy: 0.8422 - val_loss: 0.3926
# Epoch 30/50
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9062 - loss: 0.2215 - val_accuracy: 0.8570 - val_loss: 0.4075
# Epoch 31/50
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9084 - loss: 0.2213 - val_accuracy: 0.8489 - val_loss: 0.4035
# Epoch 32/50
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9246 - loss: 0.1974 - val_accuracy: 0.8623 - val_loss: 0.4238
# Epoch 33/50
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8974 - loss: 0.2260 - val_accuracy: 0.8650 - val_loss: 0.4140
# Epoch 34/50
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9089 - loss: 0.2142 - val_accuracy: 0.8610 - val_loss: 0.4102
# Epoch 35/50
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9165 - loss: 0.1957 - val_accuracy: 0.8503 - val_loss: 0.4283
# Epoch 36/50
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9188 - loss: 0.1966 - val_accuracy: 0.8610 - val_loss: 0.3912
# Epoch 37/50
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9206 - loss: 0.1844 - val_accuracy: 0.8583 - val_loss: 0.4533
# Epoch 38/50
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9180 - loss: 0.1972 - val_accuracy: 0.8529 - val_loss: 0.4501
# Epoch 39/50
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9195 - loss: 0.1877 - val_accuracy: 0.8650 - val_loss: 0.3988
# Epoch 40/50
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9297 - loss: 0.1841 - val_accuracy: 0.8690 - val_loss: 0.4100
# Epoch 41/50
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9298 - loss: 0.1733 - val_accuracy: 0.8663 - val_loss: 0.4237
# Epoch 42/50
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9240 - loss: 0.1963 - val_accuracy: 0.8676 - val_loss: 0.4787
# Epoch 43/50
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9222 - loss: 0.1834 - val_accuracy: 0.8529 - val_loss: 0.4380
# Epoch 44/50
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9275 - loss: 0.1732 - val_accuracy: 0.8543 - val_loss: 0.4679
# Epoch 45/50
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9307 - loss: 0.1715 - val_accuracy: 0.8556 - val_loss: 0.4542
# Epoch 46/50
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9096 - loss: 0.1867 - val_accuracy: 0.8690 - val_loss: 0.4390
# Epoch 47/50
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9191 - loss: 0.1819 - val_accuracy: 0.8556 - val_loss: 0.4579
# Epoch 48/50
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9358 - loss: 0.1601 - val_accuracy: 0.8583 - val_loss: 0.4596
# Epoch 49/50
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9212 - loss: 0.1811 - val_accuracy: 0.8596 - val_loss: 0.4616
# Epoch 50/50
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9385 - loss: 0.1601 - val_accuracy: 0.8623 - val_loss: 0.4898
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Proportion 3:1 - Accuracy: 0.65, Precision: 0.12, Recall: 0.52, F1-Score: 0.19
# Metrics for different proportions:
# {'proportion': 1.5, 'accuracy': 0.5177948360083741, 'precision': 0.10990502035278155, 'recall': 0.6982758620689655, 'f1_score': 0.1899179366940211}
# {'proportion': 2, 'accuracy': 0.5526866713189114, 'precision': 0.0967741935483871, 'recall': 0.5431034482758621, 'f1_score': 0.16427640156453716}
# {'proportion': 2.5, 'accuracy': 0.6245638520586183, 'precision': 0.10925925925925926, 'recall': 0.5086206896551724, 'f1_score': 0.1798780487804878}
# {'proportion': 3, 'accuracy': 0.6482903000697837, 'precision': 0.11811023622047244, 'recall': 0.5172413793103449, 'f1_score': 0.19230769230769232}

# %%
drug_pairs_df
# drop the interacting column and combined vector column
drug_pairs_df = drug_pairs_df.drop(columns=['Interacting', 'Combined_Vector'])
drug_pairs_df_test = drug_pairs_df_test.drop(columns=['Interacting', 'Combined_Vector'])

# %%
# now put each element in the vector in a seperate column
drug_pairs_df = pd.concat([drug_pairs_df, pd.DataFrame(drug_pairs_df['Drug1_Vector'].tolist(), index=drug_pairs_df.index)], axis=1)
drug_pairs_df = pd.concat([drug_pairs_df, pd.DataFrame(drug_pairs_df['Drug2_Vector'].tolist(), index=drug_pairs_df.index)], axis=1)

drug_pairs_df_test = pd.concat([drug_pairs_df_test, pd.DataFrame(drug_pairs_df_test['Drug1_Vector'].tolist(), index=drug_pairs_df_test.index)], axis=1)
drug_pairs_df_test = pd.concat([drug_pairs_df_test, pd.DataFrame(drug_pairs_df_test['Drug2_Vector'].tolist(), index=drug_pairs_df_test.index)], axis=1)

drug_pairs_df

# drop the drug1_vector and drug2_vector columns
drug_pairs_df = drug_pairs_df.drop(columns=['Drug1_Vector', 'Drug2_Vector'])
drug_pairs_df_test = drug_pairs_df_test.drop(columns=['Drug1_Vector', 'Drug2_Vector'])

drug_pairs_df
# Out:
#               Drug1               Drug2  Interaction_Label         0  \
# 56     azathioprine         chloroquine                  0 -1.758114
# 57     azathioprine                gold                  0 -1.758114
# 58     azathioprine  hydroxychloroquine                  0 -1.758114
# 59     azathioprine         leflunomide                  0 -1.758114
# 60     azathioprine       sulfasalazine                  0 -1.758114
# ...             ...                 ...                ...       ...
# 27781    atracurium          gentamycin                  0 -0.596157
# 27782    atracurium          gentamycin                  1 -0.596157
# 27783    gentamycin          atracurium                  1 -3.880826
# 27784     temazepam             ethanol                  1 -1.570436
# 27789     temazepam             ethanol                  1 -1.570436
#
#               1         2         3         4         5         6  ...  \
# 56     1.765694 -0.809791 -0.463783 -0.266910 -2.708471 -2.522802  ...
# 57     1.765694 -0.809791 -0.463783 -0.266910 -2.708471 -2.522802  ...
# 58     1.765694 -0.809791 -0.463783 -0.266910 -2.708471 -2.522802  ...
# 59     1.765694 -0.809791 -0.463783 -0.266910 -2.708471 -2.522802  ...
# 60     1.765694 -0.809791 -0.463783 -0.266910 -2.708471 -2.522802  ...
# ...         ...       ...       ...       ...       ...       ...  ...
# 27781  0.768044  0.100068  0.445121 -0.348493 -0.423195 -0.691468  ...
# 27782  0.768044  0.100068  0.445121 -0.348493 -0.423195 -0.691468  ...
# 27783  3.044013 -0.279876  1.860366  0.554343 -1.678261  1.669158  ...
# 27784 -0.409908  1.008917 -1.119097  0.743915 -1.381125  0.803105  ...
# 27789 -0.409908  1.008917 -1.119097  0.743915 -1.381125  0.803105  ...
#
#              90        91        92        93        94        95        96  \
# 56     0.609182 -1.103451 -0.674822  0.447816 -1.713301  4.287992 -1.402226
# 57    -0.729576  0.364601  2.710251 -0.833248  1.185086  1.631089 -0.814780
# 58    -0.275613 -0.838406  0.843947  0.213685  0.384436  1.972222 -0.349594
# 59     0.662011 -0.680997 -0.601133  0.480509 -0.333032  0.075027  0.277612
# 60     0.010073 -0.144867  0.196258  0.794556  1.154247  1.096374 -2.615438
# ...         ...       ...       ...       ...       ...       ...       ...
# 27781  0.512056 -0.594453  1.091237 -0.764489 -0.556747  0.720983  0.530436
# 27782  0.512056 -0.594453  1.091237 -0.764489 -0.556747  0.720983  0.530436
# 27783  1.003237 -0.423746  0.609023  0.229881 -0.473903  1.382695 -2.111334
# 27784  2.523526  0.718531  1.174054 -0.620758 -1.036825  1.218856 -3.293271
# 27789  2.523526  0.718531  1.174054 -0.620758 -1.036825  1.218856 -3.293271
#
#              97        98        99
# 56     0.362941 -0.572616 -0.255392
# 57     1.661161  1.535915 -0.144224
# 58     0.379735 -0.623572  0.896211
# 59     0.365707  0.632011  0.561221
# 60     0.366685 -1.264366  0.142015
# ...         ...       ...       ...
# 27781  0.658089 -0.250704  0.805319
# 27782  0.658089 -0.250704  0.805319
# 27783 -1.018444 -0.552565  0.552426
# 27784 -2.935991  0.644816  1.567771
# 27789 -2.935991  0.644816  1.567771
#
# [8774 rows x 203 columns]

# %%
# Drop rows where both Drug1 and Drug2 are the same
drug_pairs_df = drug_pairs_df[drug_pairs_df['Drug1'] != drug_pairs_df['Drug2']]
drug_pairs_df_test = drug_pairs_df_test[drug_pairs_df_test['Drug1'] != drug_pairs_df_test['Drug2']]

# Select feature columns for both Drug1 and Drug2 vectors
# Assuming Drug1 vector columns start at index 4 and Drug2 at index 54 in your DataFrame
X_train_full = drug_pairs_df.iloc[:, 3:].values  # All vector columns
y_train_full = drug_pairs_df['Interaction_Label'].values

X_test = drug_pairs_df_test.iloc[:, 3:].values
y_test = drug_pairs_df_test['Interaction_Label'].values

# Handle imbalanced data
proportions = [1, 2, 3, 4, 5]  # Example proportions
recalls = []

for proportion in proportions:
    # Separate majority and minority samples in the training set
    X_minority = X_train_full[y_train_full == 1]
    y_minority = y_train_full[y_train_full == 1]
    
    X_majority = X_train_full[y_train_full == 0]
    y_majority = y_train_full[y_train_full == 0]
    
    # Sample majority class to balance the dataset
    n_minority = len(X_minority)
    n_majority = n_minority * proportion
    X_majority_sampled = X_majority[:n_majority]
    y_majority_sampled = y_majority[:n_majority]
    
    # Combine the sampled majority and minority data
    X_train_balanced = np.vstack((X_minority, X_majority_sampled))
    y_train_balanced = np.concatenate((y_minority, y_majority_sampled))
    
    # Shuffle the data to ensure random distribution
    X_train_balanced, y_train_balanced = shuffle(X_train_balanced, y_train_balanced, random_state=42)
    
    # Train an XGBoost model on the balanced subset
    model = xgb.XGBClassifier(use_label_encoder=False, eval_metric='logloss')
    model.fit(X_train_balanced, y_train_balanced)
    
    # Predict on the test set
    y_pred = model.predict(X_test)
    
    # Evaluate the model using recall for both classes
    recall_class_1 = recall_score(y_test, y_pred, pos_label=1)
    recall_class_0 = recall_score(y_test, y_pred, pos_label=0)
    recalls.append((proportion, recall_class_1, recall_class_0))
    
    print(f"XGBoost - Proportion {proportion}:1 - Recall Class 1: {recall_class_1:.2f}, Recall Class 0: {recall_class_0:.2f}")
    print(f"Accuracy: {accuracy_score(y_test, y_pred):.2f}")
    print(classification_report(y_test, y_pred))

# Plot Recall vs Training Data Proportion for XGBoost
plt.figure(figsize=(10, 6))
proportions, recall_scores_class_1, recall_scores_class_0 = zip(*recalls)
plt.plot(proportions, recall_scores_class_1, marker='o', label='XGBoost Class 1')
plt.plot(proportions, recall_scores_class_0, marker='o', label='XGBoost Class 0')

plt.xlabel("Training Data Proportion (Majority:Minority)")
plt.ylabel("Recall on Test Set")
plt.title("Recall vs. Training Data Proportion for XGBoost")
plt.legend()
plt.grid(True)
plt.show()
# Out:
# c:\Users\manav\OneDrive\Desktop\NIT Surathkal\Semester 7\IT-449\Drug-Drug-Interaction-and-Alternate-Recommendation-System\.venv\lib\site-packages\xgboost\core.py:158: UserWarning: [13:57:59] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0ed59c031377d09b8-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# XGBoost - Proportion 1:1 - Recall Class 1: 0.81, Recall Class 0: 0.29
# Accuracy: 0.33
#               precision    recall  f1-score   support
#
#            0       0.95      0.29      0.44      1317
#            1       0.09      0.81      0.16       116
#
#     accuracy                           0.33      1433
#    macro avg       0.52      0.55      0.30      1433
# weighted avg       0.88      0.33      0.42      1433
# c:\Users\manav\OneDrive\Desktop\NIT Surathkal\Semester 7\IT-449\Drug-Drug-Interaction-and-Alternate-Recommendation-System\.venv\lib\site-packages\xgboost\core.py:158: UserWarning: [13:58:01] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0ed59c031377d09b8-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# XGBoost - Proportion 2:1 - Recall Class 1: 0.53, Recall Class 0: 0.64
# Accuracy: 0.63
#               precision    recall  f1-score   support
#
#            0       0.94      0.64      0.76      1317
#            1       0.11      0.53      0.19       116
#
#     accuracy                           0.63      1433
#    macro avg       0.53      0.58      0.48      1433
# weighted avg       0.87      0.63      0.72      1433
# c:\Users\manav\OneDrive\Desktop\NIT Surathkal\Semester 7\IT-449\Drug-Drug-Interaction-and-Alternate-Recommendation-System\.venv\lib\site-packages\xgboost\core.py:158: UserWarning: [13:58:03] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0ed59c031377d09b8-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# XGBoost - Proportion 3:1 - Recall Class 1: 0.50, Recall Class 0: 0.72
# Accuracy: 0.70
#               precision    recall  f1-score   support
#
#            0       0.94      0.72      0.82      1317
#            1       0.14      0.50      0.22       116
#
#     accuracy                           0.70      1433
#    macro avg       0.54      0.61      0.52      1433
# weighted avg       0.88      0.70      0.77      1433
# c:\Users\manav\OneDrive\Desktop\NIT Surathkal\Semester 7\IT-449\Drug-Drug-Interaction-and-Alternate-Recommendation-System\.venv\lib\site-packages\xgboost\core.py:158: UserWarning: [13:58:05] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0ed59c031377d09b8-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# XGBoost - Proportion 4:1 - Recall Class 1: 0.27, Recall Class 0: 0.90
# Accuracy: 0.85
#               precision    recall  f1-score   support
#
#            0       0.93      0.90      0.92      1317
#            1       0.19      0.27      0.22       116
#
#     accuracy                           0.85      1433
#    macro avg       0.56      0.58      0.57      1433
# weighted avg       0.87      0.85      0.86      1433
# c:\Users\manav\OneDrive\Desktop\NIT Surathkal\Semester 7\IT-449\Drug-Drug-Interaction-and-Alternate-Recommendation-System\.venv\lib\site-packages\xgboost\core.py:158: UserWarning: [13:58:07] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0ed59c031377d09b8-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# XGBoost - Proportion 5:1 - Recall Class 1: 0.18, Recall Class 0: 0.94
# Accuracy: 0.88
#               precision    recall  f1-score   support
#
#            0       0.93      0.94      0.94      1317
#            1       0.22      0.18      0.20       116
#
#     accuracy                           0.88      1433
#    macro avg       0.58      0.56      0.57      1433
# weighted avg       0.87      0.88      0.88      1433

# %%
# Define a function to create the MLP model
def create_mlp_model(input_dim):
    model = Sequential()
    model.add(Dense(200, input_dim=input_dim, activation='relu'))
    model.add(Dense(128, activation='relu'))
    model.add(Dropout(0.3))  # Dropout layer for regularization
    model.add(Dense(64, activation='relu'))
    model.add(Dropout(0.3))

    model.add(Dense(1, activation='sigmoid'))  # Binary classification output layer
    
    model.compile(optimizer=Adam(), loss='binary_crossentropy', metrics=['accuracy'])
    return model

# Assuming Drug1 and Drug2 vectors combined result in 200 features
input_dim = 200  

# List to store recall results for each proportion
recalls = []

# Loop through different proportions for balancing
proportions = [1, 2, 3, 4, 5, 6]  # Example proportions
for proportion in proportions:
    # Separate majority and minority samples in the training set
    X_minority = X_train_full[y_train_full == 1]
    y_minority = y_train_full[y_train_full == 1]
    
    X_majority = X_train_full[y_train_full == 0]
    y_majority = y_train_full[y_train_full == 0]
    
    # Sample majority class to balance the dataset
    n_minority = len(X_minority)
    n_majority = n_minority * proportion
    X_majority_sampled = X_majority[:n_majority]
    y_majority_sampled = y_majority[:n_majority]
    
    # Combine the sampled majority and minority data
    X_train_balanced = np.vstack((X_minority, X_majority_sampled))
    y_train_balanced = np.concatenate((y_minority, y_majority_sampled))
    
    # Shuffle the data
    X_train_balanced, y_train_balanced = shuffle(X_train_balanced, y_train_balanced, random_state=42)
    
    # Create and train the MLP model
    model = create_mlp_model(input_dim)
    model.fit(X_train_balanced, y_train_balanced, epochs=20, batch_size=32, verbose=0)
    
    # Predict on the test set
    y_pred = (model.predict(X_test) > 0.5).astype("int32")
    
    # Evaluate recall for both classes
    recall_class_1 = recall_score(y_test, y_pred, pos_label=1)
    recall_class_0 = recall_score(y_test, y_pred, pos_label=0)
    recalls.append((proportion, recall_class_1, recall_class_0))
    
    print(f"MLP - Proportion {proportion}:1 - Recall Class 1: {recall_class_1:.2f}, Recall Class 0: {recall_class_0:.2f}")
    print(f"Accuracy: {accuracy_score(y_test, y_pred):.2f}")
    print(classification_report(y_test, y_pred))

# Plot Recall vs Training Data Proportion for MLP
plt.figure(figsize=(10, 6))
proportions, recall_scores_class_1, recall_scores_class_0 = zip(*recalls)
plt.plot(proportions, recall_scores_class_1, marker='o', label='MLP Class 1')
plt.plot(proportions, recall_scores_class_0, marker='o', label='MLP Class 0')

plt.xlabel("Training Data Proportion (Majority:Minority)")
plt.ylabel("Recall on Test Set")
plt.title("Recall vs. Training Data Proportion for MLP")
plt.legend()
plt.grid(True)
plt.show()
# Out:
# c:\Users\manav\OneDrive\Desktop\NIT Surathkal\Semester 7\IT-449\Drug-Drug-Interaction-and-Alternate-Recommendation-System\.venv\lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# MLP - Proportion 1:1 - Recall Class 1: 0.78, Recall Class 0: 0.35
# Accuracy: 0.38
#               precision    recall  f1-score   support
#
#            0       0.95      0.35      0.51      1317
#            1       0.10      0.78      0.17       116
#
#     accuracy                           0.38      1433
#    macro avg       0.52      0.57      0.34      1433
# weighted avg       0.88      0.38      0.48      1433
# c:\Users\manav\OneDrive\Desktop\NIT Surathkal\Semester 7\IT-449\Drug-Drug-Interaction-and-Alternate-Recommendation-System\.venv\lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# MLP - Proportion 2:1 - Recall Class 1: 0.47, Recall Class 0: 0.65
# Accuracy: 0.64
#               precision    recall  f1-score   support
#
#            0       0.93      0.65      0.77      1317
#            1       0.11      0.47      0.17       116
#
#     accuracy                           0.64      1433
#    macro avg       0.52      0.56      0.47      1433
# weighted avg       0.87      0.64      0.72      1433
# c:\Users\manav\OneDrive\Desktop\NIT Surathkal\Semester 7\IT-449\Drug-Drug-Interaction-and-Alternate-Recommendation-System\.venv\lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# MLP - Proportion 3:1 - Recall Class 1: 0.56, Recall Class 0: 0.64
# Accuracy: 0.63
#               precision    recall  f1-score   support
#
#            0       0.94      0.64      0.76      1317
#            1       0.12      0.56      0.20       116
#
#     accuracy                           0.63      1433
#    macro avg       0.53      0.60      0.48      1433
# weighted avg       0.88      0.63      0.71      1433
# c:\Users\manav\OneDrive\Desktop\NIT Surathkal\Semester 7\IT-449\Drug-Drug-Interaction-and-Alternate-Recommendation-System\.venv\lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# MLP - Proportion 4:1 - Recall Class 1: 0.47, Recall Class 0: 0.81
# Accuracy: 0.78
#               precision    recall  f1-score   support
#
#            0       0.95      0.81      0.87      1317
#            1       0.18      0.47      0.26       116
#
#     accuracy                           0.78      1433
#    macro avg       0.56      0.64      0.56      1433
# weighted avg       0.88      0.78      0.82      1433
# c:\Users\manav\OneDrive\Desktop\NIT Surathkal\Semester 7\IT-449\Drug-Drug-Interaction-and-Alternate-Recommendation-System\.venv\lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# MLP - Proportion 5:1 - Recall Class 1: 0.34, Recall Class 0: 0.88
# Accuracy: 0.83
#               precision    recall  f1-score   support
#
#            0       0.94      0.88      0.91      1317
#            1       0.20      0.34      0.25       116
#
#     accuracy                           0.83      1433
#    macro avg       0.57      0.61      0.58      1433
# weighted avg       0.88      0.83      0.85      1433
# c:\Users\manav\OneDrive\Desktop\NIT Surathkal\Semester 7\IT-449\Drug-Drug-Interaction-and-Alternate-Recommendation-System\.venv\lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# MLP - Proportion 6:1 - Recall Class 1: 0.27, Recall Class 0: 0.91
# Accuracy: 0.86
#               precision    recall  f1-score   support
#
#            0       0.93      0.91      0.92      1317
#            1       0.21      0.27      0.23       116
#
#     accuracy                           0.86      1433
#    macro avg       0.57      0.59      0.58      1433
# weighted avg       0.87      0.86      0.87      1433

# %%
# Define a function to create the MLP model
def create_mlp_model(input_dim):
    model = Sequential()
    model.add(Dense(200, input_dim=input_dim, activation='relu'))
    model.add(Dense(128, activation='relu'))
    model.add(Dropout(0.3))  # Dropout layer for regularization
    model.add(Dense(64, activation='relu'))
    model.add(Dropout(0.3))

    model.add(Dense(1, activation='sigmoid'))  # Binary classification output layer
    
    model.compile(optimizer=Adam(), loss='binary_crossentropy', metrics=['accuracy'])
    return model

# Assuming Drug1 and Drug2 vectors combined result in 200 features
input_dim = 200  

# List to store recall results for each proportion
recalls = []

# Loop through different proportions for balancing
proportions = [1, 2, 3, 4, 5, 6]  # Example proportions
for proportion in proportions:
    # Separate majority and minority samples in the training set
    X_minority = X_train_full[y_train_full == 1]
    y_minority = y_train_full[y_train_full == 1]
    
    X_majority = X_train_full[y_train_full == 0]
    y_majority = y_train_full[y_train_full == 0]
    
    # Sample majority class to balance the dataset
    n_minority = len(X_minority)
    n_majority = n_minority * proportion
    X_majority_sampled = X_majority[:n_majority]
    y_majority_sampled = y_majority[:n_majority]
    
    # Combine the sampled majority and minority data
    X_train_balanced = np.vstack((X_minority, X_majority_sampled))
    y_train_balanced = np.concatenate((y_minority, y_majority_sampled))
    
    # Shuffle the data
    X_train_balanced, y_train_balanced = shuffle(X_train_balanced, y_train_balanced, random_state=42)
    
    # Create and train the MLP model
    model = create_mlp_model(input_dim)
    model.fit(X_train_balanced, y_train_balanced, epochs=30, batch_size=32, verbose=0)
    

    # Predict on the test set
    y_pred = (model.predict(X_test) > 0.5).astype("int32")
    
    # Evaluate recall for both classes
    recall_class_1 = recall_score(y_test, y_pred, pos_label=1)
    recall_class_0 = recall_score(y_test, y_pred, pos_label=0)
    recalls.append((proportion, recall_class_1, recall_class_0))
    
    print(f"MLP - Proportion {proportion}:1 - Recall Class 1: {recall_class_1:.2f}, Recall Class 0: {recall_class_0:.2f}")
    print(f"Accuracy: {accuracy_score(y_test, y_pred):.2f}")
    print(classification_report(y_test, y_pred))

# Plot Recall vs Training Data Proportion for MLP
plt.figure(figsize=(10, 6))
proportions, recall_scores_class_1, recall_scores_class_0 = zip(*recalls)
plt.plot(proportions, recall_scores_class_1, marker='o', label='MLP Class 1')
plt.plot(proportions, recall_scores_class_0, marker='o', label='MLP Class 0')

plt.xlabel("Training Data Proportion (Majority:Minority)")
plt.ylabel("Recall on Test Set")
plt.title("Recall vs. Training Data Proportion for MLP")
plt.legend()
plt.grid(True)
plt.show()
# Out:
# c:\Users\manav\OneDrive\Desktop\NIT Surathkal\Semester 7\IT-449\Drug-Drug-Interaction-and-Alternate-Recommendation-System\.venv\lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# MLP - Proportion 1:1 - Recall Class 1: 0.78, Recall Class 0: 0.36
# Accuracy: 0.39
#               precision    recall  f1-score   support
#
#            0       0.95      0.36      0.52      1317
#            1       0.10      0.78      0.17       116
#
#     accuracy                           0.39      1433
#    macro avg       0.52      0.57      0.34      1433
# weighted avg       0.88      0.39      0.49      1433
# c:\Users\manav\OneDrive\Desktop\NIT Surathkal\Semester 7\IT-449\Drug-Drug-Interaction-and-Alternate-Recommendation-System\.venv\lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# MLP - Proportion 2:1 - Recall Class 1: 0.47, Recall Class 0: 0.59
# Accuracy: 0.58
#               precision    recall  f1-score   support
#
#            0       0.93      0.59      0.72      1317
#            1       0.09      0.47      0.16       116
#
#     accuracy                           0.58      1433
#    macro avg       0.51      0.53      0.44      1433
# weighted avg       0.86      0.58      0.68      1433
# c:\Users\manav\OneDrive\Desktop\NIT Surathkal\Semester 7\IT-449\Drug-Drug-Interaction-and-Alternate-Recommendation-System\.venv\lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# MLP - Proportion 3:1 - Recall Class 1: 0.54, Recall Class 0: 0.64
# Accuracy: 0.64
#               precision    recall  f1-score   support
#
#            0       0.94      0.64      0.76      1317
#            1       0.12      0.54      0.19       116
#
#     accuracy                           0.64      1433
#    macro avg       0.53      0.59      0.48      1433
# weighted avg       0.87      0.64      0.72      1433
# c:\Users\manav\OneDrive\Desktop\NIT Surathkal\Semester 7\IT-449\Drug-Drug-Interaction-and-Alternate-Recommendation-System\.venv\lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# MLP - Proportion 4:1 - Recall Class 1: 0.34, Recall Class 0: 0.78
# Accuracy: 0.75
#               precision    recall  f1-score   support
#
#            0       0.93      0.78      0.85      1317
#            1       0.12      0.34      0.18       116
#
#     accuracy                           0.75      1433
#    macro avg       0.53      0.56      0.52      1433
# weighted avg       0.87      0.75      0.80      1433
# c:\Users\manav\OneDrive\Desktop\NIT Surathkal\Semester 7\IT-449\Drug-Drug-Interaction-and-Alternate-Recommendation-System\.venv\lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# MLP - Proportion 5:1 - Recall Class 1: 0.27, Recall Class 0: 0.90
# Accuracy: 0.84
#               precision    recall  f1-score   support
#
#            0       0.93      0.90      0.91      1317
#            1       0.18      0.27      0.22       116
#
#     accuracy                           0.84      1433
#    macro avg       0.56      0.58      0.57      1433
# weighted avg       0.87      0.84      0.86      1433
# c:\Users\manav\OneDrive\Desktop\NIT Surathkal\Semester 7\IT-449\Drug-Drug-Interaction-and-Alternate-Recommendation-System\.venv\lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# MLP - Proportion 6:1 - Recall Class 1: 0.21, Recall Class 0: 0.91
# Accuracy: 0.86
#               precision    recall  f1-score   support
#
#            0       0.93      0.91      0.92      1317
#            1       0.17      0.21      0.19       116
#
#     accuracy                           0.86      1433
#    macro avg       0.55      0.56      0.56      1433
# weighted avg       0.87      0.86      0.86      1433

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout
from tensorflow.keras.optimizers import Adam


# Define a function to create the MLP model
def create_mlp_model(input_dim):
    model = Sequential()
    model.add(Dense(200, input_dim=input_dim, activation='relu'))
    # model.add(Dense(128, activation='relu'))
    # model.add(Dropout(0.3))  # Dropout layer for regularization
    model.add(Dense(64, activation='relu'))
    model.add(Dropout(0.3))
    model.add(Dense(64, activation='relu'))
    model.add(Dropout(0.3))
    model.add(Dense(64, activation='relu'))
    model.add(Dropout(0.3))
    model.add(Dense(64, activation='relu'))
    model.add(Dropout(0.3))
    model.add(Dense(64, activation='relu'))
    model.add(Dropout(0.3))
    model.add(Dense(64, activation='relu'))
    model.add(Dropout(0.3))
    model.add(Dense(64, activation='relu'))
    model.add(Dropout(0.3))
    model.add(Dense(1, activation='sigmoid'))  # Binary classification output layer
    
    model.compile(optimizer=Adam(), loss='binary_crossentropy', metrics=['accuracy'])
    return model

# Assuming Drug1 and Drug2 vectors combined result in 200 features
input_dim = 200  

# List to store recall results for each proportion
recalls = []

# Loop through different proportions for balancing
proportions = [1, 2, 3, 4, 5, 6]  # Example proportions
for proportion in proportions:
    # Separate majority and minority samples in the training set
    X_minority = X_train_full[y_train_full == 1]
    y_minority = y_train_full[y_train_full == 1]
    
    X_majority = X_train_full[y_train_full == 0]
    y_majority = y_train_full[y_train_full == 0]
    
    # Sample majority class to balance the dataset
    n_minority = len(X_minority)
    n_majority = n_minority * proportion
    X_majority_sampled = X_majority[:n_majority]
    y_majority_sampled = y_majority[:n_majority]
    
    # Combine the sampled majority and minority data
    X_train_balanced = np.vstack((X_minority, X_majority_sampled))
    y_train_balanced = np.concatenate((y_minority, y_majority_sampled))
    
    # Shuffle the data
    X_train_balanced, y_train_balanced = shuffle(X_train_balanced, y_train_balanced, random_state=42)
    
    # Create and train the MLP model
    model = create_mlp_model(input_dim)
    model.fit(X_train_balanced, y_train_balanced, epochs=30, batch_size=32, verbose=0)
    
    # Predict on the test set
    y_pred = (model.predict(X_test) > 0.5).astype("int32")
    
    # Evaluate recall for both classes
    recall_class_1 = recall_score(y_test, y_pred, pos_label=1)
    recall_class_0 = recall_score(y_test, y_pred, pos_label=0)
    recalls.append((proportion, recall_class_1, recall_class_0))
    
    print(f"MLP - Proportion {proportion}:1 - Recall Class 1: {recall_class_1:.2f}, Recall Class 0: {recall_class_0:.2f}")
    print(f"Accuracy: {accuracy_score(y_test, y_pred):.2f}")
    print(classification_report(y_test, y_pred))

# Plot Recall vs Training Data Proportion for MLP
plt.figure(figsize=(10, 6))
proportions, recall_scores_class_1, recall_scores_class_0 = zip(*recalls)
plt.plot(proportions, recall_scores_class_1, marker='o', label='MLP Class 1')
plt.plot(proportions, recall_scores_class_0, marker='o', label='MLP Class 0')

plt.xlabel("Training Data Proportion (Majority:Minority)")
plt.ylabel("Recall on Test Set")
plt.title("Recall vs. Training Data Proportion for MLP")
plt.legend()
plt.grid(True)
plt.show()
# Out:
# c:\Users\manav\OneDrive\Desktop\NIT Surathkal\Semester 7\IT-449\Drug-Drug-Interaction-and-Alternate-Recommendation-System\.venv\lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step
# MLP - Proportion 1:1 - Recall Class 1: 0.85, Recall Class 0: 0.32
# Accuracy: 0.37
#               precision    recall  f1-score   support
#
#            0       0.96      0.32      0.48      1317
#            1       0.10      0.85      0.18       116
#
#     accuracy                           0.37      1433
#    macro avg       0.53      0.59      0.33      1433
# weighted avg       0.89      0.37      0.46      1433
# c:\Users\manav\OneDrive\Desktop\NIT Surathkal\Semester 7\IT-449\Drug-Drug-Interaction-and-Alternate-Recommendation-System\.venv\lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step
# MLP - Proportion 2:1 - Recall Class 1: 0.58, Recall Class 0: 0.59
# Accuracy: 0.59
#               precision    recall  f1-score   support
#
#            0       0.94      0.59      0.73      1317
#            1       0.11      0.58      0.19       116
#
#     accuracy                           0.59      1433
#    macro avg       0.53      0.59      0.46      1433
# weighted avg       0.87      0.59      0.68      1433
# c:\Users\manav\OneDrive\Desktop\NIT Surathkal\Semester 7\IT-449\Drug-Drug-Interaction-and-Alternate-Recommendation-System\.venv\lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step
# MLP - Proportion 3:1 - Recall Class 1: 0.58, Recall Class 0: 0.61
# Accuracy: 0.61
#               precision    recall  f1-score   support
#
#            0       0.94      0.61      0.74      1317
#            1       0.12      0.58      0.19       116
#
#     accuracy                           0.61      1433
#    macro avg       0.53      0.60      0.47      1433
# weighted avg       0.88      0.61      0.70      1433
# c:\Users\manav\OneDrive\Desktop\NIT Surathkal\Semester 7\IT-449\Drug-Drug-Interaction-and-Alternate-Recommendation-System\.venv\lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step
# MLP - Proportion 4:1 - Recall Class 1: 0.33, Recall Class 0: 0.84
# Accuracy: 0.80
#               precision    recall  f1-score   support
#
#            0       0.93      0.84      0.89      1317
#            1       0.16      0.33      0.21       116
#
#     accuracy                           0.80      1433
#    macro avg       0.55      0.59      0.55      1433
# weighted avg       0.87      0.80      0.83      1433
# c:\Users\manav\OneDrive\Desktop\NIT Surathkal\Semester 7\IT-449\Drug-Drug-Interaction-and-Alternate-Recommendation-System\.venv\lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# MLP - Proportion 5:1 - Recall Class 1: 0.39, Recall Class 0: 0.80
# Accuracy: 0.77
#               precision    recall  f1-score   support
#
#            0       0.94      0.80      0.86      1317
#            1       0.15      0.39      0.21       116
#
#     accuracy                           0.77      1433
#    macro avg       0.54      0.59      0.54      1433
# weighted avg       0.87      0.77      0.81      1433
# c:\Users\manav\OneDrive\Desktop\NIT Surathkal\Semester 7\IT-449\Drug-Drug-Interaction-and-Alternate-Recommendation-System\.venv\lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# MLP - Proportion 6:1 - Recall Class 1: 0.30, Recall Class 0: 0.89
# Accuracy: 0.84
#               precision    recall  f1-score   support
#
#            0       0.94      0.89      0.91      1317
#            1       0.20      0.30      0.24       116
#
#     accuracy                           0.84      1433
#    macro avg       0.57      0.60      0.58      1433
# weighted avg       0.88      0.84      0.86      1433

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout
from tensorflow.keras.optimizers import Adam


# Define a function to create the MLP model
def create_mlp_model(input_dim):
    model = Sequential()
    model.add(Dense(200, input_dim=input_dim, activation='relu'))
    # model.add(Dense(128, activation='relu'))
    # model.add(Dropout(0.3))  # Dropout layer for regularization
    model.add(Dense(128, activation='relu'))
    model.add(Dropout(0.3))
    model.add(Dense(128, activation='relu'))
    model.add(Dropout(0.3))
    model.add(Dense(128, activation='relu'))
    model.add(Dropout(0.3))
    model.add(Dense(64, activation='relu'))
    model.add(Dropout(0.3))
    model.add(Dense(64, activation='relu'))
    model.add(Dropout(0.3))
    model.add(Dense(64, activation='relu'))
    model.add(Dropout(0.3))
    model.add(Dense(64, activation='relu'))
    model.add(Dropout(0.3))
    model.add(Dense(1, activation='sigmoid'))  # Binary classification output layer
    
    model.compile(optimizer=Adam(), loss='binary_crossentropy', metrics=['accuracy'])
    return model

# Assuming Drug1 and Drug2 vectors combined result in 200 features
input_dim = 200  

# List to store recall results for each proportion
recalls = []

# Loop through different proportions for balancing
proportions = [1, 2, 3, 4, 5, 6, 7, 8]  # Example proportions
for proportion in proportions:
    # Separate majority and minority samples in the training set
    X_minority = X_train_full[y_train_full == 1]
    y_minority = y_train_full[y_train_full == 1]
    
    X_majority = X_train_full[y_train_full == 0]
    y_majority = y_train_full[y_train_full == 0]
    
    # Sample majority class to balance the dataset
    n_minority = len(X_minority)
    n_majority = n_minority * proportion
    X_majority_sampled = X_majority[:n_majority]
    y_majority_sampled = y_majority[:n_majority]
    
    # Combine the sampled majority and minority data
    X_train_balanced = np.vstack((X_minority, X_majority_sampled))
    y_train_balanced = np.concatenate((y_minority, y_majority_sampled))
    
    # Shuffle the data
    X_train_balanced, y_train_balanced = shuffle(X_train_balanced, y_train_balanced, random_state=42)
    
    # Create and train the MLP model
    model = create_mlp_model(input_dim)
    model.fit(X_train_balanced, y_train_balanced, epochs=20, batch_size=32, verbose=0)
    
    # Predict on the test set
    y_pred = (model.predict(X_test) > 0.5).astype("int32")
    
    # Evaluate recall for both classes
    recall_class_1 = recall_score(y_test, y_pred, pos_label=1)
    recall_class_0 = recall_score(y_test, y_pred, pos_label=0)
    recalls.append((proportion, recall_class_1, recall_class_0))
    
    print(f"MLP - Proportion {proportion}:1 - Recall Class 1: {recall_class_1:.2f}, Recall Class 0: {recall_class_0:.2f}")
    print(f"Accuracy: {accuracy_score(y_test, y_pred):.2f}")
    print(classification_report(y_test, y_pred))

# Plot Recall vs Training Data Proportion for MLP
plt.figure(figsize=(10, 6))
proportions, recall_scores_class_1, recall_scores_class_0 = zip(*recalls)
plt.plot(proportions, recall_scores_class_1, marker='o', label='MLP Class 1')
plt.plot(proportions, recall_scores_class_0, marker='o', label='MLP Class 0')

plt.xlabel("Training Data Proportion (Majority:Minority)")
plt.ylabel("Recall on Test Set")
plt.title("Recall vs. Training Data Proportion for MLP")
plt.legend()
plt.grid(True)
plt.show()
# Out:
# c:\Users\manav\OneDrive\Desktop\NIT Surathkal\Semester 7\IT-449\Drug-Drug-Interaction-and-Alternate-Recommendation-System\.venv\lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# MLP - Proportion 1:1 - Recall Class 1: 0.70, Recall Class 0: 0.37
# Accuracy: 0.39
#               precision    recall  f1-score   support
#
#            0       0.93      0.37      0.53      1317
#            1       0.09      0.70      0.16       116
#
#     accuracy                           0.39      1433
#    macro avg       0.51      0.53      0.34      1433
# weighted avg       0.86      0.39      0.50      1433
# c:\Users\manav\OneDrive\Desktop\NIT Surathkal\Semester 7\IT-449\Drug-Drug-Interaction-and-Alternate-Recommendation-System\.venv\lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# MLP - Proportion 2:1 - Recall Class 1: 0.41, Recall Class 0: 0.67
# Accuracy: 0.65
#               precision    recall  f1-score   support
#
#            0       0.93      0.67      0.78      1317
#            1       0.10      0.41      0.16       116
#
#     accuracy                           0.65      1433
#    macro avg       0.51      0.54      0.47      1433
# weighted avg       0.86      0.65      0.73      1433
# c:\Users\manav\OneDrive\Desktop\NIT Surathkal\Semester 7\IT-449\Drug-Drug-Interaction-and-Alternate-Recommendation-System\.venv\lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# MLP - Proportion 3:1 - Recall Class 1: 0.71, Recall Class 0: 0.60
# Accuracy: 0.61
#               precision    recall  f1-score   support
#
#            0       0.96      0.60      0.74      1317
#            1       0.13      0.71      0.23       116
#
#     accuracy                           0.61      1433
#    macro avg       0.55      0.65      0.48      1433
# weighted avg       0.89      0.61      0.70      1433
# c:\Users\manav\OneDrive\Desktop\NIT Surathkal\Semester 7\IT-449\Drug-Drug-Interaction-and-Alternate-Recommendation-System\.venv\lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# MLP - Proportion 4:1 - Recall Class 1: 0.49, Recall Class 0: 0.77
# Accuracy: 0.75
#               precision    recall  f1-score   support
#
#            0       0.95      0.77      0.85      1317
#            1       0.16      0.49      0.24       116
#
#     accuracy                           0.75      1433
#    macro avg       0.55      0.63      0.55      1433
# weighted avg       0.88      0.75      0.80      1433
# c:\Users\manav\OneDrive\Desktop\NIT Surathkal\Semester 7\IT-449\Drug-Drug-Interaction-and-Alternate-Recommendation-System\.venv\lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# MLP - Proportion 5:1 - Recall Class 1: 0.36, Recall Class 0: 0.84
# Accuracy: 0.80
#               precision    recall  f1-score   support
#
#            0       0.94      0.84      0.88      1317
#            1       0.16      0.36      0.23       116
#
#     accuracy                           0.80      1433
#    macro avg       0.55      0.60      0.56      1433
# weighted avg       0.87      0.80      0.83      1433
# c:\Users\manav\OneDrive\Desktop\NIT Surathkal\Semester 7\IT-449\Drug-Drug-Interaction-and-Alternate-Recommendation-System\.venv\lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# MLP - Proportion 6:1 - Recall Class 1: 0.33, Recall Class 0: 0.82
# Accuracy: 0.78
#               precision    recall  f1-score   support
#
#            0       0.93      0.82      0.87      1317
#            1       0.14      0.33      0.19       116
#
#     accuracy                           0.78      1433
#    macro avg       0.54      0.57      0.53      1433
# weighted avg       0.87      0.78      0.82      1433
# c:\Users\manav\OneDrive\Desktop\NIT Surathkal\Semester 7\IT-449\Drug-Drug-Interaction-and-Alternate-Recommendation-System\.venv\lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# MLP - Proportion 7:1 - Recall Class 1: 0.23, Recall Class 0: 0.92
# Accuracy: 0.86
#               precision    recall  f1-score   support
#
#            0       0.93      0.92      0.92      1317
#            1       0.20      0.23      0.21       116
#
#     accuracy                           0.86      1433
#    macro avg       0.56      0.57      0.57      1433
# weighted avg       0.87      0.86      0.87      1433
# c:\Users\manav\OneDrive\Desktop\NIT Surathkal\Semester 7\IT-449\Drug-Drug-Interaction-and-Alternate-Recommendation-System\.venv\lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# MLP - Proportion 8:1 - Recall Class 1: 0.19, Recall Class 0: 0.93
# Accuracy: 0.87
#               precision    recall  f1-score   support
#
#            0       0.93      0.93      0.93      1317
#            1       0.19      0.19      0.19       116
#
#     accuracy                           0.87      1433
#    macro avg       0.56      0.56      0.56      1433
# weighted avg       0.87      0.87      0.87      1433

# %%
import numpy as np
from sklearn.preprocessing import StandardScaler
from sklearn.utils import shuffle
from sklearn.metrics import recall_score, accuracy_score, classification_report
import matplotlib.pyplot as plt
import tensorflow as tf

def create_mlp_model(input_dim):
    model = Sequential()
    model.add(Dense(200, input_dim=input_dim, activation='relu'))
    model.add(Dense(128, activation='relu'))
    model.add(Dropout(0.3))  # Dropout layer for regularization
    model.add(Dense(64, activation='relu'))
    model.add(Dropout(0.3))

    model.add(Dense(1, activation='sigmoid'))  # Binary classification output layer
    
    model.compile(optimizer=Adam(), loss='binary_crossentropy', metrics=['accuracy'])
    return model
# Assuming the create_mlp_model function is defined and input_dim is 200
# Standardize features
scaler = StandardScaler()
X_train_full_scaled = scaler.fit_transform(X_train_full)
X_test_scaled = scaler.transform(X_test)

# List to store recall results for each proportion
recalls = []

# Loop through different proportions for balancing
proportions = [1, 2, 3, 4, 5]

for proportion in proportions:
    # Separate majority and minority samples in the training set
    X_minority = X_train_full_scaled[y_train_full == 1]
    y_minority = y_train_full[y_train_full == 1]
    
    X_majority = X_train_full_scaled[y_train_full == 0]
    y_majority = y_train_full[y_train_full == 0]
    
    # Sample majority class to balance the dataset
    n_minority = len(X_minority)
    n_majority = n_minority * proportion
    X_majority_sampled = X_majority[:n_majority]
    y_majority_sampled = y_majority[:n_majority]
    
    # Combine the sampled majority and minority data
    X_train_balanced = np.vstack((X_minority, X_majority_sampled))
    y_train_balanced = np.concatenate((y_minority, y_majority_sampled))
    
    # Shuffle the data
    X_train_balanced, y_train_balanced = shuffle(X_train_balanced, y_train_balanced, random_state=42)
    
    # Create and train the MLP model
    model = create_mlp_model(input_dim)
    model.fit(X_train_balanced, y_train_balanced, epochs=20, batch_size=32, verbose=0)
    
    # Predict on the test set
    y_pred = (model.predict(X_test_scaled) > 0.5).astype("int32")
    
    # Evaluate recall for both classes
    recall_class_1 = recall_score(y_test, y_pred, pos_label=1)
    recall_class_0 = recall_score(y_test, y_pred, pos_label=0)
    recalls.append((proportion, recall_class_1, recall_class_0))
    
    print(f"MLP - Proportion {proportion}:1 - Recall Class 1: {recall_class_1:.2f}, Recall Class 0: {recall_class_0:.2f}")
    print(f"Accuracy: {accuracy_score(y_test, y_pred):.2f}")
    print(classification_report(y_test, y_pred))

# Plot Recall vs Training Data Proportion for MLP
plt.figure(figsize=(10, 6))
proportions, recall_scores_class_1, recall_scores_class_0 = zip(*recalls)
plt.plot(proportions, recall_scores_class_1, marker='o', label='MLP Class 1')
plt.plot(proportions, recall_scores_class_0, marker='o', label='MLP Class 0')

plt.xlabel("Training Data Proportion (Majority:Minority)")
plt.ylabel("Recall on Test Set")
plt.title("Recall vs. Training Data Proportion for MLP")
plt.legend()
plt.grid(True)
plt.show()
# Out:
# c:\Users\manav\OneDrive\Desktop\NIT Surathkal\Semester 7\IT-449\Drug-Drug-Interaction-and-Alternate-Recommendation-System\.venv\lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# MLP - Proportion 1:1 - Recall Class 1: 0.76, Recall Class 0: 0.39
# Accuracy: 0.42
#               precision    recall  f1-score   support
#
#            0       0.95      0.39      0.56      1317
#            1       0.10      0.76      0.18       116
#
#     accuracy                           0.42      1433
#    macro avg       0.52      0.58      0.37      1433
# weighted avg       0.88      0.42      0.53      1433
# c:\Users\manav\OneDrive\Desktop\NIT Surathkal\Semester 7\IT-449\Drug-Drug-Interaction-and-Alternate-Recommendation-System\.venv\lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# MLP - Proportion 2:1 - Recall Class 1: 0.47, Recall Class 0: 0.65
# Accuracy: 0.63
#               precision    recall  f1-score   support
#
#            0       0.93      0.65      0.77      1317
#            1       0.11      0.47      0.17       116
#
#     accuracy                           0.63      1433
#    macro avg       0.52      0.56      0.47      1433
# weighted avg       0.87      0.63      0.72      1433
# c:\Users\manav\OneDrive\Desktop\NIT Surathkal\Semester 7\IT-449\Drug-Drug-Interaction-and-Alternate-Recommendation-System\.venv\lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# MLP - Proportion 3:1 - Recall Class 1: 0.43, Recall Class 0: 0.68
# Accuracy: 0.66
#               precision    recall  f1-score   support
#
#            0       0.93      0.68      0.78      1317
#            1       0.11      0.43      0.17       116
#
#     accuracy                           0.66      1433
#    macro avg       0.52      0.55      0.48      1433
# weighted avg       0.86      0.66      0.73      1433
# c:\Users\manav\OneDrive\Desktop\NIT Surathkal\Semester 7\IT-449\Drug-Drug-Interaction-and-Alternate-Recommendation-System\.venv\lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# MLP - Proportion 4:1 - Recall Class 1: 0.35, Recall Class 0: 0.83
# Accuracy: 0.79
#               precision    recall  f1-score   support
#
#            0       0.94      0.83      0.88      1317
#            1       0.15      0.35      0.22       116
#
#     accuracy                           0.79      1433
#    macro avg       0.55      0.59      0.55      1433
# weighted avg       0.87      0.79      0.83      1433
# c:\Users\manav\OneDrive\Desktop\NIT Surathkal\Semester 7\IT-449\Drug-Drug-Interaction-and-Alternate-Recommendation-System\.venv\lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# MLP - Proportion 5:1 - Recall Class 1: 0.31, Recall Class 0: 0.88
# Accuracy: 0.84
#               precision    recall  f1-score   support
#
#            0       0.94      0.88      0.91      1317
#            1       0.19      0.31      0.24       116
#
#     accuracy                           0.84      1433
#    macro avg       0.56      0.60      0.57      1433
# weighted avg       0.88      0.84      0.85      1433
